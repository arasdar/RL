# %%
import tensorflow as tf
print('TensorFlow Version: {}'.format(tf.__version__))
print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.7.1
# Default GPU Device:

# %% [markdown]
# ##### >**Note:** Make sure you have OpenAI Gym cloned. Then run this command `pip install -e gym/[all]`.

# %%
import numpy as np
import gym
env = gym.make('CartPole-v0')
env = gym.make('CartPole-v1')

# %%
def model_input(state_size):
    #states = tf.placeholder(tf.float32, [None, *state_size], name='states')
    states = tf.placeholder(tf.float32, [None, state_size], name='states')
    actions = tf.placeholder(tf.int32, [None], name='actions')
    next_states = tf.placeholder(tf.float32, [None, state_size], name='next_states')
    rewards = tf.placeholder(tf.float32, [None], name='rewards')
    dones = tf.placeholder(tf.float32, [None], name='dones')
    rates = tf.placeholder(tf.float32, [None], name='rates') # success rate
    return states, actions, next_states, rewards, dones, rates

# %%
def actor(states, action_size, hidden_size, reuse=False, alpha=0.1, training=False):
    with tf.variable_scope('actor', reuse=reuse):
        # First fully connected layer
        h1 = tf.layers.dense(inputs=states, units=hidden_size)
        bn1 = tf.layers.batch_normalization(h1, training=training)        
        nl1 = tf.maximum(alpha * bn1, bn1)
        
        # Second fully connected layer
        h2 = tf.layers.dense(inputs=nl1, units=hidden_size)
        bn2 = tf.layers.batch_normalization(h2, training=training)        
        nl2 = tf.maximum(alpha * bn2, bn2)
        
        # Output layer
        logits = tf.layers.dense(inputs=nl2, units=action_size)        
        return logits

# %%
def generator(actions, state_size, hidden_size, reuse=False, alpha=0.1, training=False):
    with tf.variable_scope('generator', reuse=reuse):
        # First fully connected layer
        h1 = tf.layers.dense(inputs=actions, units=hidden_size)
        bn1 = tf.layers.batch_normalization(h1, training=training)        
        nl1 = tf.maximum(alpha * bn1, bn1)
        
        # Second fully connected layer
        h2 = tf.layers.dense(inputs=nl1, units=hidden_size)
        bn2 = tf.layers.batch_normalization(h2, training=training)        
        nl2 = tf.maximum(alpha * bn2, bn2)
        
        # Output layer
        logits = tf.layers.dense(inputs=nl2, units=state_size)        
        return logits

# %%
def discriminator(states, actions, action_size, hidden_size, reuse=False, alpha=0.1, training=False):
    with tf.variable_scope('discriminator', reuse=reuse):
        # First fully connected layer
        h1 = tf.layers.dense(inputs=states, units=action_size)
        bn1 = tf.layers.batch_normalization(h1, training=training)        
        nl1 = tf.maximum(alpha * bn1, bn1)
        
        # Second fully connected layer
        nl1_fused = tf.concat(axis=1, values=[nl1, actions])
        h2 = tf.layers.dense(inputs=nl1_fused, units=hidden_size)
        bn2 = tf.layers.batch_normalization(h2, training=training)        
        nl2 = tf.maximum(alpha * bn2, bn2)
                
        # Output layer
        logits = tf.layers.dense(inputs=nl2, units=1)        
        return logits

# %%
def model_loss(state_size, action_size, hidden_size, gamma,
               states, actions, next_states, rewards, dones, rates):
    actions_logits = actor(states=states, hidden_size=hidden_size, action_size=action_size)
    actions_labels = tf.one_hot(indices=actions, depth=action_size, dtype=actions_logits.dtype)
    aloss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=actions_logits, 
                                                                      labels=actions_labels))
    ###############################################
    next_states_logits = generator(actions=actions_logits, hidden_size=hidden_size, state_size=state_size)
    next_states_labels = tf.nn.sigmoid(next_states)
    aloss += tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=next_states_logits, 
                                                                    labels=next_states_labels))
    ####################################################
    dQs = discriminator(actions=actions_labels, hidden_size=hidden_size, states=states, action_size=action_size)
    rates = tf.reshape(rates, shape=[-1, 1])
    dloss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=dQs, # GAN
                                                                   labels=rates)) # 0-1
    ####################################################
    gQs = discriminator(actions=actions_logits, hidden_size=hidden_size, states=states, action_size=action_size, 
                        reuse=True)
    dloss += tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=gQs, # GAN
                                                                    labels=tf.zeros_like(gQs))) # 0-1
    aloss2 = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=gQs, # GAN
                                                                    labels=tf.ones_like(gQs))) # 0-1
    #####################################################
    next_actions_logits = actor(states=next_states, hidden_size=hidden_size, action_size=action_size, reuse=True)
    gQs2 = discriminator(actions=next_actions_logits, hidden_size=hidden_size, states=next_states, 
                         action_size=action_size, reuse=True)
    gQs2 = tf.reshape(gQs2, shape=[-1]) * (1-dones)
    dloss += tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=gQs2, # GAN
                                                                    labels=tf.zeros_like(gQs2))) # 0-1
    aloss2 += tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=gQs2, # GAN
                                                                     labels=tf.ones_like(gQs2))) # 0-1
#     ##################################################### repeatable!
#     next_states_logits = generator(actions=next_actions_logits, hidden_size=hidden_size, state_size=state_size, 
#                                    reuse=True)
#     next_actions_logits = actor(states=next_states_logits, hidden_size=hidden_size, action_size=action_size, 
#                                 reuse=True)
#     gQs3 = discriminator(actions=next_actions_logits, hidden_size=hidden_size, states=next_states_logits, 
#                          action_size=action_size, reuse=True)
#     dones2 = tf.concat(axis=0, values=[dones[1:], tf.ones(shape=[1])])
#     gQs3 = tf.reshape(gQs3, shape=[-1]) * (1-dones2)
#     dloss += tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=gQs3, # GAN
#                                                                     labels=tf.zeros_like(gQs3))) # 0-1
#     aloss2 += tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=gQs3, # GAN
#                                                                      labels=tf.ones_like(gQs3))) # 0-1
    return actions_logits, aloss, dloss, aloss2

# %%
def model_opt(a_loss, a_loss2, d_loss, a_learning_rate, d_learning_rate):
    # Get weights and bias to update
    t_vars = tf.trainable_variables()
    a_vars = [var for var in t_vars if var.name.startswith('actor')]
    g_vars = [var for var in t_vars if var.name.startswith('generator')]
    d_vars = [var for var in t_vars if var.name.startswith('discriminator')]

    # Optimize
    with tf.control_dependencies(tf.get_collection(tf.GraphKeys.UPDATE_OPS)): # Required for batchnorm (BN)
        a_opt = tf.train.AdamOptimizer(a_learning_rate).minimize(a_loss, var_list=a_vars)
        d_opt = tf.train.AdamOptimizer(d_learning_rate).minimize(d_loss, var_list=d_vars)
        a_opt2 = tf.train.AdamOptimizer(a_learning_rate).minimize(a_loss2, var_list=a_vars)
    return a_opt, d_opt, a_opt2

# %%
class Model:
    def __init__(self, state_size, action_size, hidden_size, a_learning_rate, d_learning_rate, gamma):

        # Data of the Model: make the data available inside the framework
        self.states, self.actions, self.next_states, self.rewards, self.dones, self.rates = model_input(
            state_size=state_size)

        # Create the Model: calculating the loss and forwad pass
        self.actions_logits, self.a_loss, self.d_loss, self.a_loss2 = model_loss(
            state_size=state_size, action_size=action_size, hidden_size=hidden_size, gamma=gamma, # model init
            states=self.states, actions=self.actions, next_states=self.next_states, #model input 
            rewards=self.rewards, dones=self.dones, rates=self.rates) # model input
        
        # Update the model: backward pass and backprop
        self.a_opt, self.d_opt, self.a_opt2 = model_opt(a_loss=self.a_loss, 
                                                        a_loss2=self.a_loss2, 
                                                        d_loss=self.d_loss,
                                                        a_learning_rate=a_learning_rate,
                                                        d_learning_rate=d_learning_rate)

# %%
# def sample(buffer, batch_size):
#     idx = np.random.choice(np.arange(len(buffer)), size=batch_size, replace=False)
#     return [buffer[ii] for ii in idx]

# %%
from collections import deque
class Memory():
    def __init__(self, max_size = 1000):
        self.buffer = deque(maxlen=max_size) # data batch

# %% [markdown]
# ## Hyperparameters
#
# One of the more difficult aspects of reinforcememt learning are the large number of hyperparameters. Not only are we tuning the network, but we're tuning the simulation.

# %%
env.observation_space, env.action_space
# Out:
# (Box(4,), Discrete(2))

# %%
# Exploration parameters
explore_start = 1.0            # exploration probability at start
explore_stop = 0.01           # minimum exploration probability 
decay_rate = 0.0001            # exponential decay rate for exploration prob

# Network parameters
state_size = 4
action_size = 2
hidden_size = 4*2             # number of units in each Q-network hidden layer
a_learning_rate = 1e-4         # Q-network learning rate
d_learning_rate = 1e-4         # Q-network learning rate

# Memory parameters
memory_size = int(1e5)            # memory capacity
batch_size = int(1e3)             # experience mini-batch size: 200/500 a successfull episode size
gamma = 0.99                   # future reward discount

# %%
# Reset/init the graph/session
graph = tf.reset_default_graph()

# Init the model
model = Model(action_size=action_size, state_size=state_size, hidden_size=hidden_size,
              a_learning_rate=a_learning_rate, d_learning_rate=d_learning_rate, gamma=gamma)

# Init the memory
memory = Memory(max_size=memory_size)

# %%
state = env.reset()
total_reward = 0
num_step = 0
for _ in range(memory_size):
    action = env.action_space.sample()
    next_state, reward, done, _ = env.step(action)
    rate = -1
    memory.buffer.append([state, action, next_state, reward, float(done), rate])
    num_step += 1 # memory incremented
    total_reward += reward
    state = next_state
    if done is True:
        state = env.reset()
        rate = total_reward/500
        for idx in range(num_step): # episode length
            if memory.buffer[-1-idx][-1] == -1:
                memory.buffer[-1-idx][-1] = rate
        total_reward = 0 # reset
        num_step = 0 # reset

# %% [markdown]
# ## Training the model
#
# Below we'll train our agent. If you want to watch it train, uncomment the `env.render()` line. This is slow because it's rendering the frames slower than the network can train. But, it's cool to watch the agent get better at the game.

# %%
# Save/load the model and save for plotting
saver = tf.train.Saver()
episode_rewards_list, rewards_list = [], []
# aloss_list, dloss_list, aloss2_list = [], []

# TF session for training
with tf.Session(graph=graph) as sess:
    sess.run(tf.global_variables_initializer())
    #saver.restore(sess, 'checkpoints/model.ckpt')    
    #saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    total_step = 0 # Explore or exploit parameter
    episode_reward = deque(maxlen=100) # 100 episodes average/running average/running mean/window

    # Training episodes/epochs
    for ep in range(11111):
        total_reward = 0 # each episode
        aloss_batch, dloss_batch, aloss2_batch = [], [], []
        state = env.reset() # each episode
        num_step = 0 # each episode

        # Training steps/batches
        while True:
            # Explore (Env) or Exploit (Model)
            total_step += 1
            explore_p = explore_stop + (explore_start - explore_stop) * np.exp(-decay_rate * total_step) 
            if explore_p > np.random.rand():
                action = env.action_space.sample()
            else:
                action_logits = sess.run(model.actions_logits, feed_dict={model.states: state.reshape([1, -1])})
                action = np.argmax(action_logits)
            next_state, reward, done, _ = env.step(action)
            rate = -1
            memory.buffer.append([state, action, next_state, reward, float(done), rate])
            num_step += 1 # momory added
            total_reward += reward
            state = next_state
            
            # Rating the memory
            if done is True:
                rate = total_reward/500 # update rate at the end/ when episode is done
                for idx in range(num_step): # episode length
                    if memory.buffer[-1-idx][-1] == -1: # double-check the landmark/marked indexes
                        memory.buffer[-1-idx][-1] = rate # rate the trajectory/data
                        
            # Training with the maxrated minibatch
            batch = memory.buffer
            #for idx in range(memory_size// batch_size):
            while True:
                idx = np.random.choice(np.arange(memory_size// batch_size))
                states = np.array([each[0] for each in batch])[idx*batch_size:(idx+1)*batch_size]
                actions = np.array([each[1] for each in batch])[idx*batch_size:(idx+1)*batch_size]
                next_states = np.array([each[2] for each in batch])[idx*batch_size:(idx+1)*batch_size]
                rewards = np.array([each[3] for each in batch])[idx*batch_size:(idx+1)*batch_size]
                dones = np.array([each[4] for each in batch])[idx*batch_size:(idx+1)*batch_size]
                rates = np.array([each[5] for each in batch])[idx*batch_size:(idx+1)*batch_size]
                states = states[rates >= np.max(rates)]
                actions = actions[rates >= np.max(rates)]
                next_states = next_states[rates >= np.max(rates)]
                rewards = rewards[rates >= np.max(rates)]
                dones = dones[rates >= np.max(rates)]
                rates = rates[rates >= np.max(rates)]
                if np.count_nonzero(dones)==1 and len(dones) >= 1 and np.max(rates) > 0:
                    # print('np.count_nonzero(dones)==1 and len(dones) >= 1 and np.max(rates) > 0: ', 
                    #       np.count_nonzero(dones), len(dones), np.max(rates))
                    break
            if np.count_nonzero(dones)!=1 and len(dones) < 1 and np.max(rates) <= 0:
                print(np.count_nonzero(dones), len(dones), np.max(rates))
                break
            aloss, _ = sess.run([model.a_loss, model.a_opt],
                                feed_dict = {model.states: states, 
                                            model.actions: actions,
                                            model.next_states: next_states,
                                            model.rewards: rewards,
                                            model.dones: dones,
                                            model.rates: rates})
            dloss, _ = sess.run([model.d_loss, model.d_opt],
                                  feed_dict = {model.states: states, 
                                               model.actions: actions,
                                               model.next_states: next_states,
                                               model.rewards: rewards,
                                               model.dones: dones,
                                               model.rates: rates})
            aloss2, _= sess.run([model.a_loss2, model.a_opt2], 
                                 feed_dict = {model.states: states, 
                                              model.actions: actions,
                                              model.next_states: next_states,
                                              model.rewards: rewards,
                                              model.dones: dones,
                                              model.rates: rates})
            # print('dones:', 
            #       len(dones), np.count_nonzero(dones), 
            #       len(dones1), np.count_nonzero(dones1), 
            #       len(dones2), np.count_nonzero(dones2))
            aloss_batch.append(aloss)
            dloss_batch.append(dloss)
            aloss2_batch.append(aloss2)
            if done is True:
                break
                
        episode_reward.append(total_reward)
        print('Episode:{}'.format(ep),
              'meanR:{:.4f}'.format(np.mean(episode_reward)),
              'R:{:.4f}'.format(total_reward),
              'rate:{:.4f}'.format(rate),
              'aloss:{:.4f}'.format(np.mean(aloss_batch)),
              'dloss:{:.4f}'.format(np.mean(dloss_batch)),
              'aloss2:{:.4f}'.format(np.mean(aloss2_batch)),
              'exploreP:{:.4f}'.format(explore_p))

        # Ploting out
        episode_rewards_list.append([ep, np.mean(episode_reward)])
        rewards_list.append([ep, total_reward])
        # gloss_list.append([ep, np.mean(gloss_batch)])
        # dloss_list.append([ep, np.mean(dloss_batch)])
        
        # Break episode/epoch loop
        ## Option 1: Solve the First Version
        #The task is episodic, and in order to solve the environment, 
        #your agent must get an average score of +30 over 100 consecutive episodes.
        if np.mean(episode_reward) >= 500:
            break
            
    # At the end of all training episodes/epochs
    saver.save(sess, 'checkpoints/model.ckpt')
# Out:
# Episode:0 meanR:20.0000 R:20.0000 rate:0.0400 aloss:1.3854 dloss:2.1510 aloss2:1.3346 exploreP:0.9980
# Episode:1 meanR:21.0000 R:22.0000 rate:0.0440 aloss:1.3836 dloss:2.0366 aloss2:1.4015 exploreP:0.9959
# Episode:2 meanR:18.6667 R:14.0000 rate:0.0280 aloss:1.3969 dloss:2.0017 aloss2:1.4238 exploreP:0.9945
# Episode:3 meanR:23.7500 R:39.0000 rate:0.0780 aloss:1.3867 dloss:1.9881 aloss2:1.4246 exploreP:0.9906
# Episode:4 meanR:26.4000 R:37.0000 rate:0.0740 aloss:1.3884 dloss:1.9940 aloss2:1.4154 exploreP:0.9870
# Episode:5 meanR:24.3333 R:14.0000 rate:0.0280 aloss:1.4002 dloss:1.8716 aloss2:1.4867 exploreP:0.9857
# Episode:6 meanR:22.2857 R:10.0000 rate:0.0200 aloss:1.3857 dloss:2.0821 aloss2:1.3779 exploreP:0.9847
# Episode:7 meanR:21.5000 R:16.0000 rate:0.0320 aloss:1.3903 dloss:1.9713 aloss2:1.4260 exploreP:0.9831
# Episode:8 meanR:20.4444 R:12.0000 rate:0.0240 aloss:1.3942 dloss:1.8837 aloss2:1.4778 exploreP:0.9820
# Episode:9 meanR:22.0000 R:36.0000 rate:0.0720 aloss:1.3832 dloss:1.9119 aloss2:1.4539 exploreP:0.9785
# Episode:10 meanR:22.3636 R:26.0000 rate:0.0520 aloss:1.3778 dloss:1.9209 aloss2:1.4473 exploreP:0.9759
# Episode:11 meanR:21.9167 R:17.0000 rate:0.0340 aloss:1.3827 dloss:1.8263 aloss2:1.5032 exploreP:0.9743
# Episode:12 meanR:22.1538 R:25.0000 rate:0.0500 aloss:1.3853 dloss:1.8462 aloss2:1.5061 exploreP:0.9719
# Episode:13 meanR:23.4286 R:40.0000 rate:0.0800 aloss:1.3851 dloss:1.8112 aloss2:1.5209 exploreP:0.9681
# Episode:14 meanR:22.6000 R:11.0000 rate:0.0220 aloss:1.3798 dloss:1.7327 aloss2:1.5762 exploreP:0.9670
# Episode:15 meanR:22.8125 R:26.0000 rate:0.0520 aloss:1.3811 dloss:1.7766 aloss2:1.5463 exploreP:0.9645
# Episode:16 meanR:25.6471 R:71.0000 rate:0.1420 aloss:1.3773 dloss:1.7568 aloss2:1.5521 exploreP:0.9578
# Episode:17 meanR:25.6667 R:26.0000 rate:0.0520 aloss:1.3834 dloss:1.7045 aloss2:1.5967 exploreP:0.9553
# Episode:18 meanR:25.5263 R:23.0000 rate:0.0460 aloss:1.3823 dloss:1.7100 aloss2:1.6080 exploreP:0.9531
# Episode:19 meanR:24.8500 R:12.0000 rate:0.0240 aloss:1.3788 dloss:1.6233 aloss2:1.6619 exploreP:0.9520
# Episode:20 meanR:24.7143 R:22.0000 rate:0.0440 aloss:1.3861 dloss:1.7230 aloss2:1.6055 exploreP:0.9499
# Episode:21 meanR:25.2273 R:36.0000 rate:0.0720 aloss:1.3900 dloss:1.6298 aloss2:1.6728 exploreP:0.9466
# Episode:22 meanR:25.1304 R:23.0000 rate:0.0460 aloss:1.4182 dloss:1.6021 aloss2:1.7201 exploreP:0.9444
# Episode:23 meanR:24.7500 R:16.0000 rate:0.0320 aloss:1.3927 dloss:1.5930 aloss2:1.7198 exploreP:0.9429
# Episode:24 meanR:24.4400 R:17.0000 rate:0.0340 aloss:1.4164 dloss:1.5781 aloss2:1.7294 exploreP:0.9413
# Episode:25 meanR:24.1538 R:17.0000 rate:0.0340 aloss:1.4020 dloss:1.5486 aloss2:1.7733 exploreP:0.9397
# Episode:26 meanR:23.7778 R:14.0000 rate:0.0280 aloss:1.3676 dloss:1.6120 aloss2:1.7057 exploreP:0.9384
# Episode:27 meanR:25.6786 R:77.0000 rate:0.1540 aloss:1.3902 dloss:1.5199 aloss2:1.7999 exploreP:0.9313
# Episode:28 meanR:25.3448 R:16.0000 rate:0.0320 aloss:1.3781 dloss:1.4933 aloss2:1.8208 exploreP:0.9298
# Episode:29 meanR:26.1667 R:50.0000 rate:0.1000 aloss:1.3771 dloss:1.4959 aloss2:1.8414 exploreP:0.9253
# Episode:30 meanR:25.6774 R:11.0000 rate:0.0220 aloss:1.3808 dloss:1.4955 aloss2:1.8299 exploreP:0.9243
# Episode:31 meanR:25.4375 R:18.0000 rate:0.0360 aloss:1.3824 dloss:1.4204 aloss2:1.9143 exploreP:0.9226
# Episode:32 meanR:25.3939 R:24.0000 rate:0.0480 aloss:1.3792 dloss:1.4405 aloss2:1.9030 exploreP:0.9204
# Episode:33 meanR:25.2941 R:22.0000 rate:0.0440 aloss:1.4247 dloss:1.3417 aloss2:2.0336 exploreP:0.9184
# Episode:34 meanR:24.8857 R:11.0000 rate:0.0220 aloss:1.3881 dloss:1.3969 aloss2:1.9457 exploreP:0.9174
# Episode:35 meanR:24.7500 R:20.0000 rate:0.0400 aloss:1.3793 dloss:1.3239 aloss2:2.0321 exploreP:0.9156
# Episode:36 meanR:25.2703 R:44.0000 rate:0.0880 aloss:1.3985 dloss:1.3456 aloss2:2.0363 exploreP:0.9116
# Episode:37 meanR:24.8684 R:10.0000 rate:0.0200 aloss:1.3862 dloss:1.2722 aloss2:2.1522 exploreP:0.9107
# Episode:38 meanR:24.6923 R:18.0000 rate:0.0360 aloss:1.3773 dloss:1.3325 aloss2:2.0788 exploreP:0.9091
# Episode:39 meanR:24.6500 R:23.0000 rate:0.0460 aloss:1.3828 dloss:1.2777 aloss2:2.1238 exploreP:0.9070
# Episode:40 meanR:25.1951 R:47.0000 rate:0.0940 aloss:1.3894 dloss:1.2453 aloss2:2.1908 exploreP:0.9028
# Episode:41 meanR:27.0000 R:101.0000 rate:0.2020 aloss:1.3906 dloss:1.2026 aloss2:2.2945 exploreP:0.8939
# Episode:42 meanR:27.2326 R:37.0000 rate:0.0740 aloss:1.3957 dloss:1.1722 aloss2:2.3733 exploreP:0.8906
# Episode:43 meanR:27.0227 R:18.0000 rate:0.0360 aloss:1.4063 dloss:1.0737 aloss2:2.5345 exploreP:0.8890
# Episode:44 meanR:27.2889 R:39.0000 rate:0.0780 aloss:1.4111 dloss:1.1075 aloss2:2.5438 exploreP:0.8856
# Episode:45 meanR:27.0870 R:18.0000 rate:0.0360 aloss:1.3522 dloss:1.1039 aloss2:2.5395 exploreP:0.8840
# Episode:46 meanR:27.2766 R:36.0000 rate:0.0720 aloss:1.3891 dloss:1.0695 aloss2:2.6070 exploreP:0.8809
# Episode:47 meanR:27.0000 R:14.0000 rate:0.0280 aloss:1.4655 dloss:1.0605 aloss2:2.7479 exploreP:0.8797
# Episode:48 meanR:27.1429 R:34.0000 rate:0.0680 aloss:1.3861 dloss:1.0565 aloss2:2.6723 exploreP:0.8767
# Episode:49 meanR:27.0400 R:22.0000 rate:0.0440 aloss:1.3802 dloss:1.0604 aloss2:2.6291 exploreP:0.8748
# Episode:50 meanR:26.7255 R:11.0000 rate:0.0220 aloss:1.3881 dloss:1.0017 aloss2:2.8381 exploreP:0.8739
# Episode:51 meanR:26.6346 R:22.0000 rate:0.0440 aloss:1.3756 dloss:0.9866 aloss2:2.7783 exploreP:0.8720
# Episode:52 meanR:26.6792 R:29.0000 rate:0.0580 aloss:1.4036 dloss:0.9405 aloss2:2.9568 exploreP:0.8695
# Episode:53 meanR:26.8519 R:36.0000 rate:0.0720 aloss:1.3957 dloss:0.9354 aloss2:3.0189 exploreP:0.8664
# Episode:54 meanR:27.0182 R:36.0000 rate:0.0720 aloss:1.3823 dloss:0.9806 aloss2:2.9311 exploreP:0.8633
# Episode:55 meanR:26.9107 R:21.0000 rate:0.0420 aloss:1.3969 dloss:0.8816 aloss2:3.1214 exploreP:0.8615
# Episode:56 meanR:26.8421 R:23.0000 rate:0.0460 aloss:1.3903 dloss:0.9245 aloss2:3.1157 exploreP:0.8595
# Episode:57 meanR:26.5862 R:12.0000 rate:0.0240 aloss:1.3828 dloss:0.8944 aloss2:3.1230 exploreP:0.8585
# Episode:58 meanR:26.8983 R:45.0000 rate:0.0900 aloss:1.3972 dloss:0.9028 aloss2:3.2012 exploreP:0.8547
# Episode:59 meanR:27.1167 R:40.0000 rate:0.0800 aloss:1.3981 dloss:0.9455 aloss2:3.1607 exploreP:0.8513
# Episode:60 meanR:26.9016 R:14.0000 rate:0.0280 aloss:1.3877 dloss:0.8141 aloss2:3.5562 exploreP:0.8502
# Episode:61 meanR:26.9355 R:29.0000 rate:0.0580 aloss:1.3933 dloss:0.8631 aloss2:3.3084 exploreP:0.8477
# Episode:62 meanR:26.8889 R:24.0000 rate:0.0480 aloss:1.3934 dloss:0.8248 aloss2:3.4830 exploreP:0.8457
# Episode:63 meanR:26.7344 R:17.0000 rate:0.0340 aloss:1.3938 dloss:0.8008 aloss2:3.4822 exploreP:0.8443
# Episode:64 meanR:26.6000 R:18.0000 rate:0.0360 aloss:1.3893 dloss:0.8397 aloss2:3.4281 exploreP:0.8428
# Episode:65 meanR:26.4697 R:18.0000 rate:0.0360 aloss:1.4012 dloss:0.8027 aloss2:3.6551 exploreP:0.8413
# Episode:66 meanR:26.3881 R:21.0000 rate:0.0420 aloss:1.3810 dloss:0.8191 aloss2:3.5252 exploreP:0.8396
# Episode:67 meanR:27.0735 R:73.0000 rate:0.1460 aloss:1.3957 dloss:0.7848 aloss2:3.8367 exploreP:0.8335
# Episode:68 meanR:27.2029 R:36.0000 rate:0.0720 aloss:1.3778 dloss:0.7930 aloss2:3.6527 exploreP:0.8306
# Episode:69 meanR:27.1857 R:26.0000 rate:0.0520 aloss:1.3792 dloss:0.7639 aloss2:3.7759 exploreP:0.8284
# Episode:70 meanR:27.9296 R:80.0000 rate:0.1600 aloss:1.3887 dloss:0.7470 aloss2:3.9187 exploreP:0.8219
# Episode:71 meanR:27.7361 R:14.0000 rate:0.0280 aloss:1.3814 dloss:0.7202 aloss2:3.8992 exploreP:0.8208
# Episode:72 meanR:27.8904 R:39.0000 rate:0.0780 aloss:1.3801 dloss:0.7096 aloss2:4.1081 exploreP:0.8176
# Episode:73 meanR:27.8378 R:24.0000 rate:0.0480 aloss:1.3839 dloss:0.6864 aloss2:4.2090 exploreP:0.8157
# Episode:74 meanR:27.8533 R:29.0000 rate:0.0580 aloss:1.3874 dloss:0.6593 aloss2:4.3865 exploreP:0.8134
# Episode:75 meanR:27.6974 R:16.0000 rate:0.0320 aloss:1.3948 dloss:0.6890 aloss2:4.3697 exploreP:0.8121
# Episode:76 meanR:27.4935 R:12.0000 rate:0.0240 aloss:1.3834 dloss:0.6868 aloss2:4.2471 exploreP:0.8111
# Episode:77 meanR:27.3333 R:15.0000 rate:0.0300 aloss:1.3897 dloss:0.6457 aloss2:4.5482 exploreP:0.8099
# Episode:78 meanR:27.1899 R:16.0000 rate:0.0320 aloss:1.3775 dloss:0.6498 aloss2:4.3011 exploreP:0.8086
# Episode:79 meanR:27.0500 R:16.0000 rate:0.0320 aloss:1.3773 dloss:0.6335 aloss2:4.4708 exploreP:0.8074
# Episode:80 meanR:26.9012 R:15.0000 rate:0.0300 aloss:1.3780 dloss:0.6556 aloss2:4.5774 exploreP:0.8062
# Episode:81 meanR:26.7073 R:11.0000 rate:0.0220 aloss:1.3725 dloss:0.7146 aloss2:4.3366 exploreP:0.8053
# Episode:82 meanR:26.6627 R:23.0000 rate:0.0460 aloss:1.3905 dloss:0.6545 aloss2:4.4493 exploreP:0.8035
# Episode:83 meanR:26.5000 R:13.0000 rate:0.0260 aloss:1.3798 dloss:0.6918 aloss2:4.5049 exploreP:0.8024
# Episode:84 meanR:26.6471 R:39.0000 rate:0.0780 aloss:1.3869 dloss:0.6706 aloss2:4.6189 exploreP:0.7993
# Episode:85 meanR:26.5465 R:18.0000 rate:0.0360 aloss:1.3813 dloss:0.6562 aloss2:4.5725 exploreP:0.7979
# Episode:86 meanR:26.3908 R:13.0000 rate:0.0260 aloss:1.3787 dloss:0.6205 aloss2:4.7897 exploreP:0.7969
# Episode:87 meanR:26.2045 R:10.0000 rate:0.0200 aloss:1.3974 dloss:0.6563 aloss2:4.9299 exploreP:0.7961
# Episode:88 meanR:26.0337 R:11.0000 rate:0.0220 aloss:1.3761 dloss:0.6109 aloss2:4.6617 exploreP:0.7953
# Episode:89 meanR:26.8556 R:100.0000 rate:0.2000 aloss:1.3862 dloss:0.6379 aloss2:4.8394 exploreP:0.7874
# Episode:90 meanR:26.6813 R:11.0000 rate:0.0220 aloss:1.3868 dloss:0.6626 aloss2:4.7492 exploreP:0.7866
# Episode:91 meanR:26.6087 R:20.0000 rate:0.0400 aloss:1.3889 dloss:0.6111 aloss2:5.0305 exploreP:0.7850
# Episode:92 meanR:26.5699 R:23.0000 rate:0.0460 aloss:1.3934 dloss:0.5793 aloss2:5.0819 exploreP:0.7833
# Episode:93 meanR:26.6277 R:32.0000 rate:0.0640 aloss:1.3863 dloss:0.5987 aloss2:5.0668 exploreP:0.7808
# Episode:94 meanR:26.6211 R:26.0000 rate:0.0520 aloss:1.3892 dloss:0.6135 aloss2:5.1134 exploreP:0.7788
# Episode:95 meanR:26.7188 R:36.0000 rate:0.0720 aloss:1.4101 dloss:0.5840 aloss2:5.2364 exploreP:0.7760
# Episode:96 meanR:26.9485 R:49.0000 rate:0.0980 aloss:1.4194 dloss:0.5934 aloss2:5.3860 exploreP:0.7723
# Episode:97 meanR:26.8571 R:18.0000 rate:0.0360 aloss:1.4012 dloss:0.5962 aloss2:5.3560 exploreP:0.7709
# Episode:98 meanR:26.7576 R:17.0000 rate:0.0340 aloss:1.3846 dloss:0.5781 aloss2:5.3098 exploreP:0.7696
# Episode:99 meanR:26.6600 R:17.0000 rate:0.0340 aloss:1.3717 dloss:0.6274 aloss2:5.1528 exploreP:0.7683
# Episode:100 meanR:26.6000 R:14.0000 rate:0.0280 aloss:1.3695 dloss:0.5830 aloss2:5.5608 exploreP:0.7673
# Episode:101 meanR:27.0000 R:62.0000 rate:0.1240 aloss:1.3770 dloss:0.5808 aloss2:5.4049 exploreP:0.7626
# Episode:102 meanR:27.2500 R:39.0000 rate:0.0780 aloss:1.3767 dloss:0.5812 aloss2:5.4431 exploreP:0.7596
# Episode:103 meanR:26.9800 R:12.0000 rate:0.0240 aloss:1.3758 dloss:0.6047 aloss2:5.4119 exploreP:0.7587
# Episode:104 meanR:26.8700 R:26.0000 rate:0.0520 aloss:1.3665 dloss:0.5922 aloss2:5.4893 exploreP:0.7568
# Episode:105 meanR:27.0400 R:31.0000 rate:0.0620 aloss:1.3679 dloss:0.5773 aloss2:5.3681 exploreP:0.7545
# Episode:106 meanR:27.4500 R:51.0000 rate:0.1020 aloss:1.3707 dloss:0.5671 aloss2:5.4318 exploreP:0.7507
# Episode:107 meanR:27.6600 R:37.0000 rate:0.0740 aloss:1.3703 dloss:0.5615 aloss2:5.3798 exploreP:0.7480
# Episode:108 meanR:27.9600 R:42.0000 rate:0.0840 aloss:1.3801 dloss:0.5626 aloss2:5.5986 exploreP:0.7449
# Episode:109 meanR:27.8900 R:29.0000 rate:0.0580 aloss:1.3847 dloss:0.5898 aloss2:5.5898 exploreP:0.7428
# Episode:110 meanR:27.8900 R:26.0000 rate:0.0520 aloss:1.3790 dloss:0.5566 aloss2:5.7173 exploreP:0.7408
# Episode:111 meanR:28.5900 R:87.0000 rate:0.1740 aloss:1.3748 dloss:0.5593 aloss2:5.6289 exploreP:0.7345
# Episode:112 meanR:28.6500 R:31.0000 rate:0.0620 aloss:1.3819 dloss:0.5375 aloss2:5.9260 exploreP:0.7323
# Episode:113 meanR:28.5900 R:34.0000 rate:0.0680 aloss:1.3749 dloss:0.5414 aloss2:5.7439 exploreP:0.7298
# Episode:114 meanR:28.6800 R:20.0000 rate:0.0400 aloss:1.3714 dloss:0.5830 aloss2:5.7424 exploreP:0.7284
# Episode:115 meanR:29.1100 R:69.0000 rate:0.1380 aloss:1.3739 dloss:0.5524 aloss2:5.8593 exploreP:0.7234
# Episode:116 meanR:29.2600 R:86.0000 rate:0.1720 aloss:1.3857 dloss:0.5599 aloss2:6.0531 exploreP:0.7173
# Episode:117 meanR:29.1100 R:11.0000 rate:0.0220 aloss:1.3719 dloss:0.5526 aloss2:6.0623 exploreP:0.7166
# Episode:118 meanR:29.3000 R:42.0000 rate:0.0840 aloss:1.3697 dloss:0.5363 aloss2:6.0607 exploreP:0.7136
# Episode:119 meanR:29.6100 R:43.0000 rate:0.0860 aloss:1.3675 dloss:0.5475 aloss2:6.2345 exploreP:0.7106
# Episode:120 meanR:29.6800 R:29.0000 rate:0.0580 aloss:1.3709 dloss:0.5401 aloss2:6.2917 exploreP:0.7085
# Episode:121 meanR:29.5600 R:24.0000 rate:0.0480 aloss:1.3623 dloss:0.5981 aloss2:6.1804 exploreP:0.7069
# Episode:122 meanR:29.4700 R:14.0000 rate:0.0280 aloss:1.3654 dloss:0.5157 aloss2:6.2248 exploreP:0.7059
# Episode:123 meanR:29.8900 R:58.0000 rate:0.1160 aloss:1.3671 dloss:0.5455 aloss2:6.3259 exploreP:0.7019
# Episode:124 meanR:30.0200 R:30.0000 rate:0.0600 aloss:1.3639 dloss:0.5536 aloss2:6.2845 exploreP:0.6998
# Episode:125 meanR:30.3800 R:53.0000 rate:0.1060 aloss:1.3659 dloss:0.5508 aloss2:6.2316 exploreP:0.6962
# Episode:126 meanR:31.2400 R:100.0000 rate:0.2000 aloss:1.3643 dloss:0.5479 aloss2:6.2323 exploreP:0.6893
# Episode:127 meanR:30.8700 R:40.0000 rate:0.0800 aloss:1.3642 dloss:0.5450 aloss2:6.3334 exploreP:0.6866
# Episode:128 meanR:31.1500 R:44.0000 rate:0.0880 aloss:1.3801 dloss:0.5490 aloss2:6.3459 exploreP:0.6836
# Episode:129 meanR:31.6600 R:101.0000 rate:0.2020 aloss:1.3668 dloss:0.5396 aloss2:6.3787 exploreP:0.6769
# Episode:130 meanR:31.9900 R:44.0000 rate:0.0880 aloss:1.3696 dloss:0.5585 aloss2:6.2818 exploreP:0.6739
# Episode:131 meanR:32.6100 R:80.0000 rate:0.1600 aloss:1.3793 dloss:0.5530 aloss2:6.3777 exploreP:0.6687
# Episode:132 meanR:32.6700 R:30.0000 rate:0.0600 aloss:1.3675 dloss:0.5257 aloss2:6.2025 exploreP:0.6667
# Episode:133 meanR:32.6900 R:24.0000 rate:0.0480 aloss:1.3813 dloss:0.5261 aloss2:6.4207 exploreP:0.6651
# Episode:134 meanR:33.2300 R:65.0000 rate:0.1300 aloss:1.3850 dloss:0.5477 aloss2:6.4611 exploreP:0.6609
# Episode:135 meanR:33.4300 R:40.0000 rate:0.0800 aloss:1.3615 dloss:0.5632 aloss2:6.2487 exploreP:0.6583
# Episode:136 meanR:33.3600 R:37.0000 rate:0.0740 aloss:1.3818 dloss:0.5323 aloss2:6.3256 exploreP:0.6559
# Episode:137 meanR:33.9600 R:70.0000 rate:0.1400 aloss:1.3880 dloss:0.5418 aloss2:6.3741 exploreP:0.6514
# Episode:138 meanR:34.0700 R:29.0000 rate:0.0580 aloss:1.3811 dloss:0.5503 aloss2:6.2583 exploreP:0.6495
# Episode:139 meanR:34.6100 R:77.0000 rate:0.1540 aloss:1.3745 dloss:0.5596 aloss2:6.3469 exploreP:0.6446
# Episode:140 meanR:34.2500 R:11.0000 rate:0.0220 aloss:1.3746 dloss:0.5226 aloss2:6.2778 exploreP:0.6439
# Episode:141 meanR:33.3800 R:14.0000 rate:0.0280 aloss:1.3936 dloss:0.5240 aloss2:6.3620 exploreP:0.6430
# Episode:142 meanR:33.8600 R:85.0000 rate:0.1700 aloss:1.3825 dloss:0.5451 aloss2:6.2892 exploreP:0.6377
# Episode:143 meanR:33.9100 R:23.0000 rate:0.0460 aloss:1.3929 dloss:0.5601 aloss2:6.3612 exploreP:0.6362
# Episode:144 meanR:33.6600 R:14.0000 rate:0.0280 aloss:1.3901 dloss:0.5422 aloss2:6.3315 exploreP:0.6353
# Episode:145 meanR:33.8100 R:33.0000 rate:0.0660 aloss:1.3826 dloss:0.5747 aloss2:6.2283 exploreP:0.6333
# Episode:146 meanR:34.2700 R:82.0000 rate:0.1640 aloss:1.3845 dloss:0.5228 aloss2:6.2896 exploreP:0.6282
# Episode:147 meanR:34.5800 R:45.0000 rate:0.0900 aloss:1.3835 dloss:0.5571 aloss2:6.1804 exploreP:0.6254
# Episode:148 meanR:34.3700 R:13.0000 rate:0.0260 aloss:1.3802 dloss:0.5703 aloss2:6.2412 exploreP:0.6246
# Episode:149 meanR:34.6800 R:53.0000 rate:0.1060 aloss:1.4052 dloss:0.5594 aloss2:6.2336 exploreP:0.6214
# Episode:150 meanR:35.4600 R:89.0000 rate:0.1780 aloss:1.3917 dloss:0.5468 aloss2:6.2139 exploreP:0.6160
# Episode:151 meanR:36.1300 R:89.0000 rate:0.1780 aloss:1.3842 dloss:0.5335 aloss2:6.2089 exploreP:0.6106
# Episode:152 meanR:36.1700 R:33.0000 rate:0.0660 aloss:1.4050 dloss:0.5407 aloss2:6.2324 exploreP:0.6086
# Episode:153 meanR:36.3500 R:54.0000 rate:0.1080 aloss:1.3851 dloss:0.5471 aloss2:6.2945 exploreP:0.6054
# Episode:154 meanR:36.2900 R:30.0000 rate:0.0600 aloss:1.4293 dloss:0.5340 aloss2:6.2859 exploreP:0.6036
# Episode:155 meanR:36.5100 R:43.0000 rate:0.0860 aloss:1.4102 dloss:0.5364 aloss2:6.2744 exploreP:0.6011
# Episode:156 meanR:37.2800 R:100.0000 rate:0.2000 aloss:1.4098 dloss:0.5370 aloss2:6.3180 exploreP:0.5952
# Episode:157 meanR:37.9300 R:77.0000 rate:0.1540 aloss:1.4890 dloss:0.5589 aloss2:6.3101 exploreP:0.5907
# Episode:158 meanR:38.2300 R:75.0000 rate:0.1500 aloss:1.3861 dloss:0.5545 aloss2:6.2028 exploreP:0.5863
# Episode:159 meanR:38.7000 R:87.0000 rate:0.1740 aloss:1.4011 dloss:0.5374 aloss2:6.2789 exploreP:0.5814
# Episode:160 meanR:39.7700 R:121.0000 rate:0.2420 aloss:1.4382 dloss:0.5428 aloss2:6.2744 exploreP:0.5745
# Episode:161 meanR:40.4800 R:100.0000 rate:0.2000 aloss:1.4145 dloss:0.5583 aloss2:6.1958 exploreP:0.5689
# Episode:162 meanR:41.2600 R:102.0000 rate:0.2040 aloss:1.4331 dloss:0.5424 aloss2:6.2496 exploreP:0.5632
# Episode:163 meanR:41.7600 R:67.0000 rate:0.1340 aloss:1.4282 dloss:0.5642 aloss2:6.2165 exploreP:0.5595
# Episode:164 meanR:42.7700 R:119.0000 rate:0.2380 aloss:1.4267 dloss:0.5543 aloss2:6.1689 exploreP:0.5530
# Episode:165 meanR:43.0400 R:45.0000 rate:0.0900 aloss:1.4450 dloss:0.5265 aloss2:6.2069 exploreP:0.5506
# Episode:166 meanR:44.2900 R:146.0000 rate:0.2920 aloss:1.4656 dloss:0.5296 aloss2:6.2744 exploreP:0.5427
# Episode:167 meanR:44.5800 R:102.0000 rate:0.2040 aloss:1.4467 dloss:0.5356 aloss2:6.3018 exploreP:0.5373
# Episode:168 meanR:45.1600 R:94.0000 rate:0.1880 aloss:1.4332 dloss:0.5564 aloss2:6.3112 exploreP:0.5324
# Episode:169 meanR:45.7100 R:81.0000 rate:0.1620 aloss:1.4163 dloss:0.5315 aloss2:6.2523 exploreP:0.5282
# Episode:170 meanR:45.9600 R:105.0000 rate:0.2100 aloss:1.4564 dloss:0.5574 aloss2:6.2260 exploreP:0.5228
# Episode:171 meanR:46.6000 R:78.0000 rate:0.1560 aloss:1.4600 dloss:0.5362 aloss2:6.2373 exploreP:0.5188
# Episode:172 meanR:47.1400 R:93.0000 rate:0.1860 aloss:1.4263 dloss:0.5477 aloss2:6.1931 exploreP:0.5141
# Episode:173 meanR:47.2400 R:34.0000 rate:0.0680 aloss:1.4619 dloss:0.5369 aloss2:6.2705 exploreP:0.5124
# Episode:174 meanR:48.0500 R:110.0000 rate:0.2200 aloss:1.4798 dloss:0.5582 aloss2:6.2373 exploreP:0.5069
# Episode:175 meanR:49.1000 R:121.0000 rate:0.2420 aloss:1.4597 dloss:0.5617 aloss2:6.1675 exploreP:0.5009
# Episode:176 meanR:49.6800 R:70.0000 rate:0.1400 aloss:1.4387 dloss:0.5559 aloss2:6.2198 exploreP:0.4975
# Episode:177 meanR:49.8700 R:34.0000 rate:0.0680 aloss:1.4442 dloss:0.5269 aloss2:6.2415 exploreP:0.4958
# Episode:178 meanR:50.6200 R:91.0000 rate:0.1820 aloss:1.4766 dloss:0.5570 aloss2:6.2195 exploreP:0.4914
# Episode:179 meanR:51.0200 R:56.0000 rate:0.1120 aloss:1.5001 dloss:0.5569 aloss2:6.2221 exploreP:0.4887
# Episode:180 meanR:51.8000 R:93.0000 rate:0.1860 aloss:1.4223 dloss:0.5538 aloss2:6.2209 exploreP:0.4843
# Episode:181 meanR:53.1000 R:141.0000 rate:0.2820 aloss:1.4377 dloss:0.5334 aloss2:6.2693 exploreP:0.4776
# Episode:182 meanR:54.0100 R:114.0000 rate:0.2280 aloss:1.4584 dloss:0.5505 aloss2:6.2853 exploreP:0.4723
# Episode:183 meanR:54.9300 R:105.0000 rate:0.2100 aloss:1.4559 dloss:0.5659 aloss2:6.2205 exploreP:0.4675
# Episode:184 meanR:56.6400 R:210.0000 rate:0.4200 aloss:1.4480 dloss:0.5463 aloss2:6.2066 exploreP:0.4580
# Episode:185 meanR:57.7100 R:125.0000 rate:0.2500 aloss:1.4484 dloss:0.5802 aloss2:6.2185 exploreP:0.4524
# Episode:186 meanR:58.7000 R:112.0000 rate:0.2240 aloss:1.4276 dloss:0.5537 aloss2:6.1299 exploreP:0.4475
# Episode:187 meanR:59.8500 R:125.0000 rate:0.2500 aloss:1.4395 dloss:0.5717 aloss2:6.1640 exploreP:0.4421
# Episode:188 meanR:61.1200 R:138.0000 rate:0.2760 aloss:1.4515 dloss:0.5574 aloss2:6.1707 exploreP:0.4362
# Episode:189 meanR:61.6600 R:154.0000 rate:0.3080 aloss:1.4329 dloss:0.5552 aloss2:6.1880 exploreP:0.4296
# Episode:190 meanR:62.5600 R:101.0000 rate:0.2020 aloss:1.4444 dloss:0.6001 aloss2:6.1108 exploreP:0.4254
# Episode:191 meanR:63.0600 R:70.0000 rate:0.1400 aloss:1.4252 dloss:0.5484 aloss2:6.1305 exploreP:0.4225
# Episode:192 meanR:63.3600 R:53.0000 rate:0.1060 aloss:1.4517 dloss:0.5578 aloss2:6.1295 exploreP:0.4203
# Episode:193 meanR:65.2400 R:220.0000 rate:0.4400 aloss:1.4404 dloss:0.5584 aloss2:6.1708 exploreP:0.4114
# Episode:194 meanR:66.0000 R:102.0000 rate:0.2040 aloss:1.4340 dloss:0.5674 aloss2:6.1755 exploreP:0.4073
# Episode:195 meanR:66.8500 R:121.0000 rate:0.2420 aloss:1.4323 dloss:0.5441 aloss2:6.2047 exploreP:0.4026
# Episode:196 meanR:67.3600 R:100.0000 rate:0.2000 aloss:1.4225 dloss:0.5590 aloss2:6.2356 exploreP:0.3987
# Episode:197 meanR:68.4300 R:125.0000 rate:0.2500 aloss:1.4275 dloss:0.5827 aloss2:6.1287 exploreP:0.3938
# Episode:198 meanR:70.0400 R:178.0000 rate:0.3560 aloss:1.4230 dloss:0.5828 aloss2:6.0863 exploreP:0.3871
# Episode:199 meanR:71.5300 R:166.0000 rate:0.3320 aloss:1.4280 dloss:0.5742 aloss2:6.0840 exploreP:0.3809
# Episode:200 meanR:73.2400 R:185.0000 rate:0.3700 aloss:1.4251 dloss:0.5654 aloss2:6.1091 exploreP:0.3741
# Episode:201 meanR:73.6800 R:106.0000 rate:0.2120 aloss:1.4047 dloss:0.5532 aloss2:6.1811 exploreP:0.3702
# Episode:202 meanR:74.2900 R:100.0000 rate:0.2000 aloss:1.4285 dloss:0.5631 aloss2:6.1419 exploreP:0.3666
# Episode:203 meanR:75.2700 R:110.0000 rate:0.2200 aloss:1.4104 dloss:0.5644 aloss2:6.1734 exploreP:0.3627
# Episode:204 meanR:76.6600 R:165.0000 rate:0.3300 aloss:1.4013 dloss:0.5838 aloss2:6.1176 exploreP:0.3570
# Episode:205 meanR:76.5100 R:16.0000 rate:0.0320 aloss:1.4391 dloss:0.5374 aloss2:6.1286 exploreP:0.3564
# Episode:206 meanR:77.5800 R:158.0000 rate:0.3160 aloss:1.4097 dloss:0.5626 aloss2:6.1304 exploreP:0.3510
# Episode:207 meanR:78.6700 R:146.0000 rate:0.2920 aloss:1.4196 dloss:0.5841 aloss2:6.1106 exploreP:0.3460
# Episode:208 meanR:79.9800 R:173.0000 rate:0.3460 aloss:1.4210 dloss:0.5828 aloss2:6.0470 exploreP:0.3403
# Episode:209 meanR:81.1700 R:148.0000 rate:0.2960 aloss:1.4123 dloss:0.6052 aloss2:6.0515 exploreP:0.3354
# Episode:210 meanR:82.0600 R:115.0000 rate:0.2300 aloss:1.4276 dloss:0.5951 aloss2:5.9750 exploreP:0.3317
# Episode:211 meanR:82.3700 R:118.0000 rate:0.2360 aloss:1.4238 dloss:0.5873 aloss2:6.0309 exploreP:0.3279
# Episode:212 meanR:83.3900 R:133.0000 rate:0.2660 aloss:1.4056 dloss:0.5976 aloss2:6.0480 exploreP:0.3237
# Episode:213 meanR:84.3700 R:132.0000 rate:0.2640 aloss:1.4234 dloss:0.5952 aloss2:6.0500 exploreP:0.3196
# Episode:214 meanR:85.2800 R:111.0000 rate:0.2220 aloss:1.4376 dloss:0.6024 aloss2:5.9162 exploreP:0.3162
# Episode:215 meanR:85.5700 R:98.0000 rate:0.1960 aloss:1.4408 dloss:0.5694 aloss2:5.9976 exploreP:0.3132
# Episode:216 meanR:87.0100 R:230.0000 rate:0.4600 aloss:1.4163 dloss:0.5810 aloss2:6.0649 exploreP:0.3063
# Episode:217 meanR:88.6400 R:174.0000 rate:0.3480 aloss:1.4286 dloss:0.5679 aloss2:6.1058 exploreP:0.3012
# Episode:218 meanR:89.5500 R:133.0000 rate:0.2660 aloss:1.4095 dloss:0.5825 aloss2:6.0771 exploreP:0.2974
# Episode:219 meanR:90.2600 R:114.0000 rate:0.2280 aloss:1.4092 dloss:0.6008 aloss2:6.0541 exploreP:0.2941
# Episode:220 meanR:90.1400 R:17.0000 rate:0.0340 aloss:1.4200 dloss:0.6276 aloss2:6.0314 exploreP:0.2936
# Episode:221 meanR:91.0000 R:110.0000 rate:0.2200 aloss:1.4065 dloss:0.5882 aloss2:6.0312 exploreP:0.2905
# Episode:222 meanR:91.8900 R:103.0000 rate:0.2060 aloss:1.4377 dloss:0.6400 aloss2:5.9293 exploreP:0.2876
# Episode:223 meanR:92.5800 R:127.0000 rate:0.2540 aloss:1.4136 dloss:0.6077 aloss2:5.9685 exploreP:0.2841
# Episode:224 meanR:94.0400 R:176.0000 rate:0.3520 aloss:1.4348 dloss:0.5664 aloss2:5.9922 exploreP:0.2793
# Episode:225 meanR:94.7700 R:126.0000 rate:0.2520 aloss:1.4285 dloss:0.5892 aloss2:6.0413 exploreP:0.2760
# Episode:226 meanR:96.4800 R:271.0000 rate:0.5420 aloss:1.4109 dloss:0.5925 aloss2:6.0211 exploreP:0.2689
# Episode:227 meanR:97.3700 R:129.0000 rate:0.2580 aloss:1.4001 dloss:0.6017 aloss2:6.0538 exploreP:0.2655
# Episode:228 meanR:98.2700 R:134.0000 rate:0.2680 aloss:1.4278 dloss:0.6502 aloss2:5.9150 exploreP:0.2621
# Episode:229 meanR:98.0500 R:79.0000 rate:0.1580 aloss:1.4190 dloss:0.6195 aloss2:5.8433 exploreP:0.2602
# Episode:230 meanR:98.6100 R:100.0000 rate:0.2000 aloss:1.4127 dloss:0.6139 aloss2:5.9108 exploreP:0.2577
# Episode:231 meanR:98.8300 R:102.0000 rate:0.2040 aloss:1.4223 dloss:0.5695 aloss2:5.9509 exploreP:0.2552
# Episode:232 meanR:99.4800 R:95.0000 rate:0.1900 aloss:1.4061 dloss:0.5940 aloss2:5.9969 exploreP:0.2528
# Episode:233 meanR:101.4000 R:216.0000 rate:0.4320 aloss:1.4113 dloss:0.5898 aloss2:6.0245 exploreP:0.2477
# Episode:234 meanR:102.7000 R:195.0000 rate:0.3900 aloss:1.4396 dloss:0.5949 aloss2:6.0218 exploreP:0.2431
# Episode:235 meanR:103.7100 R:141.0000 rate:0.2820 aloss:1.4155 dloss:0.5968 aloss2:5.9794 exploreP:0.2398
# Episode:236 meanR:104.0400 R:70.0000 rate:0.1400 aloss:1.4030 dloss:0.6315 aloss2:5.9847 exploreP:0.2382
# Episode:237 meanR:104.5900 R:125.0000 rate:0.2500 aloss:1.4172 dloss:0.6325 aloss2:5.9302 exploreP:0.2354
# Episode:238 meanR:105.7900 R:149.0000 rate:0.2980 aloss:1.4174 dloss:0.6148 aloss2:5.8893 exploreP:0.2320
# Episode:239 meanR:105.9800 R:96.0000 rate:0.1920 aloss:1.4217 dloss:0.6262 aloss2:5.8985 exploreP:0.2299
# Episode:240 meanR:110.3900 R:452.0000 rate:0.9040 aloss:1.4119 dloss:0.6100 aloss2:5.9159 exploreP:0.2202
# Episode:241 meanR:111.6000 R:135.0000 rate:0.2700 aloss:1.4099 dloss:0.6143 aloss2:5.9413 exploreP:0.2174
# Episode:242 meanR:113.3700 R:262.0000 rate:0.5240 aloss:1.4239 dloss:0.6269 aloss2:5.9186 exploreP:0.2120
# Episode:243 meanR:115.0200 R:188.0000 rate:0.3760 aloss:1.4119 dloss:0.6700 aloss2:5.8017 exploreP:0.2082
# Episode:244 meanR:116.0200 R:114.0000 rate:0.2280 aloss:1.4236 dloss:0.5826 aloss2:5.8295 exploreP:0.2060
# Episode:245 meanR:116.5600 R:87.0000 rate:0.1740 aloss:1.4032 dloss:0.6025 aloss2:5.8844 exploreP:0.2043
# Episode:246 meanR:116.6800 R:94.0000 rate:0.1880 aloss:1.3991 dloss:0.6236 aloss2:5.8981 exploreP:0.2025
# Episode:247 meanR:119.3600 R:313.0000 rate:0.6260 aloss:1.4190 dloss:0.6334 aloss2:5.8745 exploreP:0.1966
# Episode:248 meanR:120.3300 R:110.0000 rate:0.2200 aloss:1.3998 dloss:0.6663 aloss2:5.8453 exploreP:0.1945
# Episode:249 meanR:121.2000 R:140.0000 rate:0.2800 aloss:1.4203 dloss:0.6241 aloss2:5.7969 exploreP:0.1919
# Episode:250 meanR:121.2500 R:94.0000 rate:0.1880 aloss:1.4096 dloss:0.6487 aloss2:5.8091 exploreP:0.1902
# Episode:251 meanR:122.6200 R:226.0000 rate:0.4520 aloss:1.4177 dloss:0.6303 aloss2:5.8134 exploreP:0.1862
# Episode:252 meanR:123.6400 R:135.0000 rate:0.2700 aloss:1.4216 dloss:0.6059 aloss2:5.9117 exploreP:0.1839
# Episode:253 meanR:124.8900 R:179.0000 rate:0.3580 aloss:1.4053 dloss:0.6814 aloss2:5.8276 exploreP:0.1808
# Episode:254 meanR:125.5300 R:94.0000 rate:0.1880 aloss:1.4214 dloss:0.6693 aloss2:5.7124 exploreP:0.1792
# Episode:255 meanR:126.9800 R:188.0000 rate:0.3760 aloss:1.4141 dloss:0.6336 aloss2:5.7735 exploreP:0.1760
# Episode:256 meanR:127.0100 R:103.0000 rate:0.2060 aloss:1.4097 dloss:0.6338 aloss2:5.7718 exploreP:0.1743
# Episode:257 meanR:128.0700 R:183.0000 rate:0.3660 aloss:1.4269 dloss:0.6535 aloss2:5.7642 exploreP:0.1713
# Episode:258 meanR:128.5500 R:123.0000 rate:0.2460 aloss:1.4033 dloss:0.6946 aloss2:5.7469 exploreP:0.1694
# Episode:259 meanR:130.0700 R:239.0000 rate:0.4780 aloss:1.4050 dloss:0.6387 aloss2:5.7326 exploreP:0.1656
# Episode:260 meanR:130.2600 R:140.0000 rate:0.2800 aloss:1.4258 dloss:0.6744 aloss2:5.7401 exploreP:0.1634
# Episode:261 meanR:129.9300 R:67.0000 rate:0.1340 aloss:1.4226 dloss:0.6353 aloss2:5.7307 exploreP:0.1624
# Episode:262 meanR:130.9300 R:202.0000 rate:0.4040 aloss:1.4059 dloss:0.6730 aloss2:5.7325 exploreP:0.1594
# Episode:263 meanR:131.0900 R:83.0000 rate:0.1660 aloss:1.4089 dloss:0.6581 aloss2:5.6906 exploreP:0.1581
# Episode:264 meanR:131.2000 R:130.0000 rate:0.2600 aloss:1.4322 dloss:0.6555 aloss2:5.6994 exploreP:0.1562
# Episode:265 meanR:132.2700 R:152.0000 rate:0.3040 aloss:1.4082 dloss:0.6257 aloss2:5.7525 exploreP:0.1540
# Episode:266 meanR:132.8100 R:200.0000 rate:0.4000 aloss:1.4040 dloss:0.6919 aloss2:5.7291 exploreP:0.1512
# Episode:267 meanR:132.6900 R:90.0000 rate:0.1800 aloss:1.4009 dloss:0.6829 aloss2:5.6695 exploreP:0.1499
# Episode:268 meanR:133.2400 R:149.0000 rate:0.2980 aloss:1.4033 dloss:0.6594 aloss2:5.6559 exploreP:0.1478
# Episode:269 meanR:133.5800 R:115.0000 rate:0.2300 aloss:1.4028 dloss:0.6753 aloss2:5.6892 exploreP:0.1463
# Episode:270 meanR:133.5200 R:99.0000 rate:0.1980 aloss:1.4053 dloss:0.6922 aloss2:5.6797 exploreP:0.1449
# Episode:271 meanR:136.2400 R:350.0000 rate:0.7000 aloss:1.4071 dloss:0.6709 aloss2:5.6627 exploreP:0.1403
# Episode:272 meanR:137.2400 R:193.0000 rate:0.3860 aloss:1.4197 dloss:0.6460 aloss2:5.6814 exploreP:0.1378
# Episode:273 meanR:138.2200 R:132.0000 rate:0.2640 aloss:1.3946 dloss:0.7023 aloss2:5.7006 exploreP:0.1361
# Episode:274 meanR:138.7800 R:166.0000 rate:0.3320 aloss:1.4093 dloss:0.6871 aloss2:5.5974 exploreP:0.1340
# Episode:275 meanR:138.6000 R:103.0000 rate:0.2060 aloss:1.4068 dloss:0.7567 aloss2:5.5995 exploreP:0.1328
# Episode:276 meanR:139.0300 R:113.0000 rate:0.2260 aloss:1.4063 dloss:0.7202 aloss2:5.5780 exploreP:0.1314
# Episode:277 meanR:140.6500 R:196.0000 rate:0.3920 aloss:1.4109 dloss:0.6622 aloss2:5.5669 exploreP:0.1290
# Episode:278 meanR:142.3700 R:263.0000 rate:0.5260 aloss:1.4095 dloss:0.6721 aloss2:5.6470 exploreP:0.1259
# Episode:279 meanR:143.4400 R:163.0000 rate:0.3260 aloss:1.4123 dloss:0.6559 aloss2:5.6852 exploreP:0.1241
# Episode:280 meanR:145.5800 R:307.0000 rate:0.6140 aloss:1.3955 dloss:0.7623 aloss2:5.5114 exploreP:0.1206
# Episode:281 meanR:146.6600 R:249.0000 rate:0.4980 aloss:1.4051 dloss:0.6963 aloss2:5.5153 exploreP:0.1179
# Episode:282 meanR:147.1900 R:167.0000 rate:0.3340 aloss:1.4164 dloss:0.6660 aloss2:5.5968 exploreP:0.1161
# Episode:283 meanR:151.1400 R:500.0000 rate:1.0000 aloss:1.4082 dloss:0.7229 aloss2:5.5160 exploreP:0.1109
# Episode:284 meanR:151.1900 R:215.0000 rate:0.4300 aloss:1.4123 dloss:0.6914 aloss2:5.5255 exploreP:0.1088
# Episode:285 meanR:153.0900 R:315.0000 rate:0.6300 aloss:1.3914 dloss:0.7328 aloss2:5.4979 exploreP:0.1057
# Episode:286 meanR:153.2000 R:123.0000 rate:0.2460 aloss:1.4037 dloss:0.6892 aloss2:5.4794 exploreP:0.1045
# Episode:287 meanR:152.7900 R:84.0000 rate:0.1680 aloss:1.4089 dloss:0.7027 aloss2:5.5212 exploreP:0.1038
# Episode:288 meanR:156.4100 R:500.0000 rate:1.0000 aloss:1.4107 dloss:0.6918 aloss2:5.5690 exploreP:0.0992
# Episode:289 meanR:157.1800 R:231.0000 rate:0.4620 aloss:1.3951 dloss:0.7698 aloss2:5.5129 exploreP:0.0971
# Episode:290 meanR:158.7400 R:257.0000 rate:0.5140 aloss:1.4023 dloss:0.7266 aloss2:5.4159 exploreP:0.0949
# Episode:291 meanR:161.2500 R:321.0000 rate:0.6420 aloss:1.4014 dloss:0.7610 aloss2:5.4188 exploreP:0.0923
# Episode:292 meanR:165.0400 R:432.0000 rate:0.8640 aloss:1.4036 dloss:0.7627 aloss2:5.3925 exploreP:0.0888
# Episode:293 meanR:164.8600 R:202.0000 rate:0.4040 aloss:1.3875 dloss:0.7945 aloss2:5.3113 exploreP:0.0872
# Episode:294 meanR:164.7500 R:91.0000 rate:0.1820 aloss:1.3943 dloss:0.7595 aloss2:5.2569 exploreP:0.0865
# Episode:295 meanR:164.8700 R:133.0000 rate:0.2660 aloss:1.3974 dloss:0.7707 aloss2:5.2956 exploreP:0.0855
# Episode:296 meanR:165.3900 R:152.0000 rate:0.3040 aloss:1.4052 dloss:0.8176 aloss2:5.2247 exploreP:0.0844
# Episode:297 meanR:165.7100 R:157.0000 rate:0.3140 aloss:1.4126 dloss:0.7657 aloss2:5.2637 exploreP:0.0832
# Episode:298 meanR:166.4300 R:250.0000 rate:0.5000 aloss:1.3973 dloss:0.7744 aloss2:5.2778 exploreP:0.0814
# Episode:299 meanR:165.9300 R:116.0000 rate:0.2320 aloss:1.3949 dloss:0.7085 aloss2:5.3058 exploreP:0.0806
# Episode:300 meanR:169.0200 R:494.0000 rate:0.9880 aloss:1.4018 dloss:0.7910 aloss2:5.2803 exploreP:0.0772
# Episode:301 meanR:170.1700 R:221.0000 rate:0.4420 aloss:1.4070 dloss:0.7378 aloss2:5.2747 exploreP:0.0757
# Episode:302 meanR:171.3900 R:222.0000 rate:0.4440 aloss:1.3955 dloss:0.8107 aloss2:5.2808 exploreP:0.0743
# Episode:303 meanR:174.5600 R:427.0000 rate:0.8540 aloss:1.4002 dloss:0.8210 aloss2:5.2363 exploreP:0.0716
# Episode:304 meanR:174.0800 R:117.0000 rate:0.2340 aloss:1.4104 dloss:0.7533 aloss2:5.1628 exploreP:0.0708
# Episode:305 meanR:175.1800 R:126.0000 rate:0.2520 aloss:1.3829 dloss:0.8781 aloss2:5.1469 exploreP:0.0701
# Episode:306 meanR:174.7500 R:115.0000 rate:0.2300 aloss:1.4105 dloss:0.8113 aloss2:5.1137 exploreP:0.0694
# Episode:307 meanR:177.2100 R:392.0000 rate:0.7840 aloss:1.3897 dloss:0.8365 aloss2:5.1153 exploreP:0.0671
# Episode:308 meanR:177.1800 R:170.0000 rate:0.3400 aloss:1.3963 dloss:0.8068 aloss2:5.0878 exploreP:0.0662

# %% [markdown]
# # Visualizing training
#
# Below I'll plot the total rewards for each episode. I'm plotting the rolling average too, in blue.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def running_mean(x, N):
    cumsum = np.cumsum(np.insert(x, 0, 0)) 
    return (cumsum[N:] - cumsum[:-N]) / N

# %%
eps, arr = np.array(episode_rewards_list).T
smoothed_arr = running_mean(arr, 10)
plt.plot(eps[-len(smoothed_arr):], smoothed_arr)
plt.plot(eps, arr, color='grey', alpha=0.3)
plt.xlabel('Episode')
plt.ylabel('Total rewards')

# %%
eps, arr = np.array(rewards_list).T
smoothed_arr = running_mean(arr, 10)
plt.plot(eps[-len(smoothed_arr):], smoothed_arr)
plt.plot(eps, arr, color='grey', alpha=0.3)
plt.xlabel('Episode')
plt.ylabel('Total rewards')

# %%
eps, arr = np.array(dloss_list).T
smoothed_arr = running_mean(arr, 10)
plt.plot(eps[-len(smoothed_arr):], smoothed_arr)
plt.plot(eps, arr, color='grey', alpha=0.3)
plt.xlabel('Episode')
plt.ylabel('D losses')

# %% [markdown]
# ## Testing
#
# Let's checkout how our trained agent plays the game.

# %%
import gym
env = gym.make('CartPole-v0')
env = gym.make('CartPole-v1')
# env = gym.make('Acrobot-v1')
# env = gym.make('MountainCar-v0')
# env = gym.make('Pendulum-v0')
# env = gym.make('Blackjack-v0')
# env = gym.make('FrozenLake-v0')
# env = gym.make('AirRaid-ram-v0')
# env = gym.make('AirRaid-v0')
# env = gym.make('BipedalWalker-v2')
# env = gym.make('Copy-v0')
# env = gym.make('CarRacing-v0')
# env = gym.make('Ant-v2') #mujoco
# env = gym.make('FetchPickAndPlace-v1') # mujoco required!

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    saver.restore(sess, 'checkpoints/model.ckpt')    
    #saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    
    # Episodes/epochs
    for _ in range(10):
        state = env.reset()
        total_reward = 0

        # Steps/batches
        while True:
            env.render()
            action_logits = sess.run(model.actions_logits, feed_dict={model.states: state.reshape([1, -1])})
            action = np.argmax(action_logits)
            state, reward, done, _ = env.step(action)
            total_reward += reward
            if done:
                print('total_reward: {}'.format(total_reward))
                break
                
env.close()
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/model.ckpt
# total_reward: 500.0
# total_reward: 500.0
# total_reward: 500.0
# total_reward: 500.0
# total_reward: 481.0
# total_reward: 481.0
# total_reward: 500.0
# total_reward: 500.0
# total_reward: 500.0
# total_reward: 500.0

# %% [markdown]
# ## Extending this
#
# So, Cart-Pole is a pretty simple game. However, the same model can be used to train an agent to play something much more complicated like Pong or Space Invaders. Instead of a state like we're using here though, you'd want to use convolutional layers to get the state from the screen images.
#
# ![Deep Q-Learning Atari](assets/atari-network.png)
#
# I'll leave it as a challenge for you to use deep Q-learning to train an agent to play Atari games. Here's the original paper which will get you started: http://www.davidqiu.com:8888/research/nature14236.pdf.
