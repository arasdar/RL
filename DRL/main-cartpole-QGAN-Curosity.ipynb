# %%
import tensorflow as tf
print('TensorFlow Version: {}'.format(tf.__version__))
print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.7.1
# Default GPU Device:

# %% [markdown]
# ##### >**Note:** Make sure you have OpenAI Gym cloned. Then run this command `pip install -e gym/[all]`.

# %%
import numpy as np
import gym
env = gym.make('CartPole-v0')
env = gym.make('CartPole-v1')

# %%
def model_input(state_size):
    #states = tf.placeholder(tf.float32, [None, *state_size], name='states')
    states = tf.placeholder(tf.float32, [None, state_size], name='states')
    actions = tf.placeholder(tf.int32, [None], name='actions')
    next_states = tf.placeholder(tf.float32, [None, state_size], name='next_states')
    rewards = tf.placeholder(tf.float32, [None], name='rewards')
    dones = tf.placeholder(tf.float32, [None], name='dones')
    rates = tf.placeholder(tf.float32, [None], name='rates') # success rate
    return states, actions, next_states, rewards, dones, rates

# %%
def Act(states, action_size, hidden_size, reuse=False, alpha=0.1, training=False):
    with tf.variable_scope('Act', reuse=reuse):
        # First fully connected layer
        h1 = tf.layers.dense(inputs=states, units=hidden_size)
        bn1 = tf.layers.batch_normalization(h1, training=training)        
        nl1 = tf.maximum(alpha * bn1, bn1)
        
        # Second fully connected layer
        h2 = tf.layers.dense(inputs=nl1, units=hidden_size)
        bn2 = tf.layers.batch_normalization(h2, training=training)        
        nl2 = tf.maximum(alpha * bn2, bn2)
        
        # Output layer
        logits = tf.layers.dense(inputs=nl2, units=action_size)        
        return logits

# %%
def Env(states, actions, state_size, action_size, hidden_size, reuse=False, alpha=0.1, training=False):
    with tf.variable_scope('Env', reuse=reuse):
        # First fully connected layer
        h1 = tf.layers.dense(inputs=states, units=action_size)
        bn1 = tf.layers.batch_normalization(h1, training=training)        
        nl1 = tf.maximum(alpha * bn1, bn1)
        
        # Second fully connected layer
        nl1_fused = tf.concat(axis=1, values=[nl1, actions])
        h2 = tf.layers.dense(inputs=nl1_fused, units=hidden_size)
        bn2 = tf.layers.batch_normalization(h2, training=training)        
        nl2 = tf.maximum(alpha * bn2, bn2)
                
        # Output layer
        states_logits = tf.layers.dense(inputs=nl2, units=state_size, trainable=False)
        Qlogits = tf.layers.dense(inputs=nl2, units=1, trainable=False)
        return states_logits, Qlogits

# %%
def model_loss(state_size, action_size, hidden_size, gamma,
               states, actions, next_states, rewards, dones, rates):
    ################################################ a = act(s)
    actions_logits = Act(states=states, hidden_size=hidden_size, action_size=action_size)
    actions_labels = tf.one_hot(indices=actions, depth=action_size, dtype=actions_logits.dtype)
    aloss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=actions_logits, 
                                                                      labels=actions_labels))
    ################################################ s', r = env(s, a)
    next_states_logits, Qs_logits = Env(actions=actions_labels, states=states, hidden_size=hidden_size, 
                                        action_size=action_size, state_size=state_size)
    next_states_labels = tf.nn.sigmoid(next_states)
    eloss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=next_states_logits,
                                                                   labels=next_states_labels))
    #################################################### s'', Q' = env(s', a')
    next_actions_logits = Act(states=next_states, hidden_size=hidden_size, action_size=action_size, reuse=True)
    next_next_states_logits, nextQs_logits = Env(actions=next_actions_logits, states=next_states, # given
                                                 hidden_size=hidden_size, action_size=action_size, 
                                                 state_size=state_size, reuse=True)
    #################################################### s'', Q' = env(~s', ~a')
    next_actions_logits_ = Act(states=next_states_logits, hidden_size=hidden_size, action_size=action_size, 
                               reuse=True)
    next_next_states_logits_, nextQs_logits_ = Env(actions=next_actions_logits_, states=next_states_logits, # pred
                                                   hidden_size=hidden_size, action_size=action_size, 
                                                   state_size=state_size, reuse=True)
    ##################################################### GAN
    Qs = tf.reshape(Qs_logits, shape=[-1])
    nextQs = tf.reshape(nextQs_logits, shape=[-1]) * (1-dones)
    nextQs_ = tf.reshape(nextQs_logits_, shape=[-1]) * (1-dones)
    eloss += tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=Qs, # GAN
                                                                    labels=rates)) # 0-1 real
    eloss += tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=nextQs, # GAN
                                                                    labels=tf.zeros_like(rates))) # min
    aloss2 = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=nextQs, # GAN
                                                                    labels=tf.ones_like(rates))) # max
    ######################################################### Curosity=intrinsic reward
    rloss = tf.square(nextQs_logits-nextQs_logits_)
    sloss = tf.reduce_sum(tf.square(next_next_states_logits-next_next_states_logits_), axis=1)
    #     #### Q/r loss
    #     mean, var = tf.nn.moments(x=rloss,axes=[0])
    #     std = tf.sqrt(var)
    #     rloss_norm = (rloss - mean)/ std 
    #     #### State loss
    #     mean, var = tf.nn.moments(x=sloss,axes=[0])
    #     std = tf.sqrt(var)
    #     sloss_norm = (sloss - mean)/ std
    #### Intrinsic_rewards
#     intrinsic_rewards = sloss + rloss
#     ########################################################## Q = r + 0.99*Q'
#     targetQs = rewards + intrinsic_rewards + (gamma * nextQs)
#     eloss += tf.reduce_mean(tf.square(Qs - targetQs))
    return actions_logits, aloss, eloss, aloss2, sloss, rloss

# %%
def model_opt(a_loss, e_loss, a_loss2, a_learning_rate, e_learning_rate):
    # Get weights and bias to update
    t_vars = tf.trainable_variables()
    a_vars = [var for var in t_vars if var.name.startswith('Act')]
    e_vars = [var for var in t_vars if var.name.startswith('Env')]

    # Optimize
    with tf.control_dependencies(tf.get_collection(tf.GraphKeys.UPDATE_OPS)): # Required for batchnorm (BN)
        a_opt = tf.train.AdamOptimizer(a_learning_rate).minimize(a_loss, var_list=a_vars)
        e_opt = tf.train.AdamOptimizer(e_learning_rate).minimize(e_loss, var_list=e_vars)
        a_opt2 = tf.train.AdamOptimizer(a_learning_rate).minimize(a_loss2, var_list=a_vars)
    return a_opt, e_opt, a_opt2

# %%
class Model:
    def __init__(self, state_size, action_size, hidden_size, a_learning_rate, e_learning_rate, gamma):

        # Data of the Model: make the data available inside the framework
        self.states, self.actions, self.next_states, self.rewards, self.dones, self.rates = model_input(
            state_size=state_size)

        # Create the Model: calculating the loss and forwad pass
        self.actions_logits, self.a_loss, self.e_loss, self.a_loss2, self.sloss, self.rloss = model_loss(
            state_size=state_size, action_size=action_size, hidden_size=hidden_size, gamma=gamma, # model init
            states=self.states, actions=self.actions, next_states=self.next_states, 
            rewards=self.rewards, dones=self.dones, rates=self.rates) # model input
        
        # Update the model: backward pass and backprop
        self.a_opt, self.e_opt, self.a_opt2 = model_opt(a_loss=self.a_loss, 
                                                        e_loss=self.e_loss,
                                                        a_loss2=self.a_loss2, 
                                                        a_learning_rate=a_learning_rate,
                                                        e_learning_rate=e_learning_rate)

# %%
from collections import deque
class Memory():
    def __init__(self, max_size = 1000):
        self.buffer = deque(maxlen=max_size) # data batch
#     def sample(self, batch_size):
#         idx = np.random.choice(np.arange(len(self.buffer)), size=batch_size, replace=False)
#         return [self.buffer[ii] for ii in idx]

# %% [markdown]
# ## Hyperparameters
#
# One of the more difficult aspects of reinforcememt learning are the large number of hyperparameters. Not only are we tuning the network, but we're tuning the simulation.

# %%
env.observation_space, env.action_space
# Out:
# (Box(4,), Discrete(2))

# %%
# Exploration parameters
explore_start = 1.0            # exploration probability at start
explore_stop = 0.01           # minimum exploration probability 
decay_rate = 0.0001            # exponential decay rate for exploration prob

# Network parameters
state_size = 4
action_size = 2
hidden_size = 4*2             # number of units in each Q-network hidden layer
a_learning_rate = 1e-4         # Q-network learning rate
e_learning_rate = 1e-4         # Q-network learning rate

# Memory parameters
memory_size = int(1e5)            # memory capacity
batch_size = int(1e3)             # experience mini-batch size
gamma=0.99

# %%
# Reset/init the graph/session
graph = tf.reset_default_graph()

# Init the model
model = Model(action_size=action_size, state_size=state_size, hidden_size=hidden_size, gamma=gamma,
              a_learning_rate=a_learning_rate, e_learning_rate=e_learning_rate)

# Init the memory
memory = Memory(max_size=memory_size)

# %%
state = env.reset()
total_reward = 0
num_step = 0
for _ in range(memory_size):
    action = env.action_space.sample()
    next_state, reward, done, _ = env.step(action)
    rate = -1
    memory.buffer.append([state, action, next_state, reward, float(done), rate])
    num_step += 1 # memory incremented
    total_reward += reward
    state = next_state
    if done is True:
        rate = total_reward/500
        for idx in range(num_step): # episode length
            if memory.buffer[-1-idx][-1] == -1:
                memory.buffer[-1-idx][-1] = rate
        state = env.reset()
        total_reward = 0 # reset
        num_step = 0 # reset

# %% [markdown]
# ## Training the model
#
# Below we'll train our agent. If you want to watch it train, uncomment the `env.render()` line. This is slow because it's rendering the frames slower than the network can train. But, it's cool to watch the agent get better at the game.

# %%
# Save/load the model and save for plotting
saver = tf.train.Saver()
episode_rewards_list, rewards_list = [], []
aloss_list, eloss_list, aloss2_list = [], [], []

# TF session for training
with tf.Session(graph=graph) as sess:
    sess.run(tf.global_variables_initializer())
    #saver.restore(sess, 'checkpoints/model.ckpt')    
    #saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    total_step = 0 # Explore or exploit parameter
    episode_reward = deque(maxlen=100) # 100 episodes for running average/running mean/window

    # Training episodes/epochs
    for ep in range(11):
        aloss_batch, eloss_batch, aloss2_batch = [], [], []
        total_reward = 0
        state = env.reset()
        num_step = 0
        rate = -1

        # Training steps/batches
        while True:
            # Explore (env) or Exploit (model)
            total_step += 1
            explore_p = explore_stop + (explore_start - explore_stop) * np.exp(-decay_rate * total_step) 
            if explore_p > np.random.rand():
                action = env.action_space.sample()
            else:
                action_logits = sess.run(model.actions_logits, feed_dict={model.states: state.reshape([1, -1])})
                action = np.argmax(action_logits)
            next_state, reward, done, _ = env.step(action)
            sloss, rloss = sess.run([model.sloss, model.rloss], 
                                  feed_dict = {model.states: state.reshape([1, -1]), 
                                               model.actions: np.reshape(action, [1]),
                                               model.next_states: next_state.reshape([1, -1])
                                              })
            print('intrinsic_rewards sloss and rloss:', sloss[0], rloss[0, 0])
            memory.buffer.append([state, action, next_state, reward, float(done), rate])
            num_step += 1 # momory added
            total_reward += reward
            state = next_state
            
            # Training with the maxrated minibatch
            batch = memory.buffer
            #for idx in range(memory_size// batch_size):
            while True:
                idx = np.random.choice(np.arange(memory_size// batch_size))
                states = np.array([each[0] for each in batch])[idx*batch_size:(idx+1)*batch_size]
                actions = np.array([each[1] for each in batch])[idx*batch_size:(idx+1)*batch_size]
                next_states = np.array([each[2] for each in batch])[idx*batch_size:(idx+1)*batch_size]
                rewards = np.array([each[3] for each in batch])[idx*batch_size:(idx+1)*batch_size]
                dones = np.array([each[4] for each in batch])[idx*batch_size:(idx+1)*batch_size]
                rates = np.array([each[5] for each in batch])[idx*batch_size:(idx+1)*batch_size]
                states = states[rates >= np.max(rates)]
                actions = actions[rates >= np.max(rates)]
                next_states = next_states[rates >= np.max(rates)]
                rewards = rewards[rates >= np.max(rates)]
                dones = dones[rates >= np.max(rates)]
                rates = rates[rates >= np.max(rates)]
                if np.count_nonzero(dones) > 0 and len(dones) > 1 and np.max(rates) > 0:
                    break
            aloss, _ = sess.run([model.a_loss, model.a_opt],
                                  feed_dict = {model.states: states, 
                                               model.actions: actions,
                                               model.next_states: next_states,
                                               model.rewards: rewards,
                                               model.dones: dones,
                                               model.rates: rates})
            eloss, _ = sess.run([model.e_loss, model.e_opt],
                                  feed_dict = {model.states: states, 
                                               model.actions: actions,
                                               model.next_states: next_states,
                                               model.rewards: rewards,
                                               model.dones: dones,
                                               model.rates: rates})
            aloss2, _ = sess.run([model.a_loss2, model.a_opt2], 
                                 feed_dict = {model.states: states, 
                                              model.actions: actions,
                                              model.next_states: next_states,
                                              model.rewards: rewards,
                                              model.dones: dones,
                                              model.rates: rates})
            # print(len(dones), np.count_nonzero(dones), np.max(rates))
            aloss_batch.append(aloss)
            eloss_batch.append(eloss)
            aloss2_batch.append(aloss2)
            if done is True:
                break
                
        # Rating the latest played episode
        rate = total_reward/500 # update rate at the end/ when episode is done
        for idx in range(num_step): # episode length
            if memory.buffer[-1-idx][-1] == -1: # double-check the landmark/marked indexes
                memory.buffer[-1-idx][-1] = rate # rate the trajectory/data

        # Print out
        episode_reward.append(total_reward)
        print('Episode:{}'.format(ep),
              'meanR:{:.4f}'.format(np.mean(episode_reward)),
              'R:{:.4f}'.format(total_reward),
              'rate:{:.4f}'.format(rate),
              'aloss:{:.4f}'.format(np.mean(aloss_batch)),
              'eloss:{:.4f}'.format(np.mean(eloss_batch)),
              'aloss2:{:.4f}'.format(np.mean(aloss2_batch)),
              'exploreP:{:.4f}'.format(explore_p))

        # Ploting out
        episode_rewards_list.append([ep, np.mean(episode_reward)])
        rewards_list.append([ep, total_reward])
        aloss_list.append([ep, np.mean(aloss_batch)])
        eloss_list.append([ep, np.mean(eloss_batch)])
        aloss2_list.append([ep, np.mean(aloss2_batch)])
        
        # Break episode/epoch loop
        ## Option 1: Solve the First Version
        #The task is episodic, and in order to solve the environment, 
        #your agent must get an average score of +30 over 100 consecutive episodes.
        if np.mean(episode_reward) >= 500:
            break
            
    # At the end of all training episodes/epochs
    saver.save(sess, 'checkpoints/model.ckpt')
# Out:
# intrinsic_rewards sloss and rloss: 0.000120248165 0.0002065008
# intrinsic_rewards sloss and rloss: 0.0017881348 6.980665e-05
# intrinsic_rewards sloss and rloss: 0.00764831 0.017075501
# intrinsic_rewards sloss and rloss: 0.011809828 0.010046507
# intrinsic_rewards sloss and rloss: 0.00012567444 0.00011652167
# intrinsic_rewards sloss and rloss: 0.008930546 0.016356982
# intrinsic_rewards sloss and rloss: 0.017418709 0.012711323
# intrinsic_rewards sloss and rloss: 0.008146282 0.01656035
# intrinsic_rewards sloss and rloss: 0.01648612 0.012505548
# intrinsic_rewards sloss and rloss: 0.007976768 0.017029282
# intrinsic_rewards sloss and rloss: 0.016040567 0.012769456
# intrinsic_rewards sloss and rloss: 0.001925536 2.3447576e-05
# intrinsic_rewards sloss and rloss: 0.0050727255 0.010776093
# intrinsic_rewards sloss and rloss: 0.009158162 0.01143005
# intrinsic_rewards sloss and rloss: 0.0007217208 0.00029603534
# intrinsic_rewards sloss and rloss: 0.0018255683 6.3020407e-06
# intrinsic_rewards sloss and rloss: 0.00094896386 0.00044512982
# intrinsic_rewards sloss and rloss: 0.001767738 7.210334e-06
# intrinsic_rewards sloss and rloss: 0.0013051505 0.0006687371
# intrinsic_rewards sloss and rloss: 0.0018813813 1.4948281e-05
# intrinsic_rewards sloss and rloss: 0.0024199374 0.0043172715
# intrinsic_rewards sloss and rloss: 0.007552022 0.009520074
# intrinsic_rewards sloss and rloss: 0.0021064281 0.0015771545
# intrinsic_rewards sloss and rloss: 0.017757665 0.024086218
# intrinsic_rewards sloss and rloss: 0.06265499 0.08105954
# intrinsic_rewards sloss and rloss: 0.114349395 0.1485247
# intrinsic_rewards sloss and rloss: 0.18189803 0.23634268
# intrinsic_rewards sloss and rloss: 0.16802536 0.23837693
# intrinsic_rewards sloss and rloss: 0.11051693 0.15494655
# intrinsic_rewards sloss and rloss: 0.06319477 0.086967714
# intrinsic_rewards sloss and rloss: 0.032198787 0.036740296
# Episode:0 meanR:31.0000 R:31.0000 rate:0.0620 aloss:0.7150 eloss:1.7680 aloss2:0.8278 exploreP:0.9969
# intrinsic_rewards sloss and rloss: 0.0007848561 0.0010989859
# intrinsic_rewards sloss and rloss: 0.0023927493 3.863081e-05
# intrinsic_rewards sloss and rloss: 0.0041455016 0.0073551517
# intrinsic_rewards sloss and rloss: 0.011874014 0.038488884
# intrinsic_rewards sloss and rloss: 0.03372758 0.09628499
# intrinsic_rewards sloss and rloss: 0.051592097 0.013387974
# intrinsic_rewards sloss and rloss: 0.021136254 3.9208103e-06
# intrinsic_rewards sloss and rloss: 0.013354856 0.044214126
# intrinsic_rewards sloss and rloss: 0.036625814 0.10799276
# intrinsic_rewards sloss and rloss: 0.07595094 0.20174094
# intrinsic_rewards sloss and rloss: 0.13171259 0.32799426
# intrinsic_rewards sloss and rloss: 0.18006249 0.16955054
# intrinsic_rewards sloss and rloss: 0.14501317 0.37401187
# intrinsic_rewards sloss and rloss: 0.19512627 0.21126194
# intrinsic_rewards sloss and rloss: 0.13054751 0.13861924
# intrinsic_rewards sloss and rloss: 0.11595573 0.33909377
# intrinsic_rewards sloss and rloss: 0.1875581 0.51854044
# Episode:1 meanR:24.0000 R:17.0000 rate:0.0340 aloss:0.7114 eloss:1.8091 aloss2:0.7820 exploreP:0.9953
# intrinsic_rewards sloss and rloss: 0.004137909 0.0091059655
# intrinsic_rewards sloss and rloss: 0.004520463 0.00776803
# intrinsic_rewards sloss and rloss: 0.0036834455 0.008618316
# intrinsic_rewards sloss and rloss: 0.004134045 0.0073848236
# intrinsic_rewards sloss and rloss: 0.0020764214 0.0023233085
# intrinsic_rewards sloss and rloss: 0.018332906 0.03070244
# intrinsic_rewards sloss and rloss: 0.063697696 0.09090791
# intrinsic_rewards sloss and rloss: 0.061114907 0.082119346
# intrinsic_rewards sloss and rloss: 0.06518166 0.09309446
# intrinsic_rewards sloss and rloss: 0.11658587 0.16752315
# intrinsic_rewards sloss and rloss: 0.111689575 0.16694479
# intrinsic_rewards sloss and rloss: 0.064520195 0.090476245
# intrinsic_rewards sloss and rloss: 0.07553074 0.1020859
# intrinsic_rewards sloss and rloss: 0.13390835 0.181698
# intrinsic_rewards sloss and rloss: 0.2093578 0.28451034
# intrinsic_rewards sloss and rloss: 0.1953907 0.2735348
# Episode:2 meanR:21.3333 R:16.0000 rate:0.0320 aloss:0.7106 eloss:1.7939 aloss2:0.7954 exploreP:0.9937
# intrinsic_rewards sloss and rloss: 8.610816e-05 4.0315634e-05
# intrinsic_rewards sloss and rloss: 0.0021266413 0.0008264703
# intrinsic_rewards sloss and rloss: 0.005533777 0.016280623
# intrinsic_rewards sloss and rloss: 0.010086145 0.004430672
# intrinsic_rewards sloss and rloss: 0.00021961145 1.5050481e-05
# intrinsic_rewards sloss and rloss: 0.002801867 0.0014422787
# intrinsic_rewards sloss and rloss: 0.00034927484 8.0727776e-05
# intrinsic_rewards sloss and rloss: 0.0030924506 0.0026704941
# intrinsic_rewards sloss and rloss: 0.0004999233 0.00019473217
# intrinsic_rewards sloss and rloss: 0.0068355105 0.01085005
# intrinsic_rewards sloss and rloss: 0.010415363 0.005677917
# intrinsic_rewards sloss and rloss: 0.0038039398 0.0046117185
# intrinsic_rewards sloss and rloss: 0.006253213 0.0232182
# intrinsic_rewards sloss and rloss: 0.016815707 0.06410814
# intrinsic_rewards sloss and rloss: 0.031914122 0.009454524
# intrinsic_rewards sloss and rloss: 0.013753431 7.2984876e-05
# intrinsic_rewards sloss and rloss: 0.0013852147 0.0017293437
# intrinsic_rewards sloss and rloss: 0.0034018368 0.00579112
# intrinsic_rewards sloss and rloss: 0.022273587 0.04048125
# intrinsic_rewards sloss and rloss: 0.027236173 0.029003832
# intrinsic_rewards sloss and rloss: 0.007327511 0.0009586769
# intrinsic_rewards sloss and rloss: 0.006512695 0.011045679
# intrinsic_rewards sloss and rloss: 0.0036647352 0.0044428925
# intrinsic_rewards sloss and rloss: 0.0067339716 0.012516575
# intrinsic_rewards sloss and rloss: 0.0045425086 0.0055184592
# intrinsic_rewards sloss and rloss: 0.0070776977 0.0143464515
# intrinsic_rewards sloss and rloss: 0.009243909 0.044308525
# intrinsic_rewards sloss and rloss: 0.017438168 0.004211455
# intrinsic_rewards sloss and rloss: 0.010538193 0.0040250244
# intrinsic_rewards sloss and rloss: 0.00015875693 0.0012831151
# intrinsic_rewards sloss and rloss: 0.01026242 0.024234574
# intrinsic_rewards sloss and rloss: 0.014209266 0.011928274
# intrinsic_rewards sloss and rloss: 0.0074409368 0.02322127
# intrinsic_rewards sloss and rloss: 0.011611072 0.009973697
# intrinsic_rewards sloss and rloss: 0.0054083616 0.022641268
# intrinsic_rewards sloss and rloss: 0.028861295 0.076366305
# intrinsic_rewards sloss and rloss: 0.03215324 0.059082594
# intrinsic_rewards sloss and rloss: 0.007724795 0.011343036
# intrinsic_rewards sloss and rloss: 0.003041646 0.024173515
# intrinsic_rewards sloss and rloss: 0.024116302 0.07782247
# intrinsic_rewards sloss and rloss: 0.027583726 0.06089772
# intrinsic_rewards sloss and rloss: 0.0067239013 0.011105203
# intrinsic_rewards sloss and rloss: 0.0063507 0.0015205962
# intrinsic_rewards sloss and rloss: 0.003855886 0.00082755426
# intrinsic_rewards sloss and rloss: 0.002611465 0.029094344
# intrinsic_rewards sloss and rloss: 0.0069793966 0.012448191
# intrinsic_rewards sloss and rloss: 0.0027806605 0.03141943
# intrinsic_rewards sloss and rloss: 0.0073084054 0.0136749055
# intrinsic_rewards sloss and rloss: 0.005068426 0.0014722194
# intrinsic_rewards sloss and rloss: 0.0041338876 0.0022829724
# intrinsic_rewards sloss and rloss: 0.003476811 0.034906425
# intrinsic_rewards sloss and rloss: 0.023795929 0.09752507
# intrinsic_rewards sloss and rloss: 0.067788124 0.20892292
# intrinsic_rewards sloss and rloss: 0.06550281 0.17406954
# intrinsic_rewards sloss and rloss: 0.028321538 0.07990342
# intrinsic_rewards sloss and rloss: 0.010499881 0.019853124
# intrinsic_rewards sloss and rloss: 0.006387204 0.00077183853
# intrinsic_rewards sloss and rloss: 0.006303403 0.008019259
# intrinsic_rewards sloss and rloss: 0.01162423 0.05112181
# intrinsic_rewards sloss and rloss: 0.040594257 0.13116908
# intrinsic_rewards sloss and rloss: 0.08726163 0.23498687
# intrinsic_rewards sloss and rloss: 0.14433792 0.3551675
# intrinsic_rewards sloss and rloss: 0.21747652 0.49911985
# Episode:3 meanR:31.7500 R:63.0000 rate:0.1260 aloss:0.7044 eloss:1.7863 aloss2:0.7934 exploreP:0.9875
# intrinsic_rewards sloss and rloss: 0.005792191 0.0030957914
# intrinsic_rewards sloss and rloss: 0.003927705 0.003625173
# intrinsic_rewards sloss and rloss: 0.005560953 0.0032349357
# intrinsic_rewards sloss and rloss: 0.0038645787 0.020573873
# intrinsic_rewards sloss and rloss: 0.0131778065 0.053673554
# intrinsic_rewards sloss and rloss: 0.05196476 0.015096747
# intrinsic_rewards sloss and rloss: 0.014559136 0.060197573
# intrinsic_rewards sloss and rloss: 0.053457115 0.01995925
# intrinsic_rewards sloss and rloss: 0.01665268 0.07030031
# intrinsic_rewards sloss and rloss: 0.056091152 0.027753783
# intrinsic_rewards sloss and rloss: 0.029061105 0.0042074453
# intrinsic_rewards sloss and rloss: 0.0086696595 0.049318198
# intrinsic_rewards sloss and rloss: 0.0349152 0.009282179
# intrinsic_rewards sloss and rloss: 0.023500176 0.00024179678
# intrinsic_rewards sloss and rloss: 0.006023697 0.026445223
# intrinsic_rewards sloss and rloss: 0.020838987 7.214229e-11
# intrinsic_rewards sloss and rloss: 0.0077933487 0.039842866
# intrinsic_rewards sloss and rloss: 0.01738441 0.102685645
# intrinsic_rewards sloss and rloss: 0.046115473 0.046173602
# intrinsic_rewards sloss and rloss: 0.02262376 0.13377519
# intrinsic_rewards sloss and rloss: 0.053627796 0.07077068
# Episode:4 meanR:29.6000 R:21.0000 rate:0.0420 aloss:0.7064 eloss:1.7968 aloss2:0.7732 exploreP:0.9855
# intrinsic_rewards sloss and rloss: 0.0067095244 0.002842446
# intrinsic_rewards sloss and rloss: 0.0038153566 0.021021707
# intrinsic_rewards sloss and rloss: 0.013353668 0.054424983
# intrinsic_rewards sloss and rloss: 0.064464115 0.021294214
# intrinsic_rewards sloss and rloss: 0.015493846 0.065672934
# intrinsic_rewards sloss and rloss: 0.06757406 0.030311458
# intrinsic_rewards sloss and rloss: 0.018665757 0.08191227
# intrinsic_rewards sloss and rloss: 0.07234955 0.04414904
# intrinsic_rewards sloss and rloss: 0.023185985 0.10498278
# intrinsic_rewards sloss and rloss: 0.07924235 0.06487305
# intrinsic_rewards sloss and rloss: 0.029465724 0.13715455
# intrinsic_rewards sloss and rloss: 0.088857256 0.09513492
# Episode:5 meanR:26.6667 R:12.0000 rate:0.0240 aloss:0.6973 eloss:1.7959 aloss2:0.7748 exploreP:0.9843
# intrinsic_rewards sloss and rloss: 0.013637457 0.002960795
# intrinsic_rewards sloss and rloss: 0.003453088 0.0014305866
# intrinsic_rewards sloss and rloss: 0.01222937 0.0025500578
# intrinsic_rewards sloss and rloss: 0.005218133 0.015615863
# intrinsic_rewards sloss and rloss: 0.015447285 0.00042930935
# intrinsic_rewards sloss and rloss: 0.0022252554 0.0018708208
# intrinsic_rewards sloss and rloss: 0.010126702 0.0024586786
# intrinsic_rewards sloss and rloss: 0.005381966 0.0141868
# intrinsic_rewards sloss and rloss: 0.0065775444 0.040332556
# intrinsic_rewards sloss and rloss: 0.04326003 0.012786165
# intrinsic_rewards sloss and rloss: 0.015341441 0.00044177787
# intrinsic_rewards sloss and rloss: 0.0053280103 0.018523911
# intrinsic_rewards sloss and rloss: 0.007742372 0.04854577
# intrinsic_rewards sloss and rloss: 0.019953316 0.09364813
# intrinsic_rewards sloss and rloss: 0.0844662 0.056017
# intrinsic_rewards sloss and rloss: 0.023214476 0.110846534
# intrinsic_rewards sloss and rloss: 0.08958549 0.07284903
# intrinsic_rewards sloss and rloss: 0.027970362 0.13595255
# intrinsic_rewards sloss and rloss: 0.09747107 0.09790414
# intrinsic_rewards sloss and rloss: 0.034760986 0.17134503
# intrinsic_rewards sloss and rloss: 0.06468284 0.2647377
# Episode:6 meanR:25.8571 R:21.0000 rate:0.0420 aloss:0.6942 eloss:1.7817 aloss2:0.7879 exploreP:0.9822
# intrinsic_rewards sloss and rloss: 8.28259e-05 0.00021031957
# intrinsic_rewards sloss and rloss: 0.0045940466 0.01535118
# intrinsic_rewards sloss and rloss: 0.018419905 0.0037264046
# intrinsic_rewards sloss and rloss: 0.0038890773 0.015453939
# intrinsic_rewards sloss and rloss: 0.02386219 0.06212342
# intrinsic_rewards sloss and rloss: 0.032151178 0.039938632
# intrinsic_rewards sloss and rloss: 0.017847087 0.0042042327
# intrinsic_rewards sloss and rloss: 0.0038077203 0.018609041
# intrinsic_rewards sloss and rloss: 0.018029612 0.004920009
# intrinsic_rewards sloss and rloss: 0.005912723 0.0019328865
# intrinsic_rewards sloss and rloss: 0.01192369 0.0017265411
# intrinsic_rewards sloss and rloss: 0.0043824916 0.010635351
# intrinsic_rewards sloss and rloss: 0.0069866315 0.03408058
# intrinsic_rewards sloss and rloss: 0.018490685 0.06857597
# intrinsic_rewards sloss and rloss: 0.10594562 0.040999185
# intrinsic_rewards sloss and rloss: 0.020040859 0.0779033
# intrinsic_rewards sloss and rloss: 0.04164908 0.13263689
# intrinsic_rewards sloss and rloss: 0.07286023 0.20535168
# intrinsic_rewards sloss and rloss: 0.11391777 0.2977967
# intrinsic_rewards sloss and rloss: 0.31517404 0.2752008
# intrinsic_rewards sloss and rloss: 0.12769349 0.3632396
# Episode:7 meanR:25.2500 R:21.0000 rate:0.0420 aloss:0.7002 eloss:1.7824 aloss2:0.7733 exploreP:0.9802
# intrinsic_rewards sloss and rloss: 0.0142725315 0.0013861747
# intrinsic_rewards sloss and rloss: 0.006032057 0.0069695422
# intrinsic_rewards sloss and rloss: 0.02201455 0.0012429854
# intrinsic_rewards sloss and rloss: 0.0064707925 0.00014160234
# intrinsic_rewards sloss and rloss: 0.011422715 0.0016202169
# intrinsic_rewards sloss and rloss: 0.006349338 0.006198737
# intrinsic_rewards sloss and rloss: 0.021656353 0.0012468934
# intrinsic_rewards sloss and rloss: 0.0038309656 0.0008490997
# intrinsic_rewards sloss and rloss: 0.009790184 0.0019500557
# intrinsic_rewards sloss and rloss: 0.0037357267 0.00085421925
# intrinsic_rewards sloss and rloss: 0.009811465 0.0020206189
# intrinsic_rewards sloss and rloss: 0.006862717 0.0068132337
# intrinsic_rewards sloss and rloss: 0.021610893 0.0016302256
# intrinsic_rewards sloss and rloss: 0.0068061133 0.008286415
# intrinsic_rewards sloss and rloss: 0.005418137 0.030206945
# intrinsic_rewards sloss and rloss: 0.05227811 0.013949684
# intrinsic_rewards sloss and rloss: 0.0063092187 0.03774231
# intrinsic_rewards sloss and rloss: 0.01566462 0.07531219
# intrinsic_rewards sloss and rloss: 0.033558644 0.12802404
# intrinsic_rewards sloss and rloss: 0.15897109 0.11039939
# intrinsic_rewards sloss and rloss: 0.039119635 0.15939614
# intrinsic_rewards sloss and rloss: 0.06824443 0.24075885
# intrinsic_rewards sloss and rloss: 0.10678274 0.34289947
# Episode:8 meanR:25.0000 R:23.0000 rate:0.0460 aloss:0.6928 eloss:1.7746 aloss2:0.7738 exploreP:0.9780
# intrinsic_rewards sloss and rloss: 0.00016897221 0.00075616344
# intrinsic_rewards sloss and rloss: 0.002865139 0.0012475847
# intrinsic_rewards sloss and rloss: 0.014315355 0.0016779321
# intrinsic_rewards sloss and rloss: 0.020269526 0.00030572392
# intrinsic_rewards sloss and rloss: 0.01484048 0.0017846614
# intrinsic_rewards sloss and rloss: 0.022905376 0.00047376822
# intrinsic_rewards sloss and rloss: 0.01577331 0.0019382187
# intrinsic_rewards sloss and rloss: 0.007167473 0.009591325
# intrinsic_rewards sloss and rloss: 0.02645025 0.0037875718
# intrinsic_rewards sloss and rloss: 0.006963102 0.012987574
# intrinsic_rewards sloss and rloss: 0.02920392 0.0054428773
# intrinsic_rewards sloss and rloss: 0.027521795 0.0011300459
# intrinsic_rewards sloss and rloss: 0.0007366976 0.0003711487
# intrinsic_rewards sloss and rloss: 0.0065791523 0.0021105688
# intrinsic_rewards sloss and rloss: 0.0010791384 0.0004978637
# intrinsic_rewards sloss and rloss: 0.0025837452 0.004937335
# intrinsic_rewards sloss and rloss: 0.017407535 1.7879603e-07
# intrinsic_rewards sloss and rloss: 0.0018900203 0.0038589663
# intrinsic_rewards sloss and rloss: 0.0060483115 0.00012109263
# intrinsic_rewards sloss and rloss: 0.001382075 0.0028831083
# intrinsic_rewards sloss and rloss: 0.0017988833 0.00048981025
# intrinsic_rewards sloss and rloss: 0.00092286017 0.0017487352
# intrinsic_rewards sloss and rloss: 0.0015019795 0.0014959987
# intrinsic_rewards sloss and rloss: 0.00060399756 0.00073602266
# intrinsic_rewards sloss and rloss: 0.005064262 0.01957663
# intrinsic_rewards sloss and rloss: 0.01739867 0.061074376
# intrinsic_rewards sloss and rloss: 0.040805794 0.027487785
# intrinsic_rewards sloss and rloss: 0.02568598 0.00028698187
# intrinsic_rewards sloss and rloss: 0.01364134 0.0023713708
# intrinsic_rewards sloss and rloss: 0.0023358853 1.2935412e-05
# intrinsic_rewards sloss and rloss: 0.00237454 0.014955777
# intrinsic_rewards sloss and rloss: 0.012482914 0.00049232756
# intrinsic_rewards sloss and rloss: 0.0016538263 0.0130567225
# intrinsic_rewards sloss and rloss: 0.007092826 0.0013879165
# intrinsic_rewards sloss and rloss: 0.0010925559 0.011443672
# intrinsic_rewards sloss and rloss: 0.008017082 0.045277026
# intrinsic_rewards sloss and rloss: 0.03363587 0.014624132
# intrinsic_rewards sloss and rloss: 0.0067537073 0.046055473
# intrinsic_rewards sloss and rloss: 0.030683639 0.014905915
# intrinsic_rewards sloss and rloss: 0.0048796656 0.049523562
# intrinsic_rewards sloss and rloss: 0.027970523 0.014798464
# intrinsic_rewards sloss and rloss: 0.011820119 0.0027206885
# intrinsic_rewards sloss and rloss: 0.020564554 0.0018412424
# intrinsic_rewards sloss and rloss: 0.016755173 0.006847893
# intrinsic_rewards sloss and rloss: 0.013964834 0.021185044
# intrinsic_rewards sloss and rloss: 0.011197062 0.046772286
# intrinsic_rewards sloss and rloss: 0.016607834 0.08116693
# intrinsic_rewards sloss and rloss: 0.029124679 0.12630947
# intrinsic_rewards sloss and rloss: 0.1949674 0.13502301
# intrinsic_rewards sloss and rloss: 0.03287332 0.15208603
# intrinsic_rewards sloss and rloss: 0.05664501 0.22348866
# intrinsic_rewards sloss and rloss: 0.090169914 0.3140584
# Episode:9 meanR:27.7000 R:52.0000 rate:0.1040 aloss:0.6951 eloss:1.7838 aloss2:0.7718 exploreP:0.9730
# intrinsic_rewards sloss and rloss: 0.00031191186 0.0042116633
# intrinsic_rewards sloss and rloss: 0.010749584 0.00026885304
# intrinsic_rewards sloss and rloss: 0.00048279454 0.0055370987
# intrinsic_rewards sloss and rloss: 0.008783928 0.034996014
# intrinsic_rewards sloss and rloss: 0.031755757 0.11110832
# intrinsic_rewards sloss and rloss: 0.051415462 0.061390128
# intrinsic_rewards sloss and rloss: 0.035705138 0.12711596
# intrinsic_rewards sloss and rloss: 0.079281226 0.22114995
# intrinsic_rewards sloss and rloss: 0.14296365 0.3316077
# intrinsic_rewards sloss and rloss: 0.14212877 0.28570873
# intrinsic_rewards sloss and rloss: 0.106099576 0.19445236
# Episode:10 meanR:26.1818 R:11.0000 rate:0.0220 aloss:0.6916 eloss:1.7964 aloss2:0.7662 exploreP:0.9719

# %% [markdown]
# # Visualizing training
#
# Below I'll plot the total rewards for each episode. I'm plotting the rolling average too, in blue.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def running_mean(x, N):
    cumsum = np.cumsum(np.insert(x, 0, 0)) 
    return (cumsum[N:] - cumsum[:-N]) / N

# %%
eps, arr = np.array(episode_rewards_list).T
smoothed_arr = running_mean(arr, 10)
plt.plot(eps[-len(smoothed_arr):], smoothed_arr)
plt.plot(eps, arr, color='grey', alpha=0.3)
plt.xlabel('Episode')
plt.ylabel('Total rewards')

# %%
eps, arr = np.array(rewards_list).T
smoothed_arr = running_mean(arr, 10)
plt.plot(eps[-len(smoothed_arr):], smoothed_arr)
plt.plot(eps, arr, color='grey', alpha=0.3)
plt.xlabel('Episode')
plt.ylabel('Total rewards')

# %%
eps, arr = np.array(aloss_list).T
smoothed_arr = running_mean(arr, 10)
plt.plot(eps[-len(smoothed_arr):], smoothed_arr)
plt.plot(eps, arr, color='grey', alpha=0.3)
plt.xlabel('Episode')
plt.ylabel('Act losses')

# %%
eps, arr = np.array(eloss_list).T
smoothed_arr = running_mean(arr, 10)
plt.plot(eps[-len(smoothed_arr):], smoothed_arr)
plt.plot(eps, arr, color='grey', alpha=0.3)
plt.xlabel('Episode')
plt.ylabel('Env losses')

# %%
eps, arr = np.array(aloss2_list).T
smoothed_arr = running_mean(arr, 10)
plt.plot(eps[-len(smoothed_arr):], smoothed_arr)
plt.plot(eps, arr, color='grey', alpha=0.3)
plt.xlabel('Episode')
plt.ylabel('Act losses 2')

# %% [markdown]
# ## Testing
#
# Let's checkout how our trained agent plays the game.

# %%
import gym
env = gym.make('CartPole-v0')
env = gym.make('CartPole-v1')

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    saver.restore(sess, 'checkpoints/model.ckpt')    
    #saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    
    # Episodes/epochs
    for _ in range(10):
        state = env.reset()
        total_reward = 0

        # Steps/batches
        while True:
            env.render()
            action_logits = sess.run(model.actions_logits, feed_dict={model.states: state.reshape([1, -1])})
            action = np.argmax(action_logits)
            state, reward, done, _ = env.step(action)
            total_reward += reward
            if done:
                print('total_reward: {}'.format(total_reward))
                break
                
env.close()
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/model.ckpt
# total_reward: 500.0
# total_reward: 500.0
# total_reward: 500.0
# total_reward: 500.0
# total_reward: 500.0
# total_reward: 500.0
# total_reward: 500.0
# total_reward: 500.0
# total_reward: 500.0
# total_reward: 500.0
