# %% [markdown]
# # Sequential DQN
#
# In this notebook, we'll build a neural network that can learn to play games through reinforcement learning. More specifically, we'll use Q-learning to train an agent to play a game called [Cart-Pole](https://gym.openai.com/envs/CartPole-v0). In this game, a freely swinging pole is attached to a cart. The cart can move to the left and right, and the goal is to keep the pole upright as long as possible.
#
# ![Cart-Pole](assets/cart-pole.jpg)
#
# We can simulate this game using [OpenAI Gym](https://gym.openai.com/). First, let's check out how OpenAI Gym works. Then, we'll get into training an agent to play the Cart-Pole game.

# %%
# In this one we should define and detect GPUs for tensorflow
# GPUs or CPU
import tensorflow as tf

# Check TensorFlow Version
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# /home/aras/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# TensorFlow Version: 1.7.1
# Default GPU Device:

# %% [markdown]
# >**Note:** Make sure you have OpenAI Gym cloned into the same directory with this notebook. I've included `gym` as a submodule, so you can run `git submodule --init --recursive` to pull the contents into the `gym` repo.

# %% [markdown]
# >**Note:** Make sure you have OpenAI Gym cloned. Then run this command `pip install -e gym/[all]`.

# %%
import gym

# Create the Cart-Pole game environment
env = gym.make('CartPole-v0')
env = gym.make('CartPole-v1')

# %% [markdown]
# We interact with the simulation through `env`. To show the simulation running, you can use `env.render()` to render one frame. Passing in an action as an integer to `env.step` will generate the next step in the simulation.  You can see how many actions are possible from `env.action_space` and to get a random action you can use `env.action_space.sample()`. This is general to all Gym games. In the Cart-Pole game, there are two possible actions, moving the cart left or right. So there are two actions we can take, encoded as 0 and 1.
#
# Run the code below to watch the simulation run.

# %%
import numpy as np
state = env.reset()
for _ in range(10):
    # env.render()
    action = env.action_space.sample()
    next_state, reward, done, info = env.step(action) # take a random action
    #print('state, action, next_state, reward, done, info:', state, action, next_state, reward, done, info)
    state = next_state
    if done:
        state = env.reset()

# %% [markdown]
# To shut the window showing the simulation, use `env.close()`.

# %% [markdown]
# If you ran the simulation above, we can look at the rewards:

# %%
# print(rewards[-20:])
# print(np.array(rewards).shape, np.array(states).shape, np.array(actions).shape, np.array(dones).shape)
# print(np.array(rewards).dtype, np.array(states).dtype, np.array(actions).dtype, np.array(dones).dtype)
# print(np.max(np.array(actions)), np.min(np.array(actions)))
# print((np.max(np.array(actions)) - np.min(np.array(actions)))+1)
# print(np.max(np.array(rewards)), np.min(np.array(rewards)))
# print(np.max(np.array(states)), np.min(np.array(states)))

# %% [markdown]
# The game resets after the pole has fallen past a certain angle. For each frame while the simulation is running, it returns a reward of 1.0. The longer the game runs, the more reward we get. Then, our network's goal is to maximize the reward by keeping the pole vertical. It will do this by moving the cart to the left and the right.

# %% [markdown]
# ## Q-Network
#
# We train our Q-learning agent using the Bellman Equation:
#
# $$
# Q(s, a) = r + \gamma \max{Q(s', a')}
# $$
#
# where $s$ is a state, $a$ is an action, and $s'$ is the next state from state $s$ and action $a$.
#
# Before we used this equation to learn values for a Q-_table_. However, for this game there are a huge number of states available. The state has four values: the position and velocity of the cart, and the position and velocity of the pole. These are all real-valued numbers, so ignoring floating point precisions, you practically have infinite states. Instead of using a table then, we'll replace it with a neural network that will approximate the Q-table lookup function.
#
# <img src="assets/deep-q-learning.png" width=450px>
#
# Now, our Q value, $Q(s, a)$ is calculated by passing in a state to the network. The output will be Q-values for each available action, with fully connected hidden layers.
#
# <img src="assets/q-network.png" width=550px>
#
#
# As I showed before, we can define our targets for training as $\hat{Q}(s,a) = r + \gamma \max{Q(s', a')}$. Then we update the weights by minimizing $(\hat{Q}(s,a) - Q(s,a))^2$.
#
# For this Cart-Pole game, we have four inputs, one for each value in the state, and two outputs, one for each action. To get $\hat{Q}$, we'll first choose an action, then simulate the game using that action. This will get us the next state, $s'$, and the reward. With that, we can calculate $\hat{Q}$ then pass it back into the $Q$ network to run the optimizer and update the weights.
#
# Below is my implementation of the Q-network. I used two fully connected layers with ReLU activations. Two seems to be good enough, three might be better. Feel free to try it out.

# %%
def model_input(state_size, hidden_size, batch_size=1):
    states = tf.placeholder(tf.float32, [None, state_size], name='states')
    actions = tf.placeholder(tf.int32, [None], name='actions')
    targetQs = tf.placeholder(tf.float32, [None], name='targetQs')
    # RNN
    cell = tf.nn.rnn_cell.GRUCell(hidden_size)
    #cell = tf.nn.rnn_cell.LSTMCell(hidden_size)
    cells = tf.nn.rnn_cell.MultiRNNCell([cell], state_is_tuple=True)
    initial_state = cells.zero_state(batch_size, tf.float32)
    return states, actions, targetQs, cells, initial_state

# %%
# RNN generator or sequence generator
def generator(states, action_size, initial_state, cells, hidden_size, reuse=False): 
    with tf.variable_scope('generator', reuse=reuse):
        # First fully connected layer
        inputs = tf.layers.dense(inputs=states, units=hidden_size)
        print(states.shape, inputs.shape)
        
        # with tf.variable_scope('dynamic_rnn_', reuse=tf.AUTO_REUSE):
        # dynamic means adapt to the batch_size and
        # static means can NOT adapt to the batch_size
        inputs_rnn = tf.reshape(inputs, [1, -1, hidden_size]) # NxH -> 1xNxH
        print(inputs_rnn.shape, initial_state)
        outputs_rnn, final_state = tf.nn.dynamic_rnn(cell=cells, inputs=inputs_rnn, initial_state=initial_state)
        print(outputs_rnn.shape, final_state)
        outputs = tf.reshape(outputs_rnn, [-1, hidden_size]) # 1xNxH -> NxH
        print(outputs.shape)

        # Last fully connected layer
        logits = tf.layers.dense(inputs=outputs, units=action_size)
        print(logits.shape)
        #predictions = tf.nn.softmax(logits)
        
        # logits are the action logits
        return logits, final_state

# %%
def model_loss(action_size, hidden_size, states, cells, initial_state, actions, targetQs):
    actions_logits, final_state = generator(states=states, cells=cells, initial_state=initial_state, 
                                            hidden_size=hidden_size, action_size=action_size)
    actions_labels = tf.one_hot(indices=actions, depth=action_size, dtype=actions_logits.dtype)
    Qs = tf.reduce_max(actions_logits*actions_labels, axis=1)
    loss = tf.reduce_mean(tf.square(Qs - targetQs))
    return actions_logits, final_state, loss

# %%
def model_opt(loss, learning_rate):
    # Get weights and bias to update
    t_vars = tf.trainable_variables()
    g_vars = [var for var in t_vars if var.name.startswith('generator')]

    # # Optimize MLP/CNN
    # with tf.control_dependencies(tf.get_collection(tf.GraphKeys.UPDATE_OPS)): # Required for batchnorm (BN)
    # #opt = tf.train.AdamOptimizer(learning_rate).minimize(loss, var_list=g_vars)

    # # Optimize RNN
    #grads, _ = tf.clip_by_global_norm(t_list=tf.gradients(loss, g_vars), clip_norm=5) # usually around 1-5
    grads = tf.gradients(loss, g_vars)
    opt = tf.train.AdamOptimizer(learning_rate).apply_gradients(grads_and_vars=zip(grads, g_vars))

    return opt

# %%
class Model:
    def __init__(self, state_size, action_size, hidden_size, learning_rate):

        # Data of the Model: make the data available inside the framework
        self.states, self.actions, self.targetQs, cells, self.initial_state = model_input(
                state_size=state_size, hidden_size=hidden_size)
        
        # Create the Model: calculating the loss and forwad pass
        self.actions_logits, self.final_state, self.loss = model_loss(
            action_size=action_size, hidden_size=hidden_size, 
            states=self.states, actions=self.actions, 
            targetQs=self.targetQs, cells=cells, initial_state=self.initial_state)

        # Update the model: backward pass and backprop
        self.opt = model_opt(loss=self.loss, learning_rate=learning_rate)

# %% [markdown]
# ## Experience replay
#
# Reinforcement learning algorithms can have stability issues due to correlations between states. To reduce correlations when training, we can store the agent's experiences and later draw a random mini-batch of those experiences to train on.
#
# Here, we'll create a `Memory` object that will store our experiences, our transitions $<s, a, r, s'>$. This memory will have a maxmium capacity, so we can keep newer experiences in memory while getting rid of older experiences. Then, we'll sample a random mini-batch of transitions $<s, a, r, s'>$ and train on those.
#
# Below, I've implemented a `Memory` object. If you're unfamiliar with `deque`, this is a double-ended queue. You can think of it like a tube open on both sides. You can put objects in either side of the tube. But if it's full, adding anything more will push an object out the other side. This is a great data structure to use for the memory buffer.

# %%
from collections import deque

class Memory():    
    def __init__(self, max_size = 1000):
        self.buffer = deque(maxlen=max_size)
        self.states = deque(maxlen=max_size)

# %% [markdown]
# ## Exploration - Exploitation
#
# To learn about the environment and rules of the game, the agent needs to explore by taking random actions. We'll do this by choosing a random action with some probability $\epsilon$ (epsilon).  That is, with some probability $\epsilon$ the agent will make a random action and with probability $1 - \epsilon$, the agent will choose an action from $Q(s,a)$. This is called an **$\epsilon$-greedy policy**.
#
#
# At first, the agent needs to do a lot of exploring. Later when it has learned more, the agent can favor choosing actions based on what it has learned. This is called _exploitation_. We'll set it up so the agent is more likely to explore early in training, then more likely to exploit later in training.

# %% [markdown]
# ## Q-Learning training algorithm
#
# Putting all this together, we can list out the algorithm we'll use to train the network. We'll train the network in _episodes_. One *episode* is one simulation of the game. For this game, the goal is to keep the pole upright for 195 frames. So we can start a new episode once meeting that goal. The game ends if the pole tilts over too far, or if the cart moves too far the left or right. When a game ends, we'll start a new episode. Now, to train the agent:
#
# * Initialize the memory $D$
# * Initialize the action-value network $Q$ with random weights
# * **For** episode = 1, $M$ **do**
#   * **For** $t$, $T$ **do**
#      * With probability $\epsilon$ select a random action $a_t$, otherwise select $a_t = \mathrm{argmax}_a Q(s,a)$
#      * Execute action $a_t$ in simulator and observe reward $r_{t+1}$ and new state $s_{t+1}$
#      * Store transition $<s_t, a_t, r_{t+1}, s_{t+1}>$ in memory $D$
#      * Sample random mini-batch from $D$: $<s_j, a_j, r_j, s'_j>$
#      * Set $\hat{Q}_j = r_j$ if the episode ends at $j+1$, otherwise set $\hat{Q}_j = r_j + \gamma \max_{a'}{Q(s'_j, a')}$
#      * Make a gradient descent step with loss $(\hat{Q}_j - Q(s_j, a_j))^2$
#   * **endfor**
# * **endfor**

# %% [markdown]
# ## Hyperparameters
#
# One of the more difficult aspects of reinforcememt learning are the large number of hyperparameters. Not only are we tuning the network, but we're tuning the simulation.

# %%
# Network parameters
action_size = 2
state_size = 4
hidden_size = 4*2              # number of units in each Q-network hidden layer
learning_rate = 0.0001         # Q-network learning rate

# Memory parameters
memory_size = 200            # memory capacity - 1000 DQN
batch_size = 200             # experience mini-batch size - 20 DQN
gamma = 0.99                 # future reward discount

# %%
# Reset/init the graph/session
graph = tf.reset_default_graph()

# Init the model
model = Model(action_size=action_size, hidden_size=hidden_size, state_size=state_size, learning_rate=learning_rate)

# Init the memory
memory = Memory(max_size=batch_size)
# Out:
# (?, 4) (?, 8)
# (1, ?, 8) (<tf.Tensor 'MultiRNNCellZeroState/GRUCellZeroState/zeros:0' shape=(1, 8) dtype=float32>,)
# (1, ?, 8) (<tf.Tensor 'generator/rnn/while/Exit_3:0' shape=(1, 8) dtype=float32>,)
# (?, 8)
# (?, 2)

# %%
model.initial_state[0]
# Out:
# <tf.Tensor 'MultiRNNCellZeroState/GRUCellZeroState/zeros:0' shape=(1, 8) dtype=float32>

# %% [markdown]
# ## Populate the memory (exprience memory)
#
# Here I'm re-initializing the simulation and pre-populating the memory. The agent is taking random actions and storing the transitions in memory. This will help the agent with exploring the game.

# %%
state = env.reset()
for _ in range(memory_size):
    action = env.action_space.sample()
    next_state, reward, done, _ = env.step(action)
    memory.buffer.append([state, action, next_state, reward, float(done)])
    memory.states.append(np.zeros([1, hidden_size])) # gru
    #memory.states.append([np.zeros([1, hidden_size]), np.zeros([1, hidden_size])]) # lstm
    state = next_state
    if done is True:
        # Reseting the env/first state
        state = env.reset()

# %%
# # Training
# batch = memory.buffer
# states = np.array([each[0] for each in batch])
# actions = np.array([each[1] for each in batch])
# next_states = np.array([each[2] for each in batch])
# rewards = np.array([each[3] for each in batch])
# dones = np.array([each[4] for each in batch])

# %%
memory.states[0].shape, model.initial_state[0].shape # gru
# memory.states[0][1].shape, model.initial_state[0][1].shape #lstm
# Out:
# ((1, 8), TensorShape([Dimension(1), Dimension(8)]))

# %%
# memory.states[0][0].shape, model.initial_state[0][0].shape

# %% [markdown]
# ## Training the model
#
# Below we'll train our agent. If you want to watch it train, uncomment the `env.render()` line. This is slow because it's rendering the frames slower than the network can train. But, it's cool to watch the agent get better at the game.

# %%
# initial_states = np.array(memory.states)
# initial_states.shape

# %%
saver = tf.train.Saver()
episode_rewards_list, rewards_list, loss_list = [], [], []

# TF session for training
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    #saver.restore(sess, 'checkpoints/model.ckpt')    
    #saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    episode_reward = deque(maxlen=100) # 100 episodes average/running average/running mean/window
    
    # Training episodes/epochs
    for ep in range(11111):
        total_reward = 0
        loss_batch = []
        state = env.reset()
        initial_state = sess.run(model.initial_state)

        # Training steps/batches
        while True:
            action_logits, final_state = sess.run([model.actions_logits, model.final_state],
                                                  feed_dict = {model.states: state.reshape([1, -1]), 
                                                               model.initial_state: initial_state})
            action = np.argmax(action_logits)
            next_state, reward, done, _ = env.step(action)
            memory.buffer.append([state, action, next_state, reward, float(done)])
            memory.states.append(initial_state)
            total_reward += reward
            state = next_state
            initial_state = final_state

            # Training
            batch = memory.buffer
            states = np.array([each[0] for each in batch])
            actions = np.array([each[1] for each in batch])
            next_states = np.array([each[2] for each in batch])
            rewards = np.array([each[3] for each in batch])
            dones = np.array([each[4] for each in batch])
            initial_states = memory.states
            next_actions_logits = sess.run(model.actions_logits, 
                                           feed_dict = {model.states: next_states,
                                                        model.initial_state: initial_states[1]})
            nextQs = np.max(next_actions_logits, axis=1) * (1-dones)
            targetQs = rewards + (gamma * nextQs)
            loss, _ = sess.run([model.loss, model.opt], feed_dict = {model.states: states, 
                                                                     model.actions: actions,
                                                                     model.targetQs: targetQs,
                                                                     model.initial_state: initial_states[0]})
            # End of training
            loss_batch.append(loss)
            if done is True:
                break
                
        # Outputing: priting out/Potting
        episode_reward.append(total_reward)
        print('Episode:{}'.format(ep),
              'meanR:{:.4f}'.format(np.mean(episode_reward)),
              'R:{:.4f}'.format(total_reward),
              'loss:{:.4f}'.format(np.mean(loss_batch)))
        # Ploting out
        episode_rewards_list.append([ep, np.mean(episode_reward)])
        rewards_list.append([ep, total_reward])
        loss_list.append([ep, np.mean(loss_batch)])
        # Break episode/epoch loop
        if np.mean(episode_reward) >= 500:
            break
            
    # At the end of all training episodes/epochs
    saver.save(sess, 'checkpoints/model.ckpt')
# Out:
# Episode:0 meanR:9.0000 R:9.0000 loss:1.4572
# Episode:1 meanR:9.0000 R:9.0000 loss:1.4470
# Episode:2 meanR:9.3333 R:10.0000 loss:1.4502
# Episode:3 meanR:9.2500 R:9.0000 loss:1.4561
# Episode:4 meanR:9.2000 R:9.0000 loss:1.4645
# Episode:5 meanR:9.1667 R:9.0000 loss:1.4784
# Episode:6 meanR:9.1429 R:9.0000 loss:1.4955
# Episode:7 meanR:9.2500 R:10.0000 loss:1.4792
# Episode:8 meanR:9.3333 R:10.0000 loss:1.4742
# Episode:9 meanR:9.3000 R:9.0000 loss:1.4791
# Episode:10 meanR:9.3636 R:10.0000 loss:1.4981
# Episode:11 meanR:9.3333 R:9.0000 loss:1.4612
# Episode:12 meanR:9.3846 R:10.0000 loss:1.4347
# Episode:13 meanR:9.4286 R:10.0000 loss:1.4436
# Episode:14 meanR:9.3333 R:8.0000 loss:1.4346
# Episode:15 meanR:9.2500 R:8.0000 loss:1.4347
# Episode:16 meanR:9.2353 R:9.0000 loss:1.4496
# Episode:17 meanR:9.2778 R:10.0000 loss:1.4729
# Episode:18 meanR:9.3158 R:10.0000 loss:1.4774
# Episode:19 meanR:9.3000 R:9.0000 loss:1.4310
# Episode:20 meanR:9.3333 R:10.0000 loss:1.3709
# Episode:21 meanR:9.3636 R:10.0000 loss:1.3527
# Episode:22 meanR:9.3478 R:9.0000 loss:1.3277
# Episode:23 meanR:9.3750 R:10.0000 loss:1.3398
# Episode:24 meanR:9.3600 R:9.0000 loss:1.3393
# Episode:25 meanR:9.3846 R:10.0000 loss:1.3432
# Episode:26 meanR:9.4444 R:11.0000 loss:1.3440
# Episode:27 meanR:9.3929 R:8.0000 loss:1.3472
# Episode:28 meanR:9.4138 R:10.0000 loss:1.3517
# Episode:29 meanR:9.4000 R:9.0000 loss:1.3579
# Episode:30 meanR:9.4194 R:10.0000 loss:1.3542
# Episode:31 meanR:9.3750 R:8.0000 loss:1.3632
# Episode:32 meanR:9.3333 R:8.0000 loss:1.3623
# Episode:33 meanR:9.3529 R:10.0000 loss:1.3657
# Episode:34 meanR:9.3143 R:8.0000 loss:1.3682
# Episode:35 meanR:9.3333 R:10.0000 loss:1.3711
# Episode:36 meanR:9.3243 R:9.0000 loss:1.3719
# Episode:37 meanR:9.3421 R:10.0000 loss:1.3716
# Episode:38 meanR:9.3333 R:9.0000 loss:1.3720
# Episode:39 meanR:9.3500 R:10.0000 loss:1.3743
# Episode:40 meanR:9.3659 R:10.0000 loss:1.3760
# Episode:41 meanR:9.3810 R:10.0000 loss:1.3776
# Episode:42 meanR:9.3721 R:9.0000 loss:1.3793
# Episode:43 meanR:9.3864 R:10.0000 loss:1.3823
# Episode:44 meanR:9.4000 R:10.0000 loss:1.3838
# Episode:45 meanR:9.4130 R:10.0000 loss:1.3810
# Episode:46 meanR:9.4043 R:9.0000 loss:1.3896
# Episode:47 meanR:9.3958 R:9.0000 loss:1.3888
# Episode:48 meanR:9.4286 R:11.0000 loss:1.3876
# Episode:49 meanR:9.4400 R:10.0000 loss:1.3889
# Episode:50 meanR:9.4706 R:11.0000 loss:1.3905
# Episode:51 meanR:9.4423 R:8.0000 loss:1.3878
# Episode:52 meanR:9.4151 R:8.0000 loss:1.3931
# Episode:53 meanR:9.4259 R:10.0000 loss:1.3957
# Episode:54 meanR:9.4182 R:9.0000 loss:1.3947
# Episode:55 meanR:9.4286 R:10.0000 loss:1.3980
# Episode:56 meanR:9.4386 R:10.0000 loss:1.3977
# Episode:57 meanR:9.4310 R:9.0000 loss:1.3989
# Episode:58 meanR:9.4068 R:8.0000 loss:1.4007
# Episode:59 meanR:9.4167 R:10.0000 loss:1.4074
# Episode:60 meanR:9.3934 R:8.0000 loss:1.4073
# Episode:61 meanR:9.3871 R:9.0000 loss:1.4181
# Episode:62 meanR:9.3810 R:9.0000 loss:1.4182
# Episode:63 meanR:9.3906 R:10.0000 loss:1.4212
# Episode:64 meanR:9.4000 R:10.0000 loss:1.4223
# Episode:65 meanR:9.3788 R:8.0000 loss:1.4253
# Episode:66 meanR:9.3881 R:10.0000 loss:1.4297
# Episode:67 meanR:9.3676 R:8.0000 loss:1.4333
# Episode:68 meanR:9.3478 R:8.0000 loss:1.4372
# Episode:69 meanR:9.3571 R:10.0000 loss:1.4418
# Episode:70 meanR:9.3803 R:11.0000 loss:1.4458
# Episode:71 meanR:9.3889 R:10.0000 loss:1.4493
# Episode:72 meanR:9.3836 R:9.0000 loss:1.4537
# Episode:73 meanR:9.3784 R:9.0000 loss:1.4571
# Episode:74 meanR:9.3867 R:10.0000 loss:1.4581
# Episode:75 meanR:9.3947 R:10.0000 loss:1.4599
# Episode:76 meanR:9.3896 R:9.0000 loss:1.4629
# Episode:77 meanR:9.3974 R:10.0000 loss:1.4674
# Episode:78 meanR:9.4051 R:10.0000 loss:1.4709
# Episode:79 meanR:9.4000 R:9.0000 loss:1.4734
# Episode:80 meanR:9.3951 R:9.0000 loss:1.4752
# Episode:81 meanR:9.4146 R:11.0000 loss:1.4740
# Episode:82 meanR:9.4096 R:9.0000 loss:1.4778
# Episode:83 meanR:9.4048 R:9.0000 loss:1.4815
# Episode:84 meanR:9.4235 R:11.0000 loss:1.4864
# Episode:85 meanR:9.4186 R:9.0000 loss:1.4881
# Episode:86 meanR:9.4023 R:8.0000 loss:1.4935
# Episode:87 meanR:9.3977 R:9.0000 loss:1.5030
# Episode:88 meanR:9.4045 R:10.0000 loss:1.4990
# Episode:89 meanR:9.4111 R:10.0000 loss:1.5025
# Episode:90 meanR:9.4066 R:9.0000 loss:1.5048
# Episode:91 meanR:9.4130 R:10.0000 loss:1.5114
# Episode:92 meanR:9.4086 R:9.0000 loss:1.5173
# Episode:93 meanR:9.3936 R:8.0000 loss:1.5282
# Episode:94 meanR:9.4000 R:10.0000 loss:1.5234
# Episode:95 meanR:9.4062 R:10.0000 loss:1.5306
# Episode:96 meanR:9.4124 R:10.0000 loss:1.5352
# Episode:97 meanR:9.4082 R:9.0000 loss:1.5393
# Episode:98 meanR:9.3939 R:8.0000 loss:1.5499
# Episode:99 meanR:9.3800 R:8.0000 loss:1.5535
# Episode:100 meanR:9.3800 R:9.0000 loss:1.5601
# Episode:101 meanR:9.3700 R:8.0000 loss:1.5653
# Episode:102 meanR:9.3700 R:10.0000 loss:1.5704
# Episode:103 meanR:9.3700 R:9.0000 loss:1.5759
# Episode:104 meanR:9.3800 R:10.0000 loss:1.5803
# Episode:105 meanR:9.3900 R:10.0000 loss:1.5823
# Episode:106 meanR:9.3800 R:8.0000 loss:1.5884
# Episode:107 meanR:9.3800 R:10.0000 loss:1.5940
# Episode:108 meanR:9.3700 R:9.0000 loss:1.5946
# Episode:109 meanR:9.3800 R:10.0000 loss:1.5976
# Episode:110 meanR:9.3700 R:9.0000 loss:1.6032
# Episode:111 meanR:9.3800 R:10.0000 loss:1.6081
# Episode:112 meanR:9.3700 R:9.0000 loss:1.6111
# Episode:113 meanR:9.3700 R:10.0000 loss:1.6151
# Episode:114 meanR:9.3800 R:9.0000 loss:1.6180
# Episode:115 meanR:9.4000 R:10.0000 loss:1.6205
# Episode:116 meanR:9.3900 R:8.0000 loss:1.6276
# Episode:117 meanR:9.3800 R:9.0000 loss:1.6356
# Episode:118 meanR:9.3800 R:10.0000 loss:1.6411
# Episode:119 meanR:9.3800 R:9.0000 loss:1.6436
# Episode:120 meanR:9.3800 R:10.0000 loss:1.6430
# Episode:121 meanR:9.3800 R:10.0000 loss:1.6419
# Episode:122 meanR:9.3700 R:8.0000 loss:1.6449
# Episode:123 meanR:9.3800 R:11.0000 loss:1.6473
# Episode:124 meanR:9.3800 R:9.0000 loss:1.6506
# Episode:125 meanR:9.3700 R:9.0000 loss:1.6556
# Episode:126 meanR:9.3600 R:10.0000 loss:1.6613
# Episode:127 meanR:9.3800 R:10.0000 loss:1.6598
# Episode:128 meanR:9.3800 R:10.0000 loss:1.6649
# Episode:129 meanR:9.3900 R:10.0000 loss:1.6687
# Episode:130 meanR:9.3900 R:10.0000 loss:1.6710
# Episode:131 meanR:9.4100 R:10.0000 loss:1.6735
# Episode:132 meanR:9.4200 R:9.0000 loss:1.6767
# Episode:133 meanR:9.4100 R:9.0000 loss:1.6824
# Episode:134 meanR:9.4200 R:9.0000 loss:1.6872
# Episode:135 meanR:9.4000 R:8.0000 loss:1.6994
# Episode:136 meanR:9.4100 R:10.0000 loss:1.6996
# Episode:137 meanR:9.4000 R:9.0000 loss:1.6973
# Episode:138 meanR:9.4100 R:10.0000 loss:1.7032
# Episode:139 meanR:9.4000 R:9.0000 loss:1.7060
# Episode:140 meanR:9.3800 R:8.0000 loss:1.7185
# Episode:141 meanR:9.3800 R:10.0000 loss:1.7198
# Episode:142 meanR:9.3900 R:10.0000 loss:1.7246
# Episode:143 meanR:9.3800 R:9.0000 loss:1.7237
# Episode:144 meanR:9.3800 R:10.0000 loss:1.7351
# Episode:145 meanR:9.3800 R:10.0000 loss:1.7328
# Episode:146 meanR:9.3800 R:9.0000 loss:1.7387
# Episode:147 meanR:9.3800 R:9.0000 loss:1.7484
# Episode:148 meanR:9.3600 R:9.0000 loss:1.7523
# Episode:149 meanR:9.3500 R:9.0000 loss:1.7600
# Episode:150 meanR:9.3400 R:10.0000 loss:1.7663
# Episode:151 meanR:9.3500 R:9.0000 loss:1.7726
# Episode:152 meanR:9.3700 R:10.0000 loss:1.7784
# Episode:153 meanR:9.3700 R:10.0000 loss:1.7823
# Episode:154 meanR:9.3800 R:10.0000 loss:1.7829
# Episode:155 meanR:9.3800 R:10.0000 loss:1.7840
# Episode:156 meanR:9.3800 R:10.0000 loss:1.7800
# Episode:157 meanR:9.3800 R:9.0000 loss:1.7853
# Episode:158 meanR:9.3900 R:9.0000 loss:1.7919
# Episode:159 meanR:9.3900 R:10.0000 loss:1.7965
# Episode:160 meanR:9.4100 R:10.0000 loss:1.7984
# Episode:161 meanR:9.4200 R:10.0000 loss:1.7961
# Episode:162 meanR:9.4300 R:10.0000 loss:1.7983
# Episode:163 meanR:9.4200 R:9.0000 loss:1.8040
# Episode:164 meanR:9.4000 R:8.0000 loss:1.8109
# Episode:165 meanR:9.4200 R:10.0000 loss:1.8184
# Episode:166 meanR:9.4200 R:10.0000 loss:1.8233
# Episode:167 meanR:9.4400 R:10.0000 loss:1.8254
# Episode:168 meanR:9.4500 R:9.0000 loss:1.8276
# Episode:169 meanR:9.4400 R:9.0000 loss:1.8321
# Episode:170 meanR:9.4300 R:10.0000 loss:1.8350
# Episode:171 meanR:9.4100 R:8.0000 loss:1.8417
# Episode:172 meanR:9.4300 R:11.0000 loss:1.8464
# Episode:173 meanR:9.4400 R:10.0000 loss:1.8479
# Episode:174 meanR:9.4400 R:10.0000 loss:1.8526
# Episode:175 meanR:9.4300 R:9.0000 loss:1.8599
# Episode:176 meanR:9.4200 R:8.0000 loss:1.8690
# Episode:177 meanR:9.4300 R:11.0000 loss:1.8776
# Episode:178 meanR:9.4300 R:10.0000 loss:1.8769
# Episode:179 meanR:9.4300 R:9.0000 loss:1.8792
# Episode:180 meanR:9.4300 R:9.0000 loss:1.8867
# Episode:181 meanR:9.4100 R:9.0000 loss:1.8954
# Episode:182 meanR:9.4200 R:10.0000 loss:1.9033
# Episode:183 meanR:9.4300 R:10.0000 loss:1.9083
# Episode:184 meanR:9.4200 R:10.0000 loss:1.9108
# Episode:185 meanR:9.4300 R:10.0000 loss:1.9079
# Episode:186 meanR:9.4500 R:10.0000 loss:1.9105
# Episode:187 meanR:9.4400 R:8.0000 loss:1.9194
# Episode:188 meanR:9.4400 R:10.0000 loss:1.9281
# Episode:189 meanR:9.4300 R:9.0000 loss:1.9325
# Episode:190 meanR:9.4300 R:9.0000 loss:1.9375
# Episode:191 meanR:9.4400 R:11.0000 loss:1.9407
# Episode:192 meanR:9.4500 R:10.0000 loss:1.9377
# Episode:193 meanR:9.4600 R:9.0000 loss:1.9473
# Episode:194 meanR:9.4400 R:8.0000 loss:1.9581
# Episode:195 meanR:9.4400 R:10.0000 loss:1.9683
# Episode:196 meanR:9.4400 R:10.0000 loss:1.9707
# Episode:197 meanR:9.4400 R:9.0000 loss:1.9701
# Episode:198 meanR:9.4500 R:9.0000 loss:1.9781
# Episode:199 meanR:9.4700 R:10.0000 loss:1.9875
# Episode:200 meanR:9.4700 R:9.0000 loss:1.9925
# Episode:201 meanR:9.4800 R:9.0000 loss:1.9974
# Episode:202 meanR:9.4700 R:9.0000 loss:2.0026
# Episode:203 meanR:9.4600 R:8.0000 loss:2.0151
# Episode:204 meanR:9.4500 R:9.0000 loss:2.0241
# Episode:205 meanR:9.4500 R:10.0000 loss:2.0318
# Episode:206 meanR:9.4700 R:10.0000 loss:2.0368
# Episode:207 meanR:9.4700 R:10.0000 loss:2.0415
# Episode:208 meanR:9.4700 R:9.0000 loss:2.0470
# Episode:209 meanR:9.4700 R:10.0000 loss:2.0462
# Episode:210 meanR:9.4700 R:9.0000 loss:2.0532
# Episode:211 meanR:9.4700 R:10.0000 loss:2.0558
# Episode:212 meanR:9.4800 R:10.0000 loss:2.0587
# Episode:213 meanR:9.4700 R:9.0000 loss:2.0704
# Episode:214 meanR:9.4800 R:10.0000 loss:2.0759
# Episode:215 meanR:9.4900 R:11.0000 loss:2.0682
# Episode:216 meanR:9.5100 R:10.0000 loss:2.0681
# Episode:217 meanR:9.5100 R:9.0000 loss:2.0752
# Episode:218 meanR:9.5000 R:9.0000 loss:2.0831
# Episode:219 meanR:9.4900 R:8.0000 loss:2.0938
# Episode:220 meanR:9.4800 R:9.0000 loss:2.0999
# Episode:221 meanR:9.4700 R:9.0000 loss:2.1099
# Episode:222 meanR:9.4800 R:9.0000 loss:2.1145
# Episode:223 meanR:9.4500 R:8.0000 loss:2.1221
# Episode:224 meanR:9.4400 R:8.0000 loss:2.1313
# Episode:225 meanR:9.4500 R:10.0000 loss:2.1305
# Episode:226 meanR:9.4400 R:9.0000 loss:2.1354
# Episode:227 meanR:9.4400 R:10.0000 loss:2.1441
# Episode:228 meanR:9.4400 R:10.0000 loss:2.1495
# Episode:229 meanR:9.4300 R:9.0000 loss:2.1566
# Episode:230 meanR:9.4100 R:8.0000 loss:2.1659
# Episode:231 meanR:9.4000 R:9.0000 loss:2.1790
# Episode:232 meanR:9.4000 R:9.0000 loss:2.1847
# Episode:233 meanR:9.4200 R:11.0000 loss:2.1882
# Episode:234 meanR:9.4300 R:10.0000 loss:2.1914
# Episode:235 meanR:9.4300 R:8.0000 loss:2.1987
# Episode:236 meanR:9.4300 R:10.0000 loss:2.2083
# Episode:237 meanR:9.4300 R:9.0000 loss:2.2221
# Episode:238 meanR:9.4300 R:10.0000 loss:2.2298
# Episode:239 meanR:9.4400 R:10.0000 loss:2.2304
# Episode:240 meanR:9.4400 R:8.0000 loss:2.2360
# Episode:241 meanR:9.4400 R:10.0000 loss:2.2340
# Episode:242 meanR:9.4400 R:10.0000 loss:2.2331
# Episode:243 meanR:9.4500 R:10.0000 loss:2.2318
# Episode:244 meanR:9.4300 R:8.0000 loss:2.2366
# Episode:245 meanR:9.4200 R:9.0000 loss:2.2367
# Episode:246 meanR:9.4400 R:11.0000 loss:2.2336
# Episode:247 meanR:9.4300 R:8.0000 loss:2.2412
# Episode:248 meanR:9.4400 R:10.0000 loss:2.2475
# Episode:249 meanR:9.4400 R:9.0000 loss:2.2559
# Episode:250 meanR:9.4300 R:9.0000 loss:2.2666
# Episode:251 meanR:9.4400 R:10.0000 loss:2.2664
# Episode:252 meanR:9.4300 R:9.0000 loss:2.2635
# Episode:253 meanR:9.4100 R:8.0000 loss:2.2715
# Episode:254 meanR:9.4100 R:10.0000 loss:2.2798
# Episode:255 meanR:9.4100 R:10.0000 loss:2.2918
# Episode:256 meanR:9.4000 R:9.0000 loss:2.2974
# Episode:257 meanR:9.4000 R:9.0000 loss:2.2984
# Episode:258 meanR:9.4000 R:9.0000 loss:2.3104
# Episode:259 meanR:9.4000 R:10.0000 loss:2.3128
# Episode:260 meanR:9.3900 R:9.0000 loss:2.3225
# Episode:261 meanR:9.3900 R:10.0000 loss:2.3277
# Episode:262 meanR:9.3800 R:9.0000 loss:2.3264
# Episode:263 meanR:9.3900 R:10.0000 loss:2.3354
# Episode:264 meanR:9.3900 R:8.0000 loss:2.3493
# Episode:265 meanR:9.4000 R:11.0000 loss:2.3522
# Episode:266 meanR:9.3900 R:9.0000 loss:2.3468
# Episode:267 meanR:9.3700 R:8.0000 loss:2.3585
# Episode:268 meanR:9.3700 R:9.0000 loss:2.3784
# Episode:269 meanR:9.3700 R:9.0000 loss:2.3782
# Episode:270 meanR:9.3600 R:9.0000 loss:2.3901
# Episode:271 meanR:9.3800 R:10.0000 loss:2.3910
# Episode:272 meanR:9.3600 R:9.0000 loss:2.3951
# Episode:273 meanR:9.3600 R:10.0000 loss:2.4022
# Episode:274 meanR:9.3600 R:10.0000 loss:2.3996
# Episode:275 meanR:9.3600 R:9.0000 loss:2.3979
# Episode:276 meanR:9.3700 R:9.0000 loss:2.4116
# Episode:277 meanR:9.3600 R:10.0000 loss:2.4183
# Episode:278 meanR:9.3500 R:9.0000 loss:2.4210
# Episode:279 meanR:9.3700 R:11.0000 loss:2.4198
# Episode:280 meanR:9.3800 R:10.0000 loss:2.4167
# Episode:281 meanR:9.3900 R:10.0000 loss:2.4193
# Episode:282 meanR:9.3900 R:10.0000 loss:2.4228
# Episode:283 meanR:9.3900 R:10.0000 loss:2.4244
# Episode:284 meanR:9.3800 R:9.0000 loss:2.4301
# Episode:285 meanR:9.3800 R:10.0000 loss:2.4312
# Episode:286 meanR:9.3600 R:8.0000 loss:2.4435
# Episode:287 meanR:9.3800 R:10.0000 loss:2.4540
# Episode:288 meanR:9.3800 R:10.0000 loss:2.4470
# Episode:289 meanR:9.3800 R:9.0000 loss:2.4470
# Episode:290 meanR:9.4000 R:11.0000 loss:2.4426
# Episode:291 meanR:9.3900 R:10.0000 loss:2.4392
# Episode:292 meanR:9.3900 R:10.0000 loss:2.4447
# Episode:293 meanR:9.4000 R:10.0000 loss:2.4441
# Episode:294 meanR:9.4100 R:9.0000 loss:2.4551
# Episode:295 meanR:9.4100 R:10.0000 loss:2.4625
# Episode:296 meanR:9.4100 R:10.0000 loss:2.4611
# Episode:297 meanR:9.4100 R:9.0000 loss:2.4646
# Episode:298 meanR:9.4000 R:8.0000 loss:2.4839
# Episode:299 meanR:9.4000 R:10.0000 loss:2.4874
# Episode:300 meanR:9.4000 R:9.0000 loss:2.5059
# Episode:301 meanR:9.4000 R:9.0000 loss:2.5194
# Episode:302 meanR:9.4000 R:9.0000 loss:2.5319
# Episode:303 meanR:9.4200 R:10.0000 loss:2.5405
# Episode:304 meanR:9.4100 R:8.0000 loss:2.5546
# Episode:305 meanR:9.4100 R:10.0000 loss:2.5635
# Episode:306 meanR:9.4000 R:9.0000 loss:2.5702
# Episode:307 meanR:9.3800 R:8.0000 loss:2.5817
# Episode:308 meanR:9.3900 R:10.0000 loss:2.5836
# Episode:309 meanR:9.3800 R:9.0000 loss:2.5938
# Episode:310 meanR:9.3900 R:10.0000 loss:2.6031
# Episode:311 meanR:9.3900 R:10.0000 loss:2.6041
# Episode:312 meanR:9.3700 R:8.0000 loss:2.6257
# Episode:313 meanR:9.3700 R:9.0000 loss:2.6432
# Episode:314 meanR:9.3500 R:8.0000 loss:2.6635
# Episode:315 meanR:9.3300 R:9.0000 loss:2.6779
# Episode:316 meanR:9.3300 R:10.0000 loss:2.6803
# Episode:317 meanR:9.3400 R:10.0000 loss:2.6853
# Episode:318 meanR:9.3400 R:9.0000 loss:2.6962
# Episode:319 meanR:9.3500 R:9.0000 loss:2.7024
# Episode:320 meanR:9.3600 R:10.0000 loss:2.6949
# Episode:321 meanR:9.3600 R:9.0000 loss:2.7063
# Episode:322 meanR:9.3600 R:9.0000 loss:2.7122
# Episode:323 meanR:9.3700 R:9.0000 loss:2.7180
# Episode:324 meanR:9.3700 R:8.0000 loss:2.7302
# Episode:325 meanR:9.3700 R:10.0000 loss:2.7382
# Episode:326 meanR:9.3700 R:9.0000 loss:2.7365
# Episode:327 meanR:9.3600 R:9.0000 loss:2.7490
# Episode:328 meanR:9.3600 R:10.0000 loss:2.7495
# Episode:329 meanR:9.3600 R:9.0000 loss:2.7444
# Episode:330 meanR:9.3800 R:10.0000 loss:2.7523
# Episode:331 meanR:9.3900 R:10.0000 loss:2.7511
# Episode:332 meanR:9.3900 R:9.0000 loss:2.7631
# Episode:333 meanR:9.3800 R:10.0000 loss:2.7696
# Episode:334 meanR:9.3700 R:9.0000 loss:2.7650
# Episode:335 meanR:9.3900 R:10.0000 loss:2.7636
# Episode:336 meanR:9.3900 R:10.0000 loss:2.7540
# Episode:337 meanR:9.4000 R:10.0000 loss:2.7540
# Episode:338 meanR:9.4000 R:10.0000 loss:2.7604
# Episode:339 meanR:9.3900 R:9.0000 loss:2.7682
# Episode:340 meanR:9.4200 R:11.0000 loss:2.7650
# Episode:341 meanR:9.4100 R:9.0000 loss:2.7667
# Episode:342 meanR:9.3900 R:8.0000 loss:2.7831
# Episode:343 meanR:9.3800 R:9.0000 loss:2.7922
# Episode:344 meanR:9.4000 R:10.0000 loss:2.7936
# Episode:345 meanR:9.4000 R:9.0000 loss:2.7896
# Episode:346 meanR:9.3900 R:10.0000 loss:2.7921
# Episode:347 meanR:9.3900 R:8.0000 loss:2.8042
# Episode:348 meanR:9.3700 R:8.0000 loss:2.8185
# Episode:349 meanR:9.3600 R:8.0000 loss:2.8335
# Episode:350 meanR:9.3700 R:10.0000 loss:2.8497
# Episode:351 meanR:9.3600 R:9.0000 loss:2.8514
# Episode:352 meanR:9.3700 R:10.0000 loss:2.8629
# Episode:353 meanR:9.3900 R:10.0000 loss:2.8683
# Episode:354 meanR:9.3700 R:8.0000 loss:2.8759
# Episode:355 meanR:9.3700 R:10.0000 loss:2.8895
# Episode:356 meanR:9.3800 R:10.0000 loss:2.8876
# Episode:357 meanR:9.3800 R:9.0000 loss:2.9002
# Episode:358 meanR:9.3900 R:10.0000 loss:2.9101
# Episode:359 meanR:9.3800 R:9.0000 loss:2.9226
# Episode:360 meanR:9.3900 R:10.0000 loss:2.9316
# Episode:361 meanR:9.3800 R:9.0000 loss:2.9357
# Episode:362 meanR:9.4000 R:11.0000 loss:2.9474
# Episode:363 meanR:9.3900 R:9.0000 loss:2.9472
# Episode:364 meanR:9.3900 R:8.0000 loss:2.9499
# Episode:365 meanR:9.3900 R:11.0000 loss:2.9493
# Episode:366 meanR:9.3900 R:9.0000 loss:2.9573
# Episode:367 meanR:9.4000 R:9.0000 loss:2.9640
# Episode:368 meanR:9.4100 R:10.0000 loss:2.9721
# Episode:369 meanR:9.4200 R:10.0000 loss:2.9567
# Episode:370 meanR:9.4300 R:10.0000 loss:2.9377
# Episode:371 meanR:9.4200 R:9.0000 loss:2.9440
# Episode:372 meanR:9.4300 R:10.0000 loss:2.9462
# Episode:373 meanR:9.4400 R:11.0000 loss:2.9435
# Episode:374 meanR:9.4300 R:9.0000 loss:2.9553
# Episode:375 meanR:9.4200 R:8.0000 loss:2.9620
# Episode:376 meanR:9.4200 R:9.0000 loss:2.9764
# Episode:377 meanR:9.4200 R:10.0000 loss:2.9859
# Episode:378 meanR:9.4200 R:9.0000 loss:2.9930
# Episode:379 meanR:9.4000 R:9.0000 loss:3.0040
# Episode:380 meanR:9.3900 R:9.0000 loss:3.0165
# Episode:381 meanR:9.3900 R:10.0000 loss:3.0216
# Episode:382 meanR:9.3800 R:9.0000 loss:3.0299
# Episode:383 meanR:9.3800 R:10.0000 loss:3.0366
# Episode:384 meanR:9.3700 R:8.0000 loss:3.0594
# Episode:385 meanR:9.3500 R:8.0000 loss:3.0751
# Episode:386 meanR:9.3600 R:9.0000 loss:3.0770
# Episode:387 meanR:9.3600 R:10.0000 loss:3.0983
# Episode:388 meanR:9.3400 R:8.0000 loss:3.1065
# Episode:389 meanR:9.3400 R:9.0000 loss:3.1187
# Episode:390 meanR:9.3200 R:9.0000 loss:3.1355
# Episode:391 meanR:9.3200 R:10.0000 loss:3.1445
# Episode:392 meanR:9.3000 R:8.0000 loss:3.1677
# Episode:393 meanR:9.3000 R:10.0000 loss:3.1682
# Episode:394 meanR:9.3100 R:10.0000 loss:3.1738
# Episode:395 meanR:9.3000 R:9.0000 loss:3.1960
# Episode:396 meanR:9.2800 R:8.0000 loss:3.2146
# Episode:397 meanR:9.2800 R:9.0000 loss:3.2184
# Episode:398 meanR:9.3000 R:10.0000 loss:3.2113
# Episode:399 meanR:9.3000 R:10.0000 loss:3.2149
# Episode:400 meanR:9.3000 R:9.0000 loss:3.2214
# Episode:401 meanR:9.3000 R:9.0000 loss:3.2277
# Episode:402 meanR:9.3100 R:10.0000 loss:3.2257
# Episode:403 meanR:9.3100 R:10.0000 loss:3.2313
# Episode:404 meanR:9.3300 R:10.0000 loss:3.2283
# Episode:405 meanR:9.3300 R:10.0000 loss:3.2334
# Episode:406 meanR:9.3300 R:9.0000 loss:3.2254
# Episode:407 meanR:9.3300 R:8.0000 loss:3.2261
# Episode:408 meanR:9.3300 R:10.0000 loss:3.2309
# Episode:409 meanR:9.3200 R:8.0000 loss:3.2531
# Episode:410 meanR:9.3200 R:10.0000 loss:3.2432
# Episode:411 meanR:9.3000 R:8.0000 loss:3.2527
# Episode:412 meanR:9.3200 R:10.0000 loss:3.2567
# Episode:413 meanR:9.3300 R:10.0000 loss:3.2622
# Episode:414 meanR:9.3600 R:11.0000 loss:3.2444
# Episode:415 meanR:9.3600 R:9.0000 loss:3.2500
# Episode:416 meanR:9.3400 R:8.0000 loss:3.2741
# Episode:417 meanR:9.3400 R:10.0000 loss:3.2786
# Episode:418 meanR:9.3400 R:9.0000 loss:3.2683
# Episode:419 meanR:9.3400 R:9.0000 loss:3.2753
# Episode:420 meanR:9.3200 R:8.0000 loss:3.2995
# Episode:421 meanR:9.3200 R:9.0000 loss:3.3240
# Episode:422 meanR:9.3200 R:9.0000 loss:3.3305
# Episode:423 meanR:9.3300 R:10.0000 loss:3.3303
# Episode:424 meanR:9.3300 R:8.0000 loss:3.3525
# Episode:425 meanR:9.3300 R:10.0000 loss:3.3659
# Episode:426 meanR:9.3300 R:9.0000 loss:3.3818
# Episode:427 meanR:9.3400 R:10.0000 loss:3.3903
# Episode:428 meanR:9.3400 R:10.0000 loss:3.3859
# Episode:429 meanR:9.3500 R:10.0000 loss:3.3702
# Episode:430 meanR:9.3300 R:8.0000 loss:3.3919
# Episode:431 meanR:9.3300 R:10.0000 loss:3.3839
# Episode:432 meanR:9.3300 R:9.0000 loss:3.3966
# Episode:433 meanR:9.3300 R:10.0000 loss:3.3847
# Episode:434 meanR:9.3300 R:9.0000 loss:3.3985
# Episode:435 meanR:9.3300 R:10.0000 loss:3.4105
# Episode:436 meanR:9.3100 R:8.0000 loss:3.4470
# Episode:437 meanR:9.3000 R:9.0000 loss:3.4559
# Episode:438 meanR:9.2900 R:9.0000 loss:3.4499
# Episode:439 meanR:9.2900 R:9.0000 loss:3.4678
# Episode:440 meanR:9.2600 R:8.0000 loss:3.4858
# Episode:441 meanR:9.2600 R:9.0000 loss:3.4942
# Episode:442 meanR:9.2700 R:9.0000 loss:3.4888
# Episode:443 meanR:9.2700 R:9.0000 loss:3.4940
# Episode:444 meanR:9.2600 R:9.0000 loss:3.5004
# Episode:445 meanR:9.2600 R:9.0000 loss:3.5183
# Episode:446 meanR:9.2400 R:8.0000 loss:3.5260
# Episode:447 meanR:9.2600 R:10.0000 loss:3.5334
# Episode:448 meanR:9.2800 R:10.0000 loss:3.5302
# Episode:449 meanR:9.2900 R:9.0000 loss:3.5441
# Episode:450 meanR:9.2900 R:10.0000 loss:3.5533
# Episode:451 meanR:9.2900 R:9.0000 loss:3.5698
# Episode:452 meanR:9.2900 R:10.0000 loss:3.5598
# Episode:453 meanR:9.2800 R:9.0000 loss:3.5720
# Episode:454 meanR:9.2900 R:9.0000 loss:3.5800
# Episode:455 meanR:9.2800 R:9.0000 loss:3.5962
# Episode:456 meanR:9.2800 R:10.0000 loss:3.5977
# Episode:457 meanR:9.2800 R:9.0000 loss:3.6104
# Episode:458 meanR:9.2800 R:10.0000 loss:3.6004
# Episode:459 meanR:9.2800 R:9.0000 loss:3.6000
# Episode:460 meanR:9.2700 R:9.0000 loss:3.6071
# Episode:461 meanR:9.2700 R:9.0000 loss:3.6131
# Episode:462 meanR:9.2500 R:9.0000 loss:3.6062
# Episode:463 meanR:9.2500 R:9.0000 loss:3.6125
# Episode:464 meanR:9.2600 R:9.0000 loss:3.6194
# Episode:465 meanR:9.2400 R:9.0000 loss:3.6260
# Episode:466 meanR:9.2500 R:10.0000 loss:3.6236
# Episode:467 meanR:9.2600 R:10.0000 loss:3.6176
# Episode:468 meanR:9.2600 R:10.0000 loss:3.5995
# Episode:469 meanR:9.2600 R:10.0000 loss:3.6068
# Episode:470 meanR:9.2500 R:9.0000 loss:3.6205
# Episode:471 meanR:9.2500 R:9.0000 loss:3.6268
# Episode:472 meanR:9.2500 R:10.0000 loss:3.6417
# Episode:473 meanR:9.2200 R:8.0000 loss:3.6472
# Episode:474 meanR:9.2300 R:10.0000 loss:3.6670
# Episode:475 meanR:9.2300 R:8.0000 loss:3.6777
# Episode:476 meanR:9.2300 R:9.0000 loss:3.6897
# Episode:477 meanR:9.2100 R:8.0000 loss:3.7064
# Episode:478 meanR:9.2200 R:10.0000 loss:3.7200
# Episode:479 meanR:9.2200 R:9.0000 loss:3.7230
# Episode:480 meanR:9.2300 R:10.0000 loss:3.7335
# Episode:481 meanR:9.2200 R:9.0000 loss:3.7380
# Episode:482 meanR:9.2300 R:10.0000 loss:3.7351
# Episode:483 meanR:9.2300 R:10.0000 loss:3.7295
# Episode:484 meanR:9.2500 R:10.0000 loss:3.7228
# Episode:485 meanR:9.2700 R:10.0000 loss:3.7179
# Episode:486 meanR:9.2800 R:10.0000 loss:3.7115
# Episode:487 meanR:9.2800 R:10.0000 loss:3.7065
# Episode:488 meanR:9.2800 R:8.0000 loss:3.7213
# Episode:489 meanR:9.2800 R:9.0000 loss:3.7520
# Episode:490 meanR:9.2900 R:10.0000 loss:3.7667
# Episode:491 meanR:9.2900 R:10.0000 loss:3.7744
# Episode:492 meanR:9.2900 R:8.0000 loss:3.7818
# Episode:493 meanR:9.2800 R:9.0000 loss:3.7953
# Episode:494 meanR:9.2700 R:9.0000 loss:3.8161
# Episode:495 meanR:9.2800 R:10.0000 loss:3.8018
# Episode:496 meanR:9.2900 R:9.0000 loss:3.8163
# Episode:497 meanR:9.2900 R:9.0000 loss:3.8085
# Episode:498 meanR:9.2800 R:9.0000 loss:3.8144
# Episode:499 meanR:9.2700 R:9.0000 loss:3.8068
# Episode:500 meanR:9.2700 R:9.0000 loss:3.8304
# Episode:501 meanR:9.2700 R:9.0000 loss:3.8370
# Episode:502 meanR:9.2700 R:10.0000 loss:3.8504
# Episode:503 meanR:9.2700 R:10.0000 loss:3.8458
# Episode:504 meanR:9.2700 R:10.0000 loss:3.8514
# Episode:505 meanR:9.2700 R:10.0000 loss:3.8607
# Episode:506 meanR:9.2700 R:9.0000 loss:3.8740
# Episode:507 meanR:9.3000 R:11.0000 loss:3.8818
# Episode:508 meanR:9.3000 R:10.0000 loss:3.8828
# Episode:509 meanR:9.3000 R:8.0000 loss:3.9036
# Episode:510 meanR:9.2900 R:9.0000 loss:3.9012
# Episode:511 meanR:9.3100 R:10.0000 loss:3.9036
# Episode:512 meanR:9.3000 R:9.0000 loss:3.9167
# Episode:513 meanR:9.2900 R:9.0000 loss:3.9392
# Episode:514 meanR:9.2800 R:10.0000 loss:3.9244
# Episode:515 meanR:9.2800 R:9.0000 loss:3.9218
# Episode:516 meanR:9.2900 R:9.0000 loss:3.9290
# Episode:517 meanR:9.2900 R:10.0000 loss:3.9470
# Episode:518 meanR:9.2900 R:9.0000 loss:3.9436
# Episode:519 meanR:9.3000 R:10.0000 loss:3.9461
# Episode:520 meanR:9.3200 R:10.0000 loss:3.9323
# Episode:521 meanR:9.3200 R:9.0000 loss:3.9332
# Episode:522 meanR:9.3200 R:9.0000 loss:3.9409
# Episode:523 meanR:9.3000 R:8.0000 loss:3.9597
# Episode:524 meanR:9.3200 R:10.0000 loss:3.9819
# Episode:525 meanR:9.3200 R:10.0000 loss:3.9910
# Episode:526 meanR:9.3100 R:8.0000 loss:4.0082
# Episode:527 meanR:9.3000 R:9.0000 loss:4.0406
# Episode:528 meanR:9.2900 R:9.0000 loss:4.0496
# Episode:529 meanR:9.2900 R:10.0000 loss:4.0768
# Episode:530 meanR:9.3200 R:11.0000 loss:4.0754
# Episode:531 meanR:9.3100 R:9.0000 loss:4.0542
# Episode:532 meanR:9.3200 R:10.0000 loss:4.0547
# Episode:533 meanR:9.3000 R:8.0000 loss:4.0770
# Episode:534 meanR:9.3000 R:9.0000 loss:4.0917
# Episode:535 meanR:9.2900 R:9.0000 loss:4.0985
# Episode:536 meanR:9.3000 R:9.0000 loss:4.1224
# Episode:537 meanR:9.3100 R:10.0000 loss:4.1198
# Episode:538 meanR:9.3200 R:10.0000 loss:4.1125
# Episode:539 meanR:9.3100 R:8.0000 loss:4.1372
# Episode:540 meanR:9.3200 R:9.0000 loss:4.1508
# Episode:541 meanR:9.3200 R:9.0000 loss:4.1738
# Episode:542 meanR:9.3100 R:8.0000 loss:4.2108
# Episode:543 meanR:9.3100 R:9.0000 loss:4.2207
# Episode:544 meanR:9.3200 R:10.0000 loss:4.2147
# Episode:545 meanR:9.3300 R:10.0000 loss:4.1903
# Episode:546 meanR:9.3500 R:10.0000 loss:4.1974
# Episode:547 meanR:9.3500 R:10.0000 loss:4.2055
# Episode:548 meanR:9.3500 R:10.0000 loss:4.1829
# Episode:549 meanR:9.3600 R:10.0000 loss:4.1748
# Episode:550 meanR:9.3400 R:8.0000 loss:4.1765
# Episode:551 meanR:9.3500 R:10.0000 loss:4.2037
# Episode:552 meanR:9.3400 R:9.0000 loss:4.2363
# Episode:553 meanR:9.3300 R:8.0000 loss:4.2563
# Episode:554 meanR:9.3400 R:10.0000 loss:4.2717
# Episode:555 meanR:9.3400 R:9.0000 loss:4.2566
# Episode:556 meanR:9.3400 R:10.0000 loss:4.2536
# Episode:557 meanR:9.3500 R:10.0000 loss:4.2467
# Episode:558 meanR:9.3500 R:10.0000 loss:4.2372
# Episode:559 meanR:9.3500 R:9.0000 loss:4.2526
# Episode:560 meanR:9.3400 R:8.0000 loss:4.2881
# Episode:561 meanR:9.3400 R:9.0000 loss:4.2823
# Episode:562 meanR:9.3500 R:10.0000 loss:4.2826
# Episode:563 meanR:9.3500 R:9.0000 loss:4.2795
# Episode:564 meanR:9.3500 R:9.0000 loss:4.2688
# Episode:565 meanR:9.3400 R:8.0000 loss:4.2843
# Episode:566 meanR:9.3500 R:11.0000 loss:4.3049
# Episode:567 meanR:9.3400 R:9.0000 loss:4.3086
# Episode:568 meanR:9.3200 R:8.0000 loss:4.3446
# Episode:569 meanR:9.3100 R:9.0000 loss:4.3757
# Episode:570 meanR:9.3100 R:9.0000 loss:4.4001
# Episode:571 meanR:9.3100 R:9.0000 loss:4.4241
# Episode:572 meanR:9.3100 R:10.0000 loss:4.4027
# Episode:573 meanR:9.3200 R:9.0000 loss:4.4223
# Episode:574 meanR:9.3200 R:10.0000 loss:4.4154
# Episode:575 meanR:9.3300 R:9.0000 loss:4.3993
# Episode:576 meanR:9.3400 R:10.0000 loss:4.4139
# Episode:577 meanR:9.3600 R:10.0000 loss:4.4050
# Episode:578 meanR:9.3600 R:10.0000 loss:4.4121
# Episode:579 meanR:9.3700 R:10.0000 loss:4.4209
# Episode:580 meanR:9.3800 R:11.0000 loss:4.4200
# Episode:581 meanR:9.3900 R:10.0000 loss:4.4033
# Episode:582 meanR:9.3800 R:9.0000 loss:4.3798
# Episode:583 meanR:9.3600 R:8.0000 loss:4.3926
# Episode:584 meanR:9.3600 R:10.0000 loss:4.4251
# Episode:585 meanR:9.3600 R:10.0000 loss:4.4164
# Episode:586 meanR:9.3500 R:9.0000 loss:4.4015
# Episode:587 meanR:9.3500 R:10.0000 loss:4.4072
# Episode:588 meanR:9.3600 R:9.0000 loss:4.4247
# Episode:589 meanR:9.3700 R:10.0000 loss:4.4069
# Episode:590 meanR:9.3600 R:9.0000 loss:4.4041
# Episode:591 meanR:9.3600 R:10.0000 loss:4.3970
# Episode:592 meanR:9.3700 R:9.0000 loss:4.3996
# Episode:593 meanR:9.3700 R:9.0000 loss:4.4245
# Episode:594 meanR:9.3700 R:9.0000 loss:4.4330
# Episode:595 meanR:9.3600 R:9.0000 loss:4.4563
# Episode:596 meanR:9.3600 R:9.0000 loss:4.4681
# Episode:597 meanR:9.3700 R:10.0000 loss:4.4751
# Episode:598 meanR:9.3700 R:9.0000 loss:4.4941
# Episode:599 meanR:9.3700 R:9.0000 loss:4.5097
# Episode:600 meanR:9.3700 R:9.0000 loss:4.5374
# Episode:601 meanR:9.3700 R:9.0000 loss:4.5640
# Episode:602 meanR:9.3600 R:9.0000 loss:4.6086
# Episode:603 meanR:9.3500 R:9.0000 loss:4.6347
# Episode:604 meanR:9.3500 R:10.0000 loss:4.6284
# Episode:605 meanR:9.3400 R:9.0000 loss:4.6104
# Episode:606 meanR:9.3500 R:10.0000 loss:4.6248
# Episode:607 meanR:9.3300 R:9.0000 loss:4.6444
# Episode:608 meanR:9.3300 R:10.0000 loss:4.6399
# Episode:609 meanR:9.3500 R:10.0000 loss:4.6479
# Episode:610 meanR:9.3500 R:9.0000 loss:4.6463
# Episode:611 meanR:9.3400 R:9.0000 loss:4.6741
# Episode:612 meanR:9.3400 R:9.0000 loss:4.6799
# Episode:613 meanR:9.3300 R:8.0000 loss:4.7217
# Episode:614 meanR:9.3300 R:10.0000 loss:4.7176
# Episode:615 meanR:9.3300 R:9.0000 loss:4.7213
# Episode:616 meanR:9.3300 R:9.0000 loss:4.7268
# Episode:617 meanR:9.3300 R:10.0000 loss:4.7211
# Episode:618 meanR:9.3400 R:10.0000 loss:4.7107
# Episode:619 meanR:9.3300 R:9.0000 loss:4.7283
# Episode:620 meanR:9.3100 R:8.0000 loss:4.7488
# Episode:621 meanR:9.3100 R:9.0000 loss:4.7623
# Episode:622 meanR:9.3200 R:10.0000 loss:4.7545
# Episode:623 meanR:9.3200 R:8.0000 loss:4.7699
# Episode:624 meanR:9.3200 R:10.0000 loss:4.7695
# Episode:625 meanR:9.3100 R:9.0000 loss:4.7704
# Episode:626 meanR:9.3300 R:10.0000 loss:4.7841
# Episode:627 meanR:9.3200 R:8.0000 loss:4.7962
# Episode:628 meanR:9.3300 R:10.0000 loss:4.8155
# Episode:629 meanR:9.3300 R:10.0000 loss:4.8052
# Episode:630 meanR:9.3100 R:9.0000 loss:4.8257
# Episode:631 meanR:9.3200 R:10.0000 loss:4.8370
# Episode:632 meanR:9.3200 R:10.0000 loss:4.8265
# Episode:633 meanR:9.3300 R:9.0000 loss:4.8269
# Episode:634 meanR:9.3300 R:9.0000 loss:4.8332
# Episode:635 meanR:9.3300 R:9.0000 loss:4.8198
# Episode:636 meanR:9.3300 R:9.0000 loss:4.8492
# Episode:637 meanR:9.3200 R:9.0000 loss:4.8552
# Episode:638 meanR:9.3000 R:8.0000 loss:4.8765
# Episode:639 meanR:9.3100 R:9.0000 loss:4.9072
# Episode:640 meanR:9.3000 R:8.0000 loss:4.9519
# Episode:641 meanR:9.3000 R:9.0000 loss:4.9621
# Episode:642 meanR:9.3200 R:10.0000 loss:4.9340
# Episode:643 meanR:9.3300 R:10.0000 loss:4.9185
# Episode:644 meanR:9.3200 R:9.0000 loss:4.9417
# Episode:645 meanR:9.3200 R:10.0000 loss:4.9136
# Episode:646 meanR:9.3000 R:8.0000 loss:4.9525
# Episode:647 meanR:9.3000 R:10.0000 loss:4.9454
# Episode:648 meanR:9.2800 R:8.0000 loss:4.9878
# Episode:649 meanR:9.2900 R:11.0000 loss:4.9471
# Episode:650 meanR:9.3100 R:10.0000 loss:4.9479
# Episode:651 meanR:9.3200 R:11.0000 loss:4.9451
# Episode:652 meanR:9.3300 R:10.0000 loss:4.9269
# Episode:653 meanR:9.3500 R:10.0000 loss:4.9341
# Episode:654 meanR:9.3500 R:10.0000 loss:4.9418
# Episode:655 meanR:9.3500 R:9.0000 loss:4.9381
# Episode:656 meanR:9.3400 R:9.0000 loss:4.9453
# Episode:657 meanR:9.3300 R:9.0000 loss:4.9537
# Episode:658 meanR:9.3300 R:10.0000 loss:4.9524
# Episode:659 meanR:9.3400 R:10.0000 loss:4.9297
# Episode:660 meanR:9.3500 R:9.0000 loss:4.9113
# Episode:661 meanR:9.3600 R:10.0000 loss:4.8829
# Episode:662 meanR:9.3600 R:10.0000 loss:4.8692
# Episode:663 meanR:9.3600 R:9.0000 loss:4.8928
# Episode:664 meanR:9.3700 R:10.0000 loss:4.9050
# Episode:665 meanR:9.3900 R:10.0000 loss:4.8922
# Episode:666 meanR:9.3800 R:10.0000 loss:4.9010
# Episode:667 meanR:9.3700 R:8.0000 loss:4.8972
# Episode:668 meanR:9.3900 R:10.0000 loss:4.9163
# Episode:669 meanR:9.3800 R:8.0000 loss:4.9142
# Episode:670 meanR:9.3700 R:8.0000 loss:4.9875
# Episode:671 meanR:9.3700 R:9.0000 loss:5.0113
# Episode:672 meanR:9.3800 R:11.0000 loss:5.0234
# Episode:673 meanR:9.3900 R:10.0000 loss:5.0345
# Episode:674 meanR:9.3800 R:9.0000 loss:5.0454
# Episode:675 meanR:9.3800 R:9.0000 loss:5.0754
# Episode:676 meanR:9.3700 R:9.0000 loss:5.1036
# Episode:677 meanR:9.3700 R:10.0000 loss:5.1040
# Episode:678 meanR:9.3800 R:11.0000 loss:5.0754
# Episode:679 meanR:9.3700 R:9.0000 loss:5.0741
# Episode:680 meanR:9.3500 R:9.0000 loss:5.0905
# Episode:681 meanR:9.3500 R:10.0000 loss:5.1140
# Episode:682 meanR:9.3600 R:10.0000 loss:5.1014
# Episode:683 meanR:9.3800 R:10.0000 loss:5.1094
# Episode:684 meanR:9.3600 R:8.0000 loss:5.1257
# Episode:685 meanR:9.3600 R:10.0000 loss:5.1441
# Episode:686 meanR:9.3500 R:8.0000 loss:5.1660
# Episode:687 meanR:9.3500 R:10.0000 loss:5.2003
# Episode:688 meanR:9.3500 R:9.0000 loss:5.2172
# Episode:689 meanR:9.3400 R:9.0000 loss:5.2024
# Episode:690 meanR:9.3500 R:10.0000 loss:5.2200
# Episode:691 meanR:9.3400 R:9.0000 loss:5.1922
# Episode:692 meanR:9.3400 R:9.0000 loss:5.1787
# Episode:693 meanR:9.3500 R:10.0000 loss:5.1812
# Episode:694 meanR:9.3600 R:10.0000 loss:5.2092
# Episode:695 meanR:9.3800 R:11.0000 loss:5.2022
# Episode:696 meanR:9.3800 R:9.0000 loss:5.1862
# Episode:697 meanR:9.3700 R:9.0000 loss:5.1925
# Episode:698 meanR:9.3800 R:10.0000 loss:5.1990
# Episode:699 meanR:9.3900 R:10.0000 loss:5.2199
# Episode:700 meanR:9.4000 R:10.0000 loss:5.2253
# Episode:701 meanR:9.3900 R:8.0000 loss:5.2416
# Episode:702 meanR:9.4000 R:10.0000 loss:5.2509
# Episode:703 meanR:9.4000 R:9.0000 loss:5.2612
# Episode:704 meanR:9.4000 R:10.0000 loss:5.2869
# Episode:705 meanR:9.4100 R:10.0000 loss:5.2821
# Episode:706 meanR:9.4100 R:10.0000 loss:5.2610
# Episode:707 meanR:9.4000 R:8.0000 loss:5.2709
# Episode:708 meanR:9.3900 R:9.0000 loss:5.2902
# Episode:709 meanR:9.4000 R:11.0000 loss:5.2727
# Episode:710 meanR:9.4200 R:11.0000 loss:5.2328
# Episode:711 meanR:9.4200 R:9.0000 loss:5.2546
# Episode:712 meanR:9.4300 R:10.0000 loss:5.2449
# Episode:713 meanR:9.4500 R:10.0000 loss:5.2317
# Episode:714 meanR:9.4300 R:8.0000 loss:5.2724
# Episode:715 meanR:9.4400 R:10.0000 loss:5.2895
# Episode:716 meanR:9.4400 R:9.0000 loss:5.3379
# Episode:717 meanR:9.4200 R:8.0000 loss:5.3665
# Episode:718 meanR:9.4300 R:11.0000 loss:5.3430
# Episode:719 meanR:9.4400 R:10.0000 loss:5.3419
# Episode:720 meanR:9.4500 R:9.0000 loss:5.3690
# Episode:721 meanR:9.4600 R:10.0000 loss:5.3786
# Episode:722 meanR:9.4600 R:10.0000 loss:5.3465
# Episode:723 meanR:9.4800 R:10.0000 loss:5.3515
# Episode:724 meanR:9.4600 R:8.0000 loss:5.3762
# Episode:725 meanR:9.4700 R:10.0000 loss:5.3884
# Episode:726 meanR:9.4600 R:9.0000 loss:5.4153
# Episode:727 meanR:9.4600 R:8.0000 loss:5.4433
# Episode:728 meanR:9.4600 R:10.0000 loss:5.4619
# Episode:729 meanR:9.4500 R:9.0000 loss:5.4391
# Episode:730 meanR:9.4500 R:9.0000 loss:5.4611
# Episode:731 meanR:9.4500 R:10.0000 loss:5.4963
# Episode:732 meanR:9.4400 R:9.0000 loss:5.5341
# Episode:733 meanR:9.4500 R:10.0000 loss:5.5334
# Episode:734 meanR:9.4500 R:9.0000 loss:5.5464
# Episode:735 meanR:9.4500 R:9.0000 loss:5.5780
# Episode:736 meanR:9.4500 R:9.0000 loss:5.5604
# Episode:737 meanR:9.4500 R:9.0000 loss:5.5910
# Episode:738 meanR:9.4600 R:9.0000 loss:5.5965
# Episode:739 meanR:9.4600 R:9.0000 loss:5.5783
# Episode:740 meanR:9.4800 R:10.0000 loss:5.6204
# Episode:741 meanR:9.4700 R:8.0000 loss:5.6576
# Episode:742 meanR:9.4600 R:9.0000 loss:5.6703
# Episode:743 meanR:9.4600 R:10.0000 loss:5.6832
# Episode:744 meanR:9.4700 R:10.0000 loss:5.6890
# Episode:745 meanR:9.4600 R:9.0000 loss:5.7145
# Episode:746 meanR:9.4900 R:11.0000 loss:5.6653
# Episode:747 meanR:9.4900 R:10.0000 loss:5.6631
# Episode:748 meanR:9.5100 R:10.0000 loss:5.6484
# Episode:749 meanR:9.5000 R:10.0000 loss:5.6096
# Episode:750 meanR:9.5100 R:11.0000 loss:5.5989
# Episode:751 meanR:9.5000 R:10.0000 loss:5.5613
# Episode:752 meanR:9.4800 R:8.0000 loss:5.6053
# Episode:753 meanR:9.4800 R:10.0000 loss:5.6041
# Episode:754 meanR:9.4800 R:10.0000 loss:5.6017
# Episode:755 meanR:9.4800 R:9.0000 loss:5.6098
# Episode:756 meanR:9.4900 R:10.0000 loss:5.5959
# Episode:757 meanR:9.4900 R:9.0000 loss:5.6012
# Episode:758 meanR:9.4700 R:8.0000 loss:5.6311
# Episode:759 meanR:9.4600 R:9.0000 loss:5.6387
# Episode:760 meanR:9.4600 R:9.0000 loss:5.6450
# Episode:761 meanR:9.4400 R:8.0000 loss:5.6717
# Episode:762 meanR:9.4400 R:10.0000 loss:5.6887
# Episode:763 meanR:9.4400 R:9.0000 loss:5.6655
# Episode:764 meanR:9.4400 R:10.0000 loss:5.6720
# Episode:765 meanR:9.4300 R:9.0000 loss:5.6972
# Episode:766 meanR:9.4200 R:9.0000 loss:5.7139
# Episode:767 meanR:9.4300 R:9.0000 loss:5.7196
# Episode:768 meanR:9.4200 R:9.0000 loss:5.7772
# Episode:769 meanR:9.4300 R:9.0000 loss:5.8100
# Episode:770 meanR:9.4500 R:10.0000 loss:5.8273
# Episode:771 meanR:9.4600 R:10.0000 loss:5.8332
# Episode:772 meanR:9.4500 R:10.0000 loss:5.8632
# Episode:773 meanR:9.4500 R:10.0000 loss:5.8685
# Episode:774 meanR:9.4500 R:9.0000 loss:5.8405
# Episode:775 meanR:9.4500 R:9.0000 loss:5.8715
# Episode:776 meanR:9.4500 R:9.0000 loss:5.9034
# Episode:777 meanR:9.4500 R:10.0000 loss:5.8928
# Episode:778 meanR:9.4400 R:10.0000 loss:5.8994
# Episode:779 meanR:9.4500 R:10.0000 loss:5.8813
# Episode:780 meanR:9.4400 R:8.0000 loss:5.8600
# Episode:781 meanR:9.4300 R:9.0000 loss:5.8819
# Episode:782 meanR:9.4300 R:10.0000 loss:5.8751
# Episode:783 meanR:9.4200 R:9.0000 loss:5.8403
# Episode:784 meanR:9.4400 R:10.0000 loss:5.8641
# Episode:785 meanR:9.4300 R:9.0000 loss:5.8526
# Episode:786 meanR:9.4400 R:9.0000 loss:5.8876
# Episode:787 meanR:9.4300 R:9.0000 loss:5.8909
# Episode:788 meanR:9.4200 R:8.0000 loss:5.9089
# Episode:789 meanR:9.4200 R:9.0000 loss:5.9298
# Episode:790 meanR:9.4100 R:9.0000 loss:5.9343
# Episode:791 meanR:9.4100 R:9.0000 loss:5.9407
# Episode:792 meanR:9.4200 R:10.0000 loss:5.9596
# Episode:793 meanR:9.4200 R:10.0000 loss:5.9645
# Episode:794 meanR:9.4200 R:10.0000 loss:5.9719
# Episode:795 meanR:9.4100 R:10.0000 loss:5.9761
# Episode:796 meanR:9.4100 R:9.0000 loss:5.9704
# Episode:797 meanR:9.4200 R:10.0000 loss:5.9652
# Episode:798 meanR:9.4100 R:9.0000 loss:5.9571
# Episode:799 meanR:9.4100 R:10.0000 loss:5.9768
# Episode:800 meanR:9.4000 R:9.0000 loss:5.9954
# Episode:801 meanR:9.4200 R:10.0000 loss:6.0133
# Episode:802 meanR:9.4200 R:10.0000 loss:5.9715
# Episode:803 meanR:9.4300 R:10.0000 loss:5.9551
# Episode:804 meanR:9.4200 R:9.0000 loss:5.9658
# Episode:805 meanR:9.4000 R:8.0000 loss:5.9803
# Episode:806 meanR:9.3900 R:9.0000 loss:6.0306
# Episode:807 meanR:9.3900 R:8.0000 loss:6.0513
# Episode:808 meanR:9.4000 R:10.0000 loss:6.0537
# Episode:809 meanR:9.4000 R:11.0000 loss:6.0269
# Episode:810 meanR:9.3900 R:10.0000 loss:5.9550
# Episode:811 meanR:9.3900 R:9.0000 loss:5.9545
# Episode:812 meanR:9.3800 R:9.0000 loss:5.9601
# Episode:813 meanR:9.3700 R:9.0000 loss:5.9849
# Episode:814 meanR:9.3800 R:9.0000 loss:6.0015
# Episode:815 meanR:9.3700 R:9.0000 loss:6.0349
# Episode:816 meanR:9.3700 R:9.0000 loss:6.0672
# Episode:817 meanR:9.3800 R:9.0000 loss:6.0998
# Episode:818 meanR:9.3700 R:10.0000 loss:6.0939
# Episode:819 meanR:9.3700 R:10.0000 loss:6.0992
# Episode:820 meanR:9.3700 R:9.0000 loss:6.0901
# Episode:821 meanR:9.3700 R:10.0000 loss:6.1113
# Episode:822 meanR:9.3600 R:9.0000 loss:6.1023
# Episode:823 meanR:9.3600 R:10.0000 loss:6.1232
# Episode:824 meanR:9.3900 R:11.0000 loss:6.1189
# Episode:825 meanR:9.3900 R:10.0000 loss:6.1122
# Episode:826 meanR:9.4000 R:10.0000 loss:6.0765
# Episode:827 meanR:9.4000 R:8.0000 loss:6.0727
# Episode:828 meanR:9.3900 R:9.0000 loss:6.0671
# Episode:829 meanR:9.3800 R:8.0000 loss:6.0845
# Episode:830 meanR:9.3800 R:9.0000 loss:6.1228
# Episode:831 meanR:9.3700 R:9.0000 loss:6.1843
# Episode:832 meanR:9.3600 R:8.0000 loss:6.2342
# Episode:833 meanR:9.3600 R:10.0000 loss:6.2317
# Episode:834 meanR:9.3700 R:10.0000 loss:6.2112
# Episode:835 meanR:9.3800 R:10.0000 loss:6.1927
# Episode:836 meanR:9.3800 R:9.0000 loss:6.1826
# Episode:837 meanR:9.3700 R:8.0000 loss:6.1986
# Episode:838 meanR:9.3800 R:10.0000 loss:6.2086
# Episode:839 meanR:9.3900 R:10.0000 loss:6.1896
# Episode:840 meanR:9.3700 R:8.0000 loss:6.2152
# Episode:841 meanR:9.3800 R:9.0000 loss:6.2638
# Episode:842 meanR:9.3800 R:9.0000 loss:6.2692
# Episode:843 meanR:9.3700 R:9.0000 loss:6.3023
# Episode:844 meanR:9.3700 R:10.0000 loss:6.2876
# Episode:845 meanR:9.3700 R:9.0000 loss:6.3100
# Episode:846 meanR:9.3400 R:8.0000 loss:6.3973
# Episode:847 meanR:9.3200 R:8.0000 loss:6.4246
# Episode:848 meanR:9.3200 R:10.0000 loss:6.4544
# Episode:849 meanR:9.3100 R:9.0000 loss:6.4629
# Episode:850 meanR:9.2900 R:9.0000 loss:6.4369
# Episode:851 meanR:9.3000 R:11.0000 loss:6.3747
# Episode:852 meanR:9.3100 R:9.0000 loss:6.3599
# Episode:853 meanR:9.3100 R:10.0000 loss:6.3414
# Episode:854 meanR:9.3000 R:9.0000 loss:6.3111
# Episode:855 meanR:9.3000 R:9.0000 loss:6.3434
# Episode:856 meanR:9.2800 R:8.0000 loss:6.4019
# Episode:857 meanR:9.2900 R:10.0000 loss:6.4099
# Episode:858 meanR:9.3000 R:9.0000 loss:6.4116
# Episode:859 meanR:9.3100 R:10.0000 loss:6.3656
# Episode:860 meanR:9.3200 R:10.0000 loss:6.3698

# %% [markdown]
# # Visualizing training
#
# Below I'll plot the total rewards for each episode. I'm plotting the rolling average too, in blue.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

def running_mean(x, N):
    cumsum = np.cumsum(np.insert(x, 0, 0)) 
    return (cumsum[N:] - cumsum[:-N]) / N

# %%
eps, arr = np.array(episode_rewards_list).T
smoothed_arr = running_mean(arr, 10)
plt.plot(eps[-len(smoothed_arr):], smoothed_arr)
plt.plot(eps, arr, color='grey', alpha=0.3)
plt.xlabel('Episode')
plt.ylabel('Total rewards')

# %%
eps, arr = np.array(rewards_list).T
smoothed_arr = running_mean(arr, 10)
plt.plot(eps[-len(smoothed_arr):], smoothed_arr)
plt.plot(eps, arr, color='grey', alpha=0.3)
plt.xlabel('Episode')
plt.ylabel('Total rewards')

# %%
eps, arr = np.array(loss_list).T
smoothed_arr = running_mean(arr, 10)
plt.plot(eps[-len(smoothed_arr):], smoothed_arr)
plt.plot(eps, arr, color='grey', alpha=0.3)
plt.xlabel('Episode')
plt.ylabel('Average losses')

# %% [markdown]
# ## Testing
#
# Let's checkout how our trained agent plays the game.

# %%
import gym
env = gym.make('CartPole-v0')
env = gym.make('CartPole-v1')

with tf.Session(graph=graph) as sess:
    sess.run(tf.global_variables_initializer())
    #saver.restore(sess, 'checkpoints/model.ckpt')    
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    
    # Episode/epoch
    for _ in range(10):
        total_reward = 0
        state = env.reset()
        initial_state = sess.run(model.initial_state) # Qs or current batch or states[:-1]
        
        # Steps/batches
        while True:
            env.render()
            action_logits, initial_state = sess.run([model.actions_logits, model.final_state],
                                                    feed_dict = {model.states: state.reshape([1, -1]), 
                                                                 model.initial_state: initial_state})
            action = np.argmax(action_logits)
            state, reward, done, _ = env.step(action)
            total_reward += reward
            if done:
                break
        # At the end of each episode
        print('total_reward:{}'.format(total_reward))

# Close the env
env.close()
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/model.ckpt
# total_reward:500.0
# total_reward:500.0
# total_reward:500.0
# total_reward:500.0
# total_reward:500.0
# total_reward:500.0
# total_reward:500.0
# total_reward:500.0
# total_reward:500.0
# total_reward:500.0

# %% [markdown]
# ## Extending this
#
# So, Cart-Pole is a pretty simple game. However, the same model can be used to train an agent to play something much more complicated like Pong or Space Invaders. Instead of a state like we're using here though, you'd want to use convolutional layers to get the state from the screen images.
#
# ![Deep Q-Learning Atari](assets/atari-network.png)
#
# I'll leave it as a challenge for you to use deep Q-learning to train an agent to play Atari games. Here's the original paper which will get you started: http://www.davidqiu.com:8888/research/nature14236.pdf.
