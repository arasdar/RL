# %%
import tensorflow as tf
print('TensorFlow Version: {}'.format(tf.__version__))
print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.7.1
# Default GPU Device:

# %% [markdown]
# ##### >**Note:** Make sure you have OpenAI Gym cloned. Then run this command `pip install -e gym/[all]`.

# %%
import numpy as np
import gym
env = gym.make('CartPole-v0')
env = gym.make('CartPole-v1')

# %%
def model_input(state_size):
    #states = tf.placeholder(tf.float32, [None, *state_size], name='states')
    states = tf.placeholder(tf.float32, [None, state_size], name='states')
    actions = tf.placeholder(tf.int32, [None], name='actions')
    next_states = tf.placeholder(tf.float32, [None, state_size], name='next_states')
    rewards = tf.placeholder(tf.float32, [None], name='rewards')
    dones = tf.placeholder(tf.float32, [None], name='dones')
    rates = tf.placeholder(tf.float32, [None], name='rates') # success rate
    return states, actions, next_states, rewards, dones, rates

# %%
def Act(states, action_size, hidden_size, reuse=False, alpha=0.1, training=False):
    with tf.variable_scope('Act', reuse=reuse):
        # First fully connected layer
        h1 = tf.layers.dense(inputs=states, units=hidden_size)
        bn1 = tf.layers.batch_normalization(h1, training=training)        
        nl1 = tf.maximum(alpha * bn1, bn1)
        
        # Second fully connected layer
        h2 = tf.layers.dense(inputs=nl1, units=hidden_size)
        bn2 = tf.layers.batch_normalization(h2, training=training)        
        nl2 = tf.maximum(alpha * bn2, bn2)
        
        # Output layer
        logits = tf.layers.dense(inputs=nl2, units=action_size)        
        return logits

# %%
def Env(states, actions, state_size, action_size, hidden_size, reuse=False, alpha=0.1, training=False):
    with tf.variable_scope('Env', reuse=reuse):
        # First fully connected layer
        h1 = tf.layers.dense(inputs=states, units=action_size)
        bn1 = tf.layers.batch_normalization(h1, training=training)        
        nl1 = tf.maximum(alpha * bn1, bn1)
        
        # Second fully connected layer
        nl1_fused = tf.concat(axis=1, values=[nl1, actions])
        h2 = tf.layers.dense(inputs=nl1_fused, units=hidden_size)
        bn2 = tf.layers.batch_normalization(h2, training=training)        
        nl2 = tf.maximum(alpha * bn2, bn2)
                
        # Output layer
        states_logits = tf.layers.dense(inputs=nl2, units=state_size, trainable=False)
        Qlogits = tf.layers.dense(inputs=nl2, units=1, trainable=False)
        return states_logits, Qlogits

# %%
def model_loss(state_size, action_size, hidden_size, gamma,
               states, actions, next_states, rewards, dones, rates):
    ################################################ s', r = env(s, a)
    actions_labels = tf.one_hot(indices=actions, depth=action_size, dtype=states.dtype)
    next_states_logits, Qs = Env(actions=actions_labels, states=states, hidden_size=hidden_size, 
                                 action_size=action_size, state_size=state_size)
    ################################################ a = act(s)
    ################################################ ~s', Q = ~env(s, a)
    actions_logits = Act(states=states, hidden_size=hidden_size, action_size=action_size)
    next_states_logits_, Qs_ = Env(actions=actions_logits, states=states, hidden_size=hidden_size, 
                                   action_size=action_size, state_size=state_size, reuse=True)
    ###########################################################  s~s'
    next_states_labels = tf.nn.sigmoid(next_states)
    eloss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=next_states_logits, # GQN
                                                                   labels=next_states_labels)) # min MCE
    eloss += tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=next_states_logits_, # GQN
                                                                    labels=next_states_labels)) # min MCE
    aloss = -tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=next_states_logits_, # GQN
                                                                    labels=next_states_labels)) # max MCE
    ############################################################## sigmQ ~ successrate
    Qlogits = tf.reshape(Qs, shape=[-1])
    Qlogits_ = tf.reshape(Qs_, shape=[-1])
    eloss += tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=Qlogits, # GAN
                                                                    labels=rates)) # min MCE
    eloss += tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=Qlogits_, # GAN
                                                                    labels=rates)) # min MCE
    aloss += -tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=Qlogits_, # GAN
                                                                     labels=rates)) # max MCE
    ################################################################ Q = r + gamma * Q'
    next_actions_logits = Act(states=next_states, hidden_size=hidden_size, action_size=action_size, reuse=True)
    _next_states_logits_, nextQs_ = Env(actions=next_actions_logits, states=next_states, hidden_size=hidden_size, 
                                        action_size=action_size, state_size=state_size, reuse=True)
    #####################################################################
    targetQs = rewards + (gamma * tf.reshape(nextQs_, shape=[-1]) * dones)
    targetQs_labels = tf.nn.sigmoid(targetQs)
    eloss += tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=Qlogits, # DQN
                                                                    labels=targetQs_labels)) # min MCE
    eloss += tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=Qlogits_, # DQN
                                                                    labels=targetQs_labels)) # min MCE
    aloss += -tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=Qlogits_, # DQN
                                                                     labels=targetQs_labels)) # max MCE
    
    return actions_logits, aloss, eloss

# %%
def model_opt(a_loss, e_loss, a_learning_rate, e_learning_rate):
    # Get weights and bias to update
    t_vars = tf.trainable_variables()
    a_vars = [var for var in t_vars if var.name.startswith('Act')]
    e_vars = [var for var in t_vars if var.name.startswith('Env')]

    # Optimize
    with tf.control_dependencies(tf.get_collection(tf.GraphKeys.UPDATE_OPS)): # Required for batchnorm (BN)
        a_opt = tf.train.AdamOptimizer(a_learning_rate).minimize(a_loss, var_list=a_vars)
        e_opt = tf.train.AdamOptimizer(e_learning_rate).minimize(e_loss, var_list=e_vars)
    return a_opt, e_opt

# %%
class Model:
    def __init__(self, state_size, action_size, hidden_size, a_learning_rate, e_learning_rate, gamma):

        # Data of the Model: make the data available inside the framework
        self.states, self.actions, self.next_states, self.rewards, self.dones, self.rates = model_input(
            state_size=state_size)

        # Create the Model: calculating the loss and forwad pass
        self.actions_logits, self.a_loss, self.e_loss = model_loss(
            state_size=state_size, action_size=action_size, hidden_size=hidden_size, gamma=gamma, # model init
            states=self.states, actions=self.actions, next_states=self.next_states, 
            rewards=self.rewards, dones=self.dones, rates=self.rates) # model input
        
        # Update the model: backward pass and backprop
        self.a_opt, self.e_opt = model_opt(a_loss=self.a_loss, e_loss=self.e_loss,
                                           a_learning_rate=a_learning_rate,
                                           e_learning_rate=e_learning_rate)

# %%
from collections import deque
class Memory():
    def __init__(self, max_size = 1000):
        self.buffer = deque(maxlen=max_size) # data batch
    def sample(self, batch_size):
        idx = np.random.choice(np.arange(len(self.buffer)), size=batch_size, replace=False)
        return [self.buffer[ii] for ii in idx]

# %% [markdown]
# ## Hyperparameters
#
# One of the more difficult aspects of reinforcememt learning are the large number of hyperparameters. Not only are we tuning the network, but we're tuning the simulation.

# %%
env.observation_space, env.action_space
# Out:
# (Box(4,), Discrete(2))

# %%
# Exploration parameters
explore_start = 1.0            # exploration probability at start
explore_stop = 0.01           # minimum exploration probability 
decay_rate = 0.0001            # exponential decay rate for exploration prob

# Network parameters
state_size = 4
action_size = 2
hidden_size = 4*2             # number of units in each Q-network hidden layer
a_learning_rate = 1e-4         # Q-network learning rate
e_learning_rate = 1e-4         # Q-network learning rate

# Memory parameters
memory_size = int(1e5)            # memory capacity
batch_size = int(1e3)             # experience mini-batch size
gamma=0.99

# %%
# Reset/init the graph/session
graph = tf.reset_default_graph()

# Init the model
model = Model(action_size=action_size, state_size=state_size, hidden_size=hidden_size, gamma=gamma,
              a_learning_rate=a_learning_rate, e_learning_rate=e_learning_rate)

# Init the memory
memory = Memory(max_size=memory_size)

# %%
state = env.reset()
total_reward = 0
num_step = 0
for _ in range(memory_size):
    action = env.action_space.sample()
    next_state, reward, done, _ = env.step(action)
    rate = -1
    memory.buffer.append([state, action, next_state, reward, float(done), rate])
    num_step += 1 # memory incremented
    total_reward += reward
    state = next_state
    if done is True:
        rate = total_reward/500
        for idx in range(num_step): # episode length
            if memory.buffer[-1-idx][-1] == -1:
                memory.buffer[-1-idx][-1] = rate
        state = env.reset()
        total_reward = 0 # reset
        num_step = 0 # reset

# %% [markdown]
# ## Training the model
#
# Below we'll train our agent. If you want to watch it train, uncomment the `env.render()` line. This is slow because it's rendering the frames slower than the network can train. But, it's cool to watch the agent get better at the game.

# %%
# def minibatch(memory):
#     batch = memory.buffer
#     #for idx in range(memory_size// batch_size):
#     while True:
#         idx = np.random.choice(np.arange(memory_size// batch_size))
#         states = np.array([each[0] for each in batch])[idx*batch_size:(idx+1)*batch_size]
#         actions = np.array([each[1] for each in batch])[idx*batch_size:(idx+1)*batch_size]
#         next_states = np.array([each[2] for each in batch])[idx*batch_size:(idx+1)*batch_size]
#         rewards = np.array([each[3] for each in batch])[idx*batch_size:(idx+1)*batch_size]
#         dones = np.array([each[4] for each in batch])[idx*batch_size:(idx+1)*batch_size]
#         rates = np.array([each[5] for each in batch])[idx*batch_size:(idx+1)*batch_size]
#         states = states[rates >= np.max(rates)]
#         actions = actions[rates >= np.max(rates)]
#         next_states = next_states[rates >= np.max(rates)]
#         rewards = rewards[rates >= np.max(rates)]
#         dones = dones[rates >= np.max(rates)]
#         rates = rates[rates >= np.max(rates)]
#         if np.count_nonzero(dones) > 0 and len(dones) > 1 and np.max(rates) > 0:
#             break
#     return states, actions, next_states, rewards, dones, rates

# %%
def minibatch(memory):
    while True:
        batch = memory.sample(batch_size=batch_size)
        rates = np.array([each[5] for each in batch])
        states = np.array([each[0] for each in batch])[rates > 0]
        actions = np.array([each[1] for each in batch])[rates > 0]
        next_states = np.array([each[2] for each in batch])[rates > 0]
        rewards = np.array([each[3] for each in batch])[rates > 0]
        dones = np.array([each[4] for each in batch])[rates > 0]
        rates = np.array([each[5] for each in batch])[rates > 0]
        if len(dones) == batch_size:
            break
    return states, actions, next_states, rewards, dones, rates

# %%
# def minibatch_online(memory):
#     batch = memory.buffer
#     rates = np.array([each[5] for each in batch])
#     states = np.array([each[0] for each in batch])[rates == -1]
#     actions = np.array([each[1] for each in batch])[rates == -1]
#     next_states = np.array([each[2] for each in batch])[rates == -1]
#     rewards = np.array([each[3] for each in batch])[rates == -1]
#     dones = np.array([each[4] for each in batch])[rates == -1]
#     rates = np.array([each[5] for each in batch])[rates == -1]
#     return states, actions, next_states, rewards, dones, rates

# %%
# states, actions, next_states, rewards, dones, rates_on = minibatch_online(memory=memory)
states, actions, next_states, rewards, dones, rates_off = minibatch(memory=memory)

# %%
rates_off#, rates_on
#        0.054, 0.038, 0.05 , 0.024, 0.02 , 0.08 , 0.04 , 0.07 , 0.052,
#        0.086, 0.066, 0.034, 0.062, 0.076, 0.076, 0.032, 0.034, 0.048,
#        0.034, 0.066, 0.12 , 0.062, 0.03 , 0.062, 0.048, 0.02 , 0.03 ,
#        0.034, 0.056, 0.044, 0.156, 0.032, 0.042, 0.046, 0.036, 0.144,
#        0.032, 0.154, 0.062, 0.05 , 0.032, 0.066, 0.034, 0.036, 0.048,
#        0.06 , 0.082, 0.03 , 0.052, 0.104, 0.072, 0.046, 0.036, 0.018,
#        0.02 , 0.106, 0.04 , 0.042, 0.048, 0.094, 0.034, 0.134, 0.032,
#        0.052, 0.084, 0.034, 0.036, 0.064, 0.036, 0.05 , 0.076, 0.052,
#        0.084, 0.09 , 0.026, 0.05 , 0.05 , 0.106, 0.038, 0.038, 0.052,
#        0.028, 0.052, 0.046, 0.026, 0.072, 0.126, 0.026, 0.054, 0.116,
#        0.076, 0.052, 0.174, 0.066, 0.052, 0.09 , 0.028, 0.052, 0.058,
#        0.062, 0.026, 0.026, 0.072, 0.082, 0.134, 0.03 , 0.028, 0.086,
#        0.132, 0.02 , 0.038, 0.026, 0.046, 0.048, 0.092, 0.05 , 0.064,
#        0.056, 0.056, 0.052, 0.048, 0.08 , 0.1  , 0.052, 0.028, 0.046,
#        0.03 , 0.152, 0.04 , 0.022, 0.056, 0.048, 0.072, 0.026, 0.03 ,
#        0.114, 0.04 , 0.058, 0.052, 0.034, 0.04 , 0.032, 0.032, 0.06 ,
#        0.04 , 0.074, 0.03 , 0.078, 0.034, 0.09 , 0.11 , 0.05 , 0.034,
#        0.034])

# %%
# Save/load the model and save for plotting
saver = tf.train.Saver()
episode_rewards_list, rewards_list = [], []
aloss_list, eloss_list = [], []

# TF session for training
with tf.Session(graph=graph) as sess:
    sess.run(tf.global_variables_initializer())
    #saver.restore(sess, 'checkpoints/model.ckpt')    
    #saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    episode_reward = deque(maxlen=100) # 100 episodes for running average/running mean/window

    # Episodes/epochs
    for ep in range(11111):
        aloss_batch, eloss_batch = [], []
        total_reward = 0
        state = env.reset()
        rate = -1
        
        # Episode steps
        for num_step in range(1111111111111):
            action_logits = sess.run(model.actions_logits, feed_dict={model.states: state.reshape([1, -1])})
            action = np.argmax(action_logits)
            next_state, reward, done, _ = env.step(action)
            memory.buffer.append([state, action, next_state, reward, float(done), rate])
            total_reward += reward
            state = next_state
            
            # Online Training/on-policy
            states, actions, next_states, rewards, dones, rates = minibatch(memory=memory)
            feed_dict = {model.states: states, model.actions: actions, model.next_states: next_states,
                         model.rewards: rewards, model.dones: dones, model.rates: rates}
            eloss, _ = sess.run([model.e_loss, model.e_opt], feed_dict)
            aloss, _ = sess.run([model.a_loss, model.a_opt], feed_dict)
            eloss_batch.append(eloss)
            aloss_batch.append(aloss)
            if done is True:
                # Rating the latest played episode
                rate = total_reward/500 # update rate at the end/ when episode is done
                for idx in range(num_step): # episode length
                    if memory.buffer[-1-idx][-1] == -1: # double-check the landmark/marked indexes
                        memory.buffer[-1-idx][-1] = rate # rate the trajectory/data
                break
                

        # Offline Training/off-policy
        # EMPTYYYYYYYYYYYYY#####
        # EMPTYYYYYYYYYYYYY#####
        # EMPTYYYYYYYYYYYYY#####
        # EMPTYYYYYYYYYYYYY#####
        
        # Print out
        episode_reward.append(total_reward)
        print('Episode:{}'.format(ep),
              'meanR:{:.4f}'.format(np.mean(episode_reward)),
              'R:{:.4f}'.format(total_reward),
              'rate:{:.4f}'.format(rate),
              'aloss:{:.4f}'.format(np.mean(aloss_batch)),
              'eloss:{:.4f}'.format(np.mean(eloss_batch)))

        # Ploting out
        episode_rewards_list.append([ep, np.mean(episode_reward)])
        rewards_list.append([ep, total_reward])
        aloss_list.append([ep, np.mean(aloss_batch)])
        eloss_list.append([ep, np.mean(eloss_batch)])
        
        # Break episode/epoch loop
        ## Option 1: Solve the First Version
        #The task is episodic, and in order to solve the environment, 
        #your agent must get an average score of +30 over 100 consecutive episodes.
        if np.mean(episode_reward) >= 500:
            break
            
    # At the end of all training episodes/epochs
    saver.save(sess, 'checkpoints/model.ckpt')
# Out:
# Episode:0 meanR:14.0000 R:14.0000 rate:0.0280 aloss:-2.0577 eloss:4.1266
# Episode:1 meanR:11.5000 R:9.0000 rate:0.0180 aloss:-2.0578 eloss:4.1261
# Episode:2 meanR:16.6667 R:27.0000 rate:0.0540 aloss:-2.0571 eloss:4.1241
# Episode:3 meanR:22.0000 R:38.0000 rate:0.0760 aloss:-2.0563 eloss:4.1213
# Episode:4 meanR:24.6000 R:35.0000 rate:0.0700 aloss:-2.0558 eloss:4.1191
# Episode:5 meanR:24.5000 R:24.0000 rate:0.0480 aloss:-2.0555 eloss:4.1175
# Episode:6 meanR:24.8571 R:27.0000 rate:0.0540 aloss:-2.0550 eloss:4.1148
# Episode:130 meanR:10.5100 R:11.0000 rate:0.0220 aloss:-2.1343 eloss:4.1585
# Episode:131 meanR:10.4400 R:11.0000 rate:0.0220 aloss:-2.1328 eloss:4.1569
# Episode:132 meanR:10.3800 R:9.0000 rate:0.0180 aloss:-2.1296 eloss:4.1541
# Episode:133 meanR:10.3200 R:10.0000 rate:0.0200 aloss:-2.1304 eloss:4.1550
# Episode:134 meanR:10.3000 R:9.0000 rate:0.0180 aloss:-2.1209 eloss:4.1451
# Episode:135 meanR:10.2700 R:9.0000 rate:0.0180 aloss:-2.1211 eloss:4.1456
# Episode:136 meanR:10.2400 R:9.0000 rate:0.0180 aloss:-2.1170 eloss:4.1409
# Episode:137 meanR:10.1800 R:9.0000 rate:0.0180 aloss:-2.1169 eloss:4.1407
# Episode:138 meanR:10.1200 R:10.0000 rate:0.0200 aloss:-2.1132 eloss:4.1368
# Episode:139 meanR:10.0500 R:8.0000 rate:0.0160 aloss:-2.1149 eloss:4.1385
# Episode:140 meanR:10.0300 R:9.0000 rate:0.0180 aloss:-2.1126 eloss:4.1365
# Episode:141 meanR:10.0000 R:8.0000 rate:0.0160 aloss:-2.1105 eloss:4.1339
# Episode:142 meanR:9.9700 R:9.0000 rate:0.0180 aloss:-2.1059 eloss:4.1298
# Episode:143 meanR:9.9100 R:10.0000 rate:0.0200 aloss:-2.1071 eloss:4.1301
# Episode:144 meanR:9.9000 R:10.0000 rate:0.0200 aloss:-2.1033 eloss:4.1266
# Episode:145 meanR:9.8500 R:10.0000 rate:0.0200 aloss:-2.1010 eloss:4.1244
# Episode:146 meanR:9.8400 R:9.0000 rate:0.0180 aloss:-2.0983 eloss:4.1211
# Episode:147 meanR:9.8400 R:10.0000 rate:0.0200 aloss:-2.0971 eloss:4.1204
# Episode:148 meanR:9.7800 R:8.0000 rate:0.0160 aloss:-2.0937 eloss:4.1170
# Episode:149 meanR:9.7400 R:9.0000 rate:0.0180 aloss:-2.0965 eloss:4.1194
# Episode:150 meanR:9.7400 R:10.0000 rate:0.0200 aloss:-2.0950 eloss:4.1177
# Episode:151 meanR:9.7000 R:10.0000 rate:0.0200 aloss:-2.0919 eloss:4.1151
# Episode:152 meanR:9.6500 R:9.0000 rate:0.0180 aloss:-2.0888 eloss:4.1126
# Episode:153 meanR:9.6600 R:10.0000 rate:0.0200 aloss:-2.0879 eloss:4.1113
# Episode:154 meanR:9.6500 R:10.0000 rate:0.0200 aloss:-2.0870 eloss:4.1100
# Episode:155 meanR:9.6400 R:10.0000 rate:0.0200 aloss:-2.0866 eloss:4.1094
# Episode:156 meanR:9.6400 R:10.0000 rate:0.0200 aloss:-2.0826 eloss:4.1058
# Episode:157 meanR:9.6000 R:10.0000 rate:0.0200 aloss:-2.0826 eloss:4.1048
# Episode:158 meanR:9.5800 R:9.0000 rate:0.0180 aloss:-2.0815 eloss:4.1045
# Episode:159 meanR:9.5600 R:13.0000 rate:0.0260 aloss:-2.0784 eloss:4.1008
# Episode:160 meanR:9.5800 R:12.0000 rate:0.0240 aloss:-2.0762 eloss:4.0988
# Episode:161 meanR:9.6100 R:13.0000 rate:0.0260 aloss:-2.0765 eloss:4.0991
# Episode:162 meanR:9.6300 R:12.0000 rate:0.0240 aloss:-2.0761 eloss:4.0989
# Episode:163 meanR:9.6700 R:14.0000 rate:0.0280 aloss:-2.0742 eloss:4.0963
# Episode:164 meanR:9.6700 R:10.0000 rate:0.0200 aloss:-2.0720 eloss:4.0950
# Episode:165 meanR:9.6900 R:12.0000 rate:0.0240 aloss:-2.0712 eloss:4.0938
# Episode:166 meanR:9.7000 R:12.0000 rate:0.0240 aloss:-2.0710 eloss:4.0927
# Episode:167 meanR:9.7300 R:12.0000 rate:0.0240 aloss:-2.0698 eloss:4.0923
# Episode:168 meanR:9.7600 R:14.0000 rate:0.0280 aloss:-2.0685 eloss:4.0908
# Episode:169 meanR:9.8200 R:15.0000 rate:0.0300 aloss:-2.0658 eloss:4.0880
# Episode:170 meanR:9.8200 R:11.0000 rate:0.0220 aloss:-2.0668 eloss:4.0891
# Episode:171 meanR:9.8200 R:13.0000 rate:0.0260 aloss:-2.0653 eloss:4.0880
# Episode:172 meanR:9.8400 R:12.0000 rate:0.0240 aloss:-2.0645 eloss:4.0870
# Episode:173 meanR:9.8800 R:15.0000 rate:0.0300 aloss:-2.0637 eloss:4.0855
# Episode:174 meanR:9.9400 R:16.0000 rate:0.0320 aloss:-2.0621 eloss:4.0847
# Episode:175 meanR:10.0100 R:16.0000 rate:0.0320 aloss:-2.0638 eloss:4.0865
# Episode:176 meanR:10.0700 R:16.0000 rate:0.0320 aloss:-2.0622 eloss:4.0845
# Episode:177 meanR:10.1000 R:13.0000 rate:0.0260 aloss:-2.0619 eloss:4.0843
# Episode:178 meanR:10.1500 R:15.0000 rate:0.0300 aloss:-2.0630 eloss:4.0858
# Episode:179 meanR:10.1700 R:12.0000 rate:0.0240 aloss:-2.0612 eloss:4.0839
# Episode:180 meanR:10.2600 R:19.0000 rate:0.0380 aloss:-2.0614 eloss:4.0845
# Episode:181 meanR:10.3200 R:15.0000 rate:0.0300 aloss:-2.0601 eloss:4.0829
# Episode:182 meanR:10.3900 R:17.0000 rate:0.0340 aloss:-2.0591 eloss:4.0816
# Episode:183 meanR:10.4400 R:15.0000 rate:0.0300 aloss:-2.0593 eloss:4.0821
# Episode:184 meanR:10.5400 R:18.0000 rate:0.0360 aloss:-2.0577 eloss:4.0807
# Episode:185 meanR:10.6100 R:15.0000 rate:0.0300 aloss:-2.0576 eloss:4.0800
# Episode:186 meanR:10.6800 R:16.0000 rate:0.0320 aloss:-2.0577 eloss:4.0813
# Episode:187 meanR:10.7400 R:16.0000 rate:0.0320 aloss:-2.0551 eloss:4.0774
# Episode:188 meanR:10.8100 R:16.0000 rate:0.0320 aloss:-2.0539 eloss:4.0765
# Episode:189 meanR:10.8900 R:18.0000 rate:0.0360 aloss:-2.0542 eloss:4.0770
# Episode:190 meanR:10.9600 R:16.0000 rate:0.0320 aloss:-2.0536 eloss:4.0769
# Episode:191 meanR:11.0800 R:21.0000 rate:0.0420 aloss:-2.0526 eloss:4.0753
# Episode:253 meanR:15.2000 R:9.0000 rate:0.0180 aloss:-2.0283 eloss:4.0521
# Episode:254 meanR:15.1900 R:9.0000 rate:0.0180 aloss:-2.0283 eloss:4.0522
# Episode:255 meanR:15.1800 R:9.0000 rate:0.0180 aloss:-2.0277 eloss:4.0509
# Episode:256 meanR:15.1800 R:10.0000 rate:0.0200 aloss:-2.0279 eloss:4.0512
# Episode:257 meanR:15.1800 R:10.0000 rate:0.0200 aloss:-2.0275 eloss:4.0504
# Episode:258 meanR:15.1900 R:10.0000 rate:0.0200 aloss:-2.0276 eloss:4.0511
# Episode:259 meanR:15.1600 R:10.0000 rate:0.0200 aloss:-2.0276 eloss:4.0511
# Episode:260 meanR:15.1300 R:9.0000 rate:0.0180 aloss:-2.0276 eloss:4.0510
# Episode:261 meanR:15.0800 R:8.0000 rate:0.0160 aloss:-2.0277 eloss:4.0512
# Episode:262 meanR:15.0600 R:10.0000 rate:0.0200 aloss:-2.0272 eloss:4.0503
# Episode:263 meanR:15.0300 R:11.0000 rate:0.0220 aloss:-2.0269 eloss:4.0500
# Episode:264 meanR:15.0300 R:10.0000 rate:0.0200 aloss:-2.0273 eloss:4.0504
# Episode:265 meanR:15.0000 R:9.0000 rate:0.0180 aloss:-2.0268 eloss:4.0499
# Episode:266 meanR:14.9600 R:8.0000 rate:0.0160 aloss:-2.0264 eloss:4.0489
# Episode:267 meanR:14.9200 R:8.0000 rate:0.0160 aloss:-2.0274 eloss:4.0511
# Episode:268 meanR:14.8700 R:9.0000 rate:0.0180 aloss:-2.0268 eloss:4.0502
# Episode:269 meanR:14.8200 R:10.0000 rate:0.0200 aloss:-2.0263 eloss:4.0492
# Episode:270 meanR:14.8100 R:10.0000 rate:0.0200 aloss:-2.0268 eloss:4.0502
# Episode:271 meanR:14.7800 R:10.0000 rate:0.0200 aloss:-2.0261 eloss:4.0488
# Episode:272 meanR:14.7600 R:10.0000 rate:0.0200 aloss:-2.0259 eloss:4.0486
# Episode:273 meanR:14.7100 R:10.0000 rate:0.0200 aloss:-2.0257 eloss:4.0482
# Episode:274 meanR:14.6400 R:9.0000 rate:0.0180 aloss:-2.0249 eloss:4.0471
# Episode:275 meanR:14.5700 R:9.0000 rate:0.0180 aloss:-2.0254 eloss:4.0482
# Episode:276 meanR:14.5000 R:9.0000 rate:0.0180 aloss:-2.0261 eloss:4.0494
# Episode:277 meanR:14.4700 R:10.0000 rate:0.0200 aloss:-2.0260 eloss:4.0490
# Episode:278 meanR:14.4200 R:10.0000 rate:0.0200 aloss:-2.0253 eloss:4.0480
# Episode:279 meanR:14.3800 R:8.0000 rate:0.0160 aloss:-2.0252 eloss:4.0479
# Episode:280 meanR:14.2900 R:10.0000 rate:0.0200 aloss:-2.0247 eloss:4.0470
# Episode:281 meanR:14.2200 R:8.0000 rate:0.0160 aloss:-2.0249 eloss:4.0472
# Episode:282 meanR:14.1400 R:9.0000 rate:0.0180 aloss:-2.0250 eloss:4.0478
# Episode:283 meanR:14.0700 R:8.0000 rate:0.0160 aloss:-2.0247 eloss:4.0470
# Episode:284 meanR:13.9900 R:10.0000 rate:0.0200 aloss:-2.0249 eloss:4.0477
# Episode:285 meanR:13.9200 R:8.0000 rate:0.0160 aloss:-2.0241 eloss:4.0460
# Episode:286 meanR:13.8500 R:9.0000 rate:0.0180 aloss:-2.0242 eloss:4.0466
# Episode:287 meanR:13.7700 R:8.0000 rate:0.0160 aloss:-2.0237 eloss:4.0457
# Episode:288 meanR:13.7100 R:10.0000 rate:0.0200 aloss:-2.0240 eloss:4.0461
# Episode:289 meanR:13.6100 R:8.0000 rate:0.0160 aloss:-2.0242 eloss:4.0465
# Episode:290 meanR:13.5400 R:9.0000 rate:0.0180 aloss:-2.0234 eloss:4.0456
# Episode:291 meanR:13.4100 R:8.0000 rate:0.0160 aloss:-2.0236 eloss:4.0457
# Episode:292 meanR:13.2600 R:9.0000 rate:0.0180 aloss:-2.0241 eloss:4.0468
# Episode:293 meanR:13.1700 R:10.0000 rate:0.0200 aloss:-2.0238 eloss:4.0462
# Episode:294 meanR:13.0400 R:11.0000 rate:0.0220 aloss:-2.0231 eloss:4.0452
# Episode:295 meanR:12.9000 R:9.0000 rate:0.0180 aloss:-2.0227 eloss:4.0446
# Episode:296 meanR:12.6700 R:10.0000 rate:0.0200 aloss:-2.0233 eloss:4.0453
# Episode:297 meanR:12.4600 R:9.0000 rate:0.0180 aloss:-2.0236 eloss:4.0459
# Episode:298 meanR:12.2100 R:8.0000 rate:0.0160 aloss:-2.0229 eloss:4.0452
# Episode:299 meanR:11.7400 R:10.0000 rate:0.0200 aloss:-2.0230 eloss:4.0451
# Episode:300 meanR:11.5200 R:10.0000 rate:0.0200 aloss:-2.0227 eloss:4.0445
# Episode:301 meanR:11.1700 R:8.0000 rate:0.0160 aloss:-2.0226 eloss:4.0443
# Episode:302 meanR:10.7700 R:10.0000 rate:0.0200 aloss:-2.0224 eloss:4.0441
# Episode:303 meanR:10.3600 R:10.0000 rate:0.0200 aloss:-2.0227 eloss:4.0446
# Episode:304 meanR:10.1100 R:10.0000 rate:0.0200 aloss:-2.0224 eloss:4.0443
# Episode:305 meanR:9.9500 R:9.0000 rate:0.0180 aloss:-2.0216 eloss:4.0427
# Episode:306 meanR:9.7700 R:9.0000 rate:0.0180 aloss:-2.0226 eloss:4.0447
# Episode:307 meanR:9.6900 R:10.0000 rate:0.0200 aloss:-2.0215 eloss:4.0427
# Episode:308 meanR:9.5600 R:9.0000 rate:0.0180 aloss:-2.0213 eloss:4.0426
# Episode:309 meanR:9.5400 R:10.0000 rate:0.0200 aloss:-2.0219 eloss:4.0437
# Episode:310 meanR:9.5000 R:10.0000 rate:0.0200 aloss:-2.0217 eloss:4.0431
# Episode:311 meanR:9.4500 R:10.0000 rate:0.0200 aloss:-2.0214 eloss:4.0428
# Episode:312 meanR:9.3900 R:9.0000 rate:0.0180 aloss:-2.0211 eloss:4.0422
# Episode:313 meanR:9.3400 R:9.0000 rate:0.0180 aloss:-2.0216 eloss:4.0429
# Episode:314 meanR:9.3400 R:11.0000 rate:0.0220 aloss:-2.0218 eloss:4.0434
# Episode:315 meanR:9.3300 R:9.0000 rate:0.0180 aloss:-2.0220 eloss:4.0439
# Episode:316 meanR:9.3400 R:10.0000 rate:0.0200 aloss:-2.0220 eloss:4.0438
# Episode:317 meanR:9.3400 R:10.0000 rate:0.0200 aloss:-2.0214 eloss:4.0428
# Episode:318 meanR:9.3400 R:9.0000 rate:0.0180 aloss:-2.0215 eloss:4.0430
# Episode:319 meanR:9.3600 R:10.0000 rate:0.0200 aloss:-2.0208 eloss:4.0420
# Episode:320 meanR:9.3500 R:9.0000 rate:0.0180 aloss:-2.0214 eloss:4.0430
# Episode:321 meanR:9.3500 R:9.0000 rate:0.0180 aloss:-2.0211 eloss:4.0425
# Episode:322 meanR:9.3400 R:9.0000 rate:0.0180 aloss:-2.0216 eloss:4.0434
# Episode:323 meanR:9.3300 R:9.0000 rate:0.0180 aloss:-2.0212 eloss:4.0426
# Episode:324 meanR:9.3200 R:9.0000 rate:0.0180 aloss:-2.0213 eloss:4.0427
# Episode:325 meanR:9.3300 R:9.0000 rate:0.0180 aloss:-2.0216 eloss:4.0434
# Episode:326 meanR:9.3400 R:10.0000 rate:0.0200 aloss:-2.0203 eloss:4.0410
# Episode:327 meanR:9.3300 R:9.0000 rate:0.0180 aloss:-2.0210 eloss:4.0424
# Episode:328 meanR:9.3300 R:8.0000 rate:0.0160 aloss:-2.0219 eloss:4.0443
# Episode:329 meanR:9.3200 R:9.0000 rate:0.0180 aloss:-2.0212 eloss:4.0429
# Episode:330 meanR:9.3000 R:8.0000 rate:0.0160 aloss:-2.0209 eloss:4.0422
# Episode:331 meanR:9.3000 R:10.0000 rate:0.0200 aloss:-2.0203 eloss:4.0411
# Episode:332 meanR:9.2900 R:10.0000 rate:0.0200 aloss:-2.0202 eloss:4.0408
# Episode:333 meanR:9.2700 R:8.0000 rate:0.0160 aloss:-2.0206 eloss:4.0417
# Episode:334 meanR:9.2800 R:10.0000 rate:0.0200 aloss:-2.0203 eloss:4.0408
# Episode:335 meanR:9.2800 R:9.0000 rate:0.0180 aloss:-2.0206 eloss:4.0417
# Episode:336 meanR:9.2900 R:10.0000 rate:0.0200 aloss:-2.0210 eloss:4.0423
# Episode:337 meanR:9.2600 R:8.0000 rate:0.0160 aloss:-2.0200 eloss:4.0405
# Episode:338 meanR:9.2700 R:9.0000 rate:0.0180 aloss:-2.0195 eloss:4.0398
# Episode:339 meanR:9.2700 R:10.0000 rate:0.0200 aloss:-2.0200 eloss:4.0407
# Episode:340 meanR:9.3000 R:11.0000 rate:0.0220 aloss:-2.0197 eloss:4.0402
# Episode:341 meanR:9.3000 R:9.0000 rate:0.0180 aloss:-2.0195 eloss:4.0399
# Episode:342 meanR:9.3200 R:10.0000 rate:0.0200 aloss:-2.0210 eloss:4.0424
# Episode:343 meanR:9.3200 R:10.0000 rate:0.0200 aloss:-2.0202 eloss:4.0412
# Episode:344 meanR:9.3300 R:9.0000 rate:0.0180 aloss:-2.0198 eloss:4.0401
# Episode:345 meanR:9.3300 R:9.0000 rate:0.0180 aloss:-2.0200 eloss:4.0406
# Episode:346 meanR:9.3000 R:8.0000 rate:0.0160 aloss:-2.0201 eloss:4.0409
# Episode:347 meanR:9.3000 R:10.0000 rate:0.0200 aloss:-2.0202 eloss:4.0412
# Episode:348 meanR:9.3000 R:10.0000 rate:0.0200 aloss:-2.0199 eloss:4.0405
# Episode:349 meanR:9.3000 R:10.0000 rate:0.0200 aloss:-2.0209 eloss:4.0422
# Episode:350 meanR:9.3000 R:8.0000 rate:0.0160 aloss:-2.0191 eloss:4.0392
# Episode:351 meanR:9.3100 R:10.0000 rate:0.0200 aloss:-2.0197 eloss:4.0401
# Episode:352 meanR:9.3200 R:9.0000 rate:0.0180 aloss:-2.0193 eloss:4.0396
# Episode:353 meanR:9.3200 R:9.0000 rate:0.0180 aloss:-2.0198 eloss:4.0405
# Episode:354 meanR:9.3400 R:11.0000 rate:0.0220 aloss:-2.0195 eloss:4.0398
# Episode:355 meanR:9.3500 R:10.0000 rate:0.0200 aloss:-2.0202 eloss:4.0411
# Episode:356 meanR:9.3500 R:10.0000 rate:0.0200 aloss:-2.0205 eloss:4.0417
# Episode:357 meanR:9.3500 R:10.0000 rate:0.0200 aloss:-2.0197 eloss:4.0403
# Episode:358 meanR:9.3500 R:10.0000 rate:0.0200 aloss:-2.0195 eloss:4.0395
# Episode:359 meanR:9.3300 R:8.0000 rate:0.0160 aloss:-2.0198 eloss:4.0402
# Episode:360 meanR:9.3400 R:10.0000 rate:0.0200 aloss:-2.0199 eloss:4.0404
# Episode:361 meanR:9.3600 R:10.0000 rate:0.0200 aloss:-2.0197 eloss:4.0402
# Episode:362 meanR:9.3400 R:8.0000 rate:0.0160 aloss:-2.0196 eloss:4.0400
# Episode:363 meanR:9.3300 R:10.0000 rate:0.0200 aloss:-2.0197 eloss:4.0401
# Episode:364 meanR:9.3300 R:10.0000 rate:0.0200 aloss:-2.0203 eloss:4.0412
# Episode:365 meanR:9.3200 R:8.0000 rate:0.0160 aloss:-2.0201 eloss:4.0407
# Episode:366 meanR:9.3300 R:9.0000 rate:0.0180 aloss:-2.0194 eloss:4.0394
# Episode:367 meanR:9.3400 R:9.0000 rate:0.0180 aloss:-2.0187 eloss:4.0381
# Episode:368 meanR:9.3300 R:8.0000 rate:0.0160 aloss:-2.0193 eloss:4.0395
# Episode:369 meanR:9.3400 R:11.0000 rate:0.0220 aloss:-2.0190 eloss:4.0386
# Episode:370 meanR:9.3300 R:9.0000 rate:0.0180 aloss:-2.0190 eloss:4.0385
# Episode:371 meanR:9.3300 R:10.0000 rate:0.0200 aloss:-2.0199 eloss:4.0402
# Episode:372 meanR:9.3300 R:10.0000 rate:0.0200 aloss:-2.0196 eloss:4.0397
# Episode:373 meanR:9.3100 R:8.0000 rate:0.0160 aloss:-2.0190 eloss:4.0382
# Episode:374 meanR:9.3200 R:10.0000 rate:0.0200 aloss:-2.0197 eloss:4.0399
# Episode:375 meanR:9.3300 R:10.0000 rate:0.0200 aloss:-2.0196 eloss:4.0396
# Episode:376 meanR:9.3300 R:9.0000 rate:0.0180 aloss:-2.0193 eloss:4.0391
# Episode:377 meanR:9.3300 R:10.0000 rate:0.0200 aloss:-2.0194 eloss:4.0397
# Episode:378 meanR:9.3100 R:8.0000 rate:0.0160 aloss:-2.0197 eloss:4.0400
# Episode:379 meanR:9.3200 R:9.0000 rate:0.0180 aloss:-2.0191 eloss:4.0389
# Episode:380 meanR:9.3100 R:9.0000 rate:0.0180 aloss:-2.0198 eloss:4.0401
# Episode:381 meanR:9.3100 R:8.0000 rate:0.0160 aloss:-2.0202 eloss:4.0406
# Episode:382 meanR:9.3200 R:10.0000 rate:0.0200 aloss:-2.0195 eloss:4.0392
# Episode:383 meanR:9.3200 R:8.0000 rate:0.0160 aloss:-2.0196 eloss:4.0399
# Episode:384 meanR:9.3100 R:9.0000 rate:0.0180 aloss:-2.0195 eloss:4.0393
# Episode:385 meanR:9.3400 R:11.0000 rate:0.0220 aloss:-2.0192 eloss:4.0389
# Episode:386 meanR:9.3400 R:9.0000 rate:0.0180 aloss:-2.0192 eloss:4.0385
# Episode:387 meanR:9.3700 R:11.0000 rate:0.0220 aloss:-2.0190 eloss:4.0385
# Episode:388 meanR:9.3700 R:10.0000 rate:0.0200 aloss:-2.0193 eloss:4.0388
# Episode:389 meanR:9.3800 R:9.0000 rate:0.0180 aloss:-2.0199 eloss:4.0399
# Episode:390 meanR:9.3900 R:10.0000 rate:0.0200 aloss:-2.0202 eloss:4.0405
# Episode:391 meanR:9.4100 R:10.0000 rate:0.0200 aloss:-2.0191 eloss:4.0387
# Episode:392 meanR:9.4200 R:10.0000 rate:0.0200 aloss:-2.0191 eloss:4.0384
# Episode:393 meanR:9.4200 R:10.0000 rate:0.0200 aloss:-2.0199 eloss:4.0399
# Episode:394 meanR:9.4100 R:10.0000 rate:0.0200 aloss:-2.0193 eloss:4.0388
# Episode:395 meanR:9.4000 R:8.0000 rate:0.0160 aloss:-2.0193 eloss:4.0390
# Episode:396 meanR:9.3900 R:9.0000 rate:0.0180 aloss:-2.0192 eloss:4.0387
# Episode:397 meanR:9.3800 R:8.0000 rate:0.0160 aloss:-2.0189 eloss:4.0380
# Episode:398 meanR:9.4000 R:10.0000 rate:0.0200 aloss:-2.0202 eloss:4.0404
# Episode:399 meanR:9.3900 R:9.0000 rate:0.0180 aloss:-2.0198 eloss:4.0397
# Episode:400 meanR:9.3700 R:8.0000 rate:0.0160 aloss:-2.0196 eloss:4.0391
# Episode:401 meanR:9.3900 R:10.0000 rate:0.0200 aloss:-2.0189 eloss:4.0381
# Episode:402 meanR:9.3900 R:10.0000 rate:0.0200 aloss:-2.0185 eloss:4.0374
# Episode:403 meanR:9.3800 R:9.0000 rate:0.0180 aloss:-2.0190 eloss:4.0380
# Episode:404 meanR:9.3800 R:10.0000 rate:0.0200 aloss:-2.0191 eloss:4.0385
# Episode:405 meanR:9.3900 R:10.0000 rate:0.0200 aloss:-2.0198 eloss:4.0393
# Episode:406 meanR:9.3900 R:9.0000 rate:0.0180 aloss:-2.0196 eloss:4.0391
# Episode:407 meanR:9.3800 R:9.0000 rate:0.0180 aloss:-2.0197 eloss:4.0391
# Episode:408 meanR:9.4000 R:11.0000 rate:0.0220 aloss:-2.0196 eloss:4.0392
# Episode:409 meanR:9.4000 R:10.0000 rate:0.0200 aloss:-2.0193 eloss:4.0384
# Episode:410 meanR:9.4000 R:10.0000 rate:0.0200 aloss:-2.0191 eloss:4.0381
# Episode:411 meanR:9.3900 R:9.0000 rate:0.0180 aloss:-2.0192 eloss:4.0382
# Episode:412 meanR:9.3900 R:9.0000 rate:0.0180 aloss:-2.0198 eloss:4.0393
# Episode:413 meanR:9.4000 R:10.0000 rate:0.0200 aloss:-2.0200 eloss:4.0398
# Episode:414 meanR:9.3900 R:10.0000 rate:0.0200 aloss:-2.0184 eloss:4.0367
# Episode:415 meanR:9.4000 R:10.0000 rate:0.0200 aloss:-2.0186 eloss:4.0371
# Episode:416 meanR:9.3900 R:9.0000 rate:0.0180 aloss:-2.0193 eloss:4.0384
# Episode:417 meanR:9.3700 R:8.0000 rate:0.0160 aloss:-2.0195 eloss:4.0387
# Episode:418 meanR:9.3800 R:10.0000 rate:0.0200 aloss:-2.0200 eloss:4.0396
# Episode:419 meanR:9.3800 R:10.0000 rate:0.0200 aloss:-2.0190 eloss:4.0380
# Episode:420 meanR:9.3900 R:10.0000 rate:0.0200 aloss:-2.0197 eloss:4.0392
# Episode:421 meanR:9.3900 R:9.0000 rate:0.0180 aloss:-2.0191 eloss:4.0379
# Episode:422 meanR:9.3900 R:9.0000 rate:0.0180 aloss:-2.0198 eloss:4.0393
# Episode:423 meanR:9.4000 R:10.0000 rate:0.0200 aloss:-2.0192 eloss:4.0380
# Episode:424 meanR:9.4000 R:9.0000 rate:0.0180 aloss:-2.0195 eloss:4.0382
# Episode:425 meanR:9.4200 R:11.0000 rate:0.0220 aloss:-2.0195 eloss:4.0384
# Episode:426 meanR:9.4200 R:10.0000 rate:0.0200 aloss:-2.0188 eloss:4.0371
# Episode:427 meanR:9.4300 R:10.0000 rate:0.0200 aloss:-2.0196 eloss:4.0385
# Episode:428 meanR:9.4400 R:9.0000 rate:0.0180 aloss:-2.0199 eloss:4.0391
# Episode:429 meanR:9.4400 R:9.0000 rate:0.0180 aloss:-2.0189 eloss:4.0373
# Episode:430 meanR:9.4700 R:11.0000 rate:0.0220 aloss:-2.0204 eloss:4.0398
# Episode:431 meanR:9.4700 R:10.0000 rate:0.0200 aloss:-2.0196 eloss:4.0386
# Episode:432 meanR:9.4700 R:10.0000 rate:0.0200 aloss:-2.0199 eloss:4.0389
# Episode:433 meanR:9.4900 R:10.0000 rate:0.0200 aloss:-2.0193 eloss:4.0378
# Episode:434 meanR:9.4800 R:9.0000 rate:0.0180 aloss:-2.0199 eloss:4.0392
# Episode:435 meanR:9.5000 R:11.0000 rate:0.0220 aloss:-2.0200 eloss:4.0393
# Episode:436 meanR:9.5000 R:10.0000 rate:0.0200 aloss:-2.0192 eloss:4.0379
# Episode:437 meanR:9.5200 R:10.0000 rate:0.0200 aloss:-2.0191 eloss:4.0375
# Episode:438 meanR:9.5300 R:10.0000 rate:0.0200 aloss:-2.0190 eloss:4.0373
# Episode:439 meanR:9.5300 R:10.0000 rate:0.0200 aloss:-2.0198 eloss:4.0386
# Episode:440 meanR:9.5100 R:9.0000 rate:0.0180 aloss:-2.0196 eloss:4.0383
# Episode:441 meanR:9.5100 R:9.0000 rate:0.0180 aloss:-2.0190 eloss:4.0371
# Episode:442 meanR:9.4900 R:8.0000 rate:0.0160 aloss:-2.0195 eloss:4.0379
# Episode:443 meanR:9.4800 R:9.0000 rate:0.0180 aloss:-2.0195 eloss:4.0382
# Episode:444 meanR:9.4900 R:10.0000 rate:0.0200 aloss:-2.0196 eloss:4.0381
# Episode:445 meanR:9.4800 R:8.0000 rate:0.0160 aloss:-2.0193 eloss:4.0374
# Episode:446 meanR:9.4900 R:9.0000 rate:0.0180 aloss:-2.0198 eloss:4.0387
# Episode:447 meanR:9.4700 R:8.0000 rate:0.0160 aloss:-2.0199 eloss:4.0388
# Episode:448 meanR:9.4500 R:8.0000 rate:0.0160 aloss:-2.0195 eloss:4.0375
# Episode:449 meanR:9.4400 R:9.0000 rate:0.0180 aloss:-2.0197 eloss:4.0384
# Episode:450 meanR:9.4500 R:9.0000 rate:0.0180 aloss:-2.0192 eloss:4.0374
# Episode:451 meanR:9.4400 R:9.0000 rate:0.0180 aloss:-2.0197 eloss:4.0384
# Episode:452 meanR:9.4500 R:10.0000 rate:0.0200 aloss:-2.0201 eloss:4.0390
# Episode:453 meanR:9.4600 R:10.0000 rate:0.0200 aloss:-2.0189 eloss:4.0368
# Episode:454 meanR:9.4400 R:9.0000 rate:0.0180 aloss:-2.0191 eloss:4.0372
# Episode:455 meanR:9.4400 R:10.0000 rate:0.0200 aloss:-2.0202 eloss:4.0392
# Episode:456 meanR:9.4400 R:10.0000 rate:0.0200 aloss:-2.0198 eloss:4.0383
# Episode:457 meanR:9.4200 R:8.0000 rate:0.0160 aloss:-2.0198 eloss:4.0384
# Episode:458 meanR:9.4000 R:8.0000 rate:0.0160 aloss:-2.0198 eloss:4.0381
# Episode:459 meanR:9.4000 R:8.0000 rate:0.0160 aloss:-2.0198 eloss:4.0386
# Episode:460 meanR:9.3900 R:9.0000 rate:0.0180 aloss:-2.0207 eloss:4.0398
# Episode:461 meanR:9.3800 R:9.0000 rate:0.0180 aloss:-2.0203 eloss:4.0394
# Episode:462 meanR:9.4000 R:10.0000 rate:0.0200 aloss:-2.0199 eloss:4.0385
# Episode:463 meanR:9.4000 R:10.0000 rate:0.0200 aloss:-2.0196 eloss:4.0378
# Episode:464 meanR:9.3900 R:9.0000 rate:0.0180 aloss:-2.0197 eloss:4.0382
# Episode:465 meanR:9.4000 R:9.0000 rate:0.0180 aloss:-2.0200 eloss:4.0384
# Episode:466 meanR:9.4100 R:10.0000 rate:0.0200 aloss:-2.0192 eloss:4.0371
# Episode:467 meanR:9.4100 R:9.0000 rate:0.0180 aloss:-2.0189 eloss:4.0366
# Episode:468 meanR:9.4200 R:9.0000 rate:0.0180 aloss:-2.0204 eloss:4.0392
# Episode:469 meanR:9.4100 R:10.0000 rate:0.0200 aloss:-2.0199 eloss:4.0384
# Episode:470 meanR:9.4200 R:10.0000 rate:0.0200 aloss:-2.0202 eloss:4.0388
# Episode:471 meanR:9.4000 R:8.0000 rate:0.0160 aloss:-2.0198 eloss:4.0383
# Episode:472 meanR:9.3900 R:9.0000 rate:0.0180 aloss:-2.0196 eloss:4.0381
# Episode:473 meanR:9.4100 R:10.0000 rate:0.0200 aloss:-2.0198 eloss:4.0380
# Episode:474 meanR:9.4100 R:10.0000 rate:0.0200 aloss:-2.0190 eloss:4.0367
# Episode:475 meanR:9.4100 R:10.0000 rate:0.0200 aloss:-2.0200 eloss:4.0383
# Episode:476 meanR:9.4000 R:8.0000 rate:0.0160 aloss:-2.0199 eloss:4.0384
# Episode:477 meanR:9.3900 R:9.0000 rate:0.0180 aloss:-2.0194 eloss:4.0373
# Episode:478 meanR:9.4000 R:9.0000 rate:0.0180 aloss:-2.0196 eloss:4.0379
# Episode:479 meanR:9.4100 R:10.0000 rate:0.0200 aloss:-2.0202 eloss:4.0390
# Episode:480 meanR:9.4300 R:11.0000 rate:0.0220 aloss:-2.0198 eloss:4.0380
# Episode:481 meanR:9.4400 R:9.0000 rate:0.0180 aloss:-2.0192 eloss:4.0371
# Episode:482 meanR:9.4400 R:10.0000 rate:0.0200 aloss:-2.0199 eloss:4.0383
# Episode:483 meanR:9.4500 R:9.0000 rate:0.0180 aloss:-2.0196 eloss:4.0378
# Episode:484 meanR:9.4700 R:11.0000 rate:0.0220 aloss:-2.0193 eloss:4.0371
# Episode:485 meanR:9.4500 R:9.0000 rate:0.0180 aloss:-2.0199 eloss:4.0384
# Episode:486 meanR:9.4500 R:9.0000 rate:0.0180 aloss:-2.0194 eloss:4.0376
# Episode:487 meanR:9.4400 R:10.0000 rate:0.0200 aloss:-2.0205 eloss:4.0392
# Episode:488 meanR:9.4400 R:10.0000 rate:0.0200 aloss:-2.0192 eloss:4.0371
# Episode:489 meanR:9.4400 R:9.0000 rate:0.0180 aloss:-2.0196 eloss:4.0378
# Episode:490 meanR:9.4400 R:10.0000 rate:0.0200 aloss:-2.0202 eloss:4.0390
# Episode:491 meanR:9.4300 R:9.0000 rate:0.0180 aloss:-2.0194 eloss:4.0375
# Episode:492 meanR:9.4300 R:10.0000 rate:0.0200 aloss:-2.0199 eloss:4.0381
# Episode:493 meanR:9.4300 R:10.0000 rate:0.0200 aloss:-2.0200 eloss:4.0386
# Episode:494 meanR:9.4100 R:8.0000 rate:0.0160 aloss:-2.0193 eloss:4.0373
# Episode:495 meanR:9.4400 R:11.0000 rate:0.0220 aloss:-2.0197 eloss:4.0382
# Episode:496 meanR:9.4400 R:9.0000 rate:0.0180 aloss:-2.0197 eloss:4.0382
# Episode:497 meanR:9.4500 R:9.0000 rate:0.0180 aloss:-2.0192 eloss:4.0372
# Episode:498 meanR:9.4500 R:10.0000 rate:0.0200 aloss:-2.0205 eloss:4.0396
# Episode:499 meanR:9.4400 R:8.0000 rate:0.0160 aloss:-2.0190 eloss:4.0370
# Episode:500 meanR:9.4500 R:9.0000 rate:0.0180 aloss:-2.0193 eloss:4.0373
# Episode:501 meanR:9.4400 R:9.0000 rate:0.0180 aloss:-2.0191 eloss:4.0371
# Episode:502 meanR:9.4300 R:9.0000 rate:0.0180 aloss:-2.0202 eloss:4.0391
# Episode:503 meanR:9.4200 R:8.0000 rate:0.0160 aloss:-2.0191 eloss:4.0372
# Episode:504 meanR:9.4000 R:8.0000 rate:0.0160 aloss:-2.0197 eloss:4.0387
# Episode:505 meanR:9.3900 R:9.0000 rate:0.0180 aloss:-2.0194 eloss:4.0377
# Episode:506 meanR:9.3800 R:8.0000 rate:0.0160 aloss:-2.0187 eloss:4.0366
# Episode:507 meanR:9.3700 R:8.0000 rate:0.0160 aloss:-2.0191 eloss:4.0372
# Episode:508 meanR:9.3500 R:9.0000 rate:0.0180 aloss:-2.0184 eloss:4.0363
# Episode:509 meanR:9.3600 R:11.0000 rate:0.0220 aloss:-2.0191 eloss:4.0372
# Episode:510 meanR:9.3400 R:8.0000 rate:0.0160 aloss:-2.0192 eloss:4.0375
# Episode:511 meanR:9.3500 R:10.0000 rate:0.0200 aloss:-2.0182 eloss:4.0358
# Episode:512 meanR:9.3400 R:8.0000 rate:0.0160 aloss:-2.0195 eloss:4.0385
# Episode:513 meanR:9.3200 R:8.0000 rate:0.0160 aloss:-2.0188 eloss:4.0370
# Episode:514 meanR:9.3200 R:10.0000 rate:0.0200 aloss:-2.0189 eloss:4.0371
# Episode:515 meanR:9.3100 R:9.0000 rate:0.0180 aloss:-2.0186 eloss:4.0368
# Episode:516 meanR:9.3000 R:8.0000 rate:0.0160 aloss:-2.0181 eloss:4.0360
# Episode:517 meanR:9.3000 R:8.0000 rate:0.0160 aloss:-2.0183 eloss:4.0363
# Episode:518 meanR:9.2900 R:9.0000 rate:0.0180 aloss:-2.0185 eloss:4.0368
# Episode:519 meanR:9.2900 R:10.0000 rate:0.0200 aloss:-2.0188 eloss:4.0371
# Episode:520 meanR:9.2900 R:10.0000 rate:0.0200 aloss:-2.0179 eloss:4.0360
# Episode:521 meanR:9.3000 R:10.0000 rate:0.0200 aloss:-2.0185 eloss:4.0371
# Episode:522 meanR:9.3200 R:11.0000 rate:0.0220 aloss:-2.0183 eloss:4.0366
# Episode:523 meanR:9.3200 R:10.0000 rate:0.0200 aloss:-2.0183 eloss:4.0366
# Episode:524 meanR:9.3300 R:10.0000 rate:0.0200 aloss:-2.0176 eloss:4.0352
# Episode:525 meanR:9.3200 R:10.0000 rate:0.0200 aloss:-2.0180 eloss:4.0363
# Episode:526 meanR:9.3200 R:10.0000 rate:0.0200 aloss:-2.0177 eloss:4.0356
# Episode:527 meanR:9.3100 R:9.0000 rate:0.0180 aloss:-2.0173 eloss:4.0350
# Episode:528 meanR:9.3200 R:10.0000 rate:0.0200 aloss:-2.0179 eloss:4.0362
# Episode:529 meanR:9.3100 R:8.0000 rate:0.0160 aloss:-2.0176 eloss:4.0358
# Episode:530 meanR:9.3000 R:10.0000 rate:0.0200 aloss:-2.0177 eloss:4.0358
# Episode:531 meanR:9.3000 R:10.0000 rate:0.0200 aloss:-2.0174 eloss:4.0355
# Episode:532 meanR:9.2800 R:8.0000 rate:0.0160 aloss:-2.0170 eloss:4.0347
# Episode:533 meanR:9.2600 R:8.0000 rate:0.0160 aloss:-2.0168 eloss:4.0345
# Episode:534 meanR:9.2600 R:9.0000 rate:0.0180 aloss:-2.0177 eloss:4.0360
# Episode:535 meanR:9.2500 R:10.0000 rate:0.0200 aloss:-2.0174 eloss:4.0354
# Episode:536 meanR:9.2500 R:10.0000 rate:0.0200 aloss:-2.0168 eloss:4.0347
# Episode:537 meanR:9.2500 R:10.0000 rate:0.0200 aloss:-2.0166 eloss:4.0344
# Episode:538 meanR:9.2400 R:9.0000 rate:0.0180 aloss:-2.0161 eloss:4.0335
# Episode:539 meanR:9.2300 R:9.0000 rate:0.0180 aloss:-2.0165 eloss:4.0344
# Episode:540 meanR:9.2300 R:9.0000 rate:0.0180 aloss:-2.0161 eloss:4.0337
# Episode:541 meanR:9.2400 R:10.0000 rate:0.0200 aloss:-2.0167 eloss:4.0347
# Episode:542 meanR:9.2600 R:10.0000 rate:0.0200 aloss:-2.0159 eloss:4.0333
# Episode:543 meanR:9.2500 R:8.0000 rate:0.0160 aloss:-2.0163 eloss:4.0340
# Episode:544 meanR:9.2400 R:9.0000 rate:0.0180 aloss:-2.0160 eloss:4.0336
# Episode:545 meanR:9.2500 R:9.0000 rate:0.0180 aloss:-2.0163 eloss:4.0344
# Episode:546 meanR:9.2500 R:9.0000 rate:0.0180 aloss:-2.0156 eloss:4.0329
# Episode:547 meanR:9.2600 R:9.0000 rate:0.0180 aloss:-2.0161 eloss:4.0340
# Episode:548 meanR:9.2700 R:9.0000 rate:0.0180 aloss:-2.0161 eloss:4.0341
# Episode:549 meanR:9.2900 R:11.0000 rate:0.0220 aloss:-2.0154 eloss:4.0329
# Episode:550 meanR:9.3100 R:11.0000 rate:0.0220 aloss:-2.0156 eloss:4.0334
# Episode:551 meanR:9.3200 R:10.0000 rate:0.0200 aloss:-2.0153 eloss:4.0330
# Episode:552 meanR:9.3000 R:8.0000 rate:0.0160 aloss:-2.0156 eloss:4.0332
# Episode:553 meanR:9.2900 R:9.0000 rate:0.0180 aloss:-2.0153 eloss:4.0331
# Episode:554 meanR:9.2900 R:9.0000 rate:0.0180 aloss:-2.0158 eloss:4.0339
# Episode:555 meanR:9.2800 R:9.0000 rate:0.0180 aloss:-2.0157 eloss:4.0336
# Episode:556 meanR:9.2800 R:10.0000 rate:0.0200 aloss:-2.0147 eloss:4.0319
# Episode:557 meanR:9.2900 R:9.0000 rate:0.0180 aloss:-2.0149 eloss:4.0324
# Episode:558 meanR:9.3100 R:10.0000 rate:0.0200 aloss:-2.0163 eloss:4.0352
# Episode:559 meanR:9.3200 R:9.0000 rate:0.0180 aloss:-2.0153 eloss:4.0332
# Episode:560 meanR:9.3100 R:8.0000 rate:0.0160 aloss:-2.0155 eloss:4.0336
# Episode:561 meanR:9.3100 R:9.0000 rate:0.0180 aloss:-2.0156 eloss:4.0340
# Episode:562 meanR:9.3200 R:11.0000 rate:0.0220 aloss:-2.0146 eloss:4.0324
# Episode:563 meanR:9.3200 R:10.0000 rate:0.0200 aloss:-2.0142 eloss:4.0316
# Episode:564 meanR:9.3300 R:10.0000 rate:0.0200 aloss:-2.0140 eloss:4.0312
# Episode:565 meanR:9.3400 R:10.0000 rate:0.0200 aloss:-2.0151 eloss:4.0333
# Episode:566 meanR:9.3500 R:11.0000 rate:0.0220 aloss:-2.0144 eloss:4.0323
# Episode:567 meanR:9.3500 R:9.0000 rate:0.0180 aloss:-2.0141 eloss:4.0317
# Episode:568 meanR:9.3700 R:11.0000 rate:0.0220 aloss:-2.0143 eloss:4.0321
# Episode:569 meanR:9.3600 R:9.0000 rate:0.0180 aloss:-2.0148 eloss:4.0328
# Episode:570 meanR:9.3500 R:9.0000 rate:0.0180 aloss:-2.0135 eloss:4.0307
# Episode:571 meanR:9.3800 R:11.0000 rate:0.0220 aloss:-2.0136 eloss:4.0310
# Episode:572 meanR:9.3900 R:10.0000 rate:0.0200 aloss:-2.0125 eloss:4.0291
# Episode:573 meanR:9.3700 R:8.0000 rate:0.0160 aloss:-2.0132 eloss:4.0303
# Episode:574 meanR:9.3700 R:10.0000 rate:0.0200 aloss:-2.0129 eloss:4.0298
# Episode:575 meanR:9.3800 R:11.0000 rate:0.0220 aloss:-2.0129 eloss:4.0301
# Episode:576 meanR:9.4000 R:10.0000 rate:0.0200 aloss:-2.0134 eloss:4.0308
# Episode:577 meanR:9.3900 R:8.0000 rate:0.0160 aloss:-2.0132 eloss:4.0305
# Episode:578 meanR:9.4000 R:10.0000 rate:0.0200 aloss:-2.0136 eloss:4.0314
# Episode:579 meanR:9.3900 R:9.0000 rate:0.0180 aloss:-2.0133 eloss:4.0307
# Episode:580 meanR:9.3600 R:8.0000 rate:0.0160 aloss:-2.0134 eloss:4.0311
# Episode:581 meanR:9.3700 R:10.0000 rate:0.0200 aloss:-2.0131 eloss:4.0307
# Episode:582 meanR:9.3600 R:9.0000 rate:0.0180 aloss:-2.0128 eloss:4.0299
# Episode:583 meanR:9.3600 R:9.0000 rate:0.0180 aloss:-2.0129 eloss:4.0301
# Episode:584 meanR:9.3600 R:11.0000 rate:0.0220 aloss:-2.0126 eloss:4.0298
# Episode:585 meanR:9.3800 R:11.0000 rate:0.0220 aloss:-2.0121 eloss:4.0290
# Episode:586 meanR:9.3900 R:10.0000 rate:0.0200 aloss:-2.0125 eloss:4.0299
# Episode:587 meanR:9.3900 R:10.0000 rate:0.0200 aloss:-2.0128 eloss:4.0304
# Episode:588 meanR:9.3900 R:10.0000 rate:0.0200 aloss:-2.0120 eloss:4.0292
# Episode:589 meanR:9.4000 R:10.0000 rate:0.0200 aloss:-2.0127 eloss:4.0304
# Episode:590 meanR:9.3900 R:9.0000 rate:0.0180 aloss:-2.0116 eloss:4.0285
# Episode:591 meanR:9.3900 R:9.0000 rate:0.0180 aloss:-2.0119 eloss:4.0287
# Episode:592 meanR:9.3900 R:10.0000 rate:0.0200 aloss:-2.0115 eloss:4.0281
# Episode:593 meanR:9.3900 R:10.0000 rate:0.0200 aloss:-2.0117 eloss:4.0287
# Episode:594 meanR:9.4000 R:9.0000 rate:0.0180 aloss:-2.0122 eloss:4.0296
# Episode:595 meanR:9.4000 R:11.0000 rate:0.0220 aloss:-2.0120 eloss:4.0293
# Episode:596 meanR:9.4000 R:9.0000 rate:0.0180 aloss:-2.0117 eloss:4.0288
# Episode:597 meanR:9.4000 R:9.0000 rate:0.0180 aloss:-2.0117 eloss:4.0286
# Episode:598 meanR:9.4200 R:12.0000 rate:0.0240 aloss:-2.0117 eloss:4.0289
# Episode:599 meanR:9.4300 R:9.0000 rate:0.0180 aloss:-2.0113 eloss:4.0280
# Episode:600 meanR:9.4500 R:11.0000 rate:0.0220 aloss:-2.0118 eloss:4.0292
# Episode:601 meanR:9.4700 R:11.0000 rate:0.0220 aloss:-2.0109 eloss:4.0276
# Episode:602 meanR:9.4900 R:11.0000 rate:0.0220 aloss:-2.0112 eloss:4.0281
# Episode:603 meanR:9.5000 R:9.0000 rate:0.0180 aloss:-2.0114 eloss:4.0283
# Episode:604 meanR:9.5200 R:10.0000 rate:0.0200 aloss:-2.0101 eloss:4.0262
# Episode:605 meanR:9.5200 R:9.0000 rate:0.0180 aloss:-2.0109 eloss:4.0276
# Episode:606 meanR:9.5400 R:10.0000 rate:0.0200 aloss:-2.0104 eloss:4.0268
# Episode:607 meanR:9.5400 R:8.0000 rate:0.0160 aloss:-2.0103 eloss:4.0265
# Episode:608 meanR:9.5700 R:12.0000 rate:0.0240 aloss:-2.0111 eloss:4.0280
# Episode:609 meanR:9.5500 R:9.0000 rate:0.0180 aloss:-2.0109 eloss:4.0278
# Episode:610 meanR:9.5700 R:10.0000 rate:0.0200 aloss:-2.0105 eloss:4.0270
# Episode:611 meanR:9.5700 R:10.0000 rate:0.0200 aloss:-2.0105 eloss:4.0272
# Episode:612 meanR:9.5800 R:9.0000 rate:0.0180 aloss:-2.0099 eloss:4.0260
# Episode:613 meanR:9.6100 R:11.0000 rate:0.0220 aloss:-2.0111 eloss:4.0283
# Episode:614 meanR:9.6200 R:11.0000 rate:0.0220 aloss:-2.0105 eloss:4.0272
# Episode:615 meanR:9.6400 R:11.0000 rate:0.0220 aloss:-2.0111 eloss:4.0282
# Episode:616 meanR:9.6800 R:12.0000 rate:0.0240 aloss:-2.0108 eloss:4.0278
# Episode:617 meanR:9.6900 R:9.0000 rate:0.0180 aloss:-2.0103 eloss:4.0269
# Episode:618 meanR:9.7100 R:11.0000 rate:0.0220 aloss:-2.0102 eloss:4.0267
# Episode:619 meanR:9.7300 R:12.0000 rate:0.0240 aloss:-2.0106 eloss:4.0276

# %% [markdown]
# # Visualizing training
#
# Below I'll plot the total rewards for each episode. I'm plotting the rolling average too, in blue.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def running_mean(x, N):
    cumsum = np.cumsum(np.insert(x, 0, 0)) 
    return (cumsum[N:] - cumsum[:-N]) / N

# %%
eps, arr = np.array(episode_rewards_list).T
smoothed_arr = running_mean(arr, 10)
plt.plot(eps[-len(smoothed_arr):], smoothed_arr)
plt.plot(eps, arr, color='grey', alpha=0.3)
plt.xlabel('Episode')
plt.ylabel('Total rewards')

# %%
eps, arr = np.array(rewards_list).T
smoothed_arr = running_mean(arr, 10)
plt.plot(eps[-len(smoothed_arr):], smoothed_arr)
plt.plot(eps, arr, color='grey', alpha=0.3)
plt.xlabel('Episode')
plt.ylabel('Total rewards')

# %%
eps, arr = np.array(aloss_list).T
smoothed_arr = running_mean(arr, 10)
plt.plot(eps[-len(smoothed_arr):], smoothed_arr)
plt.plot(eps, arr, color='grey', alpha=0.3)
plt.xlabel('Episode')
plt.ylabel('Act losses')

# %%
eps, arr = np.array(eloss_list).T
smoothed_arr = running_mean(arr, 10)
plt.plot(eps[-len(smoothed_arr):], smoothed_arr)
plt.plot(eps, arr, color='grey', alpha=0.3)
plt.xlabel('Episode')
plt.ylabel('Env losses')

# %% [markdown]
# ## Testing
#
# Let's checkout how our trained agent plays the game.

# %%
import gym
env = gym.make('CartPole-v0')
env = gym.make('CartPole-v1')

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    saver.restore(sess, 'checkpoints/model.ckpt')    
    #saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    
    # Episodes/epochs
    for _ in range(10):
        state = env.reset()
        total_reward = 0

        # Steps/batches
        while True:
            env.render()
            action_logits = sess.run(model.actions_logits, feed_dict={model.states: state.reshape([1, -1])})
            action = np.argmax(action_logits)
            state, reward, done, _ = env.step(action)
            total_reward += reward
            if done:
                print('total_reward: {}'.format(total_reward))
                break
                
env.close()
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/model.ckpt
# total_reward: 500.0
# total_reward: 500.0
# total_reward: 500.0
# total_reward: 500.0
# total_reward: 500.0
# total_reward: 500.0
# total_reward: 500.0
# total_reward: 500.0
# total_reward: 500.0
# total_reward: 500.0
