# %% [markdown]
# # Navigation
#
# ---
#
# In this notebook, you will learn how to use the Unity ML-Agents environment for the first project of the [Deep Reinforcement Learning Nanodegree](https://www.udacity.com/course/deep-reinforcement-learning-nanodegree--nd893).
#
# ### 1. Start the Environment
#
# We begin by importing some necessary packages.  If the code cell below returns an error, please revisit the project instructions to double-check that you have installed [Unity ML-Agents](https://github.com/Unity-Technologies/ml-agents/blob/master/docs/Installation.md) and [NumPy](http://www.numpy.org/).

# %%
from unityagents import UnityEnvironment
import numpy as np

# %% [markdown]
# Next, we will start the environment!  **_Before running the code cell below_**, change the `file_name` parameter to match the location of the Unity environment that you downloaded.
#
# - **Mac**: `"path/to/Banana.app"`
# - **Windows** (x86): `"path/to/Banana_Windows_x86/Banana.exe"`
# - **Windows** (x86_64): `"path/to/Banana_Windows_x86_64/Banana.exe"`
# - **Linux** (x86): `"path/to/Banana_Linux/Banana.x86"`
# - **Linux** (x86_64): `"path/to/Banana_Linux/Banana.x86_64"`
# - **Linux** (x86, headless): `"path/to/Banana_Linux_NoVis/Banana.x86"`
# - **Linux** (x86_64, headless): `"path/to/Banana_Linux_NoVis/Banana.x86_64"`
#
# For instance, if you are using a Mac, then you downloaded `Banana.app`.  If this file is in the same folder as the notebook, then the line below should appear as follows:
# ```
# env = UnityEnvironment(file_name="Banana.app")
# ```

# %%
# env = UnityEnvironment(file_name="/home/arasdar/VisualBanana_Linux/Banana.x86")
# env = UnityEnvironment(file_name="/home/aras/unity-envs/Banana_Linux/Banana.x86_64")
env = UnityEnvironment(file_name="/home/arasdar/unity-envs/Banana_Linux_NoVis/Banana.x86_64")
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
#
# Unity brain name: BananaBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 37
#         Number of stacked Vector Observation: 1
#         Vector Action space type: discrete
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# The simulation contains a single agent that navigates a large environment.  At each time step, it has four actions at its disposal:
# - `0` - walk forward
# - `1` - walk backward
# - `2` - turn left
# - `3` - turn right
#
# The state space has `37` dimensions and contains the agent's velocity, along with ray-based perception of objects around agent's forward direction.  A reward of `+1` is provided for collecting a yellow banana, and a reward of `-1` is provided for collecting a blue banana.
#
# Run the code cell below to print some information about the environment.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents in the environment
print('Number of agents:', len(env_info.agents))

# number of actions
action_size = brain.vector_action_space_size
print('Number of actions:', action_size)

# examine the state space 
state = env_info.vector_observations[0]
# print('States look like:', state)
state_size = len(state)
print('States have length:', state_size)
# print(state.shape, len(env_info.vector_observations), env_info.vector_observations.shape)
# Out:
# Number of agents: 1
# Number of actions: 4
# States have length: 37

# %% [markdown]
# ### 3. Take Random Actions in the Environment
#
# In the next code cell, you will learn how to use the Python API to control the agent and receive feedback from the environment.
#
# Once this cell is executed, you will watch the agent's performance, if it selects an action (uniformly) at random with each time step.  A window should pop up that allows you to observe the agent, as it moves through the environment.
#
# Of course, as part of the project, you'll have to change the code so that the agent is able to use its experience to gradually choose better actions when interacting with the environment!

# %%
# env_info = env.reset(train_mode=False)[brain_name] # reset the environment
# state = env_info.vector_observations[0]            # get the current state
# score = 0                                          # initialize the score
# num_steps = 0
# while True:
#     num_steps += 1
#     action = np.random.randint(action_size)        # select an action
#     env_info = env.step(action)[brain_name]        # send the action to the environment
#     next_state = env_info.vector_observations[0]   # get the next state
#     reward = env_info.rewards[0]                   # get the reward
#     done = env_info.local_done[0]                  # see if episode has finished
#     score += reward                                # update the score
#     state = next_state                             # roll over the state to next time step
#     if done:                                       # exit loop if episode finished
#         print(state.shape)
#         break
    
# print("Score: {}".format(score))
# num_steps

# %% [markdown]
# When finished, you can close the environment.

# %%
# env.close()

# %% [markdown]
# ### 4. It's Your Turn!
#
# Now it's your turn to train your own agent to solve the environment!  When training the environment, set `train_mode=True`, so that the line for resetting the environment looks like the following:
# ```python
# env_info = env.reset(train_mode=True)[brain_name]
# ```

# %%
# env_info = env.reset(train_mode=True)[brain_name] # reset the environment
# state = env_info.vector_observations[0]            # get the current state
# score = 0                                          # initialize the score
# num_steps = 0
# while True:
#     num_steps += 1
#     action = np.random.randint(action_size)        # select an action
#     env_info = env.step(action)[brain_name]        # send the action to the environment
#     next_state = env_info.vector_observations[0]   # get the next state
#     reward = env_info.rewards[0]                   # get the reward
#     done = env_info.local_done[0]                  # see if episode has finished
#     score += reward                                # update the score
#     state = next_state                             # roll over the state to next time step
#     #print(state)
#     if done:                                       # exit loop if episode finished
#         break
    
# print("Score: {}".format(score))
# num_steps

# %%
import tensorflow as tf
print('TensorFlow Version: {}'.format(tf.__version__))
print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.7.1
# Default GPU Device:

# %%
# env_info = env.reset(train_mode=True)[brain_name] # reset the environment
# state = env_info.vector_observations[0]            # get the current state
# score = 0                                          # initialize the score
# batch = []
# num_steps = 0
# while True: # infinite number of steps
#     num_steps += 1
#     action = np.random.randint(action_size)        # select an action
#     env_info = env.step(action)[brain_name]        # send the action to the environment
#     next_state = env_info.vector_observations[0]   # get the next state
#     reward = env_info.rewards[0]                   # get the reward
#     done = env_info.local_done[0]                  # see if episode has finished
#     score += reward                                # update the score
#     #print(state, action, reward, done)
#     batch.append([state, action, next_state, reward, float(done)])
#     state = next_state                             # roll over the state to next time step
#     if done:                                       # exit loop if episode finished
#         break
    
# print("Score: {}".format(score))
# num_steps

# %%
# batch[0], batch[0][1]

# %%
# batch[0]

# %%
# states = np.array([each[1] for each in batch])
# actions = np.array([each[0] for each in batch])
# next_states = np.array([each[1] for each in batch])
# rewards = np.array([each[2] for each in batch])
# dones = np.array([each[3] for each in batch])
# # infos = np.array([each[4] for each in batch])

# %%
# # print(rewards[:])
# print(np.array(rewards).shape, np.array(states).shape, np.array(actions).shape, np.array(dones).shape)
# print(np.array(rewards).dtype, np.array(states).dtype, np.array(actions).dtype, np.array(dones).dtype)
# print(np.max(np.array(actions)), np.min(np.array(actions)), 
#       (np.max(np.array(actions)) - np.min(np.array(actions)))+1)
# print(np.max(np.array(rewards)), np.min(np.array(rewards)))
# print(np.max(np.array(states)), np.min(np.array(states)))

# %%
def model_input(state_size, hidden_size, batch_size=1):
    states = tf.placeholder(tf.float32, [None, state_size], name='states')
    actions = tf.placeholder(tf.int32, [None], name='actions')
    next_states = tf.placeholder(tf.float32, [None, state_size], name='next_states')
    rewards = tf.placeholder(tf.float32, [None], name='rewards')
    dones = tf.placeholder(tf.float32, [None], name='dones')
    rate = tf.placeholder(tf.float32, [], name='rate') # success rate
    # RNN
    cell = tf.nn.rnn_cell.GRUCell(hidden_size)
    #cell = tf.nn.rnn_cell.LSTMCell(hidden_size)
    cells = tf.nn.rnn_cell.MultiRNNCell([cell], state_is_tuple=False)
    a_initial_state = cells.zero_state(batch_size, tf.float32)
    g_initial_state = cells.zero_state(batch_size, tf.float32)
    d_initial_state = cells.zero_state(batch_size, tf.float32)
    return states, actions, next_states, rewards, dones, rate, cells, a_initial_state, g_initial_state, d_initial_state

# %%
def actor(states, action_size, initial_state, cells, hidden_size, reuse=False): 
    with tf.variable_scope('actor', reuse=reuse):
        # First fully connected layer
        inputs = tf.layers.dense(inputs=states, units=hidden_size)
        print(states.shape, inputs.shape)
        
        # with tf.variable_scope('dynamic_rnn_', reuse=tf.AUTO_REUSE):
        # dynamic means adapt to the batch_size and
        # static means can NOT adapt to the batch_size
        inputs_rnn = tf.reshape(inputs, [1, -1, hidden_size]) # NxH -> 1xNxH
        print(inputs_rnn.shape, initial_state.shape)
        outputs_rnn, final_state = tf.nn.dynamic_rnn(cell=cells, inputs=inputs_rnn, initial_state=initial_state)
        print(outputs_rnn.shape, final_state)
        outputs = tf.reshape(outputs_rnn, [-1, hidden_size]) # 1xNxH -> NxH
        print(outputs.shape)

        # Last fully connected layer
        logits = tf.layers.dense(inputs=outputs, units=action_size)
        print(logits.shape)
        return logits, final_state

# %%
def generator(actions, state_size, initial_state, cells, hidden_size, reuse=False): 
    with tf.variable_scope('generator', reuse=reuse):
        # First fully connected layer
        inputs = tf.layers.dense(inputs=actions, units=hidden_size)
        print(actions.shape, inputs.shape)
        
        # with tf.variable_scope('dynamic_rnn_', reuse=tf.AUTO_REUSE):
        # dynamic means adapt to the batch_size and
        # static means can NOT adapt to the batch_size
        inputs_rnn = tf.reshape(inputs, [1, -1, hidden_size]) # NxH -> 1xNxH
        print(inputs_rnn.shape, initial_state.shape)
        outputs_rnn, final_state = tf.nn.dynamic_rnn(cell=cells, inputs=inputs_rnn, initial_state=initial_state)
        print(outputs_rnn.shape, final_state)
        outputs = tf.reshape(outputs_rnn, [-1, hidden_size]) # 1xNxH -> NxH
        print(outputs.shape)

        # Last fully connected layer
        logits = tf.layers.dense(inputs=outputs, units=state_size)
        print(logits.shape)
        return logits, final_state

# %%
def discriminator(states, actions, action_size, initial_state, cells, hidden_size, reuse=False): 
    with tf.variable_scope('discriminator', reuse=reuse):
        # First fully connected layer
        h = tf.layers.dense(inputs=states, units=action_size)
        h_fused = tf.concat(axis=1, values=[h, actions])
        inputs = tf.layers.dense(inputs=h_fused, units=hidden_size)
        print(h_fused.shape, inputs.shape)
        
        # with tf.variable_scope('dynamic_rnn_', reuse=tf.AUTO_REUSE):
        # dynamic means adapt to the batch_size and
        # static means can NOT adapt to the batch_size
        inputs_rnn = tf.reshape(inputs, [1, -1, hidden_size]) # NxH -> 1xNxH
        print(inputs_rnn.shape, initial_state.shape)
        outputs_rnn, final_state = tf.nn.dynamic_rnn(cell=cells, inputs=inputs_rnn, initial_state=initial_state)
        print(outputs_rnn.shape, final_state)
        outputs = tf.reshape(outputs_rnn, [-1, hidden_size]) # 1xNxH -> NxH
        print(outputs.shape)

        # Last fully connected layer
        logits = tf.layers.dense(inputs=outputs, units=1)
        print(logits.shape)
        return logits, final_state

# %%
def model_loss(state_size, action_size, hidden_size, 
               states, actions, next_states, rewards, dones, rate, 
               cells, a_initial_state, g_initial_state, d_initial_state):
    actions_logits, a_final_state = actor(states=states, hidden_size=hidden_size, action_size=action_size, 
                                          cells=cells, initial_state=a_initial_state)
    actions_labels = tf.one_hot(indices=actions, depth=action_size, dtype=actions_logits.dtype)
    a_loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=actions_logits, 
                                                                       labels=actions_labels))
    next_states_logits, g_final_state = generator(actions=actions_logits, hidden_size=hidden_size, 
                                                  state_size=state_size, 
                                                  cells=cells, initial_state=g_initial_state)
    next_states_labels = tf.nn.sigmoid(next_states)
    a_loss += tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=next_states_logits, 
                                                                     labels=next_states_labels))
    Qlogits_real, d_final_state = discriminator(states=states, actions=actions_labels, hidden_size=hidden_size,
                                           action_size=action_size, cells=cells, initial_state=d_initial_state)
    d_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=Qlogits_real[-1], 
                                                                    labels=rate*tf.ones_like(Qlogits_real[-1])))
    Qlogits_fake, d_final_state = discriminator(states=states, actions=actions_logits, hidden_size=hidden_size,
                                                action_size=action_size, cells=cells, 
                                                initial_state=d_initial_state, reuse=True)
    d_loss += tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=Qlogits_fake[-1], 
                                                                     labels=tf.zeros_like(Qlogits_real[-1])))
    a_loss2 = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=Qlogits_fake[-1], 
                                                                     labels=tf.ones_like(Qlogits_real[-1])))
    next_actions_logits, a_final_state = actor(states=next_states, hidden_size=hidden_size, 
                                               action_size=action_size, cells=cells, 
                                               initial_state=a_initial_state)
    nextQlogits, d_final_state = discriminator(states=next_states, actions=next_actions_logits, 
                                               hidden_size=hidden_size, action_size=action_size, cells=cells, 
                                               initial_state=d_initial_state, reuse=True)
    nextQs = tf.reshape(nextQlogits, shape=[-1]) * dones
    targetQs = rewards + (0.99*nextQs)
    Qs = tf.reshape(Qlogits_real, shape=[-1])
    loss = tf.reduce_mean(tf.square(Qs - targetQs))
    return actions_logits, final_state, loss

# %%
def model_opt(loss, learning_rate):
    # Get weights and bias to update
    t_vars = tf.trainable_variables()
    g_vars = [var for var in t_vars if var.name.startswith('generator')]

    # # Optimize MLP/CNN
    # with tf.control_dependencies(tf.get_collection(tf.GraphKeys.UPDATE_OPS)): # Required for batchnorm (BN)
    # #opt = tf.train.AdamOptimizer(learning_rate).minimize(loss, var_list=g_vars)

    # # Optimize RNN
    #grads, _ = tf.clip_by_global_norm(t_list=tf.gradients(loss, g_vars), clip_norm=5) # usually around 1-5
    grads = tf.gradients(loss, g_vars)
    opt = tf.train.AdamOptimizer(learning_rate).apply_gradients(grads_and_vars=zip(grads, g_vars))

    return opt

# %%
class Model:
    def __init__(self, state_size, action_size, hidden_size, learning_rate):

        # Data of the Model: make the data available inside the framework
        self.states, self.actions, self.targetQs, cells, self.initial_state = model_input(
                state_size=state_size, hidden_size=hidden_size)
        
        # Create the Model: calculating the loss and forwad pass
        self.actions_logits, self.final_state, self.loss = model_loss(
            action_size=action_size, hidden_size=hidden_size, 
            states=self.states, actions=self.actions, 
            targetQs=self.targetQs, cells=cells, initial_state=self.initial_state)

        # Update the model: backward pass and backprop
        self.opt = model_opt(loss=self.loss, learning_rate=learning_rate)

# %%
from collections import deque

class Memory():    
    def __init__(self, max_size = 1000):
        self.buffer = deque(maxlen=max_size)
        self.states = deque(maxlen=max_size)

# %%
# Network parameters
action_size = 4
state_size = 37
hidden_size = 37*2             # number of units in each Q-network hidden layer
learning_rate = 0.0001         # Q-network learning rate

# Memory parameters
memory_size = 50            # memory capacity - 1000 DQN
batch_size = 50             # experience mini-batch size - 20 DQN
gamma = 0.99                 # future reward discount

# %%
# Reset/init the graph/session
graph = tf.reset_default_graph()

# Init the model
model = Model(action_size=action_size, hidden_size=hidden_size, state_size=state_size, learning_rate=learning_rate)

# Init the memory
memory = Memory(max_size=memory_size)
# Out:
# (?, 37) (?, 74)
# (1, ?, 74) (<tf.Tensor 'MultiRNNCellZeroState/GRUCellZeroState/zeros:0' shape=(1, 74) dtype=float32>,)
# (1, ?, 74) (<tf.Tensor 'generator/rnn/while/Exit_3:0' shape=(1, 74) dtype=float32>,)
# (?, 74)
# (?, 4)

# %%
model.initial_state[0]
# Out:
# <tf.Tensor 'MultiRNNCellZeroState/GRUCellZeroState/zeros:0' shape=(1, 74) dtype=float32>

# %%
# state = env.reset()
# for _ in range(batch_size):
#     action = env.action_space.sample()
#     next_state, reward, done, _ = env.step(action)
#     memory.buffer.append([state, action, next_state, reward, float(done)])
#     state = next_state
#     if done is True:
#         state = env.reset()

# %%
env_info = env.reset(train_mode=True)[brain_name] # reset the environment
state = env_info.vector_observations[0]   # get the state
for _ in range(memory_size):
    action = np.random.randint(action_size)        # select an action
    env_info = env.step(action)[brain_name]        # send the action to the environment
    next_state = env_info.vector_observations[0]   # get the next state
    reward = env_info.rewards[0]                   # get the reward
    done = env_info.local_done[0]                  # see if episode has finished
    memory.buffer.append([state, action, next_state, reward, float(done)])
    memory.states.append(np.zeros([1, hidden_size])) # initial_states for rnn/mem
    state = next_state
    if done:                                       # exit loop if episode finished
        env_info = env.reset(train_mode=True)[brain_name] # reset the environment
        state = env_info.vector_observations[0]   # get the state
        break

# %%
memory.states[0].shape, model.initial_state[0].shape # gru
# memory.states[0][1].shape, model.initial_state[0][1].shape #lstm
# Out:
# ((1, 74), TensorShape([Dimension(1), Dimension(74)]))

# %%
saver = tf.train.Saver()
episode_rewards_list, rewards_list, loss_list = [], [], []

# TF session for training
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    #saver.restore(sess, 'checkpoints/model.ckpt')    
    #saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    episode_reward = deque(maxlen=100) # 100 episodes average/running average/running mean/window
    
    # Training episodes/epochs
    for ep in range(11111):
        total_reward = 0
        loss_batch = []
        #state = env.reset()
        env_info = env.reset(train_mode=True)[brain_name] # reset the environment
        state = env_info.vector_observations[0]   # get the current state
        initial_state = sess.run(model.initial_state)

        # Training steps/batches
        while True:
            action_logits, final_state = sess.run([model.actions_logits, model.final_state],
                                                  feed_dict = {model.states: state.reshape([1, -1]), 
                                                               model.initial_state: initial_state})
            action = np.argmax(action_logits)
            #state, reward, done, _ = env.step(action)
            env_info = env.step(action)[brain_name]        # send the action to the environment
            next_state = env_info.vector_observations[0]   # get the next state
            reward = env_info.rewards[0]                   # get the reward
            done = env_info.local_done[0]                  # see if episode has finished
            memory.buffer.append([state, action, next_state, reward, float(done)])
            memory.states.append(initial_state)
            total_reward += reward
            state = next_state
            initial_state = final_state
            
            # Training
            batch = memory.buffer
            states = np.array([each[0] for each in batch])
            actions = np.array([each[1] for each in batch])
            next_states = np.array([each[2] for each in batch])
            rewards = np.array([each[3] for each in batch])
            dones = np.array([each[4] for each in batch])
            initial_states = memory.states
            next_actions_logits = sess.run(model.actions_logits, 
                                           feed_dict = {model.states: next_states,
                                                        model.initial_state: initial_states[1]})
            nextQs = np.max(next_actions_logits, axis=1) * (1-dones)
            targetQs = rewards + (gamma * nextQs)
            loss, _ = sess.run([model.loss, model.opt], feed_dict = {model.states: states, 
                                                                     model.actions: actions,
                                                                     model.targetQs: targetQs,
                                                                     model.initial_state: initial_states[0]})
            # End of training
            loss_batch.append(loss)
            if done is True:
                break
                
        # Outputing: priting out/Potting
        episode_reward.append(total_reward)
        print('Episode:{}'.format(ep),
              'meanR:{:.4f}'.format(np.mean(episode_reward)),
              'R:{:.4f}'.format(total_reward),
              'loss:{:.4f}'.format(np.mean(loss_batch)))
        # Ploting out
        episode_rewards_list.append([ep, np.mean(episode_reward)])
        rewards_list.append([ep, total_reward])
        loss_list.append([ep, np.mean(loss_batch)])
        # Break episode/epoch loop
        if np.mean(episode_reward) >= +13:
            break
            
    # At the end of all training episodes/epochs
    saver.save(sess, 'checkpoints/model.ckpt')
# Out:
# Episode:0 meanR:-1.0000 R:-1.0000 loss:0.0422
# Episode:1 meanR:0.0000 R:1.0000 loss:0.0084
# Episode:2 meanR:0.6667 R:2.0000 loss:0.0116
# Episode:3 meanR:0.5000 R:0.0000 loss:0.0094
# Episode:4 meanR:0.4000 R:0.0000 loss:0.0080
# Episode:5 meanR:0.3333 R:0.0000 loss:0.0091
# Episode:6 meanR:-0.1429 R:-3.0000 loss:0.0174
# Episode:7 meanR:-0.2500 R:-1.0000 loss:0.0147
# Episode:8 meanR:-0.4444 R:-2.0000 loss:0.0175
# Episode:9 meanR:-0.6000 R:-2.0000 loss:0.0345
# Episode:10 meanR:-0.6364 R:-1.0000 loss:0.0240
# Episode:11 meanR:-0.5000 R:1.0000 loss:0.0127
# Episode:12 meanR:-0.4615 R:0.0000 loss:0.0255
# Episode:13 meanR:-0.4286 R:0.0000 loss:0.0313
# Episode:14 meanR:-0.3333 R:1.0000 loss:0.0082
# Episode:15 meanR:-0.2500 R:1.0000 loss:0.0160
# Episode:16 meanR:-0.1765 R:1.0000 loss:0.0117
# Episode:17 meanR:0.0000 R:3.0000 loss:0.0227
# Episode:18 meanR:0.1053 R:2.0000 loss:0.1274
# Episode:19 meanR:0.1000 R:0.0000 loss:0.0409
# Episode:20 meanR:0.3810 R:6.0000 loss:0.0396
# Episode:21 meanR:0.3182 R:-1.0000 loss:0.0478
# Episode:22 meanR:0.3043 R:0.0000 loss:0.0176
# Episode:23 meanR:0.3333 R:1.0000 loss:0.0136
# Episode:24 meanR:0.3600 R:1.0000 loss:0.0094
# Episode:25 meanR:0.3846 R:1.0000 loss:0.0130
# Episode:26 meanR:0.4815 R:3.0000 loss:0.0214
# Episode:27 meanR:0.5000 R:1.0000 loss:0.0495
# Episode:28 meanR:0.6207 R:4.0000 loss:0.0310
# Episode:29 meanR:0.8000 R:6.0000 loss:0.0565
# Episode:30 meanR:0.9677 R:6.0000 loss:0.0799
# Episode:31 meanR:1.1250 R:6.0000 loss:0.0532
# Episode:32 meanR:1.1212 R:1.0000 loss:0.0594
# Episode:33 meanR:1.2941 R:7.0000 loss:0.0539
# Episode:34 meanR:1.4571 R:7.0000 loss:0.0576
# Episode:35 meanR:1.6111 R:7.0000 loss:0.0482
# Episode:36 meanR:1.7568 R:7.0000 loss:0.0806
# Episode:37 meanR:1.7895 R:3.0000 loss:0.0730
# Episode:38 meanR:1.7692 R:1.0000 loss:0.0466
# Episode:39 meanR:1.9000 R:7.0000 loss:0.0477
# Episode:40 meanR:1.8537 R:0.0000 loss:0.0232
# Episode:41 meanR:1.7857 R:-1.0000 loss:0.0153
# Episode:42 meanR:1.7907 R:2.0000 loss:0.0184
# Episode:43 meanR:1.8409 R:4.0000 loss:0.0331
# Episode:44 meanR:1.8000 R:0.0000 loss:0.0447
# Episode:45 meanR:1.8043 R:2.0000 loss:0.0510
# Episode:46 meanR:1.7447 R:-1.0000 loss:0.0516
# Episode:47 meanR:1.7500 R:2.0000 loss:0.0375
# Episode:48 meanR:1.7347 R:1.0000 loss:0.0325
# Episode:49 meanR:1.8000 R:5.0000 loss:0.0467
# Episode:50 meanR:1.8627 R:5.0000 loss:0.0472
# Episode:51 meanR:1.9231 R:5.0000 loss:0.0456
# Episode:52 meanR:2.1132 R:12.0000 loss:0.0772
# Episode:53 meanR:2.1296 R:3.0000 loss:0.0648
# Episode:54 meanR:2.3091 R:12.0000 loss:0.0785
# Episode:55 meanR:2.3036 R:2.0000 loss:0.0585
# Episode:56 meanR:2.4035 R:8.0000 loss:0.0590
# Episode:57 meanR:2.3966 R:2.0000 loss:0.0367
# Episode:58 meanR:2.4576 R:6.0000 loss:0.0398
# Episode:59 meanR:2.4000 R:-1.0000 loss:0.0404
# Episode:60 meanR:2.4426 R:5.0000 loss:0.0314
# Episode:61 meanR:2.5000 R:6.0000 loss:0.0448
# Episode:62 meanR:2.4603 R:0.0000 loss:0.0229
# Episode:63 meanR:2.4062 R:-1.0000 loss:0.0136
# Episode:64 meanR:2.4462 R:5.0000 loss:0.0267
# Episode:65 meanR:2.4848 R:5.0000 loss:0.0518
# Episode:66 meanR:2.5224 R:5.0000 loss:0.0440
# Episode:67 meanR:2.5735 R:6.0000 loss:0.0586
# Episode:68 meanR:2.5217 R:-1.0000 loss:0.0333
# Episode:69 meanR:2.5143 R:2.0000 loss:0.0231
# Episode:70 meanR:2.5352 R:4.0000 loss:0.0247
# Episode:71 meanR:2.5000 R:0.0000 loss:0.0320
# Episode:72 meanR:2.4795 R:1.0000 loss:0.0295
# Episode:73 meanR:2.6216 R:13.0000 loss:0.0316
# Episode:74 meanR:2.6400 R:4.0000 loss:0.0519
# Episode:75 meanR:2.7368 R:10.0000 loss:0.0731
# Episode:76 meanR:2.7922 R:7.0000 loss:0.0521
# Episode:77 meanR:2.8077 R:4.0000 loss:0.0408
# Episode:78 meanR:2.8481 R:6.0000 loss:0.0607
# Episode:79 meanR:2.8625 R:4.0000 loss:0.0583
# Episode:80 meanR:2.9136 R:7.0000 loss:0.0494
# Episode:81 meanR:2.8902 R:1.0000 loss:0.0531
# Episode:82 meanR:2.8554 R:0.0000 loss:0.0434
# Episode:83 meanR:2.8333 R:1.0000 loss:0.0204
# Episode:84 meanR:2.8000 R:0.0000 loss:0.0077
# Episode:85 meanR:2.8023 R:3.0000 loss:0.0141
# Episode:86 meanR:2.8506 R:7.0000 loss:0.0320
# Episode:87 meanR:2.9091 R:8.0000 loss:0.0706
# Episode:88 meanR:2.9551 R:7.0000 loss:0.0673
# Episode:89 meanR:2.9333 R:1.0000 loss:0.0555
# Episode:90 meanR:2.9780 R:7.0000 loss:0.0276
# Episode:91 meanR:2.9891 R:4.0000 loss:0.0395
# Episode:92 meanR:3.0430 R:8.0000 loss:0.0410
# Episode:93 meanR:3.1489 R:13.0000 loss:0.0593
# Episode:94 meanR:3.2211 R:10.0000 loss:0.0508
# Episode:95 meanR:3.2604 R:7.0000 loss:0.0615
# Episode:96 meanR:3.3299 R:10.0000 loss:0.0634
# Episode:97 meanR:3.4592 R:16.0000 loss:0.0511
# Episode:98 meanR:3.5657 R:14.0000 loss:0.0921
# Episode:99 meanR:3.6400 R:11.0000 loss:0.0878
# Episode:100 meanR:3.7600 R:11.0000 loss:0.1052
# Episode:101 meanR:3.8200 R:7.0000 loss:0.1128
# Episode:102 meanR:3.8700 R:7.0000 loss:0.0950
# Episode:103 meanR:3.9700 R:10.0000 loss:0.0919
# Episode:104 meanR:4.0800 R:11.0000 loss:0.0787
# Episode:105 meanR:4.1500 R:7.0000 loss:0.0769
# Episode:106 meanR:4.2400 R:6.0000 loss:0.0690
# Episode:107 meanR:4.3400 R:9.0000 loss:0.0688
# Episode:108 meanR:4.4400 R:8.0000 loss:0.0677
# Episode:109 meanR:4.5100 R:5.0000 loss:0.0549
# Episode:110 meanR:4.5200 R:0.0000 loss:0.0270
# Episode:111 meanR:4.5100 R:0.0000 loss:0.0124
# Episode:112 meanR:4.5800 R:7.0000 loss:0.0332
# Episode:113 meanR:4.6600 R:8.0000 loss:0.0459
# Episode:114 meanR:4.8000 R:15.0000 loss:0.0651
# Episode:115 meanR:4.8400 R:5.0000 loss:0.0672
# Episode:116 meanR:4.9100 R:8.0000 loss:0.0801
# Episode:117 meanR:4.9600 R:8.0000 loss:0.0587
# Episode:118 meanR:5.0700 R:13.0000 loss:0.0577
# Episode:119 meanR:5.1300 R:6.0000 loss:0.0554
# Episode:120 meanR:5.1400 R:7.0000 loss:0.0510
# Episode:121 meanR:5.2100 R:6.0000 loss:0.0393
# Episode:122 meanR:5.2700 R:6.0000 loss:0.0382
# Episode:123 meanR:5.3400 R:8.0000 loss:0.0350
# Episode:124 meanR:5.3800 R:5.0000 loss:0.0409
# Episode:125 meanR:5.4600 R:9.0000 loss:0.0416
# Episode:126 meanR:5.4300 R:0.0000 loss:0.0481
# Episode:127 meanR:5.5300 R:11.0000 loss:0.0389
# Episode:128 meanR:5.6200 R:13.0000 loss:0.0700
# Episode:129 meanR:5.6400 R:8.0000 loss:0.0468
# Episode:130 meanR:5.6500 R:7.0000 loss:0.0307
# Episode:131 meanR:5.6600 R:7.0000 loss:0.0688
# Episode:132 meanR:5.7500 R:10.0000 loss:0.0545
# Episode:133 meanR:5.8400 R:16.0000 loss:0.0611
# Episode:134 meanR:5.8400 R:7.0000 loss:0.0852
# Episode:135 meanR:5.8800 R:11.0000 loss:0.0581
# Episode:136 meanR:5.9100 R:10.0000 loss:0.0670
# Episode:137 meanR:5.9000 R:2.0000 loss:0.0854
# Episode:138 meanR:5.9200 R:3.0000 loss:0.0426
# Episode:139 meanR:5.9500 R:10.0000 loss:0.0594
# Episode:140 meanR:6.0500 R:10.0000 loss:0.0586
# Episode:141 meanR:6.1800 R:12.0000 loss:0.0750
# Episode:142 meanR:6.2400 R:8.0000 loss:0.0880
# Episode:143 meanR:6.2700 R:7.0000 loss:0.0710
# Episode:144 meanR:6.3900 R:12.0000 loss:0.0461
# Episode:145 meanR:6.4600 R:9.0000 loss:0.0935
# Episode:146 meanR:6.6200 R:15.0000 loss:0.0710
# Episode:147 meanR:6.6800 R:8.0000 loss:0.0584
# Episode:148 meanR:6.7800 R:11.0000 loss:0.0603
# Episode:149 meanR:6.8700 R:14.0000 loss:0.0510
# Episode:150 meanR:6.8800 R:6.0000 loss:0.0671
# Episode:151 meanR:6.8900 R:6.0000 loss:0.0612
# Episode:152 meanR:6.8200 R:5.0000 loss:0.0775
# Episode:153 meanR:6.8800 R:9.0000 loss:0.0586
# Episode:154 meanR:6.8500 R:9.0000 loss:0.0713
# Episode:155 meanR:6.8500 R:2.0000 loss:0.0515
# Episode:156 meanR:6.8600 R:9.0000 loss:0.0351
# Episode:157 meanR:6.9000 R:6.0000 loss:0.0363
# Episode:158 meanR:6.8700 R:3.0000 loss:0.0360
# Episode:159 meanR:6.9300 R:5.0000 loss:0.0201
# Episode:160 meanR:6.9000 R:2.0000 loss:0.0307
# Episode:161 meanR:6.8500 R:1.0000 loss:0.0188
# Episode:162 meanR:6.9000 R:5.0000 loss:0.0191
# Episode:163 meanR:6.9100 R:0.0000 loss:0.0260
# Episode:164 meanR:6.8800 R:2.0000 loss:0.0103
# Episode:165 meanR:6.9200 R:9.0000 loss:0.0201
# Episode:166 meanR:6.9600 R:9.0000 loss:0.0365
# Episode:167 meanR:6.9800 R:8.0000 loss:0.0452
# Episode:168 meanR:7.0900 R:10.0000 loss:0.0404
# Episode:169 meanR:7.1400 R:7.0000 loss:0.0405
# Episode:170 meanR:7.1300 R:3.0000 loss:0.0509
# Episode:171 meanR:7.1700 R:4.0000 loss:0.0430
# Episode:172 meanR:7.2500 R:9.0000 loss:0.0399
# Episode:173 meanR:7.1500 R:3.0000 loss:0.0383
# Episode:174 meanR:7.2100 R:10.0000 loss:0.0366
# Episode:175 meanR:7.1600 R:5.0000 loss:0.0308
# Episode:176 meanR:7.2200 R:13.0000 loss:0.0456
# Episode:177 meanR:7.3100 R:13.0000 loss:0.0809
# Episode:178 meanR:7.4000 R:15.0000 loss:0.0605
# Episode:179 meanR:7.4300 R:7.0000 loss:0.0863
# Episode:180 meanR:7.5100 R:15.0000 loss:0.0701
# Episode:181 meanR:7.6200 R:12.0000 loss:0.0703
# Episode:182 meanR:7.6700 R:5.0000 loss:0.0617
# Episode:183 meanR:7.7300 R:7.0000 loss:0.0609
# Episode:184 meanR:7.7900 R:6.0000 loss:0.0489
# Episode:185 meanR:7.8500 R:9.0000 loss:0.0490
# Episode:186 meanR:7.8500 R:7.0000 loss:0.0358
# Episode:187 meanR:7.8300 R:6.0000 loss:0.0412
# Episode:188 meanR:7.8000 R:4.0000 loss:0.0640
# Episode:189 meanR:7.8200 R:3.0000 loss:0.0564
# Episode:190 meanR:7.8200 R:7.0000 loss:0.0347
# Episode:191 meanR:7.7600 R:-2.0000 loss:0.0378
# Episode:192 meanR:7.7000 R:2.0000 loss:0.0276
# Episode:193 meanR:7.5700 R:0.0000 loss:0.0200
# Episode:194 meanR:7.5200 R:5.0000 loss:0.0192
# Episode:195 meanR:7.4600 R:1.0000 loss:0.0176
# Episode:196 meanR:7.4000 R:4.0000 loss:0.0164
# Episode:197 meanR:7.2800 R:4.0000 loss:0.0167
# Episode:198 meanR:7.2000 R:6.0000 loss:0.0384
# Episode:199 meanR:7.0900 R:0.0000 loss:0.0332
# Episode:200 meanR:7.1200 R:14.0000 loss:0.0448
# Episode:201 meanR:7.1600 R:11.0000 loss:0.0837
# Episode:202 meanR:7.2100 R:12.0000 loss:0.0867
# Episode:203 meanR:7.1200 R:1.0000 loss:0.0776
# Episode:204 meanR:7.1800 R:17.0000 loss:0.0635
# Episode:205 meanR:7.1900 R:8.0000 loss:0.0609
# Episode:206 meanR:7.2400 R:11.0000 loss:0.0546
# Episode:207 meanR:7.2200 R:7.0000 loss:0.0665
# Episode:208 meanR:7.2100 R:7.0000 loss:0.0584
# Episode:209 meanR:7.2700 R:11.0000 loss:0.0401
# Episode:210 meanR:7.3500 R:8.0000 loss:0.0557
# Episode:211 meanR:7.4100 R:6.0000 loss:0.0566
# Episode:212 meanR:7.4300 R:9.0000 loss:0.0590
# Episode:213 meanR:7.4600 R:11.0000 loss:0.0571
# Episode:214 meanR:7.3300 R:2.0000 loss:0.0566
# Episode:215 meanR:7.3500 R:7.0000 loss:0.0657
# Episode:216 meanR:7.3600 R:9.0000 loss:0.0397
# Episode:217 meanR:7.3900 R:11.0000 loss:0.0692
# Episode:218 meanR:7.3800 R:12.0000 loss:0.0693
# Episode:219 meanR:7.3700 R:5.0000 loss:0.0607
# Episode:220 meanR:7.4200 R:12.0000 loss:0.0833
# Episode:221 meanR:7.4100 R:5.0000 loss:0.0828
# Episode:222 meanR:7.4200 R:7.0000 loss:0.0682
# Episode:223 meanR:7.4600 R:12.0000 loss:0.0552
# Episode:224 meanR:7.4700 R:6.0000 loss:0.0327
# Episode:225 meanR:7.4000 R:2.0000 loss:0.0482
# Episode:226 meanR:7.5100 R:11.0000 loss:0.0781
# Episode:227 meanR:7.4000 R:0.0000 loss:0.0515
# Episode:228 meanR:7.3900 R:12.0000 loss:0.0741
# Episode:229 meanR:7.4100 R:10.0000 loss:0.0698
# Episode:230 meanR:7.4900 R:15.0000 loss:0.0880
# Episode:231 meanR:7.4600 R:4.0000 loss:0.0547
# Episode:232 meanR:7.4300 R:7.0000 loss:0.0497
# Episode:233 meanR:7.3800 R:11.0000 loss:0.0522
# Episode:234 meanR:7.3400 R:3.0000 loss:0.0431
# Episode:235 meanR:7.2800 R:5.0000 loss:0.0431
# Episode:236 meanR:7.2400 R:6.0000 loss:0.0432
# Episode:237 meanR:7.3100 R:9.0000 loss:0.0474
# Episode:238 meanR:7.3200 R:4.0000 loss:0.0509
# Episode:239 meanR:7.2600 R:4.0000 loss:0.0437
# Episode:240 meanR:7.2800 R:12.0000 loss:0.0478
# Episode:241 meanR:7.3300 R:17.0000 loss:0.0822
# Episode:242 meanR:7.3500 R:10.0000 loss:0.0602
# Episode:243 meanR:7.4000 R:12.0000 loss:0.0733
# Episode:244 meanR:7.3500 R:7.0000 loss:0.0810
# Episode:245 meanR:7.2900 R:3.0000 loss:0.0398
# Episode:246 meanR:7.2600 R:12.0000 loss:0.0469
# Episode:247 meanR:7.3500 R:17.0000 loss:0.0592
# Episode:248 meanR:7.3200 R:8.0000 loss:0.0702
# Episode:249 meanR:7.3200 R:14.0000 loss:0.0644
# Episode:250 meanR:7.4100 R:15.0000 loss:0.0795
# Episode:251 meanR:7.3900 R:4.0000 loss:0.0787
# Episode:252 meanR:7.3800 R:4.0000 loss:0.0314
# Episode:253 meanR:7.3600 R:7.0000 loss:0.0335
# Episode:254 meanR:7.2900 R:2.0000 loss:0.0529
# Episode:255 meanR:7.3300 R:6.0000 loss:0.0428
# Episode:256 meanR:7.2900 R:5.0000 loss:0.0471
# Episode:257 meanR:7.2800 R:5.0000 loss:0.0570
# Episode:258 meanR:7.3300 R:8.0000 loss:0.0416
# Episode:259 meanR:7.3200 R:4.0000 loss:0.0598
# Episode:260 meanR:7.4200 R:12.0000 loss:0.0339
# Episode:261 meanR:7.4700 R:6.0000 loss:0.0572
# Episode:262 meanR:7.5700 R:15.0000 loss:0.0589
# Episode:263 meanR:7.6900 R:12.0000 loss:0.0723
# Episode:264 meanR:7.7600 R:9.0000 loss:0.0924
# Episode:265 meanR:7.7800 R:11.0000 loss:0.0603
# Episode:266 meanR:7.8500 R:16.0000 loss:0.0470
# Episode:267 meanR:7.8800 R:11.0000 loss:0.0887
# Episode:268 meanR:7.9500 R:17.0000 loss:0.0687
# Episode:269 meanR:8.0100 R:13.0000 loss:0.0509
# Episode:270 meanR:8.0700 R:9.0000 loss:0.0609
# Episode:271 meanR:8.0900 R:6.0000 loss:0.0896
# Episode:272 meanR:8.0500 R:5.0000 loss:0.0411
# Episode:273 meanR:8.1300 R:11.0000 loss:0.0473
# Episode:274 meanR:8.0900 R:6.0000 loss:0.0595
# Episode:275 meanR:8.1100 R:7.0000 loss:0.0483
# Episode:276 meanR:8.0400 R:6.0000 loss:0.0312
# Episode:277 meanR:7.9600 R:5.0000 loss:0.0630
# Episode:278 meanR:7.8400 R:3.0000 loss:0.0455
# Episode:279 meanR:7.8700 R:10.0000 loss:0.0513
# Episode:280 meanR:7.7700 R:5.0000 loss:0.0284
# Episode:281 meanR:7.7500 R:10.0000 loss:0.0400
# Episode:282 meanR:7.7900 R:9.0000 loss:0.0460
# Episode:283 meanR:7.7900 R:7.0000 loss:0.0416
# Episode:284 meanR:7.8600 R:13.0000 loss:0.0599
# Episode:285 meanR:7.8500 R:8.0000 loss:0.0612
# Episode:286 meanR:7.8700 R:9.0000 loss:0.0733
# Episode:287 meanR:7.8500 R:4.0000 loss:0.0393
# Episode:288 meanR:7.8400 R:3.0000 loss:0.0219
# Episode:289 meanR:7.8800 R:7.0000 loss:0.0587
# Episode:290 meanR:7.8600 R:5.0000 loss:0.0347
# Episode:291 meanR:7.9800 R:10.0000 loss:0.0608
# Episode:292 meanR:8.0900 R:13.0000 loss:0.0548
# Episode:293 meanR:8.1800 R:9.0000 loss:0.0770
# Episode:294 meanR:8.2300 R:10.0000 loss:0.0711
# Episode:295 meanR:8.3700 R:15.0000 loss:0.0521
# Episode:296 meanR:8.4500 R:12.0000 loss:0.0811
# Episode:297 meanR:8.5600 R:15.0000 loss:0.0843
# Episode:298 meanR:8.6100 R:11.0000 loss:0.0715
# Episode:299 meanR:8.6600 R:5.0000 loss:0.0545
# Episode:300 meanR:8.6200 R:10.0000 loss:0.0562
# Episode:301 meanR:8.5900 R:8.0000 loss:0.0388
# Episode:302 meanR:8.5400 R:7.0000 loss:0.0551
# Episode:303 meanR:8.6100 R:8.0000 loss:0.0452
# Episode:304 meanR:8.4400 R:0.0000 loss:0.0430
# Episode:305 meanR:8.3900 R:3.0000 loss:0.0312
# Episode:306 meanR:8.3500 R:7.0000 loss:0.0375
# Episode:307 meanR:8.3000 R:2.0000 loss:0.0331
# Episode:308 meanR:8.2800 R:5.0000 loss:0.0475
# Episode:309 meanR:8.2900 R:12.0000 loss:0.0419
# Episode:310 meanR:8.3300 R:12.0000 loss:0.0635
# Episode:311 meanR:8.3900 R:12.0000 loss:0.0681
# Episode:312 meanR:8.3500 R:5.0000 loss:0.0679
# Episode:313 meanR:8.3600 R:12.0000 loss:0.0523
# Episode:314 meanR:8.4500 R:11.0000 loss:0.0869
# Episode:315 meanR:8.4700 R:9.0000 loss:0.0460
# Episode:316 meanR:8.5200 R:14.0000 loss:0.0790
# Episode:317 meanR:8.5000 R:9.0000 loss:0.0481
# Episode:318 meanR:8.4100 R:3.0000 loss:0.0578
# Episode:319 meanR:8.4900 R:13.0000 loss:0.0575
# Episode:320 meanR:8.4000 R:3.0000 loss:0.0576
# Episode:321 meanR:8.4300 R:8.0000 loss:0.0448
# Episode:322 meanR:8.5100 R:15.0000 loss:0.0580
# Episode:323 meanR:8.5000 R:11.0000 loss:0.0851
# Episode:324 meanR:8.5400 R:10.0000 loss:0.0555
# Episode:325 meanR:8.5700 R:5.0000 loss:0.0528
# Episode:326 meanR:8.5500 R:9.0000 loss:0.0447
# Episode:327 meanR:8.5700 R:2.0000 loss:0.0342
# Episode:328 meanR:8.6100 R:16.0000 loss:0.0510
# Episode:329 meanR:8.5900 R:8.0000 loss:0.0768
# Episode:330 meanR:8.5500 R:11.0000 loss:0.0563
# Episode:331 meanR:8.6300 R:12.0000 loss:0.0736
# Episode:332 meanR:8.6000 R:4.0000 loss:0.0696
# Episode:333 meanR:8.5400 R:5.0000 loss:0.0465
# Episode:334 meanR:8.6300 R:12.0000 loss:0.0665
# Episode:335 meanR:8.6600 R:8.0000 loss:0.0806
# Episode:336 meanR:8.6600 R:6.0000 loss:0.0551
# Episode:337 meanR:8.6900 R:12.0000 loss:0.0642
# Episode:338 meanR:8.7500 R:10.0000 loss:0.0451
# Episode:339 meanR:8.7500 R:4.0000 loss:0.0586
# Episode:340 meanR:8.7300 R:10.0000 loss:0.0400
# Episode:341 meanR:8.6300 R:7.0000 loss:0.0597
# Episode:342 meanR:8.6400 R:11.0000 loss:0.0724
# Episode:343 meanR:8.5600 R:4.0000 loss:0.0491
# Episode:344 meanR:8.4900 R:0.0000 loss:0.0354
# Episode:345 meanR:8.4700 R:1.0000 loss:0.0161
# Episode:346 meanR:8.3700 R:2.0000 loss:0.0172
# Episode:347 meanR:8.2100 R:1.0000 loss:0.0126
# Episode:348 meanR:8.2100 R:8.0000 loss:0.0343
# Episode:349 meanR:8.1200 R:5.0000 loss:0.0472
# Episode:350 meanR:8.1100 R:14.0000 loss:0.0541
# Episode:351 meanR:8.2100 R:14.0000 loss:0.0629
# Episode:352 meanR:8.2500 R:8.0000 loss:0.0593
# Episode:353 meanR:8.2100 R:3.0000 loss:0.0434
# Episode:354 meanR:8.3600 R:17.0000 loss:0.0512
# Episode:355 meanR:8.4100 R:11.0000 loss:0.0721
# Episode:356 meanR:8.4800 R:12.0000 loss:0.0574
# Episode:357 meanR:8.5200 R:9.0000 loss:0.1034
# Episode:358 meanR:8.5400 R:10.0000 loss:0.0655
# Episode:359 meanR:8.6300 R:13.0000 loss:0.0665
# Episode:360 meanR:8.5900 R:8.0000 loss:0.0678
# Episode:361 meanR:8.6900 R:16.0000 loss:0.0734
# Episode:362 meanR:8.6000 R:6.0000 loss:0.1148
# Episode:363 meanR:8.6300 R:15.0000 loss:0.0573
# Episode:364 meanR:8.6000 R:6.0000 loss:0.0673
# Episode:365 meanR:8.5600 R:7.0000 loss:0.0628
# Episode:366 meanR:8.4700 R:7.0000 loss:0.0483
# Episode:367 meanR:8.4000 R:4.0000 loss:0.0361
# Episode:368 meanR:8.3600 R:13.0000 loss:0.0859
# Episode:369 meanR:8.2900 R:6.0000 loss:0.0566
# Episode:370 meanR:8.2900 R:9.0000 loss:0.0590
# Episode:371 meanR:8.3700 R:14.0000 loss:0.0810
# Episode:372 meanR:8.4100 R:9.0000 loss:0.0702
# Episode:373 meanR:8.4100 R:11.0000 loss:0.0547
# Episode:374 meanR:8.4000 R:5.0000 loss:0.0383
# Episode:375 meanR:8.4700 R:14.0000 loss:0.0447
# Episode:376 meanR:8.5000 R:9.0000 loss:0.0958
# Episode:377 meanR:8.4700 R:2.0000 loss:0.0675
# Episode:378 meanR:8.5600 R:12.0000 loss:0.0453
# Episode:379 meanR:8.6500 R:19.0000 loss:0.0749
# Episode:380 meanR:8.6200 R:2.0000 loss:0.0922
# Episode:381 meanR:8.5100 R:-1.0000 loss:0.0234
# Episode:382 meanR:8.4300 R:1.0000 loss:0.0427
# Episode:383 meanR:8.3700 R:1.0000 loss:0.0249
# Episode:384 meanR:8.3700 R:13.0000 loss:0.0434
# Episode:385 meanR:8.3500 R:6.0000 loss:0.0457
# Episode:386 meanR:8.3900 R:13.0000 loss:0.0581
# Episode:387 meanR:8.3900 R:4.0000 loss:0.0518
# Episode:388 meanR:8.4500 R:9.0000 loss:0.0514
# Episode:389 meanR:8.5400 R:16.0000 loss:0.0724
# Episode:390 meanR:8.6300 R:14.0000 loss:0.0646
# Episode:391 meanR:8.6300 R:10.0000 loss:0.0751
# Episode:392 meanR:8.6300 R:13.0000 loss:0.0903
# Episode:393 meanR:8.6400 R:10.0000 loss:0.0905
# Episode:394 meanR:8.6300 R:9.0000 loss:0.0638
# Episode:395 meanR:8.6300 R:15.0000 loss:0.0535
# Episode:396 meanR:8.5800 R:7.0000 loss:0.0643
# Episode:397 meanR:8.5500 R:12.0000 loss:0.0658
# Episode:398 meanR:8.5500 R:11.0000 loss:0.0662
# Episode:399 meanR:8.6500 R:15.0000 loss:0.0838
# Episode:400 meanR:8.6600 R:11.0000 loss:0.0659
# Episode:401 meanR:8.6100 R:3.0000 loss:0.0389
# Episode:402 meanR:8.6600 R:12.0000 loss:0.0718
# Episode:403 meanR:8.6700 R:9.0000 loss:0.0672
# Episode:404 meanR:8.7900 R:12.0000 loss:0.0323
# Episode:405 meanR:8.8400 R:8.0000 loss:0.0710
# Episode:406 meanR:8.8200 R:5.0000 loss:0.0274
# Episode:407 meanR:8.9300 R:13.0000 loss:0.0343
# Episode:408 meanR:8.9400 R:6.0000 loss:0.0671
# Episode:409 meanR:8.8800 R:6.0000 loss:0.0303
# Episode:410 meanR:8.8500 R:9.0000 loss:0.0326
# Episode:411 meanR:8.8200 R:9.0000 loss:0.0442
# Episode:412 meanR:8.9100 R:14.0000 loss:0.0473
# Episode:413 meanR:8.8900 R:10.0000 loss:0.0782
# Episode:414 meanR:8.8500 R:7.0000 loss:0.0811
# Episode:415 meanR:8.8500 R:9.0000 loss:0.0474
# Episode:416 meanR:8.8500 R:14.0000 loss:0.0831
# Episode:417 meanR:8.8900 R:13.0000 loss:0.0978
# Episode:418 meanR:8.9000 R:4.0000 loss:0.0466
# Episode:419 meanR:8.9000 R:13.0000 loss:0.0558
# Episode:420 meanR:9.0000 R:13.0000 loss:0.0524
# Episode:421 meanR:9.0300 R:11.0000 loss:0.0512
# Episode:422 meanR:8.9900 R:11.0000 loss:0.0591
# Episode:423 meanR:8.9600 R:8.0000 loss:0.0742
# Episode:424 meanR:8.9600 R:10.0000 loss:0.0703
# Episode:425 meanR:9.0000 R:9.0000 loss:0.0554
# Episode:426 meanR:8.9900 R:8.0000 loss:0.0483
# Episode:427 meanR:9.0600 R:9.0000 loss:0.0599
# Episode:428 meanR:9.0400 R:14.0000 loss:0.0707
# Episode:429 meanR:9.0500 R:9.0000 loss:0.0638
# Episode:430 meanR:9.0400 R:10.0000 loss:0.0812
# Episode:431 meanR:9.0200 R:10.0000 loss:0.0520
# Episode:432 meanR:9.0500 R:7.0000 loss:0.0545
# Episode:433 meanR:9.0900 R:9.0000 loss:0.0481
# Episode:434 meanR:9.0700 R:10.0000 loss:0.0648
# Episode:435 meanR:9.0500 R:6.0000 loss:0.0499
# Episode:436 meanR:9.1000 R:11.0000 loss:0.0484
# Episode:437 meanR:9.1300 R:15.0000 loss:0.0576
# Episode:438 meanR:9.1100 R:8.0000 loss:0.0871
# Episode:439 meanR:9.1700 R:10.0000 loss:0.0763
# Episode:440 meanR:9.1800 R:11.0000 loss:0.0540
# Episode:441 meanR:9.2400 R:13.0000 loss:0.0694
# Episode:442 meanR:9.2300 R:10.0000 loss:0.0463
# Episode:443 meanR:9.3300 R:14.0000 loss:0.0725
# Episode:444 meanR:9.4000 R:7.0000 loss:0.0624
# Episode:445 meanR:9.5200 R:13.0000 loss:0.0526
# Episode:446 meanR:9.5900 R:9.0000 loss:0.0702
# Episode:447 meanR:9.6400 R:6.0000 loss:0.0422
# Episode:448 meanR:9.6300 R:7.0000 loss:0.0516
# Episode:449 meanR:9.6700 R:9.0000 loss:0.0659
# Episode:450 meanR:9.5800 R:5.0000 loss:0.0479
# Episode:451 meanR:9.4400 R:0.0000 loss:0.0216
# Episode:452 meanR:9.4500 R:9.0000 loss:0.0366
# Episode:453 meanR:9.4100 R:-1.0000 loss:0.0498
# Episode:454 meanR:9.2500 R:1.0000 loss:0.0240
# Episode:455 meanR:9.2400 R:10.0000 loss:0.0367
# Episode:456 meanR:9.2300 R:11.0000 loss:0.0667
# Episode:457 meanR:9.2600 R:12.0000 loss:0.0650
# Episode:458 meanR:9.2700 R:11.0000 loss:0.0931
# Episode:459 meanR:9.2200 R:8.0000 loss:0.0627
# Episode:460 meanR:9.1900 R:5.0000 loss:0.0566
# Episode:461 meanR:9.0700 R:4.0000 loss:0.0328
# Episode:462 meanR:9.0200 R:1.0000 loss:0.0138
# Episode:463 meanR:8.9800 R:11.0000 loss:0.0343
# Episode:464 meanR:9.0300 R:11.0000 loss:0.0495
# Episode:465 meanR:9.0000 R:4.0000 loss:0.0425
# Episode:466 meanR:8.9500 R:2.0000 loss:0.0196
# Episode:467 meanR:8.9200 R:1.0000 loss:0.0119
# Episode:468 meanR:8.9100 R:12.0000 loss:0.0278
# Episode:469 meanR:8.9500 R:10.0000 loss:0.0462
# Episode:470 meanR:8.8900 R:3.0000 loss:0.0426
# Episode:471 meanR:8.7700 R:2.0000 loss:0.0282
# Episode:472 meanR:8.8000 R:12.0000 loss:0.0497
# Episode:473 meanR:8.7900 R:10.0000 loss:0.0425
# Episode:474 meanR:8.8700 R:13.0000 loss:0.0500
# Episode:475 meanR:8.8500 R:12.0000 loss:0.0638
# Episode:476 meanR:8.8700 R:11.0000 loss:0.0727
# Episode:477 meanR:8.9000 R:5.0000 loss:0.0522
# Episode:478 meanR:8.9200 R:14.0000 loss:0.0530
# Episode:479 meanR:8.8000 R:7.0000 loss:0.1069
# Episode:480 meanR:8.8800 R:10.0000 loss:0.0312
# Episode:481 meanR:8.9600 R:7.0000 loss:0.0589
# Episode:482 meanR:8.9800 R:3.0000 loss:0.0529
# Episode:483 meanR:9.0600 R:9.0000 loss:0.0172
# Episode:484 meanR:8.9800 R:5.0000 loss:0.0488
# Episode:485 meanR:8.9200 R:0.0000 loss:0.0455
# Episode:486 meanR:8.8400 R:5.0000 loss:0.0231
# Episode:487 meanR:8.8300 R:3.0000 loss:0.0257
# Episode:488 meanR:8.8600 R:12.0000 loss:0.0426
# Episode:489 meanR:8.7700 R:7.0000 loss:0.0480
# Episode:490 meanR:8.7100 R:8.0000 loss:0.0392
# Episode:491 meanR:8.6900 R:8.0000 loss:0.0291
# Episode:492 meanR:8.6600 R:10.0000 loss:0.0408
# Episode:493 meanR:8.7000 R:14.0000 loss:0.0618
# Episode:494 meanR:8.6100 R:0.0000 loss:0.0441
# Episode:495 meanR:8.5500 R:9.0000 loss:0.0402
# Episode:496 meanR:8.5700 R:9.0000 loss:0.0487
# Episode:497 meanR:8.4700 R:2.0000 loss:0.0356
# Episode:498 meanR:8.4600 R:10.0000 loss:0.0515
# Episode:499 meanR:8.4100 R:10.0000 loss:0.0409
# Episode:500 meanR:8.4300 R:13.0000 loss:0.0559
# Episode:501 meanR:8.5100 R:11.0000 loss:0.0474
# Episode:502 meanR:8.4600 R:7.0000 loss:0.0354
# Episode:503 meanR:8.4100 R:4.0000 loss:0.0523
# Episode:504 meanR:8.4000 R:11.0000 loss:0.0319
# Episode:505 meanR:8.3700 R:5.0000 loss:0.0519
# Episode:506 meanR:8.3900 R:7.0000 loss:0.0359
# Episode:507 meanR:8.3800 R:12.0000 loss:0.0433
# Episode:508 meanR:8.4200 R:10.0000 loss:0.0730
# Episode:509 meanR:8.4800 R:12.0000 loss:0.0472
# Episode:510 meanR:8.4700 R:8.0000 loss:0.0439
# Episode:511 meanR:8.4500 R:7.0000 loss:0.0586
# Episode:512 meanR:8.4100 R:10.0000 loss:0.0486
# Episode:513 meanR:8.3500 R:4.0000 loss:0.0299
# Episode:514 meanR:8.3600 R:8.0000 loss:0.0388
# Episode:515 meanR:8.3500 R:8.0000 loss:0.0622
# Episode:516 meanR:8.3700 R:16.0000 loss:0.0700
# Episode:517 meanR:8.3600 R:12.0000 loss:0.0572
# Episode:518 meanR:8.3900 R:7.0000 loss:0.0624
# Episode:519 meanR:8.3800 R:12.0000 loss:0.0627
# Episode:520 meanR:8.3300 R:8.0000 loss:0.0780
# Episode:521 meanR:8.3100 R:9.0000 loss:0.0577
# Episode:522 meanR:8.3100 R:11.0000 loss:0.0494
# Episode:523 meanR:8.2900 R:6.0000 loss:0.0425
# Episode:524 meanR:8.3000 R:11.0000 loss:0.0413
# Episode:525 meanR:8.3100 R:10.0000 loss:0.0519
# Episode:526 meanR:8.2700 R:4.0000 loss:0.0399
# Episode:527 meanR:8.2800 R:10.0000 loss:0.0529
# Episode:528 meanR:8.1800 R:4.0000 loss:0.0446
# Episode:529 meanR:8.1900 R:10.0000 loss:0.0415
# Episode:530 meanR:8.1700 R:8.0000 loss:0.0468
# Episode:531 meanR:8.1500 R:8.0000 loss:0.0379
# Episode:532 meanR:8.2100 R:13.0000 loss:0.0418
# Episode:533 meanR:8.2100 R:9.0000 loss:0.0538
# Episode:534 meanR:8.2200 R:11.0000 loss:0.0378
# Episode:535 meanR:8.3200 R:16.0000 loss:0.0586
# Episode:536 meanR:8.2500 R:4.0000 loss:0.0575
# Episode:537 meanR:8.1800 R:8.0000 loss:0.0449
# Episode:538 meanR:8.2100 R:11.0000 loss:0.0420
# Episode:539 meanR:8.1500 R:4.0000 loss:0.0616
# Episode:540 meanR:8.1400 R:10.0000 loss:0.0485
# Episode:541 meanR:8.0700 R:6.0000 loss:0.0840
# Episode:542 meanR:8.0600 R:9.0000 loss:0.0343
# Episode:543 meanR:8.0200 R:10.0000 loss:0.0626
# Episode:544 meanR:8.0400 R:9.0000 loss:0.0275
# Episode:545 meanR:8.0100 R:10.0000 loss:0.0409
# Episode:546 meanR:8.0200 R:10.0000 loss:0.0859
# Episode:547 meanR:8.0200 R:6.0000 loss:0.0490
# Episode:548 meanR:8.1000 R:15.0000 loss:0.0662
# Episode:549 meanR:8.1600 R:15.0000 loss:0.0833
# Episode:550 meanR:8.2000 R:9.0000 loss:0.0716
# Episode:551 meanR:8.3500 R:15.0000 loss:0.0671
# Episode:552 meanR:8.3800 R:12.0000 loss:0.0705
# Episode:553 meanR:8.4700 R:8.0000 loss:0.0460
# Episode:554 meanR:8.6300 R:17.0000 loss:0.0566
# Episode:555 meanR:8.6500 R:12.0000 loss:0.0679
# Episode:556 meanR:8.6300 R:9.0000 loss:0.0841
# Episode:557 meanR:8.5700 R:6.0000 loss:0.0360
# Episode:558 meanR:8.5100 R:5.0000 loss:0.0456
# Episode:559 meanR:8.5600 R:13.0000 loss:0.0517
# Episode:560 meanR:8.6400 R:13.0000 loss:0.0483
# Episode:561 meanR:8.7600 R:16.0000 loss:0.0670
# Episode:562 meanR:8.8400 R:9.0000 loss:0.0806
# Episode:563 meanR:8.8300 R:10.0000 loss:0.0730
# Episode:564 meanR:8.7800 R:6.0000 loss:0.0524
# Episode:565 meanR:8.8600 R:12.0000 loss:0.0650
# Episode:566 meanR:8.8900 R:5.0000 loss:0.0450
# Episode:567 meanR:8.9500 R:7.0000 loss:0.0515
# Episode:568 meanR:8.9200 R:9.0000 loss:0.0344
# Episode:569 meanR:8.9100 R:9.0000 loss:0.0466
# Episode:570 meanR:8.9200 R:4.0000 loss:0.0464
# Episode:571 meanR:9.0300 R:13.0000 loss:0.0547
# Episode:572 meanR:8.9800 R:7.0000 loss:0.0569
# Episode:573 meanR:8.9300 R:5.0000 loss:0.0689
# Episode:574 meanR:8.8900 R:9.0000 loss:0.0459
# Episode:575 meanR:8.8700 R:10.0000 loss:0.0517
# Episode:576 meanR:8.8200 R:6.0000 loss:0.0556
# Episode:577 meanR:8.8600 R:9.0000 loss:0.0528
# Episode:578 meanR:8.8100 R:9.0000 loss:0.0699
# Episode:579 meanR:8.8700 R:13.0000 loss:0.0965
# Episode:580 meanR:8.8900 R:12.0000 loss:0.0391
# Episode:581 meanR:8.8800 R:6.0000 loss:0.0529
# Episode:582 meanR:9.0000 R:15.0000 loss:0.1124
# Episode:583 meanR:9.0500 R:14.0000 loss:0.0596
# Episode:584 meanR:9.1300 R:13.0000 loss:0.0452
# Episode:585 meanR:9.2100 R:8.0000 loss:0.0726
# Episode:586 meanR:9.2600 R:10.0000 loss:0.0519
# Episode:587 meanR:9.4100 R:18.0000 loss:0.0666
# Episode:588 meanR:9.4000 R:11.0000 loss:0.1108
# Episode:589 meanR:9.4900 R:16.0000 loss:0.0581
# Episode:590 meanR:9.5500 R:14.0000 loss:0.0606
# Episode:591 meanR:9.5700 R:10.0000 loss:0.0650
# Episode:592 meanR:9.5900 R:12.0000 loss:0.0610
# Episode:593 meanR:9.5400 R:9.0000 loss:0.0683
# Episode:594 meanR:9.6500 R:11.0000 loss:0.0592
# Episode:595 meanR:9.5900 R:3.0000 loss:0.0414
# Episode:596 meanR:9.6400 R:14.0000 loss:0.0414
# Episode:597 meanR:9.7500 R:13.0000 loss:0.0775
# Episode:598 meanR:9.7900 R:14.0000 loss:0.0857
# Episode:599 meanR:9.7600 R:7.0000 loss:0.0866
# Episode:600 meanR:9.7600 R:13.0000 loss:0.0814
# Episode:601 meanR:9.7300 R:8.0000 loss:0.0685
# Episode:602 meanR:9.7700 R:11.0000 loss:0.0546
# Episode:603 meanR:9.7700 R:4.0000 loss:0.0657
# Episode:604 meanR:9.7500 R:9.0000 loss:0.0556
# Episode:605 meanR:9.8000 R:10.0000 loss:0.0713
# Episode:606 meanR:9.8200 R:9.0000 loss:0.0655
# Episode:607 meanR:9.8200 R:12.0000 loss:0.0550
# Episode:608 meanR:9.8500 R:13.0000 loss:0.0462
# Episode:609 meanR:9.8100 R:8.0000 loss:0.0606
# Episode:610 meanR:9.8200 R:9.0000 loss:0.0695
# Episode:611 meanR:9.8500 R:10.0000 loss:0.0580
# Episode:612 meanR:9.8900 R:14.0000 loss:0.0618
# Episode:613 meanR:9.9200 R:7.0000 loss:0.0596
# Episode:614 meanR:10.0100 R:17.0000 loss:0.0747
# Episode:615 meanR:10.0400 R:11.0000 loss:0.0483
# Episode:616 meanR:9.9900 R:11.0000 loss:0.0708
# Episode:617 meanR:9.9700 R:10.0000 loss:0.0619
# Episode:618 meanR:9.9900 R:9.0000 loss:0.0689
# Episode:619 meanR:9.9900 R:12.0000 loss:0.0462
# Episode:620 meanR:9.9700 R:6.0000 loss:0.0612
# Episode:621 meanR:9.9300 R:5.0000 loss:0.0455
# Episode:622 meanR:9.8600 R:4.0000 loss:0.0400
# Episode:623 meanR:9.8600 R:6.0000 loss:0.0294
# Episode:624 meanR:9.8100 R:6.0000 loss:0.0299
# Episode:625 meanR:9.7700 R:6.0000 loss:0.0270
# Episode:626 meanR:9.8700 R:14.0000 loss:0.0363
# Episode:627 meanR:9.9000 R:13.0000 loss:0.0689
# Episode:628 meanR:9.9000 R:4.0000 loss:0.0494
# Episode:629 meanR:9.8900 R:9.0000 loss:0.1046
# Episode:630 meanR:9.9100 R:10.0000 loss:0.0628
# Episode:631 meanR:9.9300 R:10.0000 loss:0.0616
# Episode:632 meanR:9.9400 R:14.0000 loss:0.0469
# Episode:633 meanR:9.9400 R:9.0000 loss:0.0754
# Episode:634 meanR:9.9300 R:10.0000 loss:0.0627
# Episode:635 meanR:9.8900 R:12.0000 loss:0.0589
# Episode:636 meanR:9.9900 R:14.0000 loss:0.0865
# Episode:637 meanR:9.9600 R:5.0000 loss:0.0581
# Episode:638 meanR:9.9300 R:8.0000 loss:0.0556
# Episode:639 meanR:10.0700 R:18.0000 loss:0.0665
# Episode:640 meanR:10.0400 R:7.0000 loss:0.0690
# Episode:641 meanR:10.0600 R:8.0000 loss:0.0730
# Episode:642 meanR:10.1200 R:15.0000 loss:0.0578
# Episode:643 meanR:10.1000 R:8.0000 loss:0.0526
# Episode:644 meanR:10.0900 R:8.0000 loss:0.0562
# Episode:645 meanR:10.0500 R:6.0000 loss:0.0715
# Episode:646 meanR:10.0800 R:13.0000 loss:0.0554
# Episode:647 meanR:10.0600 R:4.0000 loss:0.0361
# Episode:648 meanR:9.9900 R:8.0000 loss:0.0339
# Episode:649 meanR:9.9500 R:11.0000 loss:0.0364
# Episode:650 meanR:9.8700 R:1.0000 loss:0.0409
# Episode:651 meanR:9.8200 R:10.0000 loss:0.0392
# Episode:652 meanR:9.8500 R:15.0000 loss:0.0545
# Episode:653 meanR:9.9100 R:14.0000 loss:0.0601
# Episode:654 meanR:9.8400 R:10.0000 loss:0.0696
# Episode:655 meanR:9.7800 R:6.0000 loss:0.0810
# Episode:656 meanR:9.8000 R:11.0000 loss:0.0406
# Episode:657 meanR:9.8400 R:10.0000 loss:0.0673
# Episode:658 meanR:9.8600 R:7.0000 loss:0.0437
# Episode:659 meanR:9.8400 R:11.0000 loss:0.0397
# Episode:660 meanR:9.8000 R:9.0000 loss:0.0478
# Episode:661 meanR:9.7800 R:14.0000 loss:0.0580
# Episode:662 meanR:9.8000 R:11.0000 loss:0.0452
# Episode:663 meanR:9.8100 R:11.0000 loss:0.0588
# Episode:664 meanR:9.8600 R:11.0000 loss:0.0495
# Episode:665 meanR:9.9000 R:16.0000 loss:0.0612
# Episode:666 meanR:9.8900 R:4.0000 loss:0.0624
# Episode:667 meanR:9.9300 R:11.0000 loss:0.0661
# Episode:668 meanR:9.9200 R:8.0000 loss:0.0589
# Episode:669 meanR:9.9400 R:11.0000 loss:0.0681
# Episode:670 meanR:9.9800 R:8.0000 loss:0.0731
# Episode:671 meanR:9.9000 R:5.0000 loss:0.0769
# Episode:672 meanR:9.8600 R:3.0000 loss:0.0383
# Episode:673 meanR:9.9700 R:16.0000 loss:0.0482
# Episode:674 meanR:9.9800 R:10.0000 loss:0.0618
# Episode:675 meanR:9.9700 R:9.0000 loss:0.0678
# Episode:676 meanR:9.9900 R:8.0000 loss:0.0847
# Episode:677 meanR:9.9100 R:1.0000 loss:0.0482
# Episode:678 meanR:9.8400 R:2.0000 loss:0.0412
# Episode:679 meanR:9.7000 R:-1.0000 loss:0.0476
# Episode:680 meanR:9.6500 R:7.0000 loss:0.0430
# Episode:681 meanR:9.6900 R:10.0000 loss:0.0502
# Episode:682 meanR:9.6400 R:10.0000 loss:0.0509
# Episode:683 meanR:9.5600 R:6.0000 loss:0.0687
# Episode:684 meanR:9.5100 R:8.0000 loss:0.0362
# Episode:685 meanR:9.5300 R:10.0000 loss:0.0604
# Episode:686 meanR:9.5000 R:7.0000 loss:0.0528
# Episode:687 meanR:9.4500 R:13.0000 loss:0.0585
# Episode:688 meanR:9.4600 R:12.0000 loss:0.0543
# Episode:689 meanR:9.4100 R:11.0000 loss:0.0734
# Episode:690 meanR:9.3900 R:12.0000 loss:0.0866
# Episode:691 meanR:9.4200 R:13.0000 loss:0.0465
# Episode:692 meanR:9.3500 R:5.0000 loss:0.0511
# Episode:693 meanR:9.3800 R:12.0000 loss:0.0538
# Episode:694 meanR:9.3700 R:10.0000 loss:0.0683
# Episode:695 meanR:9.4800 R:14.0000 loss:0.0731
# Episode:696 meanR:9.4100 R:7.0000 loss:0.0695
# Episode:697 meanR:9.3200 R:4.0000 loss:0.0805
# Episode:698 meanR:9.2900 R:11.0000 loss:0.0529
# Episode:699 meanR:9.2500 R:3.0000 loss:0.0501
# Episode:700 meanR:9.2100 R:9.0000 loss:0.0352
# Episode:701 meanR:9.2100 R:8.0000 loss:0.0577
# Episode:702 meanR:9.2100 R:11.0000 loss:0.0403
# Episode:703 meanR:9.2700 R:10.0000 loss:0.0589
# Episode:704 meanR:9.2100 R:3.0000 loss:0.0498
# Episode:705 meanR:9.2600 R:15.0000 loss:0.0457
# Episode:706 meanR:9.3100 R:14.0000 loss:0.0659
# Episode:707 meanR:9.3200 R:13.0000 loss:0.0980
# Episode:708 meanR:9.3100 R:12.0000 loss:0.0640
# Episode:709 meanR:9.2300 R:0.0000 loss:0.0536
# Episode:710 meanR:9.1800 R:4.0000 loss:0.0426
# Episode:711 meanR:9.1600 R:8.0000 loss:0.0558
# Episode:712 meanR:9.1300 R:11.0000 loss:0.0551
# Episode:713 meanR:9.1600 R:10.0000 loss:0.0788
# Episode:714 meanR:9.1100 R:12.0000 loss:0.0619
# Episode:715 meanR:9.0500 R:5.0000 loss:0.0544
# Episode:716 meanR:9.0600 R:12.0000 loss:0.0470
# Episode:717 meanR:9.0300 R:7.0000 loss:0.0775
# Episode:718 meanR:9.0400 R:10.0000 loss:0.0459
# Episode:719 meanR:9.0400 R:12.0000 loss:0.0583
# Episode:720 meanR:9.1200 R:14.0000 loss:0.0553
# Episode:721 meanR:9.1900 R:12.0000 loss:0.0693
# Episode:722 meanR:9.2700 R:12.0000 loss:0.0681
# Episode:723 meanR:9.2900 R:8.0000 loss:0.0569
# Episode:724 meanR:9.3100 R:8.0000 loss:0.0507
# Episode:725 meanR:9.4000 R:15.0000 loss:0.0490
# Episode:726 meanR:9.3000 R:4.0000 loss:0.0490
# Episode:727 meanR:9.2600 R:9.0000 loss:0.0487
# Episode:728 meanR:9.3400 R:12.0000 loss:0.0623
# Episode:729 meanR:9.3500 R:10.0000 loss:0.0577
# Episode:730 meanR:9.3000 R:5.0000 loss:0.0548
# Episode:731 meanR:9.3400 R:14.0000 loss:0.0678
# Episode:732 meanR:9.2900 R:9.0000 loss:0.0769
# Episode:733 meanR:9.2900 R:9.0000 loss:0.0313
# Episode:734 meanR:9.3100 R:12.0000 loss:0.0836
# Episode:735 meanR:9.3200 R:13.0000 loss:0.0871
# Episode:736 meanR:9.3200 R:14.0000 loss:0.0678
# Episode:737 meanR:9.3500 R:8.0000 loss:0.1146
# Episode:738 meanR:9.3400 R:7.0000 loss:0.0679
# Episode:739 meanR:9.3300 R:17.0000 loss:0.0769
# Episode:740 meanR:9.3600 R:10.0000 loss:0.0750
# Episode:741 meanR:9.4400 R:16.0000 loss:0.0589
# Episode:742 meanR:9.3900 R:10.0000 loss:0.0650
# Episode:743 meanR:9.4000 R:9.0000 loss:0.0427
# Episode:744 meanR:9.3700 R:5.0000 loss:0.0443
# Episode:745 meanR:9.4000 R:9.0000 loss:0.0421
# Episode:746 meanR:9.4000 R:13.0000 loss:0.0706
# Episode:747 meanR:9.5100 R:15.0000 loss:0.0831
# Episode:748 meanR:9.5700 R:14.0000 loss:0.1161
# Episode:749 meanR:9.5700 R:11.0000 loss:0.0779
# Episode:750 meanR:9.6800 R:12.0000 loss:0.0483
# Episode:751 meanR:9.6800 R:10.0000 loss:0.0595
# Episode:752 meanR:9.6400 R:11.0000 loss:0.0599
# Episode:753 meanR:9.5500 R:5.0000 loss:0.0530
# Episode:754 meanR:9.5900 R:14.0000 loss:0.0662
# Episode:755 meanR:9.5900 R:6.0000 loss:0.0814
# Episode:756 meanR:9.5100 R:3.0000 loss:0.0519
# Episode:757 meanR:9.5500 R:14.0000 loss:0.0520
# Episode:758 meanR:9.6200 R:14.0000 loss:0.0748
# Episode:759 meanR:9.6800 R:17.0000 loss:0.0912
# Episode:760 meanR:9.7000 R:11.0000 loss:0.0644
# Episode:761 meanR:9.6600 R:10.0000 loss:0.0897
# Episode:762 meanR:9.6900 R:14.0000 loss:0.0507
# Episode:763 meanR:9.6700 R:9.0000 loss:0.0509
# Episode:764 meanR:9.7000 R:14.0000 loss:0.0798
# Episode:765 meanR:9.6900 R:15.0000 loss:0.0600
# Episode:766 meanR:9.7300 R:8.0000 loss:0.0998
# Episode:767 meanR:9.7600 R:14.0000 loss:0.0698
# Episode:768 meanR:9.7500 R:7.0000 loss:0.0775
# Episode:769 meanR:9.6500 R:1.0000 loss:0.0617
# Episode:770 meanR:9.5800 R:1.0000 loss:0.0342
# Episode:771 meanR:9.6300 R:10.0000 loss:0.0374
# Episode:772 meanR:9.6800 R:8.0000 loss:0.0477
# Episode:773 meanR:9.5700 R:5.0000 loss:0.0431
# Episode:774 meanR:9.5900 R:12.0000 loss:0.0477
# Episode:775 meanR:9.6100 R:11.0000 loss:0.0542
# Episode:776 meanR:9.5900 R:6.0000 loss:0.0363
# Episode:777 meanR:9.7400 R:16.0000 loss:0.0421
# Episode:778 meanR:9.7900 R:7.0000 loss:0.0725
# Episode:779 meanR:9.8600 R:6.0000 loss:0.0458
# Episode:780 meanR:9.9500 R:16.0000 loss:0.0571
# Episode:781 meanR:9.9700 R:12.0000 loss:0.0695
# Episode:782 meanR:10.0000 R:13.0000 loss:0.0600
# Episode:783 meanR:10.0700 R:13.0000 loss:0.0529
# Episode:784 meanR:10.0600 R:7.0000 loss:0.0573
# Episode:785 meanR:10.1000 R:14.0000 loss:0.0709
# Episode:786 meanR:10.1900 R:16.0000 loss:0.1095
# Episode:787 meanR:10.1000 R:4.0000 loss:0.0559
# Episode:788 meanR:10.0300 R:5.0000 loss:0.0421
# Episode:789 meanR:10.0500 R:13.0000 loss:0.0662
# Episode:790 meanR:10.1000 R:17.0000 loss:0.0771
# Episode:791 meanR:10.0400 R:7.0000 loss:0.1274
# Episode:792 meanR:10.0200 R:3.0000 loss:0.0807
# Episode:793 meanR:9.9300 R:3.0000 loss:0.0427
# Episode:794 meanR:9.8800 R:5.0000 loss:0.0534
# Episode:795 meanR:9.8800 R:14.0000 loss:0.0558
# Episode:796 meanR:9.8600 R:5.0000 loss:0.0663
# Episode:797 meanR:9.9400 R:12.0000 loss:0.0503
# Episode:798 meanR:9.9400 R:11.0000 loss:0.0528
# Episode:799 meanR:10.0100 R:10.0000 loss:0.0688
# Episode:800 meanR:10.0400 R:12.0000 loss:0.0792
# Episode:801 meanR:9.9900 R:3.0000 loss:0.0578
# Episode:802 meanR:9.9900 R:11.0000 loss:0.0528
# Episode:803 meanR:10.0200 R:13.0000 loss:0.0702
# Episode:804 meanR:10.1300 R:14.0000 loss:0.0815
# Episode:805 meanR:10.1700 R:19.0000 loss:0.1005
# Episode:806 meanR:10.1400 R:11.0000 loss:0.0814
# Episode:807 meanR:10.0900 R:8.0000 loss:0.0889
# Episode:808 meanR:10.0500 R:8.0000 loss:0.0503
# Episode:809 meanR:10.1500 R:10.0000 loss:0.0826
# Episode:810 meanR:10.2300 R:12.0000 loss:0.0793
# Episode:811 meanR:10.2900 R:14.0000 loss:0.0827
# Episode:812 meanR:10.1900 R:1.0000 loss:0.0809
# Episode:813 meanR:10.0900 R:0.0000 loss:0.0433
# Episode:814 meanR:10.0100 R:4.0000 loss:0.0227
# Episode:815 meanR:10.1000 R:14.0000 loss:0.0548
# Episode:816 meanR:10.0800 R:10.0000 loss:0.0507
# Episode:817 meanR:10.0900 R:8.0000 loss:0.0521
# Episode:818 meanR:10.1500 R:16.0000 loss:0.0691
# Episode:819 meanR:10.1100 R:8.0000 loss:0.0763
# Episode:820 meanR:10.0600 R:9.0000 loss:0.0344
# Episode:821 meanR:10.0000 R:6.0000 loss:0.0450
# Episode:822 meanR:10.0000 R:12.0000 loss:0.0597
# Episode:823 meanR:9.9800 R:6.0000 loss:0.0593
# Episode:824 meanR:10.0300 R:13.0000 loss:0.0397
# Episode:825 meanR:9.9500 R:7.0000 loss:0.0756
# Episode:826 meanR:10.0400 R:13.0000 loss:0.0595
# Episode:827 meanR:10.0400 R:9.0000 loss:0.0869
# Episode:828 meanR:9.9500 R:3.0000 loss:0.0460
# Episode:829 meanR:9.9900 R:14.0000 loss:0.0591
# Episode:830 meanR:10.0800 R:14.0000 loss:0.1112
# Episode:831 meanR:10.0400 R:10.0000 loss:0.0892
# Episode:832 meanR:10.0300 R:8.0000 loss:0.0594
# Episode:833 meanR:10.0700 R:13.0000 loss:0.0753
# Episode:834 meanR:9.9900 R:4.0000 loss:0.0799
# Episode:835 meanR:9.9500 R:9.0000 loss:0.0401
# Episode:836 meanR:9.8900 R:8.0000 loss:0.0726
# Episode:837 meanR:9.9400 R:13.0000 loss:0.0654
# Episode:838 meanR:9.9400 R:7.0000 loss:0.0757
# Episode:839 meanR:9.8600 R:9.0000 loss:0.0496
# Episode:840 meanR:9.9400 R:18.0000 loss:0.0451
# Episode:841 meanR:9.9000 R:12.0000 loss:0.0677
# Episode:842 meanR:9.9200 R:12.0000 loss:0.0691
# Episode:843 meanR:9.9900 R:16.0000 loss:0.0789
# Episode:844 meanR:10.0500 R:11.0000 loss:0.0588
# Episode:845 meanR:10.0900 R:13.0000 loss:0.0850
# Episode:846 meanR:10.1200 R:16.0000 loss:0.0904
# Episode:847 meanR:10.1000 R:13.0000 loss:0.0853
# Episode:848 meanR:10.0100 R:5.0000 loss:0.0938
# Episode:849 meanR:10.0500 R:15.0000 loss:0.0477
# Episode:850 meanR:10.1000 R:17.0000 loss:0.0780
# Episode:851 meanR:10.0800 R:8.0000 loss:0.0924
# Episode:852 meanR:10.1100 R:14.0000 loss:0.0702
# Episode:853 meanR:10.1500 R:9.0000 loss:0.0476
# Episode:854 meanR:10.0700 R:6.0000 loss:0.0655
# Episode:855 meanR:10.1400 R:13.0000 loss:0.0610
# Episode:856 meanR:10.3100 R:20.0000 loss:0.0800
# Episode:857 meanR:10.3000 R:13.0000 loss:0.0820
# Episode:858 meanR:10.3400 R:18.0000 loss:0.0779
# Episode:859 meanR:10.2500 R:8.0000 loss:0.1232
# Episode:860 meanR:10.2500 R:11.0000 loss:0.0787
# Episode:861 meanR:10.2400 R:9.0000 loss:0.0575
# Episode:862 meanR:10.1900 R:9.0000 loss:0.0504
# Episode:863 meanR:10.2800 R:18.0000 loss:0.0707
# Episode:864 meanR:10.2600 R:12.0000 loss:0.0756
# Episode:865 meanR:10.1600 R:5.0000 loss:0.0799
# Episode:866 meanR:10.2300 R:15.0000 loss:0.0568
# Episode:867 meanR:10.1800 R:9.0000 loss:0.0534
# Episode:868 meanR:10.2400 R:13.0000 loss:0.0655
# Episode:869 meanR:10.3600 R:13.0000 loss:0.0857
# Episode:870 meanR:10.4100 R:6.0000 loss:0.0715
# Episode:871 meanR:10.4400 R:13.0000 loss:0.0605
# Episode:872 meanR:10.4500 R:9.0000 loss:0.0820
# Episode:873 meanR:10.5300 R:13.0000 loss:0.0524
# Episode:874 meanR:10.4700 R:6.0000 loss:0.0561
# Episode:875 meanR:10.4400 R:8.0000 loss:0.0440
# Episode:876 meanR:10.4300 R:5.0000 loss:0.0641
# Episode:877 meanR:10.3200 R:5.0000 loss:0.0409
# Episode:878 meanR:10.2900 R:4.0000 loss:0.0423
# Episode:879 meanR:10.3400 R:11.0000 loss:0.0692
# Episode:880 meanR:10.3100 R:13.0000 loss:0.0562
# Episode:881 meanR:10.2600 R:7.0000 loss:0.0613
# Episode:882 meanR:10.1900 R:6.0000 loss:0.0617
# Episode:883 meanR:10.1500 R:9.0000 loss:0.0765
# Episode:884 meanR:10.1800 R:10.0000 loss:0.0491
# Episode:885 meanR:10.1700 R:13.0000 loss:0.0577
# Episode:886 meanR:10.0500 R:4.0000 loss:0.0747
# Episode:887 meanR:10.0900 R:8.0000 loss:0.0624
# Episode:888 meanR:10.0800 R:4.0000 loss:0.0338
# Episode:889 meanR:10.0700 R:12.0000 loss:0.0448
# Episode:890 meanR:10.0000 R:10.0000 loss:0.0518
# Episode:891 meanR:10.0000 R:7.0000 loss:0.0495
# Episode:892 meanR:10.1600 R:19.0000 loss:0.0916
# Episode:893 meanR:10.2300 R:10.0000 loss:0.0726
# Episode:894 meanR:10.3400 R:16.0000 loss:0.0786
# Episode:895 meanR:10.2900 R:9.0000 loss:0.0615
# Episode:896 meanR:10.3600 R:12.0000 loss:0.0528
# Episode:897 meanR:10.3600 R:12.0000 loss:0.0659
# Episode:898 meanR:10.3600 R:11.0000 loss:0.0704
# Episode:899 meanR:10.4000 R:14.0000 loss:0.0502
# Episode:900 meanR:10.3500 R:7.0000 loss:0.0661
# Episode:901 meanR:10.3700 R:5.0000 loss:0.0763
# Episode:902 meanR:10.3800 R:12.0000 loss:0.0607
# Episode:903 meanR:10.3600 R:11.0000 loss:0.0679
# Episode:904 meanR:10.3200 R:10.0000 loss:0.0508
# Episode:905 meanR:10.1400 R:1.0000 loss:0.0410
# Episode:906 meanR:10.1900 R:16.0000 loss:0.0462
# Episode:907 meanR:10.1900 R:8.0000 loss:0.0385
# Episode:908 meanR:10.2100 R:10.0000 loss:0.0448
# Episode:909 meanR:10.1700 R:6.0000 loss:0.0646
# Episode:910 meanR:10.1400 R:9.0000 loss:0.0637
# Episode:911 meanR:10.1500 R:15.0000 loss:0.0657
# Episode:912 meanR:10.2400 R:10.0000 loss:0.0684
# Episode:913 meanR:10.2700 R:3.0000 loss:0.0515
# Episode:914 meanR:10.4000 R:17.0000 loss:0.0719
# Episode:915 meanR:10.3800 R:12.0000 loss:0.0893
# Episode:916 meanR:10.3700 R:9.0000 loss:0.0523
# Episode:917 meanR:10.3600 R:7.0000 loss:0.0441
# Episode:918 meanR:10.2700 R:7.0000 loss:0.0629
# Episode:919 meanR:10.3100 R:12.0000 loss:0.0654
# Episode:920 meanR:10.4200 R:20.0000 loss:0.0593
# Episode:921 meanR:10.4100 R:5.0000 loss:0.0772
# Episode:922 meanR:10.3400 R:5.0000 loss:0.0440
# Episode:923 meanR:10.3200 R:4.0000 loss:0.0476
# Episode:924 meanR:10.3000 R:11.0000 loss:0.0608
# Episode:925 meanR:10.3100 R:8.0000 loss:0.0700
# Episode:926 meanR:10.2700 R:9.0000 loss:0.0449
# Episode:927 meanR:10.2200 R:4.0000 loss:0.0509
# Episode:928 meanR:10.3200 R:13.0000 loss:0.0428
# Episode:929 meanR:10.2800 R:10.0000 loss:0.0753
# Episode:930 meanR:10.3000 R:16.0000 loss:0.0639
# Episode:931 meanR:10.3300 R:13.0000 loss:0.0776
# Episode:932 meanR:10.3000 R:5.0000 loss:0.0853
# Episode:933 meanR:10.2800 R:11.0000 loss:0.0528
# Episode:934 meanR:10.3500 R:11.0000 loss:0.0620
# Episode:935 meanR:10.3000 R:4.0000 loss:0.0599
# Episode:936 meanR:10.3200 R:10.0000 loss:0.0401
# Episode:937 meanR:10.3600 R:17.0000 loss:0.0779
# Episode:938 meanR:10.4200 R:13.0000 loss:0.0810
# Episode:939 meanR:10.4400 R:11.0000 loss:0.0703
# Episode:940 meanR:10.2800 R:2.0000 loss:0.0340
# Episode:941 meanR:10.1900 R:3.0000 loss:0.0487
# Episode:942 meanR:10.1900 R:12.0000 loss:0.0793
# Episode:943 meanR:10.0800 R:5.0000 loss:0.0413
# Episode:944 meanR:10.0500 R:8.0000 loss:0.0486
# Episode:945 meanR:10.0500 R:13.0000 loss:0.0686
# Episode:946 meanR:9.9300 R:4.0000 loss:0.0687
# Episode:947 meanR:9.8400 R:4.0000 loss:0.0353
# Episode:948 meanR:9.8300 R:4.0000 loss:0.0314
# Episode:949 meanR:9.8100 R:13.0000 loss:0.0293
# Episode:950 meanR:9.7500 R:11.0000 loss:0.0465
# Episode:951 meanR:9.7500 R:8.0000 loss:0.0869
# Episode:952 meanR:9.6800 R:7.0000 loss:0.0583
# Episode:953 meanR:9.6200 R:3.0000 loss:0.0392
# Episode:954 meanR:9.6700 R:11.0000 loss:0.0411
# Episode:955 meanR:9.6700 R:13.0000 loss:0.0430
# Episode:956 meanR:9.5100 R:4.0000 loss:0.0574
# Episode:957 meanR:9.4100 R:3.0000 loss:0.0305
# Episode:958 meanR:9.3400 R:11.0000 loss:0.0489
# Episode:959 meanR:9.3500 R:9.0000 loss:0.0727
# Episode:960 meanR:9.3400 R:10.0000 loss:0.0542
# Episode:961 meanR:9.3200 R:7.0000 loss:0.0591
# Episode:962 meanR:9.2700 R:4.0000 loss:0.0451
# Episode:963 meanR:9.2300 R:14.0000 loss:0.0984
# Episode:964 meanR:9.2500 R:14.0000 loss:0.1079
# Episode:965 meanR:9.2800 R:8.0000 loss:0.0754
# Episode:966 meanR:9.2700 R:14.0000 loss:0.0432
# Episode:967 meanR:9.3000 R:12.0000 loss:0.0458
# Episode:968 meanR:9.3400 R:17.0000 loss:0.0595
# Episode:969 meanR:9.2600 R:5.0000 loss:0.0731
# Episode:970 meanR:9.3300 R:13.0000 loss:0.0508
# Episode:971 meanR:9.3500 R:15.0000 loss:0.0883
# Episode:972 meanR:9.3500 R:9.0000 loss:0.0819
# Episode:973 meanR:9.3600 R:14.0000 loss:0.0665
# Episode:974 meanR:9.3900 R:9.0000 loss:0.0938
# Episode:975 meanR:9.4100 R:10.0000 loss:0.0520
# Episode:976 meanR:9.5100 R:15.0000 loss:0.0596
# Episode:977 meanR:9.5800 R:12.0000 loss:0.0948
# Episode:978 meanR:9.7000 R:16.0000 loss:0.0494
# Episode:979 meanR:9.7300 R:14.0000 loss:0.0964
# Episode:980 meanR:9.7200 R:12.0000 loss:0.0531
# Episode:981 meanR:9.7800 R:13.0000 loss:0.0849
# Episode:982 meanR:9.8800 R:16.0000 loss:0.0663
# Episode:983 meanR:9.8600 R:7.0000 loss:0.0723
# Episode:984 meanR:9.7800 R:2.0000 loss:0.0435
# Episode:985 meanR:9.6700 R:2.0000 loss:0.0534
# Episode:986 meanR:9.6700 R:4.0000 loss:0.0497
# Episode:987 meanR:9.7400 R:15.0000 loss:0.0804
# Episode:988 meanR:9.7300 R:3.0000 loss:0.0411
# Episode:989 meanR:9.6500 R:4.0000 loss:0.0235
# Episode:990 meanR:9.7000 R:15.0000 loss:0.0677
# Episode:991 meanR:9.8100 R:18.0000 loss:0.0595
# Episode:992 meanR:9.7300 R:11.0000 loss:0.0740
# Episode:993 meanR:9.7700 R:14.0000 loss:0.0862
# Episode:994 meanR:9.7800 R:17.0000 loss:0.0678
# Episode:995 meanR:9.7600 R:7.0000 loss:0.0883
# Episode:996 meanR:9.6900 R:5.0000 loss:0.0275
# Episode:997 meanR:9.7100 R:14.0000 loss:0.0631
# Episode:998 meanR:9.7400 R:14.0000 loss:0.0726
# Episode:999 meanR:9.7000 R:10.0000 loss:0.0618
# Episode:1000 meanR:9.7800 R:15.0000 loss:0.0612
# Episode:1001 meanR:9.9400 R:21.0000 loss:0.1078
# Episode:1002 meanR:9.9000 R:8.0000 loss:0.0965
# Episode:1003 meanR:9.9700 R:18.0000 loss:0.1022
# Episode:1004 meanR:10.0200 R:15.0000 loss:0.1110
# Episode:1005 meanR:10.1600 R:15.0000 loss:0.0903
# Episode:1006 meanR:10.1500 R:15.0000 loss:0.0709
# Episode:1007 meanR:10.2100 R:14.0000 loss:0.1173
# Episode:1008 meanR:10.2300 R:12.0000 loss:0.1121
# Episode:1009 meanR:10.2900 R:12.0000 loss:0.0798
# Episode:1010 meanR:10.2100 R:1.0000 loss:0.0400
# Episode:1011 meanR:10.1200 R:6.0000 loss:0.0410
# Episode:1012 meanR:10.0900 R:7.0000 loss:0.0391
# Episode:1013 meanR:10.2000 R:14.0000 loss:0.0826
# Episode:1014 meanR:10.1500 R:12.0000 loss:0.1022
# Episode:1015 meanR:10.1500 R:12.0000 loss:0.1010
# Episode:1016 meanR:10.1400 R:8.0000 loss:0.0838
# Episode:1017 meanR:10.1900 R:12.0000 loss:0.0579
# Episode:1018 meanR:10.3000 R:18.0000 loss:0.1023
# Episode:1019 meanR:10.2600 R:8.0000 loss:0.0931
# Episode:1020 meanR:10.1400 R:8.0000 loss:0.0578
# Episode:1021 meanR:10.1900 R:10.0000 loss:0.0468
# Episode:1022 meanR:10.2400 R:10.0000 loss:0.0694
# Episode:1023 meanR:10.2800 R:8.0000 loss:0.0788
# Episode:1024 meanR:10.2600 R:9.0000 loss:0.0386
# Episode:1025 meanR:10.2900 R:11.0000 loss:0.0537
# Episode:1026 meanR:10.2800 R:8.0000 loss:0.0727
# Episode:1027 meanR:10.2900 R:5.0000 loss:0.0548
# Episode:1028 meanR:10.2100 R:5.0000 loss:0.0465
# Episode:1029 meanR:10.2000 R:9.0000 loss:0.0782
# ...
# Episode:4117 meanR:10.2600 R:13.0000 loss:0.0772
# Episode:4118 meanR:10.1700 R:9.0000 loss:0.0612
# Episode:4119 meanR:10.1000 R:7.0000 loss:0.0516
# Episode:4120 meanR:10.1000 R:9.0000 loss:0.0728
# Episode:4121 meanR:10.1000 R:15.0000 loss:0.0767
# Episode:4122 meanR:9.9900 R:6.0000 loss:0.0586
# Episode:4123 meanR:10.0600 R:15.0000 loss:0.0627
# Episode:4124 meanR:9.9800 R:8.0000 loss:0.0672
# Episode:4125 meanR:10.0100 R:9.0000 loss:0.0771
# Episode:4126 meanR:10.0200 R:6.0000 loss:0.0667
# Episode:4127 meanR:10.0100 R:10.0000 loss:0.0613
# Episode:4128 meanR:9.9500 R:6.0000 loss:0.0518
# Episode:4129 meanR:9.9300 R:9.0000 loss:0.0864
# Episode:4130 meanR:9.8700 R:9.0000 loss:0.0628
# Episode:4131 meanR:9.8200 R:6.0000 loss:0.0657
# Episode:4132 meanR:9.7500 R:6.0000 loss:0.0323
# Episode:4133 meanR:9.7500 R:5.0000 loss:0.0402
# Episode:4134 meanR:9.7900 R:13.0000 loss:0.0382
# Episode:4135 meanR:9.7600 R:8.0000 loss:0.0587
# Episode:4136 meanR:9.6700 R:11.0000 loss:0.0599
# Episode:4137 meanR:9.6700 R:11.0000 loss:0.0958
# Episode:4138 meanR:9.7100 R:12.0000 loss:0.0589
# Episode:4139 meanR:9.8100 R:17.0000 loss:0.0877
# Episode:4140 meanR:9.8900 R:13.0000 loss:0.0985
# Episode:4141 meanR:9.9200 R:13.0000 loss:0.0612
# Episode:4142 meanR:9.9600 R:17.0000 loss:0.0626
# Episode:4143 meanR:10.0500 R:14.0000 loss:0.0845
# Episode:4144 meanR:9.9500 R:3.0000 loss:0.0847
# Episode:4145 meanR:10.0400 R:16.0000 loss:0.0591
# Episode:4146 meanR:10.0300 R:18.0000 loss:0.0689
# Episode:4147 meanR:10.0000 R:5.0000 loss:0.0738
# Episode:4148 meanR:10.0100 R:10.0000 loss:0.0605
# Episode:4149 meanR:9.9800 R:8.0000 loss:0.0760
# Episode:4150 meanR:9.9100 R:9.0000 loss:0.0674
# Episode:4151 meanR:9.8600 R:7.0000 loss:0.0473
# Episode:4152 meanR:9.8400 R:10.0000 loss:0.0451
# Episode:4153 meanR:9.7500 R:0.0000 loss:0.0287
# Episode:4154 meanR:9.7600 R:14.0000 loss:0.0412
# Episode:4155 meanR:9.6100 R:1.0000 loss:0.0356
# Episode:4156 meanR:9.5900 R:11.0000 loss:0.0448
# Episode:4157 meanR:9.6400 R:10.0000 loss:0.0597
# Episode:4158 meanR:9.6200 R:7.0000 loss:0.0608
# Episode:4159 meanR:9.5500 R:6.0000 loss:0.0444
# Episode:4160 meanR:9.5300 R:12.0000 loss:0.0502
# Episode:4161 meanR:9.5300 R:14.0000 loss:0.0668
# Episode:4162 meanR:9.5200 R:15.0000 loss:0.0822
# Episode:4163 meanR:9.6100 R:13.0000 loss:0.0821
# Episode:4164 meanR:9.5900 R:8.0000 loss:0.0622
# Episode:4165 meanR:9.6900 R:11.0000 loss:0.0508
# Episode:4166 meanR:9.8100 R:14.0000 loss:0.0647
# Episode:4167 meanR:9.8200 R:11.0000 loss:0.0745
# Episode:4168 meanR:9.9100 R:13.0000 loss:0.0780
# Episode:4169 meanR:9.9900 R:10.0000 loss:0.0694
# Episode:4170 meanR:9.9900 R:10.0000 loss:0.0748
# Episode:4171 meanR:9.9200 R:7.0000 loss:0.0970
# Episode:4172 meanR:9.8200 R:1.0000 loss:0.0576
# Episode:4173 meanR:9.7900 R:12.0000 loss:0.0518
# Episode:4174 meanR:9.8300 R:15.0000 loss:0.0587
# Episode:4175 meanR:9.7300 R:7.0000 loss:0.0837
# Episode:4176 meanR:9.7000 R:12.0000 loss:0.0502
# Episode:4177 meanR:9.8000 R:16.0000 loss:0.0593
# Episode:4178 meanR:9.7900 R:3.0000 loss:0.0828
# Episode:4179 meanR:9.8100 R:11.0000 loss:0.0474
# Episode:4180 meanR:9.8800 R:10.0000 loss:0.0633
# Episode:4181 meanR:9.9200 R:12.0000 loss:0.0503
# Episode:4182 meanR:9.9000 R:6.0000 loss:0.0560
# Episode:4183 meanR:9.9100 R:7.0000 loss:0.0593
# Episode:4184 meanR:9.9100 R:10.0000 loss:0.0797
# Episode:4185 meanR:9.9900 R:9.0000 loss:0.0560
# Episode:4186 meanR:10.0000 R:9.0000 loss:0.0513
# Episode:4187 meanR:9.9400 R:4.0000 loss:0.0414
# Episode:4188 meanR:10.0100 R:13.0000 loss:0.0340
# Episode:4189 meanR:10.0300 R:14.0000 loss:0.0389
# Episode:4190 meanR:10.1800 R:18.0000 loss:0.0688
# Episode:4191 meanR:10.1900 R:9.0000 loss:0.0694
# Episode:4192 meanR:10.2100 R:13.0000 loss:0.0890
# Episode:4193 meanR:10.1800 R:12.0000 loss:0.0717
# Episode:4194 meanR:10.1100 R:8.0000 loss:0.0431
# Episode:4195 meanR:10.0400 R:10.0000 loss:0.0560
# Episode:4196 meanR:10.0400 R:11.0000 loss:0.0552
# Episode:4197 meanR:10.0200 R:13.0000 loss:0.0639
# Episode:4198 meanR:10.1000 R:11.0000 loss:0.0720
# Episode:4199 meanR:10.1500 R:15.0000 loss:0.0520
# Episode:4200 meanR:10.1300 R:7.0000 loss:0.0563
# Episode:4201 meanR:10.2000 R:14.0000 loss:0.0645
# Episode:4202 meanR:10.1300 R:8.0000 loss:0.0719
# Episode:4203 meanR:10.0500 R:9.0000 loss:0.0616
# Episode:4204 meanR:10.1300 R:16.0000 loss:0.0600
# Episode:4205 meanR:10.0400 R:11.0000 loss:0.0704
# Episode:4206 meanR:9.9400 R:4.0000 loss:0.0524
# Episode:4207 meanR:9.9800 R:17.0000 loss:0.0581
# Episode:4208 meanR:10.0300 R:13.0000 loss:0.0923
# Episode:4209 meanR:10.1300 R:14.0000 loss:0.0590
# Episode:4210 meanR:10.2100 R:12.0000 loss:0.0718
# Episode:4211 meanR:10.3100 R:12.0000 loss:0.0722
# Episode:4212 meanR:10.3500 R:18.0000 loss:0.0848
# Episode:4213 meanR:10.2900 R:10.0000 loss:0.0737
# Episode:4214 meanR:10.4100 R:17.0000 loss:0.0710
# Episode:4215 meanR:10.3100 R:2.0000 loss:0.0913
# Episode:4216 meanR:10.3500 R:10.0000 loss:0.0688
# Episode:4217 meanR:10.3000 R:8.0000 loss:0.0562
# Episode:4218 meanR:10.2500 R:4.0000 loss:0.0576
# Episode:4219 meanR:10.3100 R:13.0000 loss:0.0510
# Episode:4220 meanR:10.3100 R:9.0000 loss:0.0685
# Episode:4221 meanR:10.2800 R:12.0000 loss:0.0616
# Episode:4222 meanR:10.3100 R:9.0000 loss:0.0615
# Episode:4223 meanR:10.2000 R:4.0000 loss:0.0449
# Episode:4224 meanR:10.1400 R:2.0000 loss:0.0434
# Episode:4225 meanR:10.1200 R:7.0000 loss:0.0437
# Episode:4226 meanR:10.1500 R:9.0000 loss:0.0406
# Episode:4227 meanR:10.2100 R:16.0000 loss:0.0479
# Episode:4228 meanR:10.2100 R:6.0000 loss:0.0502
# Episode:4229 meanR:10.2400 R:12.0000 loss:0.0469
# Episode:4230 meanR:10.2500 R:10.0000 loss:0.0434
# Episode:4231 meanR:10.2800 R:9.0000 loss:0.0494
# Episode:4232 meanR:10.3400 R:12.0000 loss:0.0599
# Episode:4233 meanR:10.4500 R:16.0000 loss:0.0758
# Episode:4234 meanR:10.4000 R:8.0000 loss:0.0676
# Episode:4235 meanR:10.4700 R:15.0000 loss:0.0567
# Episode:4236 meanR:10.5400 R:18.0000 loss:0.0571
# Episode:4237 meanR:10.5500 R:12.0000 loss:0.0779
# Episode:4238 meanR:10.5500 R:12.0000 loss:0.0532
# Episode:4239 meanR:10.5100 R:13.0000 loss:0.0582
# Episode:4240 meanR:10.5100 R:13.0000 loss:0.0700
# Episode:4241 meanR:10.4700 R:9.0000 loss:0.0962
# Episode:4242 meanR:10.4500 R:15.0000 loss:0.0588
# Episode:4243 meanR:10.3900 R:8.0000 loss:0.0721
# Episode:4244 meanR:10.4600 R:10.0000 loss:0.0696
# Episode:4245 meanR:10.4200 R:12.0000 loss:0.0591
# Episode:4246 meanR:10.2800 R:4.0000 loss:0.0535
# Episode:4247 meanR:10.2300 R:0.0000 loss:0.0306
# Episode:4248 meanR:10.1900 R:6.0000 loss:0.0305
# Episode:4249 meanR:10.2000 R:9.0000 loss:0.0549
# Episode:4250 meanR:10.2200 R:11.0000 loss:0.0635
# Episode:4251 meanR:10.3100 R:16.0000 loss:0.0681
# Episode:4252 meanR:10.2600 R:5.0000 loss:0.0473
# Episode:4253 meanR:10.3400 R:8.0000 loss:0.0433
# Episode:4254 meanR:10.3200 R:12.0000 loss:0.0377
# Episode:4255 meanR:10.4000 R:9.0000 loss:0.0481
# Episode:4256 meanR:10.4300 R:14.0000 loss:0.0539
# Episode:4257 meanR:10.3900 R:6.0000 loss:0.0562
# Episode:4258 meanR:10.4400 R:12.0000 loss:0.0586
# Episode:4259 meanR:10.5400 R:16.0000 loss:0.0512
# Episode:4260 meanR:10.5100 R:9.0000 loss:0.0632
# Episode:4261 meanR:10.4600 R:9.0000 loss:0.0971
# Episode:4262 meanR:10.4500 R:14.0000 loss:0.0629
# Episode:4263 meanR:10.4500 R:13.0000 loss:0.0515
# Episode:4264 meanR:10.4800 R:11.0000 loss:0.0857
# Episode:4265 meanR:10.4300 R:6.0000 loss:0.0346
# Episode:4266 meanR:10.3800 R:9.0000 loss:0.0606
# Episode:4267 meanR:10.2900 R:2.0000 loss:0.0431
# Episode:4268 meanR:10.2500 R:9.0000 loss:0.0335
# Episode:4269 meanR:10.2200 R:7.0000 loss:0.0321
# Episode:4270 meanR:10.2000 R:8.0000 loss:0.0339
# Episode:4271 meanR:10.2100 R:8.0000 loss:0.0404
# Episode:4272 meanR:10.3000 R:10.0000 loss:0.0414
# Episode:4273 meanR:10.2300 R:5.0000 loss:0.0552
# Episode:4274 meanR:10.1500 R:7.0000 loss:0.0426
# Episode:4275 meanR:10.1100 R:3.0000 loss:0.0315
# Episode:4276 meanR:10.0800 R:9.0000 loss:0.0336
# Episode:4277 meanR:9.9200 R:0.0000 loss:0.0288
# Episode:4278 meanR:9.8900 R:0.0000 loss:0.0197
# Episode:4279 meanR:9.8500 R:7.0000 loss:0.0196
# Episode:4280 meanR:9.8400 R:9.0000 loss:0.0707
# Episode:4281 meanR:9.8300 R:11.0000 loss:0.0726
# Episode:4282 meanR:9.8600 R:9.0000 loss:0.0638
# Episode:4283 meanR:9.8700 R:8.0000 loss:0.0552
# Episode:4284 meanR:9.8500 R:8.0000 loss:0.0592
# Episode:4285 meanR:9.8800 R:12.0000 loss:0.0507
# Episode:4286 meanR:9.9700 R:18.0000 loss:0.0883
# Episode:4287 meanR:9.9900 R:6.0000 loss:0.0621
# Episode:4288 meanR:9.9900 R:13.0000 loss:0.0566
# Episode:4289 meanR:9.9600 R:11.0000 loss:0.0601
# Episode:4290 meanR:9.9700 R:19.0000 loss:0.0730
# Episode:4291 meanR:9.9700 R:9.0000 loss:0.0700
# Episode:4292 meanR:9.8400 R:0.0000 loss:0.0452
# Episode:4293 meanR:9.7600 R:4.0000 loss:0.0415
# Episode:4294 meanR:9.7000 R:2.0000 loss:0.0533
# Episode:4295 meanR:9.6300 R:3.0000 loss:0.0486
# Episode:4296 meanR:9.6500 R:13.0000 loss:0.0393
# Episode:4297 meanR:9.5900 R:7.0000 loss:0.0483
# Episode:4298 meanR:9.5700 R:9.0000 loss:0.0460
# Episode:4299 meanR:9.4600 R:4.0000 loss:0.0398
# Episode:4300 meanR:9.5500 R:16.0000 loss:0.0480
# Episode:4301 meanR:9.5800 R:17.0000 loss:0.0663
# Episode:4302 meanR:9.6700 R:17.0000 loss:0.1032
# Episode:4303 meanR:9.6400 R:6.0000 loss:0.0626
# Episode:4304 meanR:9.5100 R:3.0000 loss:0.0321
# Episode:4305 meanR:9.4200 R:2.0000 loss:0.0352
# Episode:4306 meanR:9.4600 R:8.0000 loss:0.0329
# Episode:4307 meanR:9.3700 R:8.0000 loss:0.0627
# Episode:4308 meanR:9.3900 R:15.0000 loss:0.0567
# Episode:4309 meanR:9.3900 R:14.0000 loss:0.0833
# Episode:4310 meanR:9.3800 R:11.0000 loss:0.0777
# Episode:4311 meanR:9.3500 R:9.0000 loss:0.0543
# Episode:4312 meanR:9.2500 R:8.0000 loss:0.0522
# Episode:4313 meanR:9.2300 R:8.0000 loss:0.0545
# Episode:4314 meanR:9.1500 R:9.0000 loss:0.0697
# Episode:4315 meanR:9.2200 R:9.0000 loss:0.0472
# Episode:4316 meanR:9.3000 R:18.0000 loss:0.0882
# Episode:4317 meanR:9.2800 R:6.0000 loss:0.0805
# Episode:4318 meanR:9.3800 R:14.0000 loss:0.0732
# Episode:4319 meanR:9.3200 R:7.0000 loss:0.0568
# Episode:4320 meanR:9.3600 R:13.0000 loss:0.0618
# Episode:4321 meanR:9.3400 R:10.0000 loss:0.0475
# Episode:4322 meanR:9.3100 R:6.0000 loss:0.0526
# Episode:4323 meanR:9.4000 R:13.0000 loss:0.0806
# Episode:4324 meanR:9.5600 R:18.0000 loss:0.0873
# Episode:4325 meanR:9.6100 R:12.0000 loss:0.0943
# Episode:4326 meanR:9.6200 R:10.0000 loss:0.0849
# Episode:4327 meanR:9.5100 R:5.0000 loss:0.0746
# Episode:4328 meanR:9.5700 R:12.0000 loss:0.0535
# Episode:4329 meanR:9.5500 R:10.0000 loss:0.0703
# Episode:4330 meanR:9.5100 R:6.0000 loss:0.0657
# Episode:4331 meanR:9.4900 R:7.0000 loss:0.0460
# Episode:4332 meanR:9.4700 R:10.0000 loss:0.0657
# Episode:4333 meanR:9.3600 R:5.0000 loss:0.0455
# Episode:4334 meanR:9.3800 R:10.0000 loss:0.0702
# Episode:4335 meanR:9.3500 R:12.0000 loss:0.0799
# Episode:4336 meanR:9.3300 R:16.0000 loss:0.0652
# Episode:4337 meanR:9.3800 R:17.0000 loss:0.0925
# Episode:4338 meanR:9.3500 R:9.0000 loss:0.0877
# Episode:4339 meanR:9.2600 R:4.0000 loss:0.0539
# Episode:4340 meanR:9.1900 R:6.0000 loss:0.0534
# Episode:4341 meanR:9.2100 R:11.0000 loss:0.0434
# Episode:4342 meanR:9.2100 R:15.0000 loss:0.0836
# Episode:4343 meanR:9.2700 R:14.0000 loss:0.0725
# Episode:4344 meanR:9.2700 R:10.0000 loss:0.0825
# Episode:4345 meanR:9.3000 R:15.0000 loss:0.0842
# Episode:4346 meanR:9.3000 R:4.0000 loss:0.0372
# Episode:4347 meanR:9.4100 R:11.0000 loss:0.0517
# Episode:4348 meanR:9.3700 R:2.0000 loss:0.0368
# Episode:4349 meanR:9.3500 R:7.0000 loss:0.0376
# Episode:4350 meanR:9.3600 R:12.0000 loss:0.0480
# Episode:4351 meanR:9.3300 R:13.0000 loss:0.0691
# Episode:4352 meanR:9.4000 R:12.0000 loss:0.0699
# Episode:4353 meanR:9.4400 R:12.0000 loss:0.0774
# Episode:4354 meanR:9.4200 R:10.0000 loss:0.0578
# Episode:4355 meanR:9.4000 R:7.0000 loss:0.0671
# Episode:4356 meanR:9.3500 R:9.0000 loss:0.0806
# Episode:4357 meanR:9.4100 R:12.0000 loss:0.0656
# Episode:4358 meanR:9.4200 R:13.0000 loss:0.0640
# Episode:4359 meanR:9.3800 R:12.0000 loss:0.0630
# Episode:4360 meanR:9.4100 R:12.0000 loss:0.0724
# Episode:4361 meanR:9.3400 R:2.0000 loss:0.0402
# Episode:4362 meanR:9.3300 R:13.0000 loss:0.0628
# Episode:4363 meanR:9.2400 R:4.0000 loss:0.0683
# Episode:4364 meanR:9.2100 R:8.0000 loss:0.0383
# Episode:4365 meanR:9.2700 R:12.0000 loss:0.0618
# Episode:4366 meanR:9.2700 R:9.0000 loss:0.0806
# Episode:4367 meanR:9.3100 R:6.0000 loss:0.0675
# Episode:4368 meanR:9.3100 R:9.0000 loss:0.0447
# Episode:4369 meanR:9.4100 R:17.0000 loss:0.0895
# Episode:4370 meanR:9.3500 R:2.0000 loss:0.0389
# Episode:4371 meanR:9.3400 R:7.0000 loss:0.0522
# Episode:4372 meanR:9.3200 R:8.0000 loss:0.0557
# Episode:4373 meanR:9.3400 R:7.0000 loss:0.0486
# Episode:4374 meanR:9.4000 R:13.0000 loss:0.0550
# Episode:4375 meanR:9.4300 R:6.0000 loss:0.0522
# Episode:4376 meanR:9.3800 R:4.0000 loss:0.0591
# Episode:4377 meanR:9.3900 R:1.0000 loss:0.0446
# Episode:4378 meanR:9.4000 R:1.0000 loss:0.0385
# Episode:4379 meanR:9.4200 R:9.0000 loss:0.0434
# Episode:4380 meanR:9.4000 R:7.0000 loss:0.0636
# Episode:4381 meanR:9.4100 R:12.0000 loss:0.0526
# Episode:4382 meanR:9.4400 R:12.0000 loss:0.0488
# Episode:4383 meanR:9.5400 R:18.0000 loss:0.0832
# Episode:4384 meanR:9.5600 R:10.0000 loss:0.0729
# Episode:4385 meanR:9.5500 R:11.0000 loss:0.0695
# Episode:4386 meanR:9.4700 R:10.0000 loss:0.0764
# Episode:4387 meanR:9.5000 R:9.0000 loss:0.0553
# Episode:4388 meanR:9.4100 R:4.0000 loss:0.0730
# Episode:4389 meanR:9.3600 R:6.0000 loss:0.0534
# Episode:4390 meanR:9.3300 R:16.0000 loss:0.0530
# Episode:4391 meanR:9.3900 R:15.0000 loss:0.0719
# Episode:4392 meanR:9.5100 R:12.0000 loss:0.0576
# Episode:4393 meanR:9.5900 R:12.0000 loss:0.0995
# Episode:4394 meanR:9.7000 R:13.0000 loss:0.0854
# Episode:4395 meanR:9.7600 R:9.0000 loss:0.0681
# Episode:4396 meanR:9.7500 R:12.0000 loss:0.0515
# Episode:4397 meanR:9.7700 R:9.0000 loss:0.0572
# Episode:4398 meanR:9.7600 R:8.0000 loss:0.0483
# Episode:4399 meanR:9.8400 R:12.0000 loss:0.0423
# Episode:4400 meanR:9.8200 R:14.0000 loss:0.0505
# Episode:4401 meanR:9.7600 R:11.0000 loss:0.0618
# Episode:4402 meanR:9.6300 R:4.0000 loss:0.0542
# Episode:4403 meanR:9.6700 R:10.0000 loss:0.0634
# Episode:4404 meanR:9.7800 R:14.0000 loss:0.0601
# Episode:4405 meanR:9.8300 R:7.0000 loss:0.0613
# Episode:4406 meanR:9.8100 R:6.0000 loss:0.0523
# Episode:4407 meanR:9.8600 R:13.0000 loss:0.0437
# Episode:4408 meanR:9.8000 R:9.0000 loss:0.0545
# Episode:4409 meanR:9.7700 R:11.0000 loss:0.0416
# Episode:4410 meanR:9.7600 R:10.0000 loss:0.0761
# Episode:4411 meanR:9.7800 R:11.0000 loss:0.0572
# Episode:4412 meanR:9.7900 R:9.0000 loss:0.0559
# Episode:4413 meanR:9.8300 R:12.0000 loss:0.0615
# Episode:4414 meanR:9.8400 R:10.0000 loss:0.0824
# Episode:4415 meanR:9.7900 R:4.0000 loss:0.0574
# Episode:4416 meanR:9.6100 R:0.0000 loss:0.0466
# Episode:4417 meanR:9.6400 R:9.0000 loss:0.0382
# Episode:4418 meanR:9.6400 R:14.0000 loss:0.0546
# Episode:4419 meanR:9.6900 R:12.0000 loss:0.0621
# Episode:4420 meanR:9.7000 R:14.0000 loss:0.0710
# Episode:4421 meanR:9.8200 R:22.0000 loss:0.0856
# Episode:4422 meanR:9.8300 R:7.0000 loss:0.0801
# Episode:4423 meanR:9.8600 R:16.0000 loss:0.0763
# Episode:4424 meanR:9.7500 R:7.0000 loss:0.0606
# Episode:4425 meanR:9.7400 R:11.0000 loss:0.0558
# Episode:4426 meanR:9.8100 R:17.0000 loss:0.0918
# Episode:4427 meanR:9.9100 R:15.0000 loss:0.0669
# Episode:4428 meanR:9.8600 R:7.0000 loss:0.0716
# Episode:4429 meanR:9.8600 R:10.0000 loss:0.0543
# Episode:4430 meanR:9.9700 R:17.0000 loss:0.0599
# Episode:4431 meanR:10.0000 R:10.0000 loss:0.0948
# Episode:4432 meanR:10.0500 R:15.0000 loss:0.0769
# Episode:4433 meanR:10.0700 R:7.0000 loss:0.0640
# Episode:4434 meanR:10.0700 R:10.0000 loss:0.0703
# Episode:4435 meanR:10.0900 R:14.0000 loss:0.0630
# Episode:4436 meanR:9.9500 R:2.0000 loss:0.0648
# Episode:4437 meanR:9.8900 R:11.0000 loss:0.0509
# Episode:4438 meanR:10.0000 R:20.0000 loss:0.0742
# Episode:4439 meanR:10.1200 R:16.0000 loss:0.1077
# Episode:4440 meanR:10.1400 R:8.0000 loss:0.0728
# Episode:4441 meanR:10.1600 R:13.0000 loss:0.0685
# Episode:4442 meanR:10.0700 R:6.0000 loss:0.0738
# Episode:4443 meanR:10.0100 R:8.0000 loss:0.0611
# Episode:4444 meanR:10.0000 R:9.0000 loss:0.0658
# Episode:4445 meanR:9.9200 R:7.0000 loss:0.0647
# Episode:4446 meanR:9.9300 R:5.0000 loss:0.0577
# Episode:4447 meanR:9.8600 R:4.0000 loss:0.0226
# Episode:4448 meanR:9.9900 R:15.0000 loss:0.0558
# Episode:4449 meanR:9.9500 R:3.0000 loss:0.0377
# Episode:4450 meanR:9.9600 R:13.0000 loss:0.0475

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

def running_mean(x, N):
    cumsum = np.cumsum(np.insert(x, 0, 0)) 
    return (cumsum[N:] - cumsum[:-N]) / N

# %%
eps, arr = np.array(episode_rewards_list).T
smoothed_arr = running_mean(arr, 10)
plt.plot(eps[-len(smoothed_arr):], smoothed_arr)
plt.plot(eps, arr, color='grey', alpha=0.3)
plt.xlabel('Episode')
plt.ylabel('Episode rewards')

# %%
eps, arr = np.array(rewards_list).T
smoothed_arr = running_mean(arr, 10)
plt.plot(eps[-len(smoothed_arr):], smoothed_arr)
plt.plot(eps, arr, color='grey', alpha=0.3)
plt.xlabel('Episode')
plt.ylabel('Total rewards')

# %%
eps, arr = np.array(loss_list).T
smoothed_arr = running_mean(arr, 10)
plt.plot(eps[-len(smoothed_arr):], smoothed_arr)
plt.plot(eps, arr, color='grey', alpha=0.3)
plt.xlabel('Episode')
plt.ylabel('Average losses')

# %%
# # TF session for training
# with tf.Session(graph=graph) as sess:
#     sess.run(tf.global_variables_initializer())
#     #saver.restore(sess, 'checkpoints/model.ckpt')    
#     saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    
#     # Testing episodes/epochs
#     for _ in range(1):
#         total_reward = 0
#         #state = env.reset()
#         env_info = env.reset(train_mode=False)[brain_name] # reset the environment
#         state = env_info.vector_observations[0]   # get the current state

#         # Testing steps/batches
#         while True:
#             action_logits = sess.run(model.actions_logits, feed_dict={model.states: state.reshape([1, -1])})
#             action = np.argmax(action_logits)
#             #state, reward, done, _ = env.step(action)
#             env_info = env.step(action)[brain_name]        # send the action to the environment
#             state = env_info.vector_observations[0]   # get the next state
#             reward = env_info.rewards[0]                   # get the reward
#             done = env_info.local_done[0]                  # see if episode has finished
#             total_reward += reward
#             if done:
#                 break
                
#         print('total_reward: {:.2f}'.format(total_reward))

# %%
# # Be careful!!!!!!!!!!!!!!!!
# # Closing the env
# env.close()
