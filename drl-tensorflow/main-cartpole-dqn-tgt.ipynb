# %% [markdown]
# # DQN
#
# In this notebook, we'll build a neural network that can learn to play games through reinforcement learning. More specifically, we'll use Q-learning to train an agent to play a game called [Cart-Pole](https://gym.openai.com/envs/CartPole-v0). In this game, a freely swinging pole is attached to a cart. The cart can move to the left and right, and the goal is to keep the pole upright as long as possible.
#
# ![Cart-Pole](assets/cart-pole.jpg)
#
# We can simulate this game using [OpenAI Gym](https://gym.openai.com/). First, let's check out how OpenAI Gym works. Then, we'll get into training an agent to play the Cart-Pole game.

# %%
import numpy as np

# %%
import tensorflow as tf
print('TensorFlow Version: {}'.format(tf.__version__))
print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.7.1
# Default GPU Device:

# %% [markdown]
# >**Note:** Make sure you have OpenAI Gym cloned into the same directory with this notebook. I've included `gym` as a submodule, so you can run `git submodule --init --recursive` to pull the contents into the `gym` repo.

# %% [markdown]
# >**Note:** Make sure you have OpenAI Gym cloned. Then run this command `pip install -e gym/[all]`.

# %%
import gym

## Create the Cart-Pole game environment
env = gym.make('CartPole-v0') # 200 total reward as goal
env = gym.make('CartPole-v1') # 500 total reward as goal
# Out:
# /home/arasdar/anaconda3/lib/python3.6/site-packages/gym/envs/registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)

# %% [markdown]
# We interact with the simulation through `env`. To show the simulation running, you can use `env.render()` to render one frame. Passing in an action as an integer to `env.step` will generate the next step in the simulation.  You can see how many actions are possible from `env.action_space` and to get a random action you can use `env.action_space.sample()`. This is general to all Gym games. In the Cart-Pole game, there are two possible actions, moving the cart left or right. So there are two actions we can take, encoded as 0 and 1.
#
# Run the code below to watch the simulation run.

# %%
# env.reset()
# batch = []
# for _ in range(1000):
#     # env.render()
#     action = env.action_space.sample()
#     state, reward, done, info = env.step(action) # take a random action
#     batch.append([action, state, reward, done, info])
#     #print('state, action, reward, done, info:', state, action, reward, done, info)
#     if done:
#         env.reset()

# %% [markdown]
# To shut the window showing the simulation, use `env.close()`.

# %% [markdown]
# If you ran the simulation above, we can look at the rewards:

# %%
# batch[0], batch[0][1].shape

# %%
# actions = np.array([each[0] for each in batch])
# states = np.array([each[1] for each in batch])
# rewards = np.array([each[2] for each in batch])
# dones = np.array([each[3] for each in batch])
# infos = np.array([each[4] for each in batch])

# %%
# print(rewards[-20:])
# print(np.array(rewards).shape, np.array(states).shape, np.array(actions).shape, np.array(dones).shape)
# print(np.array(rewards).dtype, np.array(states).dtype, np.array(actions).dtype, np.array(dones).dtype)
# print(np.max(np.array(actions)), np.min(np.array(actions)))
# print((np.max(np.array(actions)) - np.min(np.array(actions)))+1)
# print(np.max(np.array(rewards)), np.min(np.array(rewards)))
# print(np.max(np.array(states)), np.min(np.array(states)))

# %% [markdown]
# The game resets after the pole has fallen past a certain angle. For each frame while the simulation is running, it returns a reward of 1.0. The longer the game runs, the more reward we get. Then, our network's goal is to maximize the reward by keeping the pole vertical. It will do this by moving the cart to the left and the right.

# %% [markdown]
# ## Q-Network
#
# We train our Q-learning agent using the Bellman Equation:
#
# $$
# Q(s, a) = r + \gamma \max{Q(s', a')}
# $$
#
# where $s$ is a state, $a$ is an action, and $s'$ is the next state from state $s$ and action $a$.
#
# Before we used this equation to learn values for a Q-_table_. However, for this game there are a huge number of states available. The state has four values: the position and velocity of the cart, and the position and velocity of the pole. These are all real-valued numbers, so ignoring floating point precisions, you practically have infinite states. Instead of using a table then, we'll replace it with a neural network that will approximate the Q-table lookup function.
#
# <img src="assets/deep-q-learning.png" width=450px>
#
# Now, our Q value, $Q(s, a)$ is calculated by passing in a state to the network. The output will be Q-values for each available action, with fully connected hidden layers.
#
# <img src="assets/q-network.png" width=550px>
#
#
# As I showed before, we can define our targets for training as $\hat{Q}(s,a) = r + \gamma \max{Q(s', a')}$. Then we update the weights by minimizing $(\hat{Q}(s,a) - Q(s,a))^2$.
#
# For this Cart-Pole game, we have four inputs, one for each value in the state, and two outputs, one for each action. To get $\hat{Q}$, we'll first choose an action, then simulate the game using that action. This will get us the next state, $s'$, and the reward. With that, we can calculate $\hat{Q}$ then pass it back into the $Q$ network to run the optimizer and update the weights.
#
# Below is my implementation of the Q-network. I used two fully connected layers with ReLU activations. Two seems to be good enough, three might be better. Feel free to try it out.

# %%
def model_input(state_size):
    actions = tf.placeholder(tf.int32, [None], name='actions')
    states = tf.placeholder(tf.float32, [None, state_size], name='states')
    targetQs = tf.placeholder(tf.float32, [None], name='targetQs')
    return actions, states, targetQs

# %%
def actor(states, action_size, hidden_size, reuse=False, alpha=0.1, training=False):
    with tf.variable_scope('actor', reuse=reuse):
        # First fully connected layer
        h1 = tf.layers.dense(inputs=states, units=hidden_size)
        bn1 = tf.layers.batch_normalization(h1, training=training)        
        nl1 = tf.maximum(alpha * bn1, bn1)
        
        # Second fully connected layer
        h2 = tf.layers.dense(inputs=nl1, units=hidden_size)
        bn2 = tf.layers.batch_normalization(h2, training=training)        
        nl2 = tf.maximum(alpha * bn2, bn2)
        
        # Output layer
        logits = tf.layers.dense(inputs=nl2, units=action_size)        
        return logits

# %%
def actor_target(states, action_size, hidden_size, reuse=False, alpha=0.1, training=False):
    with tf.variable_scope('actor_target', reuse=reuse):
        # First fully connected layer
        h1 = tf.layers.dense(inputs=states, units=hidden_size)
        bn1 = tf.layers.batch_normalization(h1, training=training)        
        nl1 = tf.maximum(alpha * bn1, bn1)
        
        # Second fully connected layer
        h2 = tf.layers.dense(inputs=nl1, units=hidden_size)
        bn2 = tf.layers.batch_normalization(h2, training=training)        
        nl2 = tf.maximum(alpha * bn2, bn2)
        
        # Output layer
        logits = tf.layers.dense(inputs=nl2, units=action_size)        
        return logits

# %%
def model_loss(actions, states, targetQs, # model input
               action_size, hidden_size): # model init
    actions_target = actor_target(states=states, hidden_size=hidden_size, action_size=action_size)
    
    actions_logits = actor(states=states, hidden_size=hidden_size, action_size=action_size)
    actions_labels = tf.one_hot(indices=actions, depth=action_size, dtype=actions_logits.dtype)
    Qs = tf.reduce_max(actions_logits*actions_labels, axis=1)
    
    loss = tf.reduce_mean(tf.square(Qs - targetQs))
    
    return actions_target, loss

# %%
def model_opt(loss, learning_rate, gamma):
    # Get weights and bias to update
    t_vars = tf.trainable_variables()
    g_vars = [var for var in t_vars if var.name.startswith('actor')]
    g_vars_tgt = [var for var in t_vars if var.name.startswith('actor_target')]

    # Optimize
    with tf.control_dependencies(tf.get_collection(tf.GraphKeys.UPDATE_OPS)): # Required for batchnorm (BN)
        opt = tf.train.AdamOptimizer(learning_rate).minimize(loss, var_list=g_vars)
        
    opt_tgt = [g_vars_tgt[idx].assign((g_vars_tgt[idx]*gamma) + (g_vars[idx]*(1-gamma))) 
               for idx in range(len(g_vars_tgt))]
    
    return opt, opt_tgt

# %%
class Model:
    def __init__(self, state_size, action_size, hidden_size, learning_rate, gamma):

        # Data of the Model: make the data available inside the framework
        self.actions, self.states, self.targetQs = model_input(state_size=state_size)

        # Create the Model: calculating the loss and forwad pass
        self.actions_logits, self.loss = model_loss(
            action_size=action_size, hidden_size=hidden_size, # model init parameters
            states=self.states, actions=self.actions, targetQs=self.targetQs)

        # Update the model: backward pass and backprop
        self.opt, self.opt_tgt = model_opt(loss=self.loss, learning_rate=learning_rate, gamma=gamma)

# %% [markdown]
# ## Experience replay
#
# Reinforcement learning algorithms can have stability issues due to correlations between states. To reduce correlations when training, we can store the agent's experiences and later draw a random mini-batch of those experiences to train on.
#
# Here, we'll create a `Memory` object that will store our experiences, our transitions $<s, a, r, s'>$. This memory will have a maxmium capacity, so we can keep newer experiences in memory while getting rid of older experiences. Then, we'll sample a random mini-batch of transitions $<s, a, r, s'>$ and train on those.
#
# Below, I've implemented a `Memory` object. If you're unfamiliar with `deque`, this is a double-ended queue. You can think of it like a tube open on both sides. You can put objects in either side of the tube. But if it's full, adding anything more will push an object out the other side. This is a great data structure to use for the memory buffer.

# %%
from collections import deque
class Memory():
    def __init__(self, max_size = 1000):
        self.buffer = deque(maxlen=max_size)
    def sample(self, batch_size):
        idx = np.random.choice(np.arange(len(self.buffer)), 
                               size=batch_size, 
                               replace=False)
        return [self.buffer[ii] for ii in idx]

# %% [markdown]
# ## Exploration - Exploitation
#
# To learn about the environment and rules of the game, the agent needs to explore by taking random actions. We'll do this by choosing a random action with some probability $\epsilon$ (epsilon).  That is, with some probability $\epsilon$ the agent will make a random action and with probability $1 - \epsilon$, the agent will choose an action from $Q(s,a)$. This is called an **$\epsilon$-greedy policy**.
#
#
# At first, the agent needs to do a lot of exploring. Later when it has learned more, the agent can favor choosing actions based on what it has learned. This is called _exploitation_. We'll set it up so the agent is more likely to explore early in training, then more likely to exploit later in training.

# %% [markdown]
# ## Q-Learning training algorithm
#
# Putting all this together, we can list out the algorithm we'll use to train the network. We'll train the network in _episodes_. One *episode* is one simulation of the game. For this game, the goal is to keep the pole upright for 195 frames. So we can start a new episode once meeting that goal. The game ends if the pole tilts over too far, or if the cart moves too far the left or right. When a game ends, we'll start a new episode. Now, to train the agent:
#
# * Initialize the memory $D$
# * Initialize the action-value network $Q$ with random weights
# * **For** episode = 1, $M$ **do**
#   * **For** $t$, $T$ **do**
#      * With probability $\epsilon$ select a random action $a_t$, otherwise select $a_t = \mathrm{argmax}_a Q(s,a)$
#      * Execute action $a_t$ in simulator and observe reward $r_{t+1}$ and new state $s_{t+1}$
#      * Store transition $<s_t, a_t, r_{t+1}, s_{t+1}>$ in memory $D$
#      * Sample random mini-batch from $D$: $<s_j, a_j, r_j, s'_j>$
#      * Set $\hat{Q}_j = r_j$ if the episode ends at $j+1$, otherwise set $\hat{Q}_j = r_j + \gamma \max_{a'}{Q(s'_j, a')}$
#      * Make a gradient descent step with loss $(\hat{Q}_j - Q(s_j, a_j))^2$
#   * **endfor**
# * **endfor**

# %% [markdown]
# ## Hyperparameters
#
# One of the more difficult aspects of reinforcememt learning are the large number of hyperparameters. Not only are we tuning the network, but we're tuning the simulation.

# %%
# print('state size:{}'.format(states.shape), 
#       'actions:{}'.format(actions.shape)) 
# print('action size:', np.max(actions) - np.min(actions)+1)

# %%
# Exploration parameters
explore_start = 1.0            # exploration probability at start
explore_stop = 0.01            # minimum exploration probability 
decay_rate = 0.0001            # exponential decay rate for exploration prob

# Network parameters
action_size = 2
state_size = 4
hidden_size = 64               # number of units in each Q-network hidden layer
learning_rate = 0.0001         # Q-network learning rate

# Memory parameters
memory_size = 10000            # memory capacity
batch_size = 20                # experience mini-batch size
gamma = 0.99                   # future reward discount

# %%
# Reset/init the graph/session
graph = tf.reset_default_graph()

# Init the model
model = Model(action_size=action_size, hidden_size=hidden_size, state_size=state_size, learning_rate=learning_rate, 
              gamma=gamma)

# Init the memory
memory = Memory(max_size=memory_size)

# %% [markdown]
# ## Populate the memory (exprience memory)
#
# Here I'm re-initializing the simulation and pre-populating the memory. The agent is taking random actions and storing the transitions in memory. This will help the agent with exploring the game.

# %%
state = env.reset()
#for _ in range(batch_size):
for _ in range(memory_size):
    action = env.action_space.sample()
    next_state, reward, done, _ = env.step(action)
    memory.buffer.append([state, action, next_state, reward, float(done)])
    state = next_state
    if done is True:
        state = env.reset()

# %% [markdown]
# ## Training the model
#
# Below we'll train our agent. If you want to watch it train, uncomment the `env.render()` line. This is slow because it's rendering the frames slower than the network can train. But, it's cool to watch the agent get better at the game.

# %%
# Save/load the model and save for plotting
saver = tf.train.Saver()
episode_rewards_list, rewards_list, loss_list = [], [], []

# TF session for training
with tf.Session(graph=graph) as sess:
    sess.run(tf.global_variables_initializer())
    #saver.restore(sess, 'checkpoints/model.ckpt')    
    #saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    total_step = 0 # Explore or exploit parameter
    episode_reward = deque(maxlen=100) # 100 episodes average/running average/running mean/window
    
    # Training episodes/epochs
    for ep in range(11111):
        total_reward = 0
        loss_batch = []
        state = env.reset()

        # Training steps/batches
        while True:
            # Explore (Env) or Exploit (Model)
            total_step += 1
            explore_p = explore_stop + (explore_start - explore_stop) * np.exp(-decay_rate * total_step) 
            if explore_p > np.random.rand():
                action = env.action_space.sample()
            else:
                action_logits = sess.run(model.actions_logits, feed_dict={model.states: state.reshape([1, -1])})
                action = np.argmax(action_logits)
                
            next_state, reward, done, _ = env.step(action)
            memory.buffer.append([state, action, next_state, reward, float(done)])
            total_reward += reward
            state = next_state

            # Training
            batch = memory.sample(batch_size)
            states = np.array([each[0] for each in batch])
            actions = np.array([each[1] for each in batch])
            next_states = np.array([each[2] for each in batch])
            rewards = np.array([each[3] for each in batch])
            dones = np.array([each[4] for each in batch])
            
            next_actions_logits = sess.run(model.actions_logits, feed_dict = {model.states: next_states})
            nextQs = np.max(next_actions_logits, axis=1) * (1-dones)
            targetQs = rewards + (gamma * nextQs)
            
            loss, _ = sess.run([model.loss, model.opt], feed_dict = {model.states: states, 
                                                                     model.actions: actions,
                                                                     model.targetQs: targetQs})
            loss_batch.append(loss)
            
            sess.run(model.opt_tgt)
            
            if done is True:
                break
                
        episode_reward.append(total_reward)
        print('Episode:{}'.format(ep),
              'meanR:{:.4f}'.format(np.mean(episode_reward)),
              'R:{}'.format(total_reward),
              'loss:{:.4f}'.format(np.mean(loss_batch)),
              'exploreP:{:.4f}'.format(explore_p))
        # Ploting out
        episode_rewards_list.append([ep, np.mean(episode_reward)])
        rewards_list.append([ep, total_reward])
        loss_list.append([ep, np.mean(loss_batch)])
        # Break episode/epoch loop
        if np.mean(episode_reward) >= 500:
            break
            
    # At the end of all training episodes/epochs
    saver.save(sess, 'checkpoints/model-qn.ckpt')
# Out:
# Episode:0 meanR:31.0000 R:31.0 loss:1.1589 exploreP:0.9969
# Episode:1 meanR:25.5000 R:20.0 loss:1.0791 exploreP:0.9950
# Episode:2 meanR:30.3333 R:40.0 loss:0.9900 exploreP:0.9910
# Episode:3 meanR:28.0000 R:21.0 loss:0.8962 exploreP:0.9890
# Episode:4 meanR:27.8000 R:27.0 loss:0.8189 exploreP:0.9863
# Episode:5 meanR:26.0000 R:17.0 loss:0.7514 exploreP:0.9847
# Episode:6 meanR:24.1429 R:13.0 loss:0.7178 exploreP:0.9834
# Episode:7 meanR:23.1250 R:16.0 loss:0.7252 exploreP:0.9819
# Episode:8 meanR:23.2222 R:24.0 loss:0.6851 exploreP:0.9795
# Episode:9 meanR:23.6000 R:27.0 loss:0.6665 exploreP:0.9769
# Episode:10 meanR:23.2727 R:20.0 loss:0.7023 exploreP:0.9750
# Episode:11 meanR:22.0833 R:9.0 loss:0.7671 exploreP:0.9741
# Episode:12 meanR:21.0769 R:9.0 loss:0.5496 exploreP:0.9732
# Episode:13 meanR:22.2143 R:37.0 loss:0.6430 exploreP:0.9697
# Episode:14 meanR:22.0000 R:19.0 loss:0.6926 exploreP:0.9679
# Episode:15 meanR:21.7500 R:18.0 loss:0.5532 exploreP:0.9661
# Episode:16 meanR:21.7059 R:21.0 loss:0.6288 exploreP:0.9641
# Episode:17 meanR:21.7778 R:23.0 loss:0.6310 exploreP:0.9619
# Episode:18 meanR:22.4211 R:34.0 loss:0.5690 exploreP:0.9587
# Episode:19 meanR:22.2500 R:19.0 loss:0.6657 exploreP:0.9569
# Episode:20 meanR:22.0476 R:18.0 loss:0.6391 exploreP:0.9552
# Episode:21 meanR:21.6818 R:14.0 loss:0.6247 exploreP:0.9539
# Episode:22 meanR:21.4348 R:16.0 loss:0.5922 exploreP:0.9524
# Episode:23 meanR:21.2917 R:18.0 loss:0.5487 exploreP:0.9507
# Episode:24 meanR:21.0800 R:16.0 loss:0.6496 exploreP:0.9492
# Episode:25 meanR:21.1538 R:23.0 loss:0.6035 exploreP:0.9470
# Episode:26 meanR:20.9259 R:15.0 loss:0.6494 exploreP:0.9456
# Episode:27 meanR:21.2500 R:30.0 loss:0.5803 exploreP:0.9428
# Episode:28 meanR:21.2759 R:22.0 loss:0.6225 exploreP:0.9408
# Episode:29 meanR:21.2333 R:20.0 loss:0.6298 exploreP:0.9389
# Episode:30 meanR:21.0645 R:16.0 loss:0.6018 exploreP:0.9374
# Episode:31 meanR:20.8438 R:14.0 loss:0.6037 exploreP:0.9361
# Episode:32 meanR:20.9697 R:25.0 loss:0.6275 exploreP:0.9338
# Episode:33 meanR:20.8235 R:16.0 loss:0.5822 exploreP:0.9323
# Episode:34 meanR:20.6000 R:13.0 loss:0.6920 exploreP:0.9311
# Episode:35 meanR:20.5278 R:18.0 loss:0.6318 exploreP:0.9295
# Episode:36 meanR:20.2703 R:11.0 loss:0.6207 exploreP:0.9285
# Episode:37 meanR:20.7105 R:37.0 loss:0.5945 exploreP:0.9251
# Episode:38 meanR:20.8718 R:27.0 loss:0.6057 exploreP:0.9226
# Episode:39 meanR:20.7000 R:14.0 loss:0.5798 exploreP:0.9213
# Episode:40 meanR:20.6829 R:20.0 loss:0.6296 exploreP:0.9195
# Episode:41 meanR:20.4762 R:12.0 loss:0.5500 exploreP:0.9184
# Episode:42 meanR:20.4186 R:18.0 loss:0.6036 exploreP:0.9168
# Episode:43 meanR:20.3864 R:19.0 loss:0.5780 exploreP:0.9151
# Episode:44 meanR:20.4000 R:21.0 loss:0.6204 exploreP:0.9132
# Episode:45 meanR:20.2174 R:12.0 loss:0.6268 exploreP:0.9121
# Episode:46 meanR:20.6170 R:39.0 loss:0.6150 exploreP:0.9086
# Episode:47 meanR:20.4375 R:12.0 loss:0.6078 exploreP:0.9075
# Episode:48 meanR:20.3265 R:15.0 loss:0.5870 exploreP:0.9061
# Episode:49 meanR:20.1200 R:10.0 loss:0.6634 exploreP:0.9053
# Episode:50 meanR:20.5490 R:42.0 loss:0.5900 exploreP:0.9015
# Episode:51 meanR:20.4615 R:16.0 loss:0.6222 exploreP:0.9001
# Episode:52 meanR:20.3396 R:14.0 loss:0.5930 exploreP:0.8988
# Episode:53 meanR:20.1481 R:10.0 loss:0.5815 exploreP:0.8979
# Episode:54 meanR:20.3091 R:29.0 loss:0.6820 exploreP:0.8954
# Episode:55 meanR:20.2679 R:18.0 loss:0.6156 exploreP:0.8938
# Episode:56 meanR:20.2456 R:19.0 loss:0.6375 exploreP:0.8921
# Episode:57 meanR:20.1207 R:13.0 loss:0.5581 exploreP:0.8910
# Episode:58 meanR:20.1186 R:20.0 loss:0.6073 exploreP:0.8892
# Episode:59 meanR:20.1333 R:21.0 loss:0.6366 exploreP:0.8873
# Episode:60 meanR:20.2295 R:26.0 loss:0.6477 exploreP:0.8851
# Episode:61 meanR:20.2581 R:22.0 loss:0.5493 exploreP:0.8831
# Episode:62 meanR:20.1746 R:15.0 loss:0.6491 exploreP:0.8818
# Episode:63 meanR:20.4219 R:36.0 loss:0.5717 exploreP:0.8787
# Episode:64 meanR:20.2923 R:12.0 loss:0.6149 exploreP:0.8777
# Episode:65 meanR:20.3636 R:25.0 loss:0.6163 exploreP:0.8755
# Episode:66 meanR:20.3134 R:17.0 loss:0.5949 exploreP:0.8740
# Episode:67 meanR:20.3088 R:20.0 loss:0.6258 exploreP:0.8723
# Episode:68 meanR:20.3188 R:21.0 loss:0.5851 exploreP:0.8705
# Episode:69 meanR:20.2000 R:12.0 loss:0.6024 exploreP:0.8695
# Episode:70 meanR:20.1972 R:20.0 loss:0.6067 exploreP:0.8677
# Episode:71 meanR:20.2361 R:23.0 loss:0.6091 exploreP:0.8658
# Episode:72 meanR:20.1507 R:14.0 loss:0.6231 exploreP:0.8646
# Episode:73 meanR:20.0946 R:16.0 loss:0.6045 exploreP:0.8632
# Episode:74 meanR:20.2400 R:31.0 loss:0.6077 exploreP:0.8606
# Episode:75 meanR:20.2763 R:23.0 loss:0.5985 exploreP:0.8586
# Episode:76 meanR:20.1169 R:8.0 loss:0.5587 exploreP:0.8579
# Episode:77 meanR:20.1154 R:20.0 loss:0.6166 exploreP:0.8562
# Episode:78 meanR:20.0127 R:12.0 loss:0.6522 exploreP:0.8552
# Episode:79 meanR:19.9125 R:12.0 loss:0.5843 exploreP:0.8542
# Episode:80 meanR:20.1975 R:43.0 loss:0.6095 exploreP:0.8506
# Episode:81 meanR:20.1220 R:14.0 loss:0.5238 exploreP:0.8494
# Episode:82 meanR:20.0482 R:14.0 loss:0.5903 exploreP:0.8482
# Episode:83 meanR:20.1190 R:26.0 loss:0.5918 exploreP:0.8461
# Episode:84 meanR:20.1882 R:26.0 loss:0.6619 exploreP:0.8439
# Episode:85 meanR:20.2558 R:26.0 loss:0.5839 exploreP:0.8417
# Episode:86 meanR:20.2759 R:22.0 loss:0.6182 exploreP:0.8399
# Episode:87 meanR:20.2841 R:21.0 loss:0.6465 exploreP:0.8382
# Episode:88 meanR:20.2022 R:13.0 loss:0.6090 exploreP:0.8371
# Episode:89 meanR:20.1333 R:14.0 loss:0.6289 exploreP:0.8359
# Episode:90 meanR:20.4396 R:48.0 loss:0.6499 exploreP:0.8320
# Episode:91 meanR:20.4239 R:19.0 loss:0.6038 exploreP:0.8304
# Episode:92 meanR:20.5054 R:28.0 loss:0.5797 exploreP:0.8281
# Episode:93 meanR:20.4149 R:12.0 loss:0.5243 exploreP:0.8271
# Episode:94 meanR:20.4737 R:26.0 loss:0.6324 exploreP:0.8250
# Episode:95 meanR:20.4688 R:20.0 loss:0.6489 exploreP:0.8234
# Episode:96 meanR:20.5876 R:32.0 loss:0.6195 exploreP:0.8208
# Episode:97 meanR:20.7551 R:37.0 loss:0.5973 exploreP:0.8178
# Episode:98 meanR:21.4444 R:89.0 loss:0.6077 exploreP:0.8106
# Episode:99 meanR:21.4700 R:24.0 loss:0.5834 exploreP:0.8087
# Episode:100 meanR:21.3500 R:19.0 loss:0.6077 exploreP:0.8072
# Episode:101 meanR:21.3600 R:21.0 loss:0.6119 exploreP:0.8055
# Episode:102 meanR:21.2200 R:26.0 loss:0.5851 exploreP:0.8035
# Episode:103 meanR:21.1600 R:15.0 loss:0.5985 exploreP:0.8023
# Episode:104 meanR:21.0900 R:20.0 loss:0.6397 exploreP:0.8007
# Episode:105 meanR:21.2100 R:29.0 loss:0.6282 exploreP:0.7984
# Episode:106 meanR:21.2900 R:21.0 loss:0.6434 exploreP:0.7967
# Episode:107 meanR:21.4500 R:32.0 loss:0.5884 exploreP:0.7942
# Episode:108 meanR:21.5300 R:32.0 loss:0.5667 exploreP:0.7917
# Episode:109 meanR:21.4500 R:19.0 loss:0.5973 exploreP:0.7902
# Episode:110 meanR:21.3600 R:11.0 loss:0.5819 exploreP:0.7894
# Episode:111 meanR:21.3600 R:9.0 loss:0.5744 exploreP:0.7887
# Episode:112 meanR:21.3800 R:11.0 loss:0.5763 exploreP:0.7878
# Episode:113 meanR:21.3400 R:33.0 loss:0.6570 exploreP:0.7853
# Episode:114 meanR:21.3900 R:24.0 loss:0.6252 exploreP:0.7834
# Episode:115 meanR:21.4400 R:23.0 loss:0.5975 exploreP:0.7816
# Episode:116 meanR:21.3600 R:13.0 loss:0.6641 exploreP:0.7806
# Episode:117 meanR:21.2600 R:13.0 loss:0.6534 exploreP:0.7796
# Episode:118 meanR:21.3200 R:40.0 loss:0.6049 exploreP:0.7766
# Episode:119 meanR:21.2500 R:12.0 loss:0.6948 exploreP:0.7756
# Episode:120 meanR:21.2900 R:22.0 loss:0.5848 exploreP:0.7740
# Episode:121 meanR:21.2700 R:12.0 loss:0.6312 exploreP:0.7730
# Episode:122 meanR:21.2800 R:17.0 loss:0.6451 exploreP:0.7717
# Episode:123 meanR:21.3400 R:24.0 loss:0.6717 exploreP:0.7699
# Episode:124 meanR:21.3600 R:18.0 loss:0.6596 exploreP:0.7685
# Episode:125 meanR:21.2400 R:11.0 loss:0.5595 exploreP:0.7677
# Episode:126 meanR:21.2200 R:13.0 loss:0.5898 exploreP:0.7667
# Episode:127 meanR:21.0900 R:17.0 loss:0.6359 exploreP:0.7654
# Episode:128 meanR:21.1100 R:24.0 loss:0.6206 exploreP:0.7636
# Episode:129 meanR:21.0300 R:12.0 loss:0.6493 exploreP:0.7627
# Episode:130 meanR:20.9600 R:9.0 loss:0.5145 exploreP:0.7621
# Episode:131 meanR:21.0700 R:25.0 loss:0.5841 exploreP:0.7602
# Episode:132 meanR:21.0100 R:19.0 loss:0.5943 exploreP:0.7587
# Episode:133 meanR:21.1100 R:26.0 loss:0.5754 exploreP:0.7568
# Episode:134 meanR:21.1600 R:18.0 loss:0.5667 exploreP:0.7555
# Episode:135 meanR:21.1800 R:20.0 loss:0.5734 exploreP:0.7540
# Episode:136 meanR:21.2400 R:17.0 loss:0.6444 exploreP:0.7527
# Episode:137 meanR:21.0800 R:21.0 loss:0.6039 exploreP:0.7512
# Episode:138 meanR:20.9500 R:14.0 loss:0.6451 exploreP:0.7501
# Episode:139 meanR:20.9300 R:12.0 loss:0.6414 exploreP:0.7492
# Episode:140 meanR:20.9400 R:21.0 loss:0.6423 exploreP:0.7477
# Episode:141 meanR:21.2400 R:42.0 loss:0.5902 exploreP:0.7446
# Episode:142 meanR:21.2500 R:19.0 loss:0.6050 exploreP:0.7432
# Episode:143 meanR:21.3200 R:26.0 loss:0.6347 exploreP:0.7413
# Episode:144 meanR:21.2500 R:14.0 loss:0.6188 exploreP:0.7403
# Episode:145 meanR:21.3200 R:19.0 loss:0.6341 exploreP:0.7389
# Episode:146 meanR:21.0500 R:12.0 loss:0.5417 exploreP:0.7380
# Episode:147 meanR:21.1900 R:26.0 loss:0.6244 exploreP:0.7361
# Episode:148 meanR:21.2700 R:23.0 loss:0.5853 exploreP:0.7344
# Episode:149 meanR:21.2800 R:11.0 loss:0.5889 exploreP:0.7336
# Episode:150 meanR:21.1300 R:27.0 loss:0.6479 exploreP:0.7317
# Episode:151 meanR:21.1400 R:17.0 loss:0.6730 exploreP:0.7305
# Episode:152 meanR:21.0900 R:9.0 loss:0.6651 exploreP:0.7298
# Episode:153 meanR:21.0800 R:9.0 loss:0.6912 exploreP:0.7292
# Episode:154 meanR:21.0000 R:21.0 loss:0.6562 exploreP:0.7277
# Episode:155 meanR:21.0000 R:18.0 loss:0.5533 exploreP:0.7264
# Episode:156 meanR:20.9700 R:16.0 loss:0.6164 exploreP:0.7252
# Episode:157 meanR:20.9300 R:9.0 loss:0.6332 exploreP:0.7246
# Episode:158 meanR:20.9700 R:24.0 loss:0.5733 exploreP:0.7229
# Episode:159 meanR:20.9600 R:20.0 loss:0.6476 exploreP:0.7214
# Episode:160 meanR:20.9300 R:23.0 loss:0.6379 exploreP:0.7198
# Episode:161 meanR:20.9200 R:21.0 loss:0.6893 exploreP:0.7183
# Episode:162 meanR:21.2700 R:50.0 loss:0.6371 exploreP:0.7148
# Episode:163 meanR:21.1500 R:24.0 loss:0.6819 exploreP:0.7131
# Episode:164 meanR:21.1900 R:16.0 loss:0.5869 exploreP:0.7120
# Episode:165 meanR:21.1000 R:16.0 loss:0.6322 exploreP:0.7109
# Episode:166 meanR:21.0800 R:15.0 loss:0.6504 exploreP:0.7098
# Episode:167 meanR:21.1000 R:22.0 loss:0.5781 exploreP:0.7083
# Episode:168 meanR:21.1800 R:29.0 loss:0.6313 exploreP:0.7062
# Episode:169 meanR:21.2500 R:19.0 loss:0.5449 exploreP:0.7049
# Episode:170 meanR:21.1600 R:11.0 loss:0.6025 exploreP:0.7042
# Episode:171 meanR:21.0800 R:15.0 loss:0.5789 exploreP:0.7031
# Episode:172 meanR:21.0600 R:12.0 loss:0.6221 exploreP:0.7023
# Episode:173 meanR:21.1200 R:22.0 loss:0.5756 exploreP:0.7008
# Episode:174 meanR:21.0100 R:20.0 loss:0.6080 exploreP:0.6994
# Episode:175 meanR:21.0000 R:22.0 loss:0.6175 exploreP:0.6979
# Episode:176 meanR:21.1200 R:20.0 loss:0.6193 exploreP:0.6965
# Episode:177 meanR:21.2400 R:32.0 loss:0.6368 exploreP:0.6943
# Episode:178 meanR:21.2900 R:17.0 loss:0.6463 exploreP:0.6931
# Episode:179 meanR:21.3100 R:14.0 loss:0.5635 exploreP:0.6922
# Episode:180 meanR:21.1100 R:23.0 loss:0.6192 exploreP:0.6906
# Episode:181 meanR:21.1000 R:13.0 loss:0.6586 exploreP:0.6897
# Episode:182 meanR:21.1500 R:19.0 loss:0.6298 exploreP:0.6884
# Episode:183 meanR:21.0100 R:12.0 loss:0.6378 exploreP:0.6876
# Episode:184 meanR:21.0900 R:34.0 loss:0.6666 exploreP:0.6853
# Episode:185 meanR:21.0800 R:25.0 loss:0.6136 exploreP:0.6836
# Episode:186 meanR:21.0500 R:19.0 loss:0.6306 exploreP:0.6824
# Episode:187 meanR:20.9500 R:11.0 loss:0.6852 exploreP:0.6816
# Episode:188 meanR:21.0500 R:23.0 loss:0.6449 exploreP:0.6801
# Episode:189 meanR:21.1300 R:22.0 loss:0.6371 exploreP:0.6786
# Episode:190 meanR:20.8000 R:15.0 loss:0.6595 exploreP:0.6776
# Episode:191 meanR:20.8900 R:28.0 loss:0.6336 exploreP:0.6757
# Episode:192 meanR:20.8300 R:22.0 loss:0.6058 exploreP:0.6743
# Episode:193 meanR:20.9800 R:27.0 loss:0.6319 exploreP:0.6725
# Episode:194 meanR:20.8400 R:12.0 loss:0.5857 exploreP:0.6717
# Episode:195 meanR:20.8300 R:19.0 loss:0.6334 exploreP:0.6704
# Episode:196 meanR:20.7000 R:19.0 loss:0.5774 exploreP:0.6692
# Episode:197 meanR:20.8700 R:54.0 loss:0.6519 exploreP:0.6656
# Episode:198 meanR:20.2900 R:31.0 loss:0.6124 exploreP:0.6636
# Episode:199 meanR:20.2700 R:22.0 loss:0.6472 exploreP:0.6622
# Episode:200 meanR:20.2000 R:12.0 loss:0.6253 exploreP:0.6614
# Episode:201 meanR:20.0900 R:10.0 loss:0.6224 exploreP:0.6607
# Episode:202 meanR:20.0300 R:20.0 loss:0.6299 exploreP:0.6594
# Episode:203 meanR:20.1300 R:25.0 loss:0.6288 exploreP:0.6578
# Episode:204 meanR:20.0900 R:16.0 loss:0.5900 exploreP:0.6568
# Episode:205 meanR:20.1800 R:38.0 loss:0.6445 exploreP:0.6543
# Episode:206 meanR:20.1700 R:20.0 loss:0.6259 exploreP:0.6530
# Episode:207 meanR:20.1300 R:28.0 loss:0.6559 exploreP:0.6512
# Episode:208 meanR:20.0700 R:26.0 loss:0.6676 exploreP:0.6496
# Episode:209 meanR:20.0300 R:15.0 loss:0.5895 exploreP:0.6486
# Episode:210 meanR:20.1700 R:25.0 loss:0.6446 exploreP:0.6470
# Episode:211 meanR:20.3100 R:23.0 loss:0.6234 exploreP:0.6456
# Episode:212 meanR:20.4200 R:22.0 loss:0.6365 exploreP:0.6442
# Episode:213 meanR:20.2000 R:11.0 loss:0.6316 exploreP:0.6435
# Episode:214 meanR:20.1600 R:20.0 loss:0.6620 exploreP:0.6422
# Episode:215 meanR:20.1100 R:18.0 loss:0.6310 exploreP:0.6411
# Episode:216 meanR:20.2300 R:25.0 loss:0.6293 exploreP:0.6395
# Episode:217 meanR:20.2800 R:18.0 loss:0.6014 exploreP:0.6384
# Episode:218 meanR:20.0600 R:18.0 loss:0.6258 exploreP:0.6372
# Episode:219 meanR:20.1700 R:23.0 loss:0.6568 exploreP:0.6358
# Episode:220 meanR:20.1500 R:20.0 loss:0.6486 exploreP:0.6345
# Episode:221 meanR:20.2700 R:24.0 loss:0.6364 exploreP:0.6330
# Episode:222 meanR:20.3000 R:20.0 loss:0.6351 exploreP:0.6318
# Episode:223 meanR:20.2100 R:15.0 loss:0.6132 exploreP:0.6309
# Episode:224 meanR:20.1800 R:15.0 loss:0.6477 exploreP:0.6299
# Episode:225 meanR:20.1900 R:12.0 loss:0.5647 exploreP:0.6292
# Episode:226 meanR:20.2200 R:16.0 loss:0.6264 exploreP:0.6282
# Episode:227 meanR:20.3600 R:31.0 loss:0.6052 exploreP:0.6263
# Episode:228 meanR:20.3400 R:22.0 loss:0.6082 exploreP:0.6249
# Episode:229 meanR:20.5000 R:28.0 loss:0.6083 exploreP:0.6232
# Episode:230 meanR:20.7200 R:31.0 loss:0.6099 exploreP:0.6213
# Episode:231 meanR:20.6300 R:16.0 loss:0.6253 exploreP:0.6203
# Episode:232 meanR:20.7600 R:32.0 loss:0.6481 exploreP:0.6184
# Episode:233 meanR:20.8200 R:32.0 loss:0.6032 exploreP:0.6164
# Episode:234 meanR:20.7600 R:12.0 loss:0.6244 exploreP:0.6157
# Episode:235 meanR:20.6900 R:13.0 loss:0.6466 exploreP:0.6149
# Episode:236 meanR:20.6400 R:12.0 loss:0.6888 exploreP:0.6142
# Episode:237 meanR:20.5200 R:9.0 loss:0.6752 exploreP:0.6137
# Episode:238 meanR:20.5600 R:18.0 loss:0.6281 exploreP:0.6126
# Episode:239 meanR:20.7100 R:27.0 loss:0.5768 exploreP:0.6109
# Episode:240 meanR:20.6200 R:12.0 loss:0.5770 exploreP:0.6102
# Episode:241 meanR:20.3900 R:19.0 loss:0.6416 exploreP:0.6091
# Episode:242 meanR:20.3800 R:18.0 loss:0.6536 exploreP:0.6080
# Episode:243 meanR:20.2400 R:12.0 loss:0.6510 exploreP:0.6073
# Episode:244 meanR:20.2200 R:12.0 loss:0.5959 exploreP:0.6066
# Episode:245 meanR:20.1600 R:13.0 loss:0.5943 exploreP:0.6058
# Episode:246 meanR:20.4600 R:42.0 loss:0.5982 exploreP:0.6033
# Episode:247 meanR:20.3400 R:14.0 loss:0.6512 exploreP:0.6025
# Episode:248 meanR:20.4600 R:35.0 loss:0.6375 exploreP:0.6004
# Episode:249 meanR:20.5000 R:15.0 loss:0.6421 exploreP:0.5995
# Episode:250 meanR:20.5000 R:27.0 loss:0.6349 exploreP:0.5979
# Episode:251 meanR:20.6100 R:28.0 loss:0.6711 exploreP:0.5963
# Episode:252 meanR:20.8200 R:30.0 loss:0.6845 exploreP:0.5945
# Episode:253 meanR:20.9300 R:20.0 loss:0.6510 exploreP:0.5934
# Episode:254 meanR:20.8100 R:9.0 loss:0.6032 exploreP:0.5928
# Episode:255 meanR:20.9800 R:35.0 loss:0.6258 exploreP:0.5908
# Episode:256 meanR:21.1000 R:28.0 loss:0.6563 exploreP:0.5892
# Episode:257 meanR:21.2300 R:22.0 loss:0.6031 exploreP:0.5879
# Episode:258 meanR:21.1700 R:18.0 loss:0.6045 exploreP:0.5869
# Episode:259 meanR:21.0700 R:10.0 loss:0.6509 exploreP:0.5863
# Episode:260 meanR:20.9700 R:13.0 loss:0.6663 exploreP:0.5855
# Episode:261 meanR:20.8800 R:12.0 loss:0.6325 exploreP:0.5848
# Episode:262 meanR:20.5600 R:18.0 loss:0.7087 exploreP:0.5838
# Episode:263 meanR:20.8400 R:52.0 loss:0.6303 exploreP:0.5808
# Episode:264 meanR:20.8700 R:19.0 loss:0.6277 exploreP:0.5798
# Episode:265 meanR:20.8100 R:10.0 loss:0.6424 exploreP:0.5792
# Episode:266 meanR:20.8800 R:22.0 loss:0.6824 exploreP:0.5779
# Episode:267 meanR:20.8200 R:16.0 loss:0.6519 exploreP:0.5770
# Episode:268 meanR:20.8100 R:28.0 loss:0.6226 exploreP:0.5754
# Episode:269 meanR:20.7100 R:9.0 loss:0.6798 exploreP:0.5749
# Episode:270 meanR:20.7400 R:14.0 loss:0.5745 exploreP:0.5741
# Episode:271 meanR:20.7000 R:11.0 loss:0.6048 exploreP:0.5735
# Episode:272 meanR:20.7500 R:17.0 loss:0.6696 exploreP:0.5726
# Episode:273 meanR:20.6600 R:13.0 loss:0.6118 exploreP:0.5718
# Episode:274 meanR:20.7100 R:25.0 loss:0.6485 exploreP:0.5704
# Episode:275 meanR:20.6300 R:14.0 loss:0.6443 exploreP:0.5696
# Episode:276 meanR:20.5300 R:10.0 loss:0.7709 exploreP:0.5691
# Episode:277 meanR:20.4200 R:21.0 loss:0.6695 exploreP:0.5679
# Episode:278 meanR:20.3500 R:10.0 loss:0.5866 exploreP:0.5674
# Episode:279 meanR:20.3300 R:12.0 loss:0.6468 exploreP:0.5667
# Episode:280 meanR:20.2600 R:16.0 loss:0.5665 exploreP:0.5658
# Episode:281 meanR:20.2900 R:16.0 loss:0.5847 exploreP:0.5649
# Episode:282 meanR:20.3300 R:23.0 loss:0.6344 exploreP:0.5636
# Episode:283 meanR:20.3300 R:12.0 loss:0.5390 exploreP:0.5630
# Episode:284 meanR:20.1200 R:13.0 loss:0.6504 exploreP:0.5623
# Episode:285 meanR:20.0500 R:18.0 loss:0.6209 exploreP:0.5613
# Episode:286 meanR:20.1300 R:27.0 loss:0.6787 exploreP:0.5598
# Episode:287 meanR:20.2300 R:21.0 loss:0.7028 exploreP:0.5586
# Episode:288 meanR:20.1400 R:14.0 loss:0.6536 exploreP:0.5579
# Episode:289 meanR:20.0100 R:9.0 loss:0.5909 exploreP:0.5574
# Episode:290 meanR:20.3000 R:44.0 loss:0.6468 exploreP:0.5550
# Episode:291 meanR:20.2400 R:22.0 loss:0.6306 exploreP:0.5538
# Episode:292 meanR:20.2700 R:25.0 loss:0.6404 exploreP:0.5524
# Episode:293 meanR:20.2000 R:20.0 loss:0.6358 exploreP:0.5513
# Episode:294 meanR:20.3500 R:27.0 loss:0.6469 exploreP:0.5499
# Episode:295 meanR:20.2700 R:11.0 loss:0.6044 exploreP:0.5493
# Episode:296 meanR:20.1700 R:9.0 loss:0.6395 exploreP:0.5488
# Episode:297 meanR:19.7300 R:10.0 loss:0.6834 exploreP:0.5482
# Episode:298 meanR:19.5300 R:11.0 loss:0.5976 exploreP:0.5476
# Episode:299 meanR:19.4100 R:10.0 loss:0.7084 exploreP:0.5471
# Episode:300 meanR:19.4500 R:16.0 loss:0.7003 exploreP:0.5463
# Episode:301 meanR:19.4500 R:10.0 loss:0.6038 exploreP:0.5457
# Episode:302 meanR:19.3900 R:14.0 loss:0.6526 exploreP:0.5450
# Episode:303 meanR:19.2400 R:10.0 loss:0.5856 exploreP:0.5444
# Episode:304 meanR:19.2100 R:13.0 loss:0.6859 exploreP:0.5437
# Episode:305 meanR:18.9900 R:16.0 loss:0.6824 exploreP:0.5429
# Episode:306 meanR:18.8900 R:10.0 loss:0.6672 exploreP:0.5424
# Episode:307 meanR:18.7600 R:15.0 loss:0.5938 exploreP:0.5416
# Episode:308 meanR:18.6400 R:14.0 loss:0.6299 exploreP:0.5408
# Episode:309 meanR:18.6700 R:18.0 loss:0.6477 exploreP:0.5399
# Episode:310 meanR:18.5400 R:12.0 loss:0.6332 exploreP:0.5392
# Episode:311 meanR:18.4900 R:18.0 loss:0.6780 exploreP:0.5383
# Episode:312 meanR:18.5200 R:25.0 loss:0.6224 exploreP:0.5369
# Episode:313 meanR:18.5200 R:11.0 loss:0.6897 exploreP:0.5364
# Episode:314 meanR:18.6000 R:28.0 loss:0.6853 exploreP:0.5349
# Episode:315 meanR:18.5700 R:15.0 loss:0.6275 exploreP:0.5341
# Episode:316 meanR:18.4300 R:11.0 loss:0.5488 exploreP:0.5335
# Episode:317 meanR:18.5000 R:25.0 loss:0.6828 exploreP:0.5322
# Episode:318 meanR:18.6200 R:30.0 loss:0.6315 exploreP:0.5307
# Episode:319 meanR:18.5800 R:19.0 loss:0.6701 exploreP:0.5297
# Episode:320 meanR:18.5700 R:19.0 loss:0.6937 exploreP:0.5287
# Episode:321 meanR:18.6100 R:28.0 loss:0.6562 exploreP:0.5272
# Episode:322 meanR:18.4900 R:8.0 loss:0.7694 exploreP:0.5268
# Episode:323 meanR:18.6000 R:26.0 loss:0.6066 exploreP:0.5255
# Episode:324 meanR:18.6100 R:16.0 loss:0.6138 exploreP:0.5247
# Episode:325 meanR:18.6600 R:17.0 loss:0.6778 exploreP:0.5238
# Episode:326 meanR:18.7400 R:24.0 loss:0.6876 exploreP:0.5226
# Episode:327 meanR:18.5400 R:11.0 loss:0.7103 exploreP:0.5220
# Episode:328 meanR:18.4800 R:16.0 loss:0.6544 exploreP:0.5212
# Episode:329 meanR:18.2900 R:9.0 loss:0.6603 exploreP:0.5207
# Episode:330 meanR:18.0900 R:11.0 loss:0.6938 exploreP:0.5202
# Episode:331 meanR:18.0800 R:15.0 loss:0.6720 exploreP:0.5194
# Episode:332 meanR:17.9300 R:17.0 loss:0.5981 exploreP:0.5185
# Episode:333 meanR:17.8200 R:21.0 loss:0.6557 exploreP:0.5175
# Episode:334 meanR:17.8200 R:12.0 loss:0.6475 exploreP:0.5168
# Episode:335 meanR:17.9500 R:26.0 loss:0.6725 exploreP:0.5155
# Episode:336 meanR:18.3400 R:51.0 loss:0.6341 exploreP:0.5130
# Episode:337 meanR:18.3700 R:12.0 loss:0.6069 exploreP:0.5124
# Episode:338 meanR:18.3800 R:19.0 loss:0.6178 exploreP:0.5114
# Episode:339 meanR:18.2800 R:17.0 loss:0.6949 exploreP:0.5105
# Episode:340 meanR:18.3800 R:22.0 loss:0.6461 exploreP:0.5094
# Episode:341 meanR:18.2900 R:10.0 loss:0.6554 exploreP:0.5089
# Episode:342 meanR:18.2200 R:11.0 loss:0.6221 exploreP:0.5084
# Episode:343 meanR:18.2900 R:19.0 loss:0.7012 exploreP:0.5075
# Episode:344 meanR:18.3400 R:17.0 loss:0.6641 exploreP:0.5066
# Episode:345 meanR:18.3400 R:13.0 loss:0.7059 exploreP:0.5060
# Episode:346 meanR:18.0400 R:12.0 loss:0.7164 exploreP:0.5054
# Episode:347 meanR:18.0100 R:11.0 loss:0.6245 exploreP:0.5048
# Episode:348 meanR:17.8100 R:15.0 loss:0.6806 exploreP:0.5041
# Episode:349 meanR:17.9100 R:25.0 loss:0.6331 exploreP:0.5029
# Episode:350 meanR:18.0300 R:39.0 loss:0.6605 exploreP:0.5009
# Episode:351 meanR:17.9300 R:18.0 loss:0.6147 exploreP:0.5000
# Episode:352 meanR:17.7400 R:11.0 loss:0.6303 exploreP:0.4995
# Episode:353 meanR:17.6600 R:12.0 loss:0.6667 exploreP:0.4989
# Episode:354 meanR:17.9400 R:37.0 loss:0.6630 exploreP:0.4971
# Episode:355 meanR:17.6900 R:10.0 loss:0.5828 exploreP:0.4966
# Episode:356 meanR:17.5700 R:16.0 loss:0.7022 exploreP:0.4959
# Episode:357 meanR:17.4900 R:14.0 loss:0.6773 exploreP:0.4952
# Episode:358 meanR:17.4800 R:17.0 loss:0.6585 exploreP:0.4943
# Episode:359 meanR:17.6600 R:28.0 loss:0.6505 exploreP:0.4930
# Episode:360 meanR:17.8100 R:28.0 loss:0.6292 exploreP:0.4916
# Episode:361 meanR:17.9200 R:23.0 loss:0.6668 exploreP:0.4905
# Episode:362 meanR:17.8900 R:15.0 loss:0.6182 exploreP:0.4898
# Episode:363 meanR:17.4700 R:10.0 loss:0.6633 exploreP:0.4893
# Episode:364 meanR:17.5900 R:31.0 loss:0.6663 exploreP:0.4879
# Episode:365 meanR:17.6500 R:16.0 loss:0.5914 exploreP:0.4871
# Episode:366 meanR:17.5200 R:9.0 loss:0.6529 exploreP:0.4867
# Episode:367 meanR:17.6900 R:33.0 loss:0.6758 exploreP:0.4851
# Episode:368 meanR:17.5700 R:16.0 loss:0.6705 exploreP:0.4843
# Episode:369 meanR:18.0100 R:53.0 loss:0.6442 exploreP:0.4818
# Episode:370 meanR:17.9700 R:10.0 loss:0.6468 exploreP:0.4814
# Episode:371 meanR:17.9900 R:13.0 loss:0.6526 exploreP:0.4807
# Episode:372 meanR:17.9200 R:10.0 loss:0.5677 exploreP:0.4803
# Episode:373 meanR:17.8700 R:8.0 loss:0.6088 exploreP:0.4799
# Episode:374 meanR:17.7400 R:12.0 loss:0.6636 exploreP:0.4793
# Episode:375 meanR:17.8300 R:23.0 loss:0.6370 exploreP:0.4783
# Episode:376 meanR:17.8600 R:13.0 loss:0.6743 exploreP:0.4776
# Episode:377 meanR:17.9200 R:27.0 loss:0.6681 exploreP:0.4764
# Episode:378 meanR:17.9300 R:11.0 loss:0.7195 exploreP:0.4759
# Episode:379 meanR:17.9800 R:17.0 loss:0.6925 exploreP:0.4751
# Episode:380 meanR:17.9100 R:9.0 loss:0.7567 exploreP:0.4747
# Episode:381 meanR:17.8700 R:12.0 loss:0.6069 exploreP:0.4741
# Episode:382 meanR:17.7700 R:13.0 loss:0.6550 exploreP:0.4735
# Episode:383 meanR:17.7400 R:9.0 loss:0.6565 exploreP:0.4731
# Episode:384 meanR:17.8400 R:23.0 loss:0.6309 exploreP:0.4720
# Episode:385 meanR:17.8600 R:20.0 loss:0.6514 exploreP:0.4711
# Episode:386 meanR:17.7100 R:12.0 loss:0.6173 exploreP:0.4705
# Episode:387 meanR:17.6000 R:10.0 loss:0.6066 exploreP:0.4701
# Episode:388 meanR:17.6000 R:14.0 loss:0.6622 exploreP:0.4694
# Episode:389 meanR:17.6000 R:9.0 loss:0.6253 exploreP:0.4690
# Episode:390 meanR:17.3600 R:20.0 loss:0.6297 exploreP:0.4681
# Episode:391 meanR:17.5000 R:36.0 loss:0.6173 exploreP:0.4665
# Episode:392 meanR:17.5300 R:28.0 loss:0.6620 exploreP:0.4652
# Episode:393 meanR:17.4300 R:10.0 loss:0.6351 exploreP:0.4647
# Episode:394 meanR:17.4300 R:27.0 loss:0.6509 exploreP:0.4635
# Episode:395 meanR:17.4300 R:11.0 loss:0.6442 exploreP:0.4630
# Episode:396 meanR:17.6400 R:30.0 loss:0.6331 exploreP:0.4616
# Episode:397 meanR:17.6300 R:9.0 loss:0.6130 exploreP:0.4612
# Episode:398 meanR:17.6700 R:15.0 loss:0.6928 exploreP:0.4606
# Episode:399 meanR:17.8000 R:23.0 loss:0.6424 exploreP:0.4595
# Episode:400 meanR:17.9700 R:33.0 loss:0.6790 exploreP:0.4581
# Episode:401 meanR:18.0300 R:16.0 loss:0.6624 exploreP:0.4573
# Episode:402 meanR:18.0100 R:12.0 loss:0.6039 exploreP:0.4568
# Episode:403 meanR:18.1800 R:27.0 loss:0.6496 exploreP:0.4556
# Episode:404 meanR:18.2500 R:20.0 loss:0.6379 exploreP:0.4547
# Episode:405 meanR:18.3700 R:28.0 loss:0.6329 exploreP:0.4535
# Episode:406 meanR:18.4700 R:20.0 loss:0.7206 exploreP:0.4526
# Episode:407 meanR:18.5100 R:19.0 loss:0.6636 exploreP:0.4517
# Episode:408 meanR:18.5300 R:16.0 loss:0.7381 exploreP:0.4510
# Episode:409 meanR:18.5400 R:19.0 loss:0.6528 exploreP:0.4502
# Episode:410 meanR:18.5900 R:17.0 loss:0.6933 exploreP:0.4494
# Episode:411 meanR:18.5000 R:9.0 loss:0.7447 exploreP:0.4490
# Episode:412 meanR:18.3700 R:12.0 loss:0.6554 exploreP:0.4485
# Episode:413 meanR:18.5900 R:33.0 loss:0.6810 exploreP:0.4471
# Episode:414 meanR:18.3900 R:8.0 loss:0.6717 exploreP:0.4467
# Episode:415 meanR:18.5100 R:27.0 loss:0.6987 exploreP:0.4455
# Episode:416 meanR:18.5000 R:10.0 loss:0.5983 exploreP:0.4451
# Episode:417 meanR:18.3600 R:11.0 loss:0.6074 exploreP:0.4446
# Episode:418 meanR:18.2200 R:16.0 loss:0.6549 exploreP:0.4439
# Episode:419 meanR:18.2200 R:19.0 loss:0.6118 exploreP:0.4431
# Episode:420 meanR:18.1500 R:12.0 loss:0.6655 exploreP:0.4426
# Episode:421 meanR:17.9800 R:11.0 loss:0.6924 exploreP:0.4421
# Episode:422 meanR:18.0800 R:18.0 loss:0.6854 exploreP:0.4413
# Episode:423 meanR:17.9400 R:12.0 loss:0.6462 exploreP:0.4408
# Episode:424 meanR:17.8700 R:9.0 loss:0.6775 exploreP:0.4404
# Episode:425 meanR:17.8300 R:13.0 loss:0.6542 exploreP:0.4399
# Episode:426 meanR:17.8000 R:21.0 loss:0.6928 exploreP:0.4390
# Episode:427 meanR:17.8000 R:11.0 loss:0.6376 exploreP:0.4385
# Episode:428 meanR:17.7500 R:11.0 loss:0.6896 exploreP:0.4380
# Episode:429 meanR:17.8300 R:17.0 loss:0.6382 exploreP:0.4373
# Episode:430 meanR:17.9700 R:25.0 loss:0.7030 exploreP:0.4362
# Episode:431 meanR:17.9000 R:8.0 loss:0.7289 exploreP:0.4359
# Episode:432 meanR:17.9300 R:20.0 loss:0.6767 exploreP:0.4350
# Episode:433 meanR:17.9400 R:22.0 loss:0.6925 exploreP:0.4341
# Episode:434 meanR:17.9900 R:17.0 loss:0.6302 exploreP:0.4334
# Episode:435 meanR:17.8600 R:13.0 loss:0.6981 exploreP:0.4328
# Episode:436 meanR:17.5900 R:24.0 loss:0.7107 exploreP:0.4318
# Episode:437 meanR:17.6700 R:20.0 loss:0.6876 exploreP:0.4310
# Episode:438 meanR:17.7600 R:28.0 loss:0.7156 exploreP:0.4298
# Episode:439 meanR:17.6800 R:9.0 loss:0.6902 exploreP:0.4294
# Episode:440 meanR:17.5900 R:13.0 loss:0.7228 exploreP:0.4289
# Episode:441 meanR:17.6900 R:20.0 loss:0.7323 exploreP:0.4281
# Episode:442 meanR:17.6900 R:11.0 loss:0.7007 exploreP:0.4276
# Episode:443 meanR:17.7000 R:20.0 loss:0.6061 exploreP:0.4268
# Episode:444 meanR:17.7500 R:22.0 loss:0.6245 exploreP:0.4258
# Episode:445 meanR:17.8200 R:20.0 loss:0.6912 exploreP:0.4250
# Episode:446 meanR:17.7900 R:9.0 loss:0.6586 exploreP:0.4246
# Episode:447 meanR:17.7700 R:9.0 loss:0.6979 exploreP:0.4243
# Episode:448 meanR:17.9100 R:29.0 loss:0.6946 exploreP:0.4231
# Episode:449 meanR:17.7900 R:13.0 loss:0.6281 exploreP:0.4225
# Episode:450 meanR:17.5400 R:14.0 loss:0.6816 exploreP:0.4220
# Episode:451 meanR:17.4700 R:11.0 loss:0.6507 exploreP:0.4215
# Episode:452 meanR:17.4900 R:13.0 loss:0.7463 exploreP:0.4210
# Episode:453 meanR:17.4600 R:9.0 loss:0.7079 exploreP:0.4206
# Episode:454 meanR:17.2400 R:15.0 loss:0.6953 exploreP:0.4200
# Episode:455 meanR:17.2400 R:10.0 loss:0.7437 exploreP:0.4196
# Episode:456 meanR:17.3800 R:30.0 loss:0.7092 exploreP:0.4183
# Episode:457 meanR:17.5200 R:28.0 loss:0.6639 exploreP:0.4172
# Episode:458 meanR:17.5700 R:22.0 loss:0.6750 exploreP:0.4163
# Episode:459 meanR:17.4000 R:11.0 loss:0.6562 exploreP:0.4159
# Episode:460 meanR:17.2300 R:11.0 loss:0.6536 exploreP:0.4154
# Episode:461 meanR:17.0900 R:9.0 loss:0.6480 exploreP:0.4150
# Episode:462 meanR:17.0600 R:12.0 loss:0.7050 exploreP:0.4146
# Episode:463 meanR:17.2400 R:28.0 loss:0.6608 exploreP:0.4134
# Episode:464 meanR:17.1400 R:21.0 loss:0.6760 exploreP:0.4126
# Episode:465 meanR:17.0800 R:10.0 loss:0.7337 exploreP:0.4122
# Episode:466 meanR:17.2000 R:21.0 loss:0.6723 exploreP:0.4113
# Episode:467 meanR:17.2700 R:40.0 loss:0.6706 exploreP:0.4097
# Episode:468 meanR:17.4000 R:29.0 loss:0.7087 exploreP:0.4086
# Episode:469 meanR:17.1600 R:29.0 loss:0.7623 exploreP:0.4074
# Episode:470 meanR:17.1700 R:11.0 loss:0.6991 exploreP:0.4070
# Episode:471 meanR:17.2400 R:20.0 loss:0.6873 exploreP:0.4062
# Episode:472 meanR:17.3700 R:23.0 loss:0.6872 exploreP:0.4053
# Episode:473 meanR:17.4700 R:18.0 loss:0.6641 exploreP:0.4046
# Episode:474 meanR:17.4600 R:11.0 loss:0.7377 exploreP:0.4041
# Episode:475 meanR:17.3300 R:10.0 loss:0.6897 exploreP:0.4037
# Episode:476 meanR:17.4900 R:29.0 loss:0.6818 exploreP:0.4026
# Episode:477 meanR:17.3300 R:11.0 loss:0.7239 exploreP:0.4022
# Episode:478 meanR:17.3400 R:12.0 loss:0.7437 exploreP:0.4017
# Episode:479 meanR:17.2600 R:9.0 loss:0.7018 exploreP:0.4014
# Episode:480 meanR:17.3600 R:19.0 loss:0.6738 exploreP:0.4006
# Episode:481 meanR:17.3600 R:12.0 loss:0.7157 exploreP:0.4001
# Episode:482 meanR:17.3800 R:15.0 loss:0.7016 exploreP:0.3996
# Episode:483 meanR:17.3800 R:9.0 loss:0.6699 exploreP:0.3992
# Episode:484 meanR:17.2700 R:12.0 loss:0.7534 exploreP:0.3987
# Episode:485 meanR:17.3800 R:31.0 loss:0.6928 exploreP:0.3975
# Episode:486 meanR:17.3600 R:10.0 loss:0.7463 exploreP:0.3971
# Episode:487 meanR:17.4200 R:16.0 loss:0.7139 exploreP:0.3965
# Episode:488 meanR:17.4600 R:18.0 loss:0.6745 exploreP:0.3958
# Episode:489 meanR:17.6900 R:32.0 loss:0.7041 exploreP:0.3946
# Episode:490 meanR:17.9000 R:41.0 loss:0.7066 exploreP:0.3930
# Episode:491 meanR:17.7500 R:21.0 loss:0.6979 exploreP:0.3922
# Episode:492 meanR:17.5900 R:12.0 loss:0.7100 exploreP:0.3918
# Episode:493 meanR:17.5800 R:9.0 loss:0.6862 exploreP:0.3914
# Episode:494 meanR:17.6000 R:29.0 loss:0.7113 exploreP:0.3903
# Episode:495 meanR:17.6100 R:12.0 loss:0.6612 exploreP:0.3899
# Episode:496 meanR:17.4500 R:14.0 loss:0.6636 exploreP:0.3893
# Episode:497 meanR:17.4800 R:12.0 loss:0.7295 exploreP:0.3889
# Episode:498 meanR:17.5900 R:26.0 loss:0.6741 exploreP:0.3879
# Episode:499 meanR:17.4600 R:10.0 loss:0.6552 exploreP:0.3875
# Episode:500 meanR:17.4400 R:31.0 loss:0.6964 exploreP:0.3863
# Episode:501 meanR:17.4600 R:18.0 loss:0.6941 exploreP:0.3857
# Episode:502 meanR:17.6000 R:26.0 loss:0.7228 exploreP:0.3847
# Episode:503 meanR:17.5800 R:25.0 loss:0.7402 exploreP:0.3838
# Episode:504 meanR:17.4800 R:10.0 loss:0.6176 exploreP:0.3834
# Episode:505 meanR:17.3000 R:10.0 loss:0.7156 exploreP:0.3830
# Episode:506 meanR:17.2700 R:17.0 loss:0.7300 exploreP:0.3824
# Episode:507 meanR:17.2000 R:12.0 loss:0.7437 exploreP:0.3819
# Episode:508 meanR:17.1700 R:13.0 loss:0.7580 exploreP:0.3814
# Episode:509 meanR:17.1700 R:19.0 loss:0.6958 exploreP:0.3807
# Episode:510 meanR:17.3600 R:36.0 loss:0.6740 exploreP:0.3794
# Episode:511 meanR:17.5700 R:30.0 loss:0.6785 exploreP:0.3783
# Episode:512 meanR:17.6200 R:17.0 loss:0.6930 exploreP:0.3777
# Episode:513 meanR:17.3900 R:10.0 loss:0.7166 exploreP:0.3773
# Episode:514 meanR:17.4200 R:11.0 loss:0.7166 exploreP:0.3769
# Episode:515 meanR:17.2800 R:13.0 loss:0.7114 exploreP:0.3764
# Episode:516 meanR:17.3100 R:13.0 loss:0.7265 exploreP:0.3760
# Episode:517 meanR:17.3700 R:17.0 loss:0.7440 exploreP:0.3753
# Episode:518 meanR:17.3100 R:10.0 loss:0.7248 exploreP:0.3750
# Episode:519 meanR:17.2200 R:10.0 loss:0.7492 exploreP:0.3746
# Episode:520 meanR:17.5500 R:45.0 loss:0.6979 exploreP:0.3730
# Episode:521 meanR:17.6400 R:20.0 loss:0.7304 exploreP:0.3722
# Episode:522 meanR:17.8100 R:35.0 loss:0.7196 exploreP:0.3710
# Episode:523 meanR:17.8000 R:11.0 loss:0.7239 exploreP:0.3706
# Episode:524 meanR:17.8900 R:18.0 loss:0.7180 exploreP:0.3699
# Episode:525 meanR:17.8400 R:8.0 loss:0.6629 exploreP:0.3696
# Episode:526 meanR:17.7200 R:9.0 loss:0.7224 exploreP:0.3693
# Episode:527 meanR:17.7200 R:11.0 loss:0.7214 exploreP:0.3689
# Episode:528 meanR:17.9000 R:29.0 loss:0.6784 exploreP:0.3679
# Episode:529 meanR:17.8600 R:13.0 loss:0.7154 exploreP:0.3674
# Episode:530 meanR:17.8500 R:24.0 loss:0.6707 exploreP:0.3666
# Episode:531 meanR:17.8600 R:9.0 loss:0.7011 exploreP:0.3662
# Episode:532 meanR:17.7500 R:9.0 loss:0.7405 exploreP:0.3659
# Episode:533 meanR:17.7800 R:25.0 loss:0.7125 exploreP:0.3650
# Episode:534 meanR:17.7300 R:12.0 loss:0.7890 exploreP:0.3646
# Episode:535 meanR:17.8100 R:21.0 loss:0.7949 exploreP:0.3639
# Episode:536 meanR:17.7400 R:17.0 loss:0.6888 exploreP:0.3633
# Episode:537 meanR:17.7800 R:24.0 loss:0.7105 exploreP:0.3624
# Episode:538 meanR:17.7200 R:22.0 loss:0.6910 exploreP:0.3616
# Episode:539 meanR:17.8700 R:24.0 loss:0.7429 exploreP:0.3608
# Episode:540 meanR:18.0400 R:30.0 loss:0.7552 exploreP:0.3597
# Episode:541 meanR:18.0600 R:22.0 loss:0.7165 exploreP:0.3590
# Episode:542 meanR:18.0800 R:13.0 loss:0.7172 exploreP:0.3585
# Episode:543 meanR:18.0400 R:16.0 loss:0.7074 exploreP:0.3580
# Episode:544 meanR:17.9200 R:10.0 loss:0.6609 exploreP:0.3576
# Episode:545 meanR:17.8200 R:10.0 loss:0.7426 exploreP:0.3573
# Episode:546 meanR:17.8700 R:14.0 loss:0.7857 exploreP:0.3568
# Episode:547 meanR:17.8800 R:10.0 loss:0.6420 exploreP:0.3564
# Episode:548 meanR:17.6800 R:9.0 loss:0.7691 exploreP:0.3561
# Episode:549 meanR:17.6600 R:11.0 loss:0.7402 exploreP:0.3557
# Episode:550 meanR:17.6900 R:17.0 loss:0.6466 exploreP:0.3552
# Episode:551 meanR:17.7600 R:18.0 loss:0.7049 exploreP:0.3545
# Episode:552 meanR:17.7400 R:11.0 loss:0.7210 exploreP:0.3542
# Episode:553 meanR:17.7400 R:9.0 loss:0.7188 exploreP:0.3538
# Episode:554 meanR:17.6800 R:9.0 loss:0.7157 exploreP:0.3535
# Episode:555 meanR:17.9700 R:39.0 loss:0.7210 exploreP:0.3522
# Episode:556 meanR:17.8100 R:14.0 loss:0.7504 exploreP:0.3517
# Episode:557 meanR:17.7000 R:17.0 loss:0.6552 exploreP:0.3511
# Episode:558 meanR:17.5900 R:11.0 loss:0.6544 exploreP:0.3508
# Episode:559 meanR:17.6300 R:15.0 loss:0.7249 exploreP:0.3503
# Episode:560 meanR:17.6200 R:10.0 loss:0.7633 exploreP:0.3499
# Episode:561 meanR:17.7700 R:24.0 loss:0.7466 exploreP:0.3491
# Episode:562 meanR:17.7500 R:10.0 loss:0.6989 exploreP:0.3488
# Episode:563 meanR:17.5500 R:8.0 loss:0.6469 exploreP:0.3485
# Episode:564 meanR:17.4900 R:15.0 loss:0.7334 exploreP:0.3480
# Episode:565 meanR:17.7100 R:32.0 loss:0.7131 exploreP:0.3469
# Episode:566 meanR:17.5800 R:8.0 loss:0.7665 exploreP:0.3466
# Episode:567 meanR:17.3100 R:13.0 loss:0.7319 exploreP:0.3462
# Episode:568 meanR:17.1100 R:9.0 loss:0.7518 exploreP:0.3459
# Episode:569 meanR:16.9200 R:10.0 loss:0.7337 exploreP:0.3456
# Episode:570 meanR:16.9000 R:9.0 loss:0.7769 exploreP:0.3453
# Episode:571 meanR:16.7900 R:9.0 loss:0.8219 exploreP:0.3450
# Episode:572 meanR:16.7000 R:14.0 loss:0.7448 exploreP:0.3445
# Episode:573 meanR:16.6100 R:9.0 loss:0.6446 exploreP:0.3442
# Episode:574 meanR:16.7700 R:27.0 loss:0.7237 exploreP:0.3433
# Episode:575 meanR:16.9300 R:26.0 loss:0.7507 exploreP:0.3424
# Episode:576 meanR:16.8800 R:24.0 loss:0.7682 exploreP:0.3416
# Episode:577 meanR:17.0400 R:27.0 loss:0.7300 exploreP:0.3407
# Episode:578 meanR:17.0600 R:14.0 loss:0.7026 exploreP:0.3403
# Episode:579 meanR:17.0600 R:9.0 loss:0.7676 exploreP:0.3400
# Episode:580 meanR:17.0000 R:13.0 loss:0.7503 exploreP:0.3395
# Episode:581 meanR:17.0100 R:13.0 loss:0.7526 exploreP:0.3391
# Episode:582 meanR:17.1500 R:29.0 loss:0.6755 exploreP:0.3382
# Episode:583 meanR:17.1600 R:10.0 loss:0.6376 exploreP:0.3378
# Episode:584 meanR:17.1400 R:10.0 loss:0.7864 exploreP:0.3375
# Episode:585 meanR:17.1600 R:33.0 loss:0.7571 exploreP:0.3364
# Episode:586 meanR:17.1900 R:13.0 loss:0.7152 exploreP:0.3360
# Episode:587 meanR:17.1200 R:9.0 loss:0.6932 exploreP:0.3357
# Episode:588 meanR:17.2300 R:29.0 loss:0.7166 exploreP:0.3348
# Episode:589 meanR:17.1700 R:26.0 loss:0.7036 exploreP:0.3339
# Episode:590 meanR:16.9900 R:23.0 loss:0.7149 exploreP:0.3332
# Episode:591 meanR:17.0000 R:22.0 loss:0.6729 exploreP:0.3325
# Episode:592 meanR:17.0800 R:20.0 loss:0.7873 exploreP:0.3318
# Episode:593 meanR:17.3800 R:39.0 loss:0.7159 exploreP:0.3306
# Episode:594 meanR:17.6400 R:55.0 loss:0.7179 exploreP:0.3288
# Episode:595 meanR:17.7600 R:24.0 loss:0.7547 exploreP:0.3280
# Episode:596 meanR:17.7200 R:10.0 loss:0.6502 exploreP:0.3277
# Episode:597 meanR:17.7400 R:14.0 loss:0.7328 exploreP:0.3273
# Episode:598 meanR:17.7600 R:28.0 loss:0.7279 exploreP:0.3264
# Episode:599 meanR:17.7600 R:10.0 loss:0.7700 exploreP:0.3261
# Episode:600 meanR:17.8100 R:36.0 loss:0.7374 exploreP:0.3249
# Episode:601 meanR:17.7500 R:12.0 loss:0.7315 exploreP:0.3246
# Episode:602 meanR:17.6000 R:11.0 loss:0.6917 exploreP:0.3242
# Episode:603 meanR:17.5900 R:24.0 loss:0.7564 exploreP:0.3235
# Episode:604 meanR:17.7100 R:22.0 loss:0.7066 exploreP:0.3228
# Episode:605 meanR:17.7100 R:10.0 loss:0.7687 exploreP:0.3225
# Episode:606 meanR:17.6800 R:14.0 loss:0.6996 exploreP:0.3220
# Episode:607 meanR:17.6700 R:11.0 loss:0.7105 exploreP:0.3217
# Episode:608 meanR:17.8000 R:26.0 loss:0.6906 exploreP:0.3209
# Episode:609 meanR:17.7500 R:14.0 loss:0.7339 exploreP:0.3204
# Episode:610 meanR:17.5600 R:17.0 loss:0.7067 exploreP:0.3199
# Episode:611 meanR:17.5100 R:25.0 loss:0.7604 exploreP:0.3191
# Episode:612 meanR:17.4800 R:14.0 loss:0.7066 exploreP:0.3187
# Episode:613 meanR:17.5700 R:19.0 loss:0.7354 exploreP:0.3181
# Episode:614 meanR:17.5900 R:13.0 loss:0.7578 exploreP:0.3177
# Episode:615 meanR:17.7500 R:29.0 loss:0.6870 exploreP:0.3168
# Episode:616 meanR:17.8600 R:24.0 loss:0.7334 exploreP:0.3161
# Episode:617 meanR:17.8700 R:18.0 loss:0.7172 exploreP:0.3155
# Episode:618 meanR:17.9900 R:22.0 loss:0.7564 exploreP:0.3149
# Episode:619 meanR:17.9900 R:10.0 loss:0.7174 exploreP:0.3146
# Episode:620 meanR:17.6400 R:10.0 loss:0.7492 exploreP:0.3143
# Episode:621 meanR:17.7800 R:34.0 loss:0.7291 exploreP:0.3132
# Episode:622 meanR:17.7200 R:29.0 loss:0.7149 exploreP:0.3124
# Episode:623 meanR:17.8900 R:28.0 loss:0.7122 exploreP:0.3115
# Episode:624 meanR:17.8500 R:14.0 loss:0.8012 exploreP:0.3111
# Episode:625 meanR:17.9600 R:19.0 loss:0.6568 exploreP:0.3105
# Episode:626 meanR:18.1300 R:26.0 loss:0.7354 exploreP:0.3097
# Episode:627 meanR:18.3300 R:31.0 loss:0.7311 exploreP:0.3088
# Episode:628 meanR:18.3100 R:27.0 loss:0.7121 exploreP:0.3080
# Episode:629 meanR:18.2900 R:11.0 loss:0.7806 exploreP:0.3077
# Episode:630 meanR:18.3200 R:27.0 loss:0.7058 exploreP:0.3069
# Episode:631 meanR:18.4200 R:19.0 loss:0.7070 exploreP:0.3063
# Episode:632 meanR:18.5300 R:20.0 loss:0.7330 exploreP:0.3057
# Episode:633 meanR:18.5100 R:23.0 loss:0.7643 exploreP:0.3050
# Episode:634 meanR:18.6300 R:24.0 loss:0.7370 exploreP:0.3043
# Episode:635 meanR:18.6300 R:21.0 loss:0.7046 exploreP:0.3037
# Episode:636 meanR:18.6100 R:15.0 loss:0.7199 exploreP:0.3033
# Episode:637 meanR:18.7100 R:34.0 loss:0.7429 exploreP:0.3023
# Episode:638 meanR:18.5800 R:9.0 loss:0.8064 exploreP:0.3020
# Episode:639 meanR:18.6900 R:35.0 loss:0.7357 exploreP:0.3010
# Episode:640 meanR:18.6400 R:25.0 loss:0.7559 exploreP:0.3003
# Episode:641 meanR:18.5000 R:8.0 loss:0.6678 exploreP:0.3000
# Episode:642 meanR:18.5900 R:22.0 loss:0.7339 exploreP:0.2994
# Episode:643 meanR:18.7000 R:27.0 loss:0.7293 exploreP:0.2986
# Episode:644 meanR:18.7000 R:10.0 loss:0.8204 exploreP:0.2983
# Episode:645 meanR:18.7800 R:18.0 loss:0.7583 exploreP:0.2978
# Episode:646 meanR:18.9100 R:27.0 loss:0.7399 exploreP:0.2970
# Episode:647 meanR:19.0400 R:23.0 loss:0.7468 exploreP:0.2964
# Episode:648 meanR:19.0900 R:14.0 loss:0.7632 exploreP:0.2960
# Episode:649 meanR:19.0900 R:11.0 loss:0.8061 exploreP:0.2957
# Episode:650 meanR:19.0000 R:8.0 loss:0.7178 exploreP:0.2954
# Episode:651 meanR:19.1100 R:29.0 loss:0.7272 exploreP:0.2946
# Episode:652 meanR:19.0800 R:8.0 loss:0.6968 exploreP:0.2944
# Episode:653 meanR:19.0800 R:9.0 loss:0.7369 exploreP:0.2941
# Episode:654 meanR:19.2800 R:29.0 loss:0.7517 exploreP:0.2933
# Episode:655 meanR:19.1900 R:30.0 loss:0.7301 exploreP:0.2925
# Episode:656 meanR:19.1500 R:10.0 loss:0.7140 exploreP:0.2922
# Episode:657 meanR:19.2200 R:24.0 loss:0.7222 exploreP:0.2915
# Episode:658 meanR:19.3200 R:21.0 loss:0.7189 exploreP:0.2909
# Episode:659 meanR:19.2500 R:8.0 loss:0.7106 exploreP:0.2907
# Episode:660 meanR:19.3600 R:21.0 loss:0.7000 exploreP:0.2901
# Episode:661 meanR:19.2300 R:11.0 loss:0.7511 exploreP:0.2898
# Episode:662 meanR:19.5500 R:42.0 loss:0.7616 exploreP:0.2886
# Episode:663 meanR:19.5900 R:12.0 loss:0.6753 exploreP:0.2883
# Episode:664 meanR:19.5500 R:11.0 loss:0.7604 exploreP:0.2880
# Episode:665 meanR:19.3100 R:8.0 loss:0.7346 exploreP:0.2877
# Episode:666 meanR:19.4500 R:22.0 loss:0.7549 exploreP:0.2871
# Episode:667 meanR:19.5700 R:25.0 loss:0.7228 exploreP:0.2864
# Episode:668 meanR:19.5800 R:10.0 loss:0.7282 exploreP:0.2862
# Episode:669 meanR:19.6000 R:12.0 loss:0.7024 exploreP:0.2858
# Episode:670 meanR:19.7100 R:20.0 loss:0.7566 exploreP:0.2853
# Episode:671 meanR:19.8300 R:21.0 loss:0.7597 exploreP:0.2847
# Episode:672 meanR:19.7800 R:9.0 loss:0.7514 exploreP:0.2845
# Episode:673 meanR:19.7800 R:9.0 loss:0.8040 exploreP:0.2842
# Episode:674 meanR:19.7800 R:27.0 loss:0.7171 exploreP:0.2835
# Episode:675 meanR:19.7500 R:23.0 loss:0.7673 exploreP:0.2828
# Episode:676 meanR:19.6000 R:9.0 loss:0.7422 exploreP:0.2826
# Episode:677 meanR:19.5300 R:20.0 loss:0.7185 exploreP:0.2821
# Episode:678 meanR:19.6400 R:25.0 loss:0.7023 exploreP:0.2814
# Episode:679 meanR:19.6600 R:11.0 loss:0.7228 exploreP:0.2811
# Episode:680 meanR:19.7900 R:26.0 loss:0.7117 exploreP:0.2804
# Episode:681 meanR:19.9600 R:30.0 loss:0.7622 exploreP:0.2796
# Episode:682 meanR:19.7800 R:11.0 loss:0.6754 exploreP:0.2793
# Episode:683 meanR:19.8000 R:12.0 loss:0.7465 exploreP:0.2789
# Episode:684 meanR:20.0000 R:30.0 loss:0.7404 exploreP:0.2781
# Episode:685 meanR:19.8200 R:15.0 loss:0.7094 exploreP:0.2777
# Episode:686 meanR:19.9500 R:26.0 loss:0.7380 exploreP:0.2770
# Episode:687 meanR:20.1400 R:28.0 loss:0.7101 exploreP:0.2763
# Episode:688 meanR:20.1800 R:33.0 loss:0.7004 exploreP:0.2754
# Episode:689 meanR:20.0400 R:12.0 loss:0.7219 exploreP:0.2751
# Episode:690 meanR:19.9700 R:16.0 loss:0.7537 exploreP:0.2747
# Episode:691 meanR:19.8300 R:8.0 loss:0.7502 exploreP:0.2745
# Episode:692 meanR:19.8900 R:26.0 loss:0.7195 exploreP:0.2738
# Episode:693 meanR:19.6000 R:10.0 loss:0.6965 exploreP:0.2735
# Episode:694 meanR:19.3000 R:25.0 loss:0.7438 exploreP:0.2729
# Episode:695 meanR:19.2800 R:22.0 loss:0.7476 exploreP:0.2723
# Episode:696 meanR:19.2800 R:10.0 loss:0.7747 exploreP:0.2720
# Episode:697 meanR:19.2500 R:11.0 loss:0.6973 exploreP:0.2717
# Episode:698 meanR:19.3000 R:33.0 loss:0.7432 exploreP:0.2709
# Episode:699 meanR:19.3800 R:18.0 loss:0.7336 exploreP:0.2704
# Episode:700 meanR:19.1300 R:11.0 loss:0.7816 exploreP:0.2701
# Episode:701 meanR:19.1200 R:11.0 loss:0.7091 exploreP:0.2698
# Episode:702 meanR:19.1600 R:15.0 loss:0.7353 exploreP:0.2694
# Episode:703 meanR:19.0200 R:10.0 loss:0.7499 exploreP:0.2692
# Episode:704 meanR:19.0000 R:20.0 loss:0.7158 exploreP:0.2687
# Episode:705 meanR:19.0200 R:12.0 loss:0.6659 exploreP:0.2683
# Episode:706 meanR:19.0600 R:18.0 loss:0.7047 exploreP:0.2679
# Episode:707 meanR:19.0400 R:9.0 loss:0.7847 exploreP:0.2677
# Episode:708 meanR:18.8700 R:9.0 loss:0.7178 exploreP:0.2674
# Episode:709 meanR:19.0300 R:30.0 loss:0.7272 exploreP:0.2666
# Episode:710 meanR:18.9600 R:10.0 loss:0.7201 exploreP:0.2664
# Episode:711 meanR:18.9900 R:28.0 loss:0.7358 exploreP:0.2657
# Episode:712 meanR:19.1400 R:29.0 loss:0.6913 exploreP:0.2649
# Episode:713 meanR:19.0400 R:9.0 loss:0.7481 exploreP:0.2647
# Episode:714 meanR:19.0100 R:10.0 loss:0.7563 exploreP:0.2645
# Episode:715 meanR:18.9100 R:19.0 loss:0.7437 exploreP:0.2640
# Episode:716 meanR:18.7900 R:12.0 loss:0.7497 exploreP:0.2637
# Episode:717 meanR:18.7100 R:10.0 loss:0.7031 exploreP:0.2634
# Episode:718 meanR:18.6500 R:16.0 loss:0.6895 exploreP:0.2630
# Episode:719 meanR:18.6500 R:10.0 loss:0.7358 exploreP:0.2628
# Episode:720 meanR:18.8900 R:34.0 loss:0.7019 exploreP:0.2619
# Episode:721 meanR:18.7500 R:20.0 loss:0.7772 exploreP:0.2614
# Episode:722 meanR:18.6800 R:22.0 loss:0.6954 exploreP:0.2608
# Episode:723 meanR:18.5200 R:12.0 loss:0.7241 exploreP:0.2605
# Episode:724 meanR:18.6000 R:22.0 loss:0.7435 exploreP:0.2600
# Episode:725 meanR:18.7900 R:38.0 loss:0.7700 exploreP:0.2590
# Episode:726 meanR:18.6200 R:9.0 loss:0.7160 exploreP:0.2588
# Episode:727 meanR:18.6300 R:32.0 loss:0.7621 exploreP:0.2580
# Episode:728 meanR:18.7200 R:36.0 loss:0.7061 exploreP:0.2571
# Episode:729 meanR:18.6900 R:8.0 loss:0.7123 exploreP:0.2569
# Episode:730 meanR:18.5500 R:13.0 loss:0.6803 exploreP:0.2566
# Episode:731 meanR:18.6100 R:25.0 loss:0.7084 exploreP:0.2560
# Episode:732 meanR:18.5700 R:16.0 loss:0.7521 exploreP:0.2556
# Episode:733 meanR:18.4200 R:8.0 loss:0.7814 exploreP:0.2554
# Episode:734 meanR:18.3900 R:21.0 loss:0.7231 exploreP:0.2549
# Episode:735 meanR:18.2700 R:9.0 loss:0.7605 exploreP:0.2547
# Episode:736 meanR:18.2000 R:8.0 loss:0.6846 exploreP:0.2545
# Episode:737 meanR:18.0100 R:15.0 loss:0.7570 exploreP:0.2541
# Episode:738 meanR:18.1600 R:24.0 loss:0.7085 exploreP:0.2535
# Episode:739 meanR:18.0800 R:27.0 loss:0.6806 exploreP:0.2529
# Episode:740 meanR:17.9600 R:13.0 loss:0.7784 exploreP:0.2525
# Episode:741 meanR:18.0400 R:16.0 loss:0.7431 exploreP:0.2522
# Episode:742 meanR:17.9400 R:12.0 loss:0.7090 exploreP:0.2519
# Episode:743 meanR:17.8300 R:16.0 loss:0.7653 exploreP:0.2515
# Episode:744 meanR:17.8200 R:9.0 loss:0.8029 exploreP:0.2513
# Episode:745 meanR:17.8400 R:20.0 loss:0.7622 exploreP:0.2508
# Episode:746 meanR:17.8100 R:24.0 loss:0.7541 exploreP:0.2502
# Episode:747 meanR:17.8100 R:23.0 loss:0.7327 exploreP:0.2497
# Episode:748 meanR:17.7600 R:9.0 loss:0.7451 exploreP:0.2494
# Episode:749 meanR:17.7400 R:9.0 loss:0.6541 exploreP:0.2492
# Episode:750 meanR:17.7600 R:10.0 loss:0.8197 exploreP:0.2490
# Episode:751 meanR:17.7300 R:26.0 loss:0.7881 exploreP:0.2484
# Episode:752 meanR:17.7400 R:9.0 loss:0.6535 exploreP:0.2482
# Episode:753 meanR:17.7500 R:10.0 loss:0.8217 exploreP:0.2479
# Episode:754 meanR:17.5500 R:9.0 loss:0.7227 exploreP:0.2477
# Episode:755 meanR:17.4200 R:17.0 loss:0.7534 exploreP:0.2473
# Episode:756 meanR:17.4300 R:11.0 loss:0.7666 exploreP:0.2470
# Episode:757 meanR:17.3000 R:11.0 loss:0.7636 exploreP:0.2468
# Episode:758 meanR:17.3600 R:27.0 loss:0.7471 exploreP:0.2461
# Episode:759 meanR:17.4800 R:20.0 loss:0.7721 exploreP:0.2457
# Episode:760 meanR:17.3600 R:9.0 loss:0.7275 exploreP:0.2455
# Episode:761 meanR:17.3600 R:11.0 loss:0.6614 exploreP:0.2452
# Episode:762 meanR:17.2000 R:26.0 loss:0.6927 exploreP:0.2446
# Episode:763 meanR:17.2200 R:14.0 loss:0.7655 exploreP:0.2443
# Episode:764 meanR:17.3100 R:20.0 loss:0.7374 exploreP:0.2438
# Episode:765 meanR:17.3300 R:10.0 loss:0.6994 exploreP:0.2436
# Episode:766 meanR:17.3000 R:19.0 loss:0.7752 exploreP:0.2431
# Episode:767 meanR:17.2700 R:22.0 loss:0.7392 exploreP:0.2426
# Episode:768 meanR:17.4600 R:29.0 loss:0.7726 exploreP:0.2419
# Episode:769 meanR:17.4200 R:8.0 loss:0.7776 exploreP:0.2417
# Episode:770 meanR:17.3200 R:10.0 loss:0.7643 exploreP:0.2415
# Episode:771 meanR:17.3500 R:24.0 loss:0.7372 exploreP:0.2410
# Episode:772 meanR:17.3500 R:9.0 loss:0.7405 exploreP:0.2407
# Episode:773 meanR:17.3800 R:12.0 loss:0.7582 exploreP:0.2405
# Episode:774 meanR:17.2100 R:10.0 loss:0.7338 exploreP:0.2402
# Episode:775 meanR:17.2200 R:24.0 loss:0.6896 exploreP:0.2397
# Episode:776 meanR:17.2200 R:9.0 loss:0.8681 exploreP:0.2395
# Episode:777 meanR:17.3000 R:28.0 loss:0.7254 exploreP:0.2388
# Episode:778 meanR:17.1500 R:10.0 loss:0.6767 exploreP:0.2386
# Episode:779 meanR:17.4000 R:36.0 loss:0.7774 exploreP:0.2378
# Episode:780 meanR:17.2400 R:10.0 loss:0.7400 exploreP:0.2376
# Episode:781 meanR:17.2000 R:26.0 loss:0.7061 exploreP:0.2370
# Episode:782 meanR:17.1900 R:10.0 loss:0.8184 exploreP:0.2367
# Episode:783 meanR:17.1900 R:12.0 loss:0.7440 exploreP:0.2365
# Episode:784 meanR:17.1500 R:26.0 loss:0.7789 exploreP:0.2359
# Episode:785 meanR:17.3800 R:38.0 loss:0.7009 exploreP:0.2350
# Episode:786 meanR:17.3500 R:23.0 loss:0.7270 exploreP:0.2345
# Episode:787 meanR:17.1900 R:12.0 loss:0.7576 exploreP:0.2342
# Episode:788 meanR:16.9500 R:9.0 loss:0.7330 exploreP:0.2340
# ...
# Episode:2998 meanR:18.6700 R:34.0 loss:0.7279 exploreP:0.0141
# Episode:2999 meanR:18.5500 R:11.0 loss:0.7982 exploreP:0.0141
# Episode:3000 meanR:18.5900 R:28.0 loss:0.7457 exploreP:0.0141
# Episode:3001 meanR:18.4500 R:8.0 loss:0.6419 exploreP:0.0141
# Episode:3002 meanR:18.5700 R:21.0 loss:0.7655 exploreP:0.0141
# Episode:3003 meanR:18.8200 R:33.0 loss:0.7195 exploreP:0.0141
# Episode:3004 meanR:18.6600 R:8.0 loss:0.7000 exploreP:0.0141
# Episode:3005 meanR:18.5500 R:9.0 loss:0.7013 exploreP:0.0141
# Episode:3006 meanR:18.5500 R:21.0 loss:0.6934 exploreP:0.0140
# Episode:3007 meanR:18.6600 R:22.0 loss:0.6991 exploreP:0.0140
# Episode:3008 meanR:18.5800 R:11.0 loss:0.7375 exploreP:0.0140
# Episode:3009 meanR:18.0300 R:9.0 loss:0.7108 exploreP:0.0140
# Episode:3010 meanR:17.8100 R:8.0 loss:0.7613 exploreP:0.0140
# Episode:3011 meanR:17.8700 R:36.0 loss:0.7130 exploreP:0.0140
# Episode:3012 meanR:17.7400 R:9.0 loss:0.7006 exploreP:0.0140
# Episode:3013 meanR:17.7500 R:24.0 loss:0.7289 exploreP:0.0140
# Episode:3014 meanR:17.7300 R:8.0 loss:0.7500 exploreP:0.0140
# Episode:3015 meanR:17.8500 R:21.0 loss:0.7144 exploreP:0.0140
# Episode:3016 meanR:17.9100 R:28.0 loss:0.7233 exploreP:0.0140
# Episode:3017 meanR:18.0900 R:27.0 loss:0.7494 exploreP:0.0140
# Episode:3018 meanR:18.0400 R:8.0 loss:0.8272 exploreP:0.0140
# Episode:3019 meanR:18.0500 R:9.0 loss:0.7451 exploreP:0.0140
# Episode:3020 meanR:18.0400 R:8.0 loss:0.7469 exploreP:0.0140
# Episode:3021 meanR:18.2300 R:27.0 loss:0.7331 exploreP:0.0139
# Episode:3022 meanR:18.0900 R:10.0 loss:0.7559 exploreP:0.0139
# Episode:3023 meanR:18.2500 R:34.0 loss:0.7424 exploreP:0.0139
# Episode:3024 meanR:18.3000 R:32.0 loss:0.6859 exploreP:0.0139
# Episode:3025 meanR:18.1500 R:8.0 loss:0.7643 exploreP:0.0139
# Episode:3026 meanR:18.1400 R:8.0 loss:0.6691 exploreP:0.0139
# Episode:3027 meanR:17.9900 R:11.0 loss:0.6889 exploreP:0.0139
# Episode:3028 meanR:18.1600 R:26.0 loss:0.7512 exploreP:0.0139
# Episode:3029 meanR:18.0100 R:24.0 loss:0.7125 exploreP:0.0139
# Episode:3030 meanR:18.1700 R:24.0 loss:0.7327 exploreP:0.0139
# Episode:3031 meanR:17.9500 R:9.0 loss:0.7561 exploreP:0.0139
# Episode:3032 meanR:17.9300 R:22.0 loss:0.7615 exploreP:0.0139
# Episode:3033 meanR:17.9000 R:21.0 loss:0.7579 exploreP:0.0139
# Episode:3034 meanR:17.7700 R:17.0 loss:0.6927 exploreP:0.0138
# Episode:3035 meanR:17.7700 R:9.0 loss:0.6858 exploreP:0.0138
# Episode:3036 meanR:17.7100 R:9.0 loss:0.7104 exploreP:0.0138
# Episode:3037 meanR:18.0000 R:38.0 loss:0.7348 exploreP:0.0138
# Episode:3038 meanR:18.0000 R:9.0 loss:0.7551 exploreP:0.0138
# Episode:3039 meanR:17.8000 R:8.0 loss:0.7224 exploreP:0.0138
# Episode:3040 meanR:17.6100 R:11.0 loss:0.7174 exploreP:0.0138
# Episode:3041 meanR:17.5900 R:9.0 loss:0.7885 exploreP:0.0138
# Episode:3042 meanR:17.4000 R:9.0 loss:0.6895 exploreP:0.0138
# Episode:3043 meanR:17.4100 R:9.0 loss:0.7821 exploreP:0.0138
# Episode:3044 meanR:17.2500 R:9.0 loss:0.8039 exploreP:0.0138
# Episode:3045 meanR:17.6400 R:48.0 loss:0.7159 exploreP:0.0138
# Episode:3046 meanR:17.6400 R:9.0 loss:0.7479 exploreP:0.0138
# Episode:3047 meanR:17.6200 R:11.0 loss:0.7391 exploreP:0.0138
# Episode:3048 meanR:17.6100 R:8.0 loss:0.7425 exploreP:0.0138
# Episode:3049 meanR:17.6900 R:37.0 loss:0.7584 exploreP:0.0138
# Episode:3050 meanR:17.7000 R:10.0 loss:0.7918 exploreP:0.0138
# Episode:3051 meanR:17.7300 R:25.0 loss:0.7494 exploreP:0.0137
# Episode:3052 meanR:17.7400 R:9.0 loss:0.6980 exploreP:0.0137
# Episode:3053 meanR:18.2300 R:58.0 loss:0.7649 exploreP:0.0137
# Episode:3054 meanR:18.2000 R:10.0 loss:0.7467 exploreP:0.0137
# Episode:3055 meanR:18.0700 R:9.0 loss:0.7421 exploreP:0.0137
# Episode:3056 meanR:17.9200 R:10.0 loss:0.7093 exploreP:0.0137
# Episode:3057 meanR:17.6500 R:13.0 loss:0.6974 exploreP:0.0137
# Episode:3058 meanR:17.6400 R:9.0 loss:0.7540 exploreP:0.0137
# Episode:3059 meanR:17.5700 R:22.0 loss:0.7887 exploreP:0.0137
# Episode:3060 meanR:17.6300 R:26.0 loss:0.7768 exploreP:0.0137
# Episode:3061 meanR:17.8300 R:28.0 loss:0.7213 exploreP:0.0137
# Episode:3062 meanR:17.8300 R:9.0 loss:0.7428 exploreP:0.0137
# Episode:3063 meanR:17.8300 R:9.0 loss:0.7745 exploreP:0.0137
# Episode:3064 meanR:17.8300 R:9.0 loss:0.7884 exploreP:0.0137
# Episode:3065 meanR:17.7400 R:21.0 loss:0.6929 exploreP:0.0137
# Episode:3066 meanR:18.0500 R:40.0 loss:0.7565 exploreP:0.0136
# Episode:3067 meanR:18.1900 R:35.0 loss:0.7789 exploreP:0.0136
# Episode:3068 meanR:17.8700 R:9.0 loss:0.7570 exploreP:0.0136
# Episode:3069 meanR:17.9100 R:31.0 loss:0.7361 exploreP:0.0136
# Episode:3070 meanR:17.9000 R:21.0 loss:0.6891 exploreP:0.0136
# Episode:3071 meanR:18.0000 R:33.0 loss:0.7557 exploreP:0.0136
# Episode:3072 meanR:17.8800 R:9.0 loss:0.7594 exploreP:0.0136
# Episode:3073 meanR:17.7200 R:8.0 loss:0.8172 exploreP:0.0136
# Episode:3074 meanR:17.5700 R:9.0 loss:0.7164 exploreP:0.0136
# Episode:3075 meanR:17.5700 R:9.0 loss:0.6892 exploreP:0.0136
# Episode:3076 meanR:17.4800 R:20.0 loss:0.7288 exploreP:0.0136
# Episode:3077 meanR:17.6900 R:30.0 loss:0.7830 exploreP:0.0136
# Episode:3078 meanR:17.5600 R:9.0 loss:0.6817 exploreP:0.0136
# Episode:3079 meanR:17.7400 R:27.0 loss:0.7448 exploreP:0.0135
# Episode:3080 meanR:17.6900 R:22.0 loss:0.7548 exploreP:0.0135
# Episode:3081 meanR:17.7200 R:25.0 loss:0.6977 exploreP:0.0135
# Episode:3082 meanR:17.5900 R:8.0 loss:0.7553 exploreP:0.0135
# Episode:3083 meanR:17.6000 R:9.0 loss:0.7290 exploreP:0.0135
# Episode:3084 meanR:17.6000 R:22.0 loss:0.6984 exploreP:0.0135
# Episode:3085 meanR:17.7900 R:28.0 loss:0.7158 exploreP:0.0135
# Episode:3086 meanR:17.9900 R:28.0 loss:0.7584 exploreP:0.0135
# Episode:3087 meanR:17.8500 R:8.0 loss:0.7014 exploreP:0.0135
# Episode:3088 meanR:17.9700 R:34.0 loss:0.7370 exploreP:0.0135
# Episode:3089 meanR:18.1300 R:25.0 loss:0.7557 exploreP:0.0135
# Episode:3090 meanR:18.2400 R:35.0 loss:0.7400 exploreP:0.0135
# Episode:3091 meanR:18.2400 R:9.0 loss:0.7558 exploreP:0.0135
# Episode:3092 meanR:18.4200 R:26.0 loss:0.7391 exploreP:0.0135
# Episode:3093 meanR:18.2700 R:9.0 loss:0.7027 exploreP:0.0134
# Episode:3094 meanR:18.1300 R:9.0 loss:0.7092 exploreP:0.0134
# Episode:3095 meanR:18.1500 R:12.0 loss:0.7836 exploreP:0.0134
# Episode:3096 meanR:18.4300 R:36.0 loss:0.7304 exploreP:0.0134
# Episode:3097 meanR:18.2800 R:9.0 loss:0.7526 exploreP:0.0134
# Episode:3098 meanR:18.0300 R:9.0 loss:0.7240 exploreP:0.0134
# Episode:3099 meanR:18.1200 R:20.0 loss:0.7253 exploreP:0.0134
# Episode:3100 meanR:18.0500 R:21.0 loss:0.7586 exploreP:0.0134
# Episode:3101 meanR:18.0600 R:9.0 loss:0.7091 exploreP:0.0134
# Episode:3102 meanR:18.1300 R:28.0 loss:0.7837 exploreP:0.0134
# Episode:3103 meanR:17.9100 R:11.0 loss:0.7509 exploreP:0.0134
# Episode:3104 meanR:18.1200 R:29.0 loss:0.7502 exploreP:0.0134
# Episode:3105 meanR:18.1200 R:9.0 loss:0.8452 exploreP:0.0134
# Episode:3106 meanR:18.3000 R:39.0 loss:0.7207 exploreP:0.0134
# Episode:3107 meanR:18.3600 R:28.0 loss:0.7675 exploreP:0.0134
# Episode:3108 meanR:18.4700 R:22.0 loss:0.7583 exploreP:0.0134
# Episode:3109 meanR:18.4900 R:11.0 loss:0.7512 exploreP:0.0133
# Episode:3110 meanR:18.7000 R:29.0 loss:0.7713 exploreP:0.0133
# Episode:3111 meanR:18.4200 R:8.0 loss:0.7323 exploreP:0.0133
# Episode:3112 meanR:18.4100 R:8.0 loss:0.8137 exploreP:0.0133
# Episode:3113 meanR:18.2800 R:11.0 loss:0.6856 exploreP:0.0133
# Episode:3114 meanR:18.4100 R:21.0 loss:0.8062 exploreP:0.0133
# Episode:3115 meanR:18.2900 R:9.0 loss:0.7157 exploreP:0.0133
# Episode:3116 meanR:18.1200 R:11.0 loss:0.7719 exploreP:0.0133
# Episode:3117 meanR:18.0700 R:22.0 loss:0.7216 exploreP:0.0133
# Episode:3118 meanR:18.0700 R:8.0 loss:0.7716 exploreP:0.0133
# Episode:3119 meanR:18.1800 R:20.0 loss:0.7663 exploreP:0.0133
# Episode:3120 meanR:18.2300 R:13.0 loss:0.7282 exploreP:0.0133
# Episode:3121 meanR:18.2500 R:29.0 loss:0.7283 exploreP:0.0133
# Episode:3122 meanR:18.2300 R:8.0 loss:0.7341 exploreP:0.0133
# Episode:3123 meanR:18.1900 R:30.0 loss:0.7225 exploreP:0.0133
# Episode:3124 meanR:18.1700 R:30.0 loss:0.7293 exploreP:0.0133
# Episode:3125 meanR:18.3500 R:26.0 loss:0.7391 exploreP:0.0133
# Episode:3126 meanR:18.5900 R:32.0 loss:0.7158 exploreP:0.0132
# Episode:3127 meanR:18.7200 R:24.0 loss:0.7323 exploreP:0.0132
# Episode:3128 meanR:18.7000 R:24.0 loss:0.7931 exploreP:0.0132
# Episode:3129 meanR:18.7100 R:25.0 loss:0.7505 exploreP:0.0132
# Episode:3130 meanR:18.5500 R:8.0 loss:0.6923 exploreP:0.0132
# Episode:3131 meanR:18.5600 R:10.0 loss:0.7248 exploreP:0.0132
# Episode:3132 meanR:18.4300 R:9.0 loss:0.6863 exploreP:0.0132
# Episode:3133 meanR:18.4600 R:24.0 loss:0.7040 exploreP:0.0132
# Episode:3134 meanR:18.3800 R:9.0 loss:0.7490 exploreP:0.0132
# Episode:3135 meanR:18.3700 R:8.0 loss:0.7803 exploreP:0.0132
# Episode:3136 meanR:18.3700 R:9.0 loss:0.7262 exploreP:0.0132
# Episode:3137 meanR:18.2100 R:22.0 loss:0.7453 exploreP:0.0132
# Episode:3138 meanR:18.2100 R:9.0 loss:0.7732 exploreP:0.0132
# Episode:3139 meanR:18.4200 R:29.0 loss:0.7111 exploreP:0.0132
# Episode:3140 meanR:18.4100 R:10.0 loss:0.7215 exploreP:0.0132
# Episode:3141 meanR:18.6400 R:32.0 loss:0.7196 exploreP:0.0132
# Episode:3142 meanR:18.6400 R:9.0 loss:0.7653 exploreP:0.0132
# Episode:3143 meanR:18.6800 R:13.0 loss:0.7645 exploreP:0.0132
# Episode:3144 meanR:18.9100 R:32.0 loss:0.7480 exploreP:0.0131
# Episode:3145 meanR:18.7200 R:29.0 loss:0.7473 exploreP:0.0131
# Episode:3146 meanR:18.7200 R:9.0 loss:0.7451 exploreP:0.0131
# Episode:3147 meanR:18.7000 R:9.0 loss:0.7821 exploreP:0.0131
# Episode:3148 meanR:18.7100 R:9.0 loss:0.6925 exploreP:0.0131
# Episode:3149 meanR:18.5600 R:22.0 loss:0.7011 exploreP:0.0131
# Episode:3150 meanR:18.7700 R:31.0 loss:0.7319 exploreP:0.0131
# Episode:3151 meanR:18.7900 R:27.0 loss:0.7155 exploreP:0.0131
# Episode:3152 meanR:19.0700 R:37.0 loss:0.7736 exploreP:0.0131
# Episode:3153 meanR:18.7700 R:28.0 loss:0.7261 exploreP:0.0131
# Episode:3154 meanR:18.7600 R:9.0 loss:0.7336 exploreP:0.0131
# Episode:3155 meanR:18.7600 R:9.0 loss:0.8211 exploreP:0.0131
# Episode:3156 meanR:18.7500 R:9.0 loss:0.7596 exploreP:0.0131
# Episode:3157 meanR:18.7100 R:9.0 loss:0.7109 exploreP:0.0131
# Episode:3158 meanR:18.7200 R:10.0 loss:0.6454 exploreP:0.0131
# Episode:3159 meanR:18.6000 R:10.0 loss:0.7878 exploreP:0.0131
# Episode:3160 meanR:18.5800 R:24.0 loss:0.7494 exploreP:0.0131
# Episode:3161 meanR:18.4000 R:10.0 loss:0.7465 exploreP:0.0131
# Episode:3162 meanR:18.3900 R:8.0 loss:0.7697 exploreP:0.0131
# Episode:3163 meanR:18.3800 R:8.0 loss:0.7861 exploreP:0.0130
# Episode:3164 meanR:18.7000 R:41.0 loss:0.7112 exploreP:0.0130
# Episode:3165 meanR:18.8500 R:36.0 loss:0.7643 exploreP:0.0130
# Episode:3166 meanR:18.5600 R:11.0 loss:0.7405 exploreP:0.0130
# Episode:3167 meanR:18.3000 R:9.0 loss:0.7248 exploreP:0.0130
# Episode:3168 meanR:18.3000 R:9.0 loss:0.7142 exploreP:0.0130
# Episode:3169 meanR:18.0800 R:9.0 loss:0.7275 exploreP:0.0130
# Episode:3170 meanR:17.9500 R:8.0 loss:0.6804 exploreP:0.0130
# Episode:3171 meanR:17.8700 R:25.0 loss:0.7512 exploreP:0.0130
# Episode:3172 meanR:17.8600 R:8.0 loss:0.7371 exploreP:0.0130
# Episode:3173 meanR:18.0200 R:24.0 loss:0.7879 exploreP:0.0130
# Episode:3174 meanR:18.0100 R:8.0 loss:0.7793 exploreP:0.0130
# Episode:3175 meanR:18.0000 R:8.0 loss:0.7601 exploreP:0.0130
# Episode:3176 meanR:18.1400 R:34.0 loss:0.6971 exploreP:0.0130
# Episode:3177 meanR:17.9200 R:8.0 loss:0.6362 exploreP:0.0130
# Episode:3178 meanR:17.9200 R:9.0 loss:0.7405 exploreP:0.0130
# Episode:3179 meanR:17.7400 R:9.0 loss:0.7883 exploreP:0.0130
# Episode:3180 meanR:17.6000 R:8.0 loss:0.7257 exploreP:0.0130
# Episode:3181 meanR:17.5900 R:24.0 loss:0.7532 exploreP:0.0130
# Episode:3182 meanR:17.6400 R:13.0 loss:0.7771 exploreP:0.0130
# Episode:3183 meanR:17.7900 R:24.0 loss:0.7391 exploreP:0.0130
# Episode:3184 meanR:17.6600 R:9.0 loss:0.7870 exploreP:0.0129
# Episode:3185 meanR:17.6300 R:25.0 loss:0.7428 exploreP:0.0129
# Episode:3186 meanR:17.4600 R:11.0 loss:0.6848 exploreP:0.0129
# Episode:3187 meanR:17.4700 R:9.0 loss:0.7871 exploreP:0.0129
# Episode:3188 meanR:17.3800 R:25.0 loss:0.7931 exploreP:0.0129
# Episode:3189 meanR:17.2100 R:8.0 loss:0.6725 exploreP:0.0129
# Episode:3190 meanR:16.9500 R:9.0 loss:0.6766 exploreP:0.0129
# Episode:3191 meanR:16.9500 R:9.0 loss:0.6953 exploreP:0.0129
# Episode:3192 meanR:16.9500 R:26.0 loss:0.7561 exploreP:0.0129
# Episode:3193 meanR:17.0300 R:17.0 loss:0.7197 exploreP:0.0129
# Episode:3194 meanR:17.0300 R:9.0 loss:0.7395 exploreP:0.0129
# Episode:3195 meanR:17.3400 R:43.0 loss:0.7439 exploreP:0.0129
# Episode:3196 meanR:17.2500 R:27.0 loss:0.7448 exploreP:0.0129
# Episode:3197 meanR:17.4000 R:24.0 loss:0.7447 exploreP:0.0129
# Episode:3198 meanR:17.5200 R:21.0 loss:0.7346 exploreP:0.0129
# Episode:3199 meanR:17.5300 R:21.0 loss:0.7437 exploreP:0.0129
# Episode:3200 meanR:17.4100 R:9.0 loss:0.7387 exploreP:0.0129
# Episode:3201 meanR:17.5500 R:23.0 loss:0.7647 exploreP:0.0129
# Episode:3202 meanR:17.4700 R:20.0 loss:0.7315 exploreP:0.0129
# Episode:3203 meanR:17.5700 R:21.0 loss:0.7251 exploreP:0.0128
# Episode:3204 meanR:17.3700 R:9.0 loss:0.7074 exploreP:0.0128
# Episode:3205 meanR:17.3600 R:8.0 loss:0.7439 exploreP:0.0128
# Episode:3206 meanR:17.0600 R:9.0 loss:0.8012 exploreP:0.0128
# Episode:3207 meanR:16.9300 R:15.0 loss:0.7332 exploreP:0.0128
# Episode:3208 meanR:17.0000 R:29.0 loss:0.6866 exploreP:0.0128
# Episode:3209 meanR:16.9800 R:9.0 loss:0.8263 exploreP:0.0128
# Episode:3210 meanR:16.9700 R:28.0 loss:0.7234 exploreP:0.0128
# Episode:3211 meanR:17.1000 R:21.0 loss:0.7460 exploreP:0.0128
# Episode:3212 meanR:17.1000 R:8.0 loss:0.6936 exploreP:0.0128
# Episode:3213 meanR:17.2500 R:26.0 loss:0.7191 exploreP:0.0128
# Episode:3214 meanR:17.1400 R:10.0 loss:0.7956 exploreP:0.0128
# Episode:3215 meanR:17.2700 R:22.0 loss:0.7321 exploreP:0.0128
# Episode:3216 meanR:17.4100 R:25.0 loss:0.7355 exploreP:0.0128
# Episode:3217 meanR:17.8100 R:62.0 loss:0.7167 exploreP:0.0128
# Episode:3218 meanR:17.8400 R:11.0 loss:0.6795 exploreP:0.0128
# Episode:3219 meanR:17.7300 R:9.0 loss:0.7527 exploreP:0.0128
# Episode:3220 meanR:17.6900 R:9.0 loss:0.7662 exploreP:0.0128
# Episode:3221 meanR:17.5000 R:10.0 loss:0.7065 exploreP:0.0128
# Episode:3222 meanR:17.6300 R:21.0 loss:0.7447 exploreP:0.0128
# Episode:3223 meanR:17.4500 R:12.0 loss:0.7558 exploreP:0.0127
# Episode:3224 meanR:17.2400 R:9.0 loss:0.6513 exploreP:0.0127
# Episode:3225 meanR:17.2800 R:30.0 loss:0.7278 exploreP:0.0127
# Episode:3226 meanR:17.0500 R:9.0 loss:0.6976 exploreP:0.0127
# Episode:3227 meanR:17.0300 R:22.0 loss:0.6889 exploreP:0.0127
# Episode:3228 meanR:17.0900 R:30.0 loss:0.7355 exploreP:0.0127
# Episode:3229 meanR:16.9300 R:9.0 loss:0.7573 exploreP:0.0127
# Episode:3230 meanR:16.9400 R:9.0 loss:0.7676 exploreP:0.0127
# Episode:3231 meanR:17.0700 R:23.0 loss:0.7299 exploreP:0.0127
# Episode:3232 meanR:17.2500 R:27.0 loss:0.7105 exploreP:0.0127
# Episode:3233 meanR:17.1200 R:11.0 loss:0.7746 exploreP:0.0127
# Episode:3234 meanR:17.1100 R:8.0 loss:0.7174 exploreP:0.0127
# Episode:3235 meanR:17.3100 R:28.0 loss:0.7270 exploreP:0.0127
# Episode:3236 meanR:17.3100 R:9.0 loss:0.6910 exploreP:0.0127
# Episode:3237 meanR:17.1800 R:9.0 loss:0.7601 exploreP:0.0127
# Episode:3238 meanR:17.1800 R:9.0 loss:0.6441 exploreP:0.0127
# Episode:3239 meanR:16.9800 R:9.0 loss:0.6441 exploreP:0.0127
# Episode:3240 meanR:17.1000 R:22.0 loss:0.7787 exploreP:0.0127
# Episode:3241 meanR:16.8700 R:9.0 loss:0.6864 exploreP:0.0127
# Episode:3242 meanR:16.9900 R:21.0 loss:0.7993 exploreP:0.0127
# Episode:3243 meanR:17.1200 R:26.0 loss:0.8113 exploreP:0.0127
# Episode:3244 meanR:16.8900 R:9.0 loss:0.7797 exploreP:0.0127
# Episode:3245 meanR:16.6800 R:8.0 loss:0.7225 exploreP:0.0127
# Episode:3246 meanR:16.8500 R:26.0 loss:0.7685 exploreP:0.0126
# Episode:3247 meanR:16.8400 R:8.0 loss:0.6911 exploreP:0.0126
# Episode:3248 meanR:17.0000 R:25.0 loss:0.7420 exploreP:0.0126
# Episode:3249 meanR:17.0100 R:23.0 loss:0.7794 exploreP:0.0126
# Episode:3250 meanR:16.8700 R:17.0 loss:0.6843 exploreP:0.0126
# Episode:3251 meanR:16.6900 R:9.0 loss:0.7404 exploreP:0.0126
# Episode:3252 meanR:16.5600 R:24.0 loss:0.7165 exploreP:0.0126
# Episode:3253 meanR:16.3700 R:9.0 loss:0.7497 exploreP:0.0126
# Episode:3254 meanR:16.4600 R:18.0 loss:0.7724 exploreP:0.0126
# Episode:3255 meanR:16.4800 R:11.0 loss:0.7994 exploreP:0.0126
# Episode:3256 meanR:16.5900 R:20.0 loss:0.6767 exploreP:0.0126

# %% [markdown]
# # Visualizing training
#
# Below I'll plot the total rewards for each episode. I'm plotting the rolling average too, in blue.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

def running_mean(x, N):
    cumsum = np.cumsum(np.insert(x, 0, 0)) 
    return (cumsum[N:] - cumsum[:-N]) / N

# %%
eps, arr = np.array(episode_rewards_list).T
smoothed_arr = running_mean(arr, 10)
plt.plot(eps[-len(smoothed_arr):], smoothed_arr)
plt.plot(eps, arr, color='grey', alpha=0.3)
plt.xlabel('Episode')
plt.ylabel('Total rewards')
# Out:
# Text(0, 0.5, 'Total rewards')

# %%
eps, arr = np.array(rewards_list).T
smoothed_arr = running_mean(arr, 10)
plt.plot(eps[-len(smoothed_arr):], smoothed_arr)
plt.plot(eps, arr, color='grey', alpha=0.3)
plt.xlabel('Episode')
plt.ylabel('Total rewards')
# Out:
# Text(0, 0.5, 'Total rewards')

# %%
eps, arr = np.array(episode_rewards_list).T
smoothed_arr = running_mean(arr, 10)
plt.plot(eps[-len(smoothed_arr):], smoothed_arr)
plt.plot(eps, arr, color='grey', alpha=0.3)
plt.xlabel('Episode')
plt.ylabel('Total rewards')
# Out:
# Text(0, 0.5, 'Total rewards')

# %%
eps, arr = np.array(rewards_list).T
smoothed_arr = running_mean(arr, 10)
plt.plot(eps[-len(smoothed_arr):], smoothed_arr)
plt.plot(eps, arr, color='grey', alpha=0.3)
plt.xlabel('Episode')
plt.ylabel('Total rewards')
# Out:
# Text(0, 0.5, 'Total rewards')

# %%
eps, arr = np.array(loss_list).T
smoothed_arr = running_mean(arr, 10)
plt.plot(eps[-len(smoothed_arr):], smoothed_arr)
plt.plot(eps, arr, color='grey', alpha=0.3)
plt.xlabel('Episode')
plt.ylabel('Average losses')
# Out:
# Text(0, 0.5, 'Average losses')

# %%
eps, arr = np.array(episode_rewards_list).T
smoothed_arr = running_mean(arr, 10)
plt.plot(eps[-len(smoothed_arr):], smoothed_arr)
plt.plot(eps, arr, color='grey', alpha=0.3)
plt.xlabel('Episode')
plt.ylabel('Total rewards')
# Out:
# Text(0,0.5,'Total rewards')

# %%
eps, arr = np.array(rewards_list).T
smoothed_arr = running_mean(arr, 10)
plt.plot(eps[-len(smoothed_arr):], smoothed_arr)
plt.plot(eps, arr, color='grey', alpha=0.3)
plt.xlabel('Episode')
plt.ylabel('Total rewards')
# Out:
# Text(0,0.5,'Total rewards')

# %%
eps, arr = np.array(loss_list).T
smoothed_arr = running_mean(arr, 10)
plt.plot(eps[-len(smoothed_arr):], smoothed_arr)
plt.plot(eps, arr, color='grey', alpha=0.3)
plt.xlabel('Episode')
plt.ylabel('Average losses')
# Out:
# Text(0,0.5,'Average losses')

# %% [markdown]
# ## Testing
#
# Let's checkout how our trained agent plays the game.

# %%
# Creating a gym env
import gym
env = gym.make('CartPole-v0')
env = gym.make('CartPole-v1')

# A training graph session
with tf.Session(graph=graph) as sess:
    #sess.run(tf.global_variables_initializer())
    #saver.restore(sess, 'checkpoints/model-qn.ckpt')    
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    
    # Episodes/epochs
    for _ in range(10):
        state = env.reset()
        total_reward = 0

        # Steps/batches
        while True:
            env.render()
            action_logits = sess.run(model.actions_logits, feed_dict={model.states: np.reshape(state, [1, -1])})
            action = np.argmax(action_logits)
            state, reward, done, _ = env.step(action)
            total_reward += reward
            if done:
                break
                
        # Closing the env
        print('total_reward: {}'.format(total_reward))
# Close the env at the end
env.close()
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/model-qn.ckpt
# /home/arasdar/anaconda3/lib/python3.6/site-packages/gym/envs/registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)
# total_reward: 500.0
# total_reward: 500.0
# total_reward: 500.0
# total_reward: 500.0
# total_reward: 500.0
# total_reward: 500.0
# total_reward: 500.0
# total_reward: 500.0
# total_reward: 500.0
# total_reward: 500.0

# %% [markdown]
# ## Extending this
#
# So, Cart-Pole is a pretty simple game. However, the same model can be used to train an agent to play something much more complicated like Pong or Space Invaders. Instead of a state like we're using here though, you'd want to use convolutional layers to get the state from the screen images.
#
# ![Deep Q-Learning Atari](assets/atari-network.png)
#
# I'll leave it as a challenge for you to use deep Q-learning to train an agent to play Atari games. Here's the original paper which will get you started: http://www.davidqiu.com:8888/research/nature14236.pdf.
