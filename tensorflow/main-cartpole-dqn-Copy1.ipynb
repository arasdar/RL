# %% [markdown]
# # Deep Q-learning (DQL) or Deep Q-network (DQN)
#
# In this notebook, we'll build a neural network that can learn to play games through reinforcement learning. More specifically, we'll use Q-learning to train an agent to play a game called [Cart-Pole](https://gym.openai.com/envs/CartPole-v0). In this game, a freely swinging pole is attached to a cart. The cart can move to the left and right, and the goal is to keep the pole upright as long as possible.
#
# ![Cart-Pole](assets/cart-pole.jpg)
#
# We can simulate this game using [OpenAI Gym](https://gym.openai.com/). First, let's check out how OpenAI Gym works. Then, we'll get into training an agent to play the Cart-Pole game.

# %%
import numpy as np

# %%
import tensorflow as tf
print('TensorFlow Version: {}'.format(tf.__version__))
print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.7.1
# Default GPU Device:

# %% [markdown]
# >**Note:** Make sure you have OpenAI Gym cloned into the same directory with this notebook. I've included `gym` as a submodule, so you can run `git submodule --init --recursive` to pull the contents into the `gym` repo.

# %% [markdown]
# >**Note:** Make sure you have OpenAI Gym cloned. Then run this command `pip install -e gym/[all]`.

# %%
import gym

## Create the Cart-Pole game environment
# env = gym.make('CartPole-v0') # 200 total reward as goal
env = gym.make('CartPole-v1') # 500 total reward as goal
# Out:
# /home/arasdar/anaconda3/lib/python3.6/site-packages/gym/envs/registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)

# %% [markdown]
# We interact with the simulation through `env`. To show the simulation running, you can use `env.render()` to render one frame. Passing in an action as an integer to `env.step` will generate the next step in the simulation.  You can see how many actions are possible from `env.action_space` and to get a random action you can use `env.action_space.sample()`. This is general to all Gym games. In the Cart-Pole game, there are two possible actions, moving the cart left or right. So there are two actions we can take, encoded as 0 and 1.
#
# Run the code below to watch the simulation run.

# %%
# env.reset()
# batch = []
# for _ in range(1000):
#     # env.render()
#     action = env.action_space.sample()
#     state, reward, done, info = env.step(action) # take a random action
#     batch.append([action, state, reward, done, info])
#     #print('state, action, reward, done, info:', state, action, reward, done, info)
#     if done:
#         env.reset()

# %% [markdown]
# To shut the window showing the simulation, use `env.close()`.

# %% [markdown]
# If you ran the simulation above, we can look at the rewards:

# %%
# batch[0], batch[0][1].shape

# %%
# actions = np.array([each[0] for each in batch])
# states = np.array([each[1] for each in batch])
# rewards = np.array([each[2] for each in batch])
# dones = np.array([each[3] for each in batch])
# infos = np.array([each[4] for each in batch])

# %%
# print(rewards[-20:])
# print(np.array(rewards).shape, np.array(states).shape, np.array(actions).shape, np.array(dones).shape)
# print(np.array(rewards).dtype, np.array(states).dtype, np.array(actions).dtype, np.array(dones).dtype)
# print(np.max(np.array(actions)), np.min(np.array(actions)))
# print((np.max(np.array(actions)) - np.min(np.array(actions)))+1)
# print(np.max(np.array(rewards)), np.min(np.array(rewards)))
# print(np.max(np.array(states)), np.min(np.array(states)))

# %% [markdown]
# The game resets after the pole has fallen past a certain angle. For each frame while the simulation is running, it returns a reward of 1.0. The longer the game runs, the more reward we get. Then, our network's goal is to maximize the reward by keeping the pole vertical. It will do this by moving the cart to the left and the right.

# %% [markdown]
# ## Q-Network
#
# We train our Q-learning agent using the Bellman Equation:
#
# $$
# Q(s, a) = r + \gamma \max{Q(s', a')}
# $$
#
# where $s$ is a state, $a$ is an action, and $s'$ is the next state from state $s$ and action $a$.
#
# Before we used this equation to learn values for a Q-_table_. However, for this game there are a huge number of states available. The state has four values: the position and velocity of the cart, and the position and velocity of the pole. These are all real-valued numbers, so ignoring floating point precisions, you practically have infinite states. Instead of using a table then, we'll replace it with a neural network that will approximate the Q-table lookup function.
#
# <img src="assets/deep-q-learning.png" width=450px>
#
# Now, our Q value, $Q(s, a)$ is calculated by passing in a state to the network. The output will be Q-values for each available action, with fully connected hidden layers.
#
# <img src="assets/q-network.png" width=550px>
#
#
# As I showed before, we can define our targets for training as $\hat{Q}(s,a) = r + \gamma \max{Q(s', a')}$. Then we update the weights by minimizing $(\hat{Q}(s,a) - Q(s,a))^2$.
#
# For this Cart-Pole game, we have four inputs, one for each value in the state, and two outputs, one for each action. To get $\hat{Q}$, we'll first choose an action, then simulate the game using that action. This will get us the next state, $s'$, and the reward. With that, we can calculate $\hat{Q}$ then pass it back into the $Q$ network to run the optimizer and update the weights.
#
# Below is my implementation of the Q-network. I used two fully connected layers with ReLU activations. Two seems to be good enough, three might be better. Feel free to try it out.

# %%
def model_input(state_size):
    actions = tf.placeholder(tf.int32, [None], name='actions')
    states = tf.placeholder(tf.float32, [None, state_size], name='states')
    targetQs = tf.placeholder(tf.float32, [None], name='targetQs')
    is_training = tf.placeholder(tf.bool, name='is_training')
    return actions, states, targetQs, is_training

# %%
def init_xavier(random_seed=1, dtype=tf.float32, uniform=False):
    xavier = tf.contrib.layers.xavier_initializer(
        dtype=dtype,
        seed=tf.set_random_seed(random_seed), 
        uniform=uniform) # False: normal
    return xavier

# %%
def mlp(inputs, units, trainable=True):
    outputs = tf.layers.dense(
        inputs=inputs,
        units=units,
        activation=None,
        use_bias=True,
        kernel_initializer=init_xavier(), # Xavier with normal init
        bias_initializer=tf.zeros_initializer(),
        kernel_regularizer=None,
        bias_regularizer=None,
        activity_regularizer=None,
        kernel_constraint=None,
        bias_constraint=None,
        trainable=trainable,
        name=None,
        reuse=None)
    return outputs

# %%
# tf.nn.leaky_relu(
#     features,
#     alpha=0.2,
#     name=None
# )
def nl(inputs, alpha=0.2):
    outputs = tf.maximum(alpha * inputs, inputs)
    return outputs

# %%
def bn(inputs, training=False):
    outputs = tf.layers.batch_normalization(
        inputs=inputs,
        axis=-1,
        momentum=0.99,
        epsilon=0.001,
        center=True,
        scale=True,
        beta_initializer=tf.zeros_initializer(),
        gamma_initializer=tf.ones_initializer(),
        moving_mean_initializer=tf.zeros_initializer(),
        moving_variance_initializer=tf.ones_initializer(),
        beta_regularizer=None,
        gamma_regularizer=None,
        beta_constraint=None,
        gamma_constraint=None,
        training=training,
        trainable=True,
        name=None,
        reuse=None,
        renorm=False,
        renorm_clipping=None,
        renorm_momentum=0.99,
        fused=None,
        virtual_batch_size=None,
        adjustment=None)
    return outputs

# %%
# Actor-Critic/ D/Q
def D(states, action_size, hidden_size, reuse=False, alpha=0.2, is_training=False):
    with tf.variable_scope('D', reuse=reuse):
        # First fully connected layer
        h = mlp(inputs=states, units=hidden_size)
        h = bn(inputs=h, training=is_training)
        h = nl(h)
        print(states.shape, h.shape)
        
        # Second fully connected layer
        h = mlp(inputs=h, units=hidden_size)
        h = bn(inputs=h, training=is_training)
        h = nl(h)
        print(h.shape)
        
        # Output layer
        actions = mlp(inputs=h, units=action_size)
        return actions

# %%
def model_loss(actions, states, targetQs, action_size, hidden_size, is_training=False):
    
    actions_logits = D(states=states, hidden_size=hidden_size, action_size=action_size, 
                       is_training=is_training)
    
    actions_labels = tf.one_hot(indices=actions, depth=action_size, dtype=actions_logits.dtype)
    
    Qs = tf.reduce_max(actions_logits*actions_labels, axis=1)
    
    loss = tf.reduce_mean((Qs - targetQs)**2)
    
    return actions_logits, loss

# %%
def model_opt(loss, learning_rate):
    # Get weights and bias to update
    t_vars = tf.trainable_variables()
    d_vars = [var for var in t_vars if var.name.startswith('D')]

    # Optimize
    with tf.control_dependencies(tf.get_collection(tf.GraphKeys.UPDATE_OPS)): # Required for batchnorm (BN)
        opt = tf.train.AdamOptimizer(learning_rate).minimize(loss, var_list=d_vars)

    return opt

# %%
class Model:
    def __init__(self, state_size, action_size, hidden_size, learning_rate):

        # Data of the Model: make the data available inside the framework
        self.actions, self.states, self.targetQs, self.is_training = model_input(state_size=state_size)

        # Create the Model: calculating the loss and forwad pass
        self.actions_logits, self.loss = model_loss(action_size=action_size, hidden_size=hidden_size,
                                                    states=self.states, actions=self.actions, 
                                                    targetQs=self.targetQs, is_training=self.is_training)

        # Update the model: backward pass and backprop
        self.opt = model_opt(loss=self.loss, learning_rate=learning_rate)

# %% [markdown]
# ## Experience replay
#
# Reinforcement learning algorithms can have stability issues due to correlations between states. To reduce correlations when training, we can store the agent's experiences and later draw a random mini-batch of those experiences to train on.
#
# Here, we'll create a `Memory` object that will store our experiences, our transitions $<s, a, r, s'>$. This memory will have a maxmium capacity, so we can keep newer experiences in memory while getting rid of older experiences. Then, we'll sample a random mini-batch of transitions $<s, a, r, s'>$ and train on those.
#
# Below, I've implemented a `Memory` object. If you're unfamiliar with `deque`, this is a double-ended queue. You can think of it like a tube open on both sides. You can put objects in either side of the tube. But if it's full, adding anything more will push an object out the other side. This is a great data structure to use for the memory buffer.

# %%
from collections import deque
class Memory():
    def __init__(self, max_size = 1000):
        self.buffer = deque(maxlen=max_size)
    def sample(self, batch_size):
        idx = np.random.choice(np.arange(len(self.buffer)), 
                               size=batch_size, 
                               replace=False)
        return [self.buffer[ii] for ii in idx]

# %% [markdown]
# ## Exploration - Exploitation
#
# To learn about the environment and rules of the game, the agent needs to explore by taking random actions. We'll do this by choosing a random action with some probability $\epsilon$ (epsilon).  That is, with some probability $\epsilon$ the agent will make a random action and with probability $1 - \epsilon$, the agent will choose an action from $Q(s,a)$. This is called an **$\epsilon$-greedy policy**.
#
#
# At first, the agent needs to do a lot of exploring. Later when it has learned more, the agent can favor choosing actions based on what it has learned. This is called _exploitation_. We'll set it up so the agent is more likely to explore early in training, then more likely to exploit later in training.

# %% [markdown]
# ## Q-Learning training algorithm
#
# Putting all this together, we can list out the algorithm we'll use to train the network. We'll train the network in _episodes_. One *episode* is one simulation of the game. For this game, the goal is to keep the pole upright for 195 frames. So we can start a new episode once meeting that goal. The game ends if the pole tilts over too far, or if the cart moves too far the left or right. When a game ends, we'll start a new episode. Now, to train the agent:
#
# * Initialize the memory $D$
# * Initialize the action-value network $Q$ with random weights
# * **For** episode = 1, $M$ **do**
#   * **For** $t$, $T$ **do**
#      * With probability $\epsilon$ select a random action $a_t$, otherwise select $a_t = \mathrm{argmax}_a Q(s,a)$
#      * Execute action $a_t$ in simulator and observe reward $r_{t+1}$ and new state $s_{t+1}$
#      * Store transition $<s_t, a_t, r_{t+1}, s_{t+1}>$ in memory $D$
#      * Sample random mini-batch from $D$: $<s_j, a_j, r_j, s'_j>$
#      * Set $\hat{Q}_j = r_j$ if the episode ends at $j+1$, otherwise set $\hat{Q}_j = r_j + \gamma \max_{a'}{Q(s'_j, a')}$
#      * Make a gradient descent step with loss $(\hat{Q}_j - Q(s_j, a_j))^2$
#   * **endfor**
# * **endfor**

# %% [markdown]
# ## Hyperparameters
#
# One of the more difficult aspects of reinforcememt learning are the large number of hyperparameters. Not only are we tuning the network, but we're tuning the simulation.

# %%
# print('state size:{}'.format(states.shape), 
#       'actions:{}'.format(actions.shape)) 
# print('action size:', np.max(actions) - np.min(actions)+1)

# %%
# Exploration parameters
explore_start = 1.0            # exploration probability at start
explore_stop = 0.01            # minimum exploration probability 
decay_rate = 0.0001            # exponential decay rate for exploration prob

# Network parameters
action_size = 2
state_size = 4
hidden_size = 64               # number of units in each Q-network hidden layer
learning_rate = 1e-04         # Q-network learning rate

# Memory parameters
memory_size = int(1e5)            # memory capacity
batch_size = 20             # experience mini-batch size
gamma = 0.99                 # future reward discount

# %%
# Reset/init the graph/session
graph = tf.reset_default_graph()

# Init the model
model = Model(action_size=action_size, hidden_size=hidden_size, state_size=state_size, learning_rate=learning_rate)

# Init the memory
memory = Memory(max_size=memory_size)
# Out:
# (?, 4) (?, 64)
# (?, 64)

# %% [markdown]
# ## Populate the memory (exprience memory)
#
# Here I'm re-initializing the simulation and pre-populating the memory. The agent is taking random actions and storing the transitions in memory. This will help the agent with exploring the game.

# %%
# state = env.reset()

# for _ in range(memory_size):
    
#     action = env.action_space.sample()
    
#     next_state, reward, done, _ = env.step(action)
    
#     memory.buffer.append([state, action, next_state, reward, float(done)])
    
#     state = next_state
    
#     if done is True:
#         state = env.reset()

# %% [markdown]
# ## Training the model
#
# Below we'll train our agent. If you want to watch it train, uncomment the `env.render()` line. This is slow because it's rendering the frames slower than the network can train. But, it's cool to watch the agent get better at the game.

# %%
def learn(sess, memory, batch_size):
    
    batch = memory.sample(batch_size)
    states = np.array([each[0] for each in batch])
    actions = np.array([each[1] for each in batch])
    next_states = np.array([each[2] for each in batch])
    rewards = np.array([each[3] for each in batch])
    dones = np.array([each[4] for each in batch])
    
    next_actions_logits = sess.run(model.actions_logits, feed_dict = {model.states: next_states, 
                                                                      model.is_training: False})
    
    nextQs = np.max(next_actions_logits, axis=1) * (1-dones)
    
    targetQs = rewards + (gamma * nextQs)
    
    loss, _ = sess.run([model.loss, model.opt], feed_dict = {model.states: states, 
                                                             model.actions: actions,
                                                             model.targetQs: targetQs, 
                                                             model.is_training: False})
    return loss

# %%
def act(sess, state):
    
    action_logits = sess.run(model.actions_logits, feed_dict={model.states: state.reshape([1, -1]), 
                                                              model.is_training: False})
    
    action = np.argmax(action_logits, axis=1)[0]
    #print(action)
    
    return action

# %%
# Save/load the model and save for plotting
saver = tf.train.Saver()
episode_rewards_list, rewards_list, loss_list = [], [], []

# TF session for training
with tf.Session(graph=graph) as sess:
    sess.run(tf.global_variables_initializer())
    #saver.restore(sess, 'checkpoints/model.ckpt')    
    #saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    total_step = 0 # Explore or exploit parameter
    episode_reward = deque(maxlen=100) # 100 episodes average/running average/running mean/window
    
    # Training episodes/epochs
    for ep in range(11111):
        total_reward = 0
        loss_batch = []
        state = env.reset()

        # Training steps/batches
        while True:
            # Explore (Env) or Exploit (Model)
            total_step += 1
            explore_p = explore_stop + (explore_start - explore_stop) * np.exp(-decay_rate * total_step)
            
            if explore_p > np.random.rand():
                action = env.action_space.sample()
            else:
                action = act(sess, state)
                
            next_state, reward, done, _ = env.step(action)
            
            memory.buffer.append([state, action, next_state, reward, float(done)])
            
            total_reward += reward
            state = next_state

            # Training
            if len(memory.buffer) >= batch_size:
                loss = learn(sess, memory, batch_size)
                loss_batch.append(loss)
            
            if done is True:
                break
                
        if len(memory.buffer) >= batch_size:
            episode_reward.append(total_reward)

            print('Episode:{}'.format(ep),
                  'meanR:{:.4f}'.format(np.mean(episode_reward)),
                  'R:{}'.format(total_reward),
                  'loss:{:.4f}'.format(np.mean(loss_batch)),
                  'exploreP:{:.4f}'.format(explore_p))

            # Ploting out
            episode_rewards_list.append([ep, np.mean(episode_reward)])
            rewards_list.append([ep, total_reward])
            loss_list.append([ep, np.mean(loss_batch)])

            # Break episode/epoch loop
            if np.mean(episode_reward) >= 500:
                break
                
        else: print('len(memory.buffer) < batch_size', len(memory.buffer), batch_size)
            
    # At the end of all training episodes/epochs
    saver.save(sess, 'checkpoints/model.ckpt')
# Out:
# len(memory.buffer) < batch_size 14 20
# Episode:1 meanR:13.0000 R:13.0 loss:1.1100 exploreP:0.9973
# Episode:2 meanR:13.0000 R:13.0 loss:1.1357 exploreP:0.9960
# Episode:3 meanR:14.0000 R:16.0 loss:1.1424 exploreP:0.9945
# Episode:4 meanR:15.7500 R:21.0 loss:1.1484 exploreP:0.9924
# Episode:5 meanR:17.4000 R:24.0 loss:1.1872 exploreP:0.9901
# Episode:6 meanR:16.6667 R:13.0 loss:1.2499 exploreP:0.9888
# Episode:7 meanR:17.2857 R:21.0 loss:1.2149 exploreP:0.9867
# Episode:8 meanR:17.7500 R:21.0 loss:1.2078 exploreP:0.9847
# Episode:9 meanR:17.7778 R:18.0 loss:1.2370 exploreP:0.9829
# Episode:10 meanR:17.7000 R:17.0 loss:1.2289 exploreP:0.9813
# Episode:11 meanR:17.3636 R:14.0 loss:1.2786 exploreP:0.9799
# Episode:12 meanR:17.4167 R:18.0 loss:1.2696 exploreP:0.9782
# Episode:13 meanR:18.3077 R:29.0 loss:1.3517 exploreP:0.9754
# Episode:14 meanR:19.0000 R:28.0 loss:1.4419 exploreP:0.9727
# Episode:15 meanR:19.7333 R:30.0 loss:1.5502 exploreP:0.9698
# Episode:16 meanR:19.4375 R:15.0 loss:1.6027 exploreP:0.9683
# Episode:17 meanR:19.0588 R:13.0 loss:1.7462 exploreP:0.9671
# Episode:18 meanR:18.5556 R:10.0 loss:1.8462 exploreP:0.9661
# Episode:19 meanR:19.4737 R:36.0 loss:2.1800 exploreP:0.9627
# Episode:20 meanR:19.2000 R:14.0 loss:2.1412 exploreP:0.9614
# Episode:21 meanR:18.8571 R:12.0 loss:2.5777 exploreP:0.9602
# Episode:22 meanR:18.7727 R:17.0 loss:3.0608 exploreP:0.9586
# Episode:23 meanR:19.3913 R:33.0 loss:3.3512 exploreP:0.9555
# Episode:24 meanR:19.2917 R:17.0 loss:3.6839 exploreP:0.9539
# Episode:25 meanR:19.3600 R:21.0 loss:4.1669 exploreP:0.9519
# Episode:26 meanR:20.5385 R:50.0 loss:4.9420 exploreP:0.9472
# Episode:27 meanR:20.3704 R:16.0 loss:5.5240 exploreP:0.9457
# Episode:28 meanR:20.1429 R:14.0 loss:6.1677 exploreP:0.9444
# Episode:29 meanR:19.7241 R:8.0 loss:9.0992 exploreP:0.9437
# Episode:30 meanR:19.6333 R:17.0 loss:7.6649 exploreP:0.9421
# Episode:31 meanR:20.1613 R:36.0 loss:7.8519 exploreP:0.9387
# Episode:32 meanR:20.5938 R:34.0 loss:10.5721 exploreP:0.9356
# Episode:33 meanR:20.6364 R:22.0 loss:9.3646 exploreP:0.9335
# Episode:34 meanR:20.4412 R:14.0 loss:8.1854 exploreP:0.9322
# Episode:35 meanR:20.5714 R:25.0 loss:17.4207 exploreP:0.9299
# Episode:36 meanR:20.2778 R:10.0 loss:10.6457 exploreP:0.9290
# Episode:37 meanR:20.0270 R:11.0 loss:18.7556 exploreP:0.9280
# Episode:38 meanR:20.1579 R:25.0 loss:11.5190 exploreP:0.9257
# Episode:39 meanR:20.4103 R:30.0 loss:15.7110 exploreP:0.9230
# Episode:40 meanR:21.0250 R:45.0 loss:16.3349 exploreP:0.9189
# Episode:41 meanR:20.7805 R:11.0 loss:17.2157 exploreP:0.9179
# Episode:42 meanR:20.5952 R:13.0 loss:17.3387 exploreP:0.9167
# Episode:43 meanR:20.8605 R:32.0 loss:16.5623 exploreP:0.9138
# Episode:44 meanR:20.6364 R:11.0 loss:16.5413 exploreP:0.9128
# Episode:45 meanR:20.5556 R:17.0 loss:19.3991 exploreP:0.9113
# Episode:46 meanR:20.8043 R:32.0 loss:24.4097 exploreP:0.9084
# Episode:47 meanR:20.6383 R:13.0 loss:23.0873 exploreP:0.9072
# Episode:48 meanR:20.5000 R:14.0 loss:23.1622 exploreP:0.9060
# Episode:49 meanR:20.4286 R:17.0 loss:16.7777 exploreP:0.9044
# Episode:50 meanR:20.2200 R:10.0 loss:19.2026 exploreP:0.9036
# Episode:51 meanR:20.3725 R:28.0 loss:29.8302 exploreP:0.9011
# Episode:52 meanR:20.3846 R:21.0 loss:22.4619 exploreP:0.8992
# Episode:53 meanR:20.3585 R:19.0 loss:17.8151 exploreP:0.8975
# Episode:54 meanR:20.2778 R:16.0 loss:15.7729 exploreP:0.8961
# Episode:55 meanR:20.2182 R:17.0 loss:25.2467 exploreP:0.8946
# Episode:56 meanR:20.0714 R:12.0 loss:22.5262 exploreP:0.8935
# Episode:57 meanR:20.0877 R:21.0 loss:18.3965 exploreP:0.8917
# Episode:58 meanR:19.9138 R:10.0 loss:32.4083 exploreP:0.8908
# Episode:59 meanR:19.7458 R:10.0 loss:10.7050 exploreP:0.8899
# Episode:60 meanR:19.8167 R:24.0 loss:21.7660 exploreP:0.8878
# Episode:61 meanR:19.8033 R:19.0 loss:22.0744 exploreP:0.8861
# Episode:62 meanR:19.9194 R:27.0 loss:18.6244 exploreP:0.8838
# Episode:63 meanR:20.1587 R:35.0 loss:22.5026 exploreP:0.8807
# Episode:64 meanR:20.3125 R:30.0 loss:20.5111 exploreP:0.8781
# Episode:65 meanR:20.1692 R:11.0 loss:22.7898 exploreP:0.8771
# Episode:66 meanR:20.5152 R:43.0 loss:23.4045 exploreP:0.8734
# Episode:67 meanR:20.4478 R:16.0 loss:15.3098 exploreP:0.8720
# Episode:68 meanR:20.2941 R:10.0 loss:29.5151 exploreP:0.8712
# Episode:69 meanR:20.5797 R:40.0 loss:23.3766 exploreP:0.8677
# Episode:70 meanR:20.7143 R:30.0 loss:27.4679 exploreP:0.8652
# Episode:71 meanR:20.7183 R:21.0 loss:37.6414 exploreP:0.8634
# Episode:72 meanR:20.7083 R:20.0 loss:17.5353 exploreP:0.8617
# Episode:73 meanR:20.6712 R:18.0 loss:15.8103 exploreP:0.8601
# Episode:74 meanR:20.5946 R:15.0 loss:27.9456 exploreP:0.8589
# Episode:75 meanR:20.4800 R:12.0 loss:35.9125 exploreP:0.8579
# Episode:76 meanR:20.4211 R:16.0 loss:32.1135 exploreP:0.8565
# Episode:77 meanR:20.3247 R:13.0 loss:37.3270 exploreP:0.8554
# Episode:78 meanR:20.2308 R:13.0 loss:27.2458 exploreP:0.8543
# Episode:79 meanR:20.2025 R:18.0 loss:36.5911 exploreP:0.8528
# Episode:80 meanR:20.5875 R:51.0 loss:26.2454 exploreP:0.8485
# Episode:81 meanR:20.7654 R:35.0 loss:27.9737 exploreP:0.8456
# Episode:82 meanR:20.6220 R:9.0 loss:13.4218 exploreP:0.8448
# Episode:83 meanR:20.6265 R:21.0 loss:30.2442 exploreP:0.8431
# Episode:84 meanR:21.0357 R:55.0 loss:33.8538 exploreP:0.8385
# Episode:85 meanR:21.1176 R:28.0 loss:28.7887 exploreP:0.8362
# Episode:86 meanR:21.0349 R:14.0 loss:45.3310 exploreP:0.8350
# Episode:87 meanR:21.0805 R:25.0 loss:28.2359 exploreP:0.8330
# Episode:88 meanR:21.0682 R:20.0 loss:33.8606 exploreP:0.8313
# Episode:89 meanR:20.9663 R:12.0 loss:21.7958 exploreP:0.8303
# Episode:90 meanR:20.9889 R:23.0 loss:28.9212 exploreP:0.8284
# Episode:91 meanR:21.0769 R:29.0 loss:25.6875 exploreP:0.8261
# Episode:92 meanR:21.0326 R:17.0 loss:26.9328 exploreP:0.8247
# Episode:93 meanR:20.9355 R:12.0 loss:26.0198 exploreP:0.8237
# Episode:94 meanR:20.9043 R:18.0 loss:36.3606 exploreP:0.8222
# Episode:95 meanR:20.8526 R:16.0 loss:25.4832 exploreP:0.8209
# Episode:96 meanR:20.7917 R:15.0 loss:30.4502 exploreP:0.8197
# Episode:97 meanR:21.0206 R:43.0 loss:32.5754 exploreP:0.8163
# Episode:98 meanR:20.9082 R:10.0 loss:30.1166 exploreP:0.8155
# Episode:99 meanR:20.8384 R:14.0 loss:34.5922 exploreP:0.8143
# Episode:100 meanR:20.7700 R:14.0 loss:25.3936 exploreP:0.8132
# Episode:101 meanR:20.8300 R:19.0 loss:26.4894 exploreP:0.8117
# Episode:102 meanR:20.8600 R:16.0 loss:27.9796 exploreP:0.8104
# Episode:103 meanR:20.8200 R:12.0 loss:23.5974 exploreP:0.8094
# Episode:104 meanR:20.7300 R:12.0 loss:28.7485 exploreP:0.8085
# Episode:105 meanR:20.6200 R:13.0 loss:47.4430 exploreP:0.8074
# Episode:106 meanR:20.9300 R:44.0 loss:28.1122 exploreP:0.8039
# Episode:107 meanR:21.0500 R:33.0 loss:31.2357 exploreP:0.8013
# Episode:108 meanR:21.0600 R:22.0 loss:26.0542 exploreP:0.7996
# Episode:109 meanR:21.0000 R:12.0 loss:21.7069 exploreP:0.7986
# Episode:110 meanR:21.0100 R:18.0 loss:31.7106 exploreP:0.7972
# Episode:111 meanR:21.0300 R:16.0 loss:19.5890 exploreP:0.7960
# Episode:112 meanR:21.0000 R:15.0 loss:33.8778 exploreP:0.7948
# Episode:113 meanR:20.8700 R:16.0 loss:23.7015 exploreP:0.7935
# Episode:114 meanR:20.7200 R:13.0 loss:16.2857 exploreP:0.7925
# Episode:115 meanR:20.6100 R:19.0 loss:38.7688 exploreP:0.7910
# Episode:116 meanR:20.7300 R:27.0 loss:27.2414 exploreP:0.7889
# Episode:117 meanR:20.7900 R:19.0 loss:16.6931 exploreP:0.7874
# Episode:118 meanR:20.8000 R:11.0 loss:21.0822 exploreP:0.7866
# Episode:119 meanR:20.6100 R:17.0 loss:22.3500 exploreP:0.7853
# Episode:120 meanR:20.6700 R:20.0 loss:27.2646 exploreP:0.7837
# Episode:121 meanR:20.7400 R:19.0 loss:27.9758 exploreP:0.7822
# Episode:122 meanR:20.7300 R:16.0 loss:28.0902 exploreP:0.7810
# Episode:123 meanR:20.5600 R:16.0 loss:26.8606 exploreP:0.7798
# Episode:124 meanR:20.7800 R:39.0 loss:23.0002 exploreP:0.7768
# Episode:125 meanR:20.7100 R:14.0 loss:11.0418 exploreP:0.7757
# Episode:126 meanR:20.3400 R:13.0 loss:21.3570 exploreP:0.7747
# Episode:127 meanR:20.4000 R:22.0 loss:19.8772 exploreP:0.7730
# Episode:128 meanR:20.4700 R:21.0 loss:21.0874 exploreP:0.7714
# Episode:129 meanR:20.5300 R:14.0 loss:26.1121 exploreP:0.7704
# Episode:130 meanR:20.4700 R:11.0 loss:22.2332 exploreP:0.7695
# Episode:131 meanR:20.2600 R:15.0 loss:29.9072 exploreP:0.7684
# Episode:132 meanR:20.0200 R:10.0 loss:23.4170 exploreP:0.7676
# Episode:133 meanR:19.8900 R:9.0 loss:21.8834 exploreP:0.7670
# Episode:134 meanR:19.8600 R:11.0 loss:22.1560 exploreP:0.7661
# Episode:135 meanR:19.7300 R:12.0 loss:17.3888 exploreP:0.7652
# Episode:136 meanR:19.7600 R:13.0 loss:11.7021 exploreP:0.7642
# Episode:137 meanR:20.0000 R:35.0 loss:14.2627 exploreP:0.7616
# Episode:138 meanR:19.8600 R:11.0 loss:14.9125 exploreP:0.7608
# Episode:139 meanR:19.7300 R:17.0 loss:15.3143 exploreP:0.7595
# Episode:140 meanR:19.3900 R:11.0 loss:21.2672 exploreP:0.7587
# Episode:141 meanR:19.4200 R:14.0 loss:15.7751 exploreP:0.7576
# Episode:142 meanR:19.7600 R:47.0 loss:23.0198 exploreP:0.7541
# Episode:143 meanR:19.6400 R:20.0 loss:18.7061 exploreP:0.7526
# Episode:144 meanR:19.6900 R:16.0 loss:24.4961 exploreP:0.7514
# Episode:145 meanR:19.6300 R:11.0 loss:21.7325 exploreP:0.7506
# Episode:146 meanR:19.4400 R:13.0 loss:13.8062 exploreP:0.7497
# Episode:147 meanR:19.4700 R:16.0 loss:16.2119 exploreP:0.7485
# Episode:148 meanR:19.6300 R:30.0 loss:17.0872 exploreP:0.7463
# Episode:149 meanR:19.8600 R:40.0 loss:16.7711 exploreP:0.7433
# Episode:150 meanR:19.8800 R:12.0 loss:8.7514 exploreP:0.7425
# Episode:151 meanR:19.8500 R:25.0 loss:23.4892 exploreP:0.7406
# Episode:152 meanR:19.7700 R:13.0 loss:21.0664 exploreP:0.7397
# Episode:153 meanR:19.7700 R:19.0 loss:18.6483 exploreP:0.7383
# Episode:154 meanR:19.7300 R:12.0 loss:17.5622 exploreP:0.7374
# Episode:155 meanR:19.7600 R:20.0 loss:14.8270 exploreP:0.7360
# Episode:156 meanR:19.8300 R:19.0 loss:25.9231 exploreP:0.7346
# Episode:157 meanR:19.7300 R:11.0 loss:11.6079 exploreP:0.7338
# Episode:158 meanR:19.7700 R:14.0 loss:16.5935 exploreP:0.7328
# Episode:159 meanR:19.7900 R:12.0 loss:10.3873 exploreP:0.7319
# Episode:160 meanR:19.6700 R:12.0 loss:16.5365 exploreP:0.7310
# Episode:161 meanR:19.8500 R:37.0 loss:17.9910 exploreP:0.7284
# Episode:162 meanR:19.7000 R:12.0 loss:18.7543 exploreP:0.7275
# Episode:163 meanR:19.4700 R:12.0 loss:22.2916 exploreP:0.7267
# Episode:164 meanR:19.3700 R:20.0 loss:12.3202 exploreP:0.7252
# Episode:165 meanR:19.5300 R:27.0 loss:21.3331 exploreP:0.7233
# Episode:166 meanR:19.3200 R:22.0 loss:15.0906 exploreP:0.7217
# Episode:167 meanR:19.5000 R:34.0 loss:16.7437 exploreP:0.7193
# Episode:168 meanR:19.6800 R:28.0 loss:15.6143 exploreP:0.7173
# Episode:169 meanR:19.5200 R:24.0 loss:16.3826 exploreP:0.7156
# Episode:170 meanR:19.3500 R:13.0 loss:17.3539 exploreP:0.7147
# Episode:171 meanR:19.2400 R:10.0 loss:19.3672 exploreP:0.7140
# Episode:172 meanR:19.1700 R:13.0 loss:9.5786 exploreP:0.7131
# Episode:173 meanR:20.0100 R:102.0 loss:14.8856 exploreP:0.7060
# Episode:174 meanR:20.0100 R:15.0 loss:13.7129 exploreP:0.7049
# Episode:175 meanR:20.0400 R:15.0 loss:13.2798 exploreP:0.7039
# Episode:176 meanR:20.0600 R:18.0 loss:11.6634 exploreP:0.7026
# Episode:177 meanR:20.2400 R:31.0 loss:13.2052 exploreP:0.7005
# Episode:178 meanR:20.2800 R:17.0 loss:18.3813 exploreP:0.6993
# Episode:179 meanR:20.5500 R:45.0 loss:13.5048 exploreP:0.6962
# Episode:180 meanR:20.5400 R:50.0 loss:13.0350 exploreP:0.6928
# Episode:181 meanR:20.3700 R:18.0 loss:14.6368 exploreP:0.6916
# Episode:182 meanR:20.7300 R:45.0 loss:15.6703 exploreP:0.6885
# Episode:183 meanR:20.7400 R:22.0 loss:9.4136 exploreP:0.6870
# Episode:184 meanR:20.9100 R:72.0 loss:11.6122 exploreP:0.6822
# Episode:185 meanR:21.0400 R:41.0 loss:12.7172 exploreP:0.6794
# Episode:186 meanR:21.9600 R:106.0 loss:11.8770 exploreP:0.6724
# Episode:187 meanR:21.9400 R:23.0 loss:16.3144 exploreP:0.6708
# Episode:188 meanR:21.9400 R:20.0 loss:16.7437 exploreP:0.6695
# Episode:189 meanR:22.2300 R:41.0 loss:16.1881 exploreP:0.6668
# Episode:190 meanR:22.1300 R:13.0 loss:11.3001 exploreP:0.6660
# Episode:191 meanR:22.1100 R:27.0 loss:13.2518 exploreP:0.6642
# Episode:192 meanR:22.2100 R:27.0 loss:12.9943 exploreP:0.6624
# Episode:193 meanR:22.3900 R:30.0 loss:15.0620 exploreP:0.6605
# Episode:194 meanR:22.5300 R:32.0 loss:12.0534 exploreP:0.6584
# Episode:195 meanR:22.6200 R:25.0 loss:11.6388 exploreP:0.6568
# Episode:196 meanR:22.8700 R:40.0 loss:18.6474 exploreP:0.6542
# Episode:197 meanR:22.5700 R:13.0 loss:12.0194 exploreP:0.6534
# Episode:198 meanR:22.7300 R:26.0 loss:9.7323 exploreP:0.6517
# Episode:199 meanR:22.8600 R:27.0 loss:16.3112 exploreP:0.6500
# Episode:200 meanR:23.2600 R:54.0 loss:13.0455 exploreP:0.6465
# Episode:201 meanR:23.4600 R:39.0 loss:13.3281 exploreP:0.6440
# Episode:202 meanR:23.5300 R:23.0 loss:15.6827 exploreP:0.6426
# Episode:203 meanR:23.5400 R:13.0 loss:11.4158 exploreP:0.6418
# Episode:204 meanR:23.8400 R:42.0 loss:11.9851 exploreP:0.6391
# Episode:205 meanR:23.9000 R:19.0 loss:14.8314 exploreP:0.6379
# Episode:206 meanR:23.8400 R:38.0 loss:11.0025 exploreP:0.6355
# Episode:207 meanR:23.9300 R:42.0 loss:17.0311 exploreP:0.6329
# Episode:208 meanR:24.2700 R:56.0 loss:15.4411 exploreP:0.6294
# Episode:209 meanR:24.4900 R:34.0 loss:10.9856 exploreP:0.6273
# Episode:210 meanR:24.8500 R:54.0 loss:14.1683 exploreP:0.6240
# Episode:211 meanR:25.0600 R:37.0 loss:14.0131 exploreP:0.6217
# Episode:212 meanR:25.2200 R:31.0 loss:16.0474 exploreP:0.6198
# Episode:213 meanR:25.6800 R:62.0 loss:10.6029 exploreP:0.6161
# Episode:214 meanR:26.4300 R:88.0 loss:13.1504 exploreP:0.6108
# Episode:215 meanR:26.7300 R:49.0 loss:11.5048 exploreP:0.6078
# Episode:216 meanR:26.8600 R:40.0 loss:11.7932 exploreP:0.6054
# Episode:217 meanR:26.8400 R:17.0 loss:10.4385 exploreP:0.6044
# Episode:218 meanR:27.2200 R:49.0 loss:14.3816 exploreP:0.6015
# Episode:219 meanR:27.2300 R:18.0 loss:10.0641 exploreP:0.6005
# Episode:220 meanR:27.2100 R:18.0 loss:6.8168 exploreP:0.5994
# Episode:221 meanR:27.4100 R:39.0 loss:12.7045 exploreP:0.5971
# Episode:222 meanR:27.8500 R:60.0 loss:16.3265 exploreP:0.5936
# Episode:223 meanR:27.8100 R:12.0 loss:11.6680 exploreP:0.5929
# Episode:224 meanR:28.0000 R:58.0 loss:14.6794 exploreP:0.5895
# Episode:225 meanR:28.0700 R:21.0 loss:11.3063 exploreP:0.5883
# Episode:226 meanR:28.3900 R:45.0 loss:15.7452 exploreP:0.5857
# Episode:227 meanR:28.5800 R:41.0 loss:14.8698 exploreP:0.5834
# Episode:228 meanR:28.7900 R:42.0 loss:14.1732 exploreP:0.5810
# Episode:229 meanR:29.0700 R:42.0 loss:13.5133 exploreP:0.5786
# Episode:230 meanR:29.3700 R:41.0 loss:14.4805 exploreP:0.5762
# Episode:231 meanR:29.9000 R:68.0 loss:12.2733 exploreP:0.5724
# Episode:232 meanR:30.0000 R:20.0 loss:22.9004 exploreP:0.5713
# Episode:233 meanR:30.2100 R:30.0 loss:17.7183 exploreP:0.5696
# Episode:234 meanR:30.9600 R:86.0 loss:14.3643 exploreP:0.5648
# Episode:235 meanR:31.2100 R:37.0 loss:19.5566 exploreP:0.5627
# Episode:236 meanR:31.5900 R:51.0 loss:25.1314 exploreP:0.5599
# Episode:237 meanR:31.4000 R:16.0 loss:24.2216 exploreP:0.5591
# Episode:238 meanR:31.7900 R:50.0 loss:18.2009 exploreP:0.5563
# Episode:239 meanR:32.2500 R:63.0 loss:18.8163 exploreP:0.5529
# Episode:240 meanR:32.6500 R:51.0 loss:14.8716 exploreP:0.5501
# Episode:241 meanR:33.6500 R:114.0 loss:14.5538 exploreP:0.5440
# Episode:242 meanR:33.6900 R:51.0 loss:14.5263 exploreP:0.5413
# Episode:243 meanR:34.3000 R:81.0 loss:15.5549 exploreP:0.5370
# Episode:244 meanR:34.5900 R:45.0 loss:17.2538 exploreP:0.5346
# Episode:245 meanR:35.1000 R:62.0 loss:15.8334 exploreP:0.5314
# Episode:246 meanR:35.8200 R:85.0 loss:18.2430 exploreP:0.5270
# Episode:247 meanR:35.9200 R:26.0 loss:13.5432 exploreP:0.5256
# Episode:248 meanR:36.2200 R:60.0 loss:18.4321 exploreP:0.5226
# Episode:249 meanR:36.0400 R:22.0 loss:19.4167 exploreP:0.5214
# Episode:250 meanR:36.2700 R:35.0 loss:19.6643 exploreP:0.5196
# Episode:251 meanR:36.3200 R:30.0 loss:13.8620 exploreP:0.5181
# Episode:252 meanR:36.4300 R:24.0 loss:19.7739 exploreP:0.5169
# Episode:253 meanR:36.6900 R:45.0 loss:18.4792 exploreP:0.5146
# Episode:254 meanR:36.8100 R:24.0 loss:10.0885 exploreP:0.5134
# Episode:255 meanR:36.8900 R:28.0 loss:16.6733 exploreP:0.5120
# Episode:256 meanR:37.0300 R:33.0 loss:18.3117 exploreP:0.5103
# Episode:257 meanR:38.5000 R:158.0 loss:19.7974 exploreP:0.5025
# Episode:258 meanR:39.3300 R:97.0 loss:13.7459 exploreP:0.4978
# Episode:259 meanR:40.0800 R:87.0 loss:15.1994 exploreP:0.4935
# Episode:260 meanR:40.4500 R:49.0 loss:16.1910 exploreP:0.4912
# Episode:261 meanR:41.2800 R:120.0 loss:18.1977 exploreP:0.4854
# Episode:262 meanR:41.9600 R:80.0 loss:19.5235 exploreP:0.4816
# Episode:263 meanR:42.6300 R:79.0 loss:18.4300 exploreP:0.4779
# Episode:264 meanR:42.9800 R:55.0 loss:21.9365 exploreP:0.4754
# Episode:265 meanR:43.0300 R:32.0 loss:25.0738 exploreP:0.4739
# Episode:266 meanR:43.3000 R:49.0 loss:20.8135 exploreP:0.4716
# Episode:267 meanR:43.6000 R:64.0 loss:17.5586 exploreP:0.4687
# Episode:268 meanR:43.5700 R:25.0 loss:15.1067 exploreP:0.4675
# Episode:269 meanR:43.8900 R:56.0 loss:20.1723 exploreP:0.4650
# Episode:270 meanR:44.0200 R:26.0 loss:17.3464 exploreP:0.4638
# Episode:271 meanR:44.2200 R:30.0 loss:18.7237 exploreP:0.4624
# Episode:272 meanR:44.7100 R:62.0 loss:19.8460 exploreP:0.4596
# Episode:273 meanR:44.1800 R:49.0 loss:22.0791 exploreP:0.4574
# Episode:274 meanR:45.0400 R:101.0 loss:17.1537 exploreP:0.4529
# Episode:275 meanR:45.3400 R:45.0 loss:14.1160 exploreP:0.4509
# Episode:276 meanR:45.4300 R:27.0 loss:14.8158 exploreP:0.4497
# Episode:277 meanR:45.5900 R:47.0 loss:18.6640 exploreP:0.4477
# Episode:278 meanR:45.6900 R:27.0 loss:25.4032 exploreP:0.4465
# Episode:279 meanR:45.6000 R:36.0 loss:17.2193 exploreP:0.4449
# Episode:280 meanR:45.2200 R:12.0 loss:30.8385 exploreP:0.4444
# Episode:281 meanR:45.3300 R:29.0 loss:25.7728 exploreP:0.4432
# Episode:282 meanR:45.1900 R:31.0 loss:16.6690 exploreP:0.4418
# Episode:283 meanR:45.4800 R:51.0 loss:15.4870 exploreP:0.4396
# Episode:284 meanR:45.5500 R:79.0 loss:20.6357 exploreP:0.4362
# Episode:285 meanR:45.8600 R:72.0 loss:24.6865 exploreP:0.4332
# Episode:286 meanR:45.0500 R:25.0 loss:24.8840 exploreP:0.4321
# Episode:287 meanR:45.1200 R:30.0 loss:23.0255 exploreP:0.4309
# Episode:288 meanR:45.3300 R:41.0 loss:21.5616 exploreP:0.4291
# Episode:289 meanR:45.7500 R:83.0 loss:25.3267 exploreP:0.4257
# Episode:290 meanR:46.2700 R:65.0 loss:22.8360 exploreP:0.4230
# Episode:291 meanR:46.3100 R:31.0 loss:24.1695 exploreP:0.4217
# Episode:292 meanR:46.4300 R:39.0 loss:23.2210 exploreP:0.4201
# Episode:293 meanR:46.6300 R:50.0 loss:25.3674 exploreP:0.4181
# Episode:294 meanR:46.8200 R:51.0 loss:23.4518 exploreP:0.4160
# Episode:295 meanR:46.9900 R:42.0 loss:21.5824 exploreP:0.4143
# Episode:296 meanR:46.8200 R:23.0 loss:20.4575 exploreP:0.4134
# Episode:297 meanR:47.2300 R:54.0 loss:22.1687 exploreP:0.4112
# Episode:298 meanR:47.1800 R:21.0 loss:20.0088 exploreP:0.4103
# Episode:299 meanR:47.3700 R:46.0 loss:28.8662 exploreP:0.4085
# Episode:300 meanR:47.1600 R:33.0 loss:29.3318 exploreP:0.4072
# Episode:301 meanR:47.8300 R:106.0 loss:22.3140 exploreP:0.4030
# Episode:302 meanR:48.4000 R:80.0 loss:23.6448 exploreP:0.3999
# Episode:303 meanR:49.0400 R:77.0 loss:24.2646 exploreP:0.3969
# Episode:304 meanR:48.8600 R:24.0 loss:29.7649 exploreP:0.3959
# Episode:305 meanR:48.8400 R:17.0 loss:22.3764 exploreP:0.3953
# Episode:306 meanR:49.1500 R:69.0 loss:24.9006 exploreP:0.3926
# Episode:307 meanR:49.6000 R:87.0 loss:17.7459 exploreP:0.3893
# Episode:308 meanR:49.4000 R:36.0 loss:30.9554 exploreP:0.3880
# Episode:309 meanR:49.6400 R:58.0 loss:20.8577 exploreP:0.3858
# Episode:310 meanR:50.0600 R:96.0 loss:26.1473 exploreP:0.3822
# Episode:311 meanR:50.0800 R:39.0 loss:21.1176 exploreP:0.3807
# Episode:312 meanR:50.4500 R:68.0 loss:20.6923 exploreP:0.3782
# Episode:313 meanR:50.2300 R:40.0 loss:28.7900 exploreP:0.3768
# Episode:314 meanR:50.0800 R:73.0 loss:20.8805 exploreP:0.3741
# Episode:315 meanR:49.9000 R:31.0 loss:25.0953 exploreP:0.3730
# Episode:316 meanR:50.0000 R:50.0 loss:35.2732 exploreP:0.3712
# Episode:317 meanR:50.1900 R:36.0 loss:19.1990 exploreP:0.3699
# Episode:318 meanR:50.0100 R:31.0 loss:14.2488 exploreP:0.3687
# Episode:319 meanR:50.3800 R:55.0 loss:21.9570 exploreP:0.3668
# Episode:320 meanR:50.6600 R:46.0 loss:26.5166 exploreP:0.3651
# Episode:321 meanR:51.0200 R:75.0 loss:28.1713 exploreP:0.3625
# Episode:322 meanR:50.7900 R:37.0 loss:31.5054 exploreP:0.3612
# Episode:323 meanR:51.4400 R:77.0 loss:37.1411 exploreP:0.3585
# Episode:324 meanR:51.4500 R:59.0 loss:18.6458 exploreP:0.3564
# Episode:325 meanR:52.1400 R:90.0 loss:23.8528 exploreP:0.3533
# Episode:326 meanR:52.2400 R:55.0 loss:23.3311 exploreP:0.3515
# Episode:327 meanR:52.0100 R:18.0 loss:30.8479 exploreP:0.3508
# Episode:328 meanR:51.9600 R:37.0 loss:35.0249 exploreP:0.3496
# Episode:329 meanR:51.9600 R:42.0 loss:26.2389 exploreP:0.3482
# Episode:330 meanR:51.9100 R:36.0 loss:32.9558 exploreP:0.3469
# Episode:331 meanR:51.6200 R:39.0 loss:26.6087 exploreP:0.3456
# Episode:332 meanR:51.8100 R:39.0 loss:28.0281 exploreP:0.3443
# Episode:333 meanR:51.9900 R:48.0 loss:29.6941 exploreP:0.3427
# Episode:334 meanR:51.5000 R:37.0 loss:30.7156 exploreP:0.3415
# Episode:335 meanR:51.6200 R:49.0 loss:20.2726 exploreP:0.3399
# Episode:336 meanR:51.7200 R:61.0 loss:29.6382 exploreP:0.3379
# Episode:337 meanR:52.3300 R:77.0 loss:26.7022 exploreP:0.3354
# Episode:338 meanR:53.1000 R:127.0 loss:23.8596 exploreP:0.3312
# Episode:339 meanR:52.8400 R:37.0 loss:36.2308 exploreP:0.3301
# Episode:340 meanR:52.7100 R:38.0 loss:39.6997 exploreP:0.3288
# Episode:341 meanR:51.9800 R:41.0 loss:29.3796 exploreP:0.3275
# Episode:342 meanR:51.9300 R:46.0 loss:23.4086 exploreP:0.3261
# Episode:343 meanR:51.8900 R:77.0 loss:25.6461 exploreP:0.3237
# Episode:344 meanR:51.8200 R:38.0 loss:24.4569 exploreP:0.3225
# Episode:345 meanR:51.5900 R:39.0 loss:33.0440 exploreP:0.3213
# Episode:346 meanR:51.1700 R:43.0 loss:43.3015 exploreP:0.3199
# Episode:347 meanR:51.5600 R:65.0 loss:23.2193 exploreP:0.3179
# Episode:348 meanR:51.4900 R:53.0 loss:20.6816 exploreP:0.3163
# Episode:349 meanR:51.7100 R:44.0 loss:25.1774 exploreP:0.3149
# Episode:350 meanR:52.4800 R:112.0 loss:33.3324 exploreP:0.3115
# Episode:351 meanR:52.8100 R:63.0 loss:30.0682 exploreP:0.3096
# Episode:352 meanR:53.1700 R:60.0 loss:27.2018 exploreP:0.3079
# Episode:353 meanR:53.3000 R:58.0 loss:34.9885 exploreP:0.3061
# Episode:354 meanR:53.6400 R:58.0 loss:24.8688 exploreP:0.3044
# Episode:355 meanR:53.9400 R:58.0 loss:24.7313 exploreP:0.3027
# Episode:356 meanR:54.4000 R:79.0 loss:29.1983 exploreP:0.3004
# Episode:357 meanR:53.4300 R:61.0 loss:34.8491 exploreP:0.2986
# Episode:358 meanR:52.6300 R:17.0 loss:40.1135 exploreP:0.2982
# Episode:359 meanR:52.6000 R:84.0 loss:29.5420 exploreP:0.2957
# Episode:360 meanR:52.9800 R:87.0 loss:28.5954 exploreP:0.2933
# Episode:361 meanR:52.5700 R:79.0 loss:40.5953 exploreP:0.2910
# Episode:362 meanR:52.8000 R:103.0 loss:31.1920 exploreP:0.2882
# Episode:363 meanR:52.4100 R:40.0 loss:26.8824 exploreP:0.2871
# Episode:364 meanR:52.2000 R:34.0 loss:29.7435 exploreP:0.2861
# Episode:365 meanR:52.6100 R:73.0 loss:27.8379 exploreP:0.2841
# Episode:366 meanR:52.6100 R:49.0 loss:28.8543 exploreP:0.2828
# Episode:367 meanR:52.5900 R:62.0 loss:43.5558 exploreP:0.2811
# Episode:368 meanR:52.8300 R:49.0 loss:30.7380 exploreP:0.2798
# Episode:369 meanR:52.6600 R:39.0 loss:36.1123 exploreP:0.2787
# Episode:370 meanR:53.0000 R:60.0 loss:26.3269 exploreP:0.2771
# Episode:371 meanR:53.0300 R:33.0 loss:30.3671 exploreP:0.2762
# Episode:372 meanR:53.0600 R:65.0 loss:18.8850 exploreP:0.2745
# Episode:373 meanR:53.3900 R:82.0 loss:24.4879 exploreP:0.2723
# Episode:374 meanR:53.3800 R:100.0 loss:36.5572 exploreP:0.2697
# Episode:375 meanR:53.5400 R:61.0 loss:37.0362 exploreP:0.2681
# Episode:376 meanR:54.4600 R:119.0 loss:34.0819 exploreP:0.2651
# Episode:377 meanR:54.8300 R:84.0 loss:33.0102 exploreP:0.2630
# Episode:378 meanR:55.0700 R:51.0 loss:33.9035 exploreP:0.2617
# Episode:379 meanR:56.4400 R:173.0 loss:31.6011 exploreP:0.2574
# Episode:380 meanR:56.9300 R:61.0 loss:28.8173 exploreP:0.2558
# Episode:381 meanR:56.9700 R:33.0 loss:42.7827 exploreP:0.2550
# Episode:382 meanR:57.8900 R:123.0 loss:34.4601 exploreP:0.2520
# Episode:383 meanR:58.1900 R:81.0 loss:31.2143 exploreP:0.2501
# Episode:384 meanR:57.8900 R:49.0 loss:29.8885 exploreP:0.2489
# Episode:385 meanR:57.7900 R:62.0 loss:31.2768 exploreP:0.2474
# Episode:386 meanR:58.2500 R:71.0 loss:34.0060 exploreP:0.2458
# Episode:387 meanR:58.5500 R:60.0 loss:29.3025 exploreP:0.2443
# Episode:388 meanR:59.1700 R:103.0 loss:27.8771 exploreP:0.2419
# Episode:389 meanR:58.9000 R:56.0 loss:30.2840 exploreP:0.2407
# Episode:390 meanR:59.7100 R:146.0 loss:32.7249 exploreP:0.2373
# Episode:391 meanR:60.3900 R:99.0 loss:38.3871 exploreP:0.2351
# Episode:392 meanR:61.0700 R:107.0 loss:35.3572 exploreP:0.2327
# Episode:393 meanR:61.1800 R:61.0 loss:26.0831 exploreP:0.2313
# Episode:394 meanR:61.1800 R:51.0 loss:27.1428 exploreP:0.2302
# Episode:395 meanR:61.6700 R:91.0 loss:30.9138 exploreP:0.2282
# Episode:396 meanR:62.2000 R:76.0 loss:34.1229 exploreP:0.2265
# Episode:397 meanR:62.5800 R:92.0 loss:40.6676 exploreP:0.2246
# Episode:398 meanR:62.8600 R:49.0 loss:39.3292 exploreP:0.2235
# Episode:399 meanR:63.2600 R:86.0 loss:33.9454 exploreP:0.2217
# Episode:400 meanR:63.3800 R:45.0 loss:42.1565 exploreP:0.2207
# Episode:401 meanR:63.2800 R:96.0 loss:32.9976 exploreP:0.2187
# Episode:402 meanR:63.2400 R:76.0 loss:36.5367 exploreP:0.2171
# Episode:403 meanR:63.4200 R:95.0 loss:32.3539 exploreP:0.2152
# Episode:404 meanR:63.5400 R:36.0 loss:23.1497 exploreP:0.2144
# Episode:405 meanR:64.1000 R:73.0 loss:39.3953 exploreP:0.2130
# Episode:406 meanR:65.0400 R:163.0 loss:29.7882 exploreP:0.2097
# Episode:407 meanR:64.7300 R:56.0 loss:32.5194 exploreP:0.2086
# Episode:408 meanR:65.6000 R:123.0 loss:38.9667 exploreP:0.2061
# Episode:409 meanR:66.1600 R:114.0 loss:35.1959 exploreP:0.2039
# Episode:410 meanR:66.8100 R:161.0 loss:34.9294 exploreP:0.2008
# Episode:411 meanR:67.0900 R:67.0 loss:29.0104 exploreP:0.1995
# Episode:412 meanR:67.0000 R:59.0 loss:48.1165 exploreP:0.1984
# Episode:413 meanR:67.8800 R:128.0 loss:34.5001 exploreP:0.1960
# Episode:414 meanR:67.6600 R:51.0 loss:36.5176 exploreP:0.1951
# Episode:415 meanR:68.1600 R:81.0 loss:37.7596 exploreP:0.1936
# Episode:416 meanR:68.3400 R:68.0 loss:30.6831 exploreP:0.1923
# Episode:417 meanR:68.7100 R:73.0 loss:43.0645 exploreP:0.1910
# Episode:418 meanR:69.4900 R:109.0 loss:32.4608 exploreP:0.1891
# Episode:419 meanR:70.5700 R:163.0 loss:42.3695 exploreP:0.1862
# Episode:420 meanR:71.1900 R:108.0 loss:34.6323 exploreP:0.1843
# Episode:421 meanR:71.8100 R:137.0 loss:35.7732 exploreP:0.1819
# Episode:422 meanR:72.9100 R:147.0 loss:30.1173 exploreP:0.1794
# Episode:423 meanR:73.5500 R:141.0 loss:33.5653 exploreP:0.1770
# Episode:424 meanR:77.4600 R:450.0 loss:32.8921 exploreP:0.1697
# Episode:425 meanR:77.4100 R:85.0 loss:34.1329 exploreP:0.1683
# Episode:426 meanR:77.8300 R:97.0 loss:29.9071 exploreP:0.1668
# Episode:427 meanR:78.2900 R:64.0 loss:39.0407 exploreP:0.1658
# Episode:428 meanR:79.6600 R:174.0 loss:28.9105 exploreP:0.1631
# Episode:429 meanR:80.5700 R:133.0 loss:39.4362 exploreP:0.1611
# Episode:430 meanR:81.0300 R:82.0 loss:32.9116 exploreP:0.1598
# Episode:431 meanR:81.6100 R:97.0 loss:33.7708 exploreP:0.1584
# Episode:432 meanR:82.7800 R:156.0 loss:32.6624 exploreP:0.1561
# Episode:433 meanR:82.9900 R:69.0 loss:22.1390 exploreP:0.1551
# Episode:434 meanR:83.3400 R:72.0 loss:37.3782 exploreP:0.1541
# Episode:435 meanR:83.6400 R:79.0 loss:29.0475 exploreP:0.1529
# Episode:436 meanR:84.1000 R:107.0 loss:26.5555 exploreP:0.1514
# Episode:437 meanR:84.6200 R:129.0 loss:37.3713 exploreP:0.1496
# Episode:438 meanR:84.1100 R:76.0 loss:37.8445 exploreP:0.1485
# Episode:439 meanR:84.5200 R:78.0 loss:37.5286 exploreP:0.1475
# Episode:440 meanR:85.5500 R:141.0 loss:36.3007 exploreP:0.1455
# Episode:441 meanR:85.6400 R:50.0 loss:38.4977 exploreP:0.1449
# Episode:442 meanR:86.4500 R:127.0 loss:30.7766 exploreP:0.1432
# Episode:443 meanR:86.5700 R:89.0 loss:37.6602 exploreP:0.1420
# Episode:444 meanR:86.9900 R:80.0 loss:25.7708 exploreP:0.1409
# Episode:445 meanR:87.5600 R:96.0 loss:38.6310 exploreP:0.1397
# Episode:446 meanR:89.2100 R:208.0 loss:32.8643 exploreP:0.1370
# Episode:447 meanR:89.6000 R:104.0 loss:25.4834 exploreP:0.1357
# Episode:448 meanR:90.6100 R:154.0 loss:29.8951 exploreP:0.1338
# Episode:449 meanR:91.6800 R:151.0 loss:40.6373 exploreP:0.1319
# Episode:450 meanR:92.2000 R:164.0 loss:30.9500 exploreP:0.1299
# Episode:451 meanR:92.7900 R:122.0 loss:32.5201 exploreP:0.1285
# Episode:452 meanR:94.4800 R:229.0 loss:36.8781 exploreP:0.1258
# Episode:453 meanR:96.0500 R:215.0 loss:33.2506 exploreP:0.1233
# Episode:454 meanR:98.7100 R:324.0 loss:31.9663 exploreP:0.1197
# Episode:455 meanR:99.5200 R:139.0 loss:42.7614 exploreP:0.1182
# Episode:456 meanR:100.3800 R:165.0 loss:38.9341 exploreP:0.1164
# Episode:457 meanR:101.1000 R:133.0 loss:36.9377 exploreP:0.1150
# Episode:458 meanR:102.8800 R:195.0 loss:30.8194 exploreP:0.1130
# Episode:459 meanR:103.1700 R:113.0 loss:32.4230 exploreP:0.1118
# Episode:460 meanR:103.6100 R:131.0 loss:32.3612 exploreP:0.1105
# Episode:461 meanR:106.0300 R:321.0 loss:31.9591 exploreP:0.1073
# Episode:462 meanR:106.4200 R:142.0 loss:32.3837 exploreP:0.1060
# Episode:463 meanR:108.1300 R:211.0 loss:35.5158 exploreP:0.1040
# Episode:464 meanR:110.0000 R:221.0 loss:39.9264 exploreP:0.1019
# Episode:465 meanR:110.5800 R:131.0 loss:33.6781 exploreP:0.1007
# Episode:466 meanR:111.8600 R:177.0 loss:35.7406 exploreP:0.0991
# Episode:467 meanR:112.8000 R:156.0 loss:34.7448 exploreP:0.0977
# Episode:468 meanR:115.2200 R:291.0 loss:37.7335 exploreP:0.0952
# Episode:469 meanR:117.6500 R:282.0 loss:32.1946 exploreP:0.0929
# Episode:470 meanR:118.6700 R:162.0 loss:37.2737 exploreP:0.0915
# Episode:471 meanR:120.7700 R:243.0 loss:39.8843 exploreP:0.0896
# Episode:472 meanR:122.9900 R:287.0 loss:40.8616 exploreP:0.0873
# Episode:473 meanR:123.7000 R:153.0 loss:24.0130 exploreP:0.0861
# Episode:474 meanR:124.5200 R:182.0 loss:39.3686 exploreP:0.0848
# Episode:475 meanR:125.4400 R:153.0 loss:43.0841 exploreP:0.0836
# Episode:476 meanR:126.5800 R:233.0 loss:41.8514 exploreP:0.0819
# Episode:477 meanR:128.3100 R:257.0 loss:37.1198 exploreP:0.0801
# Episode:478 meanR:130.6700 R:287.0 loss:34.7904 exploreP:0.0781
# Episode:479 meanR:130.9700 R:203.0 loss:43.8247 exploreP:0.0768
# Episode:480 meanR:132.8400 R:248.0 loss:35.2949 exploreP:0.0751
# Episode:481 meanR:136.0400 R:353.0 loss:37.5555 exploreP:0.0729
# Episode:482 meanR:137.4100 R:260.0 loss:41.4136 exploreP:0.0713
# Episode:483 meanR:138.6700 R:207.0 loss:35.8070 exploreP:0.0700
# Episode:484 meanR:139.9400 R:176.0 loss:31.6820 exploreP:0.0690
# Episode:485 meanR:143.2400 R:392.0 loss:37.8741 exploreP:0.0667
# Episode:486 meanR:145.6300 R:310.0 loss:30.8582 exploreP:0.0650
# Episode:487 meanR:147.0900 R:206.0 loss:41.8606 exploreP:0.0638
# Episode:488 meanR:148.2100 R:215.0 loss:35.7319 exploreP:0.0627
# Episode:489 meanR:150.2500 R:260.0 loss:40.5804 exploreP:0.0613
# Episode:490 meanR:151.0900 R:230.0 loss:32.3886 exploreP:0.0602
# Episode:491 meanR:152.9700 R:287.0 loss:32.8866 exploreP:0.0587
# Episode:492 meanR:154.8300 R:293.0 loss:41.9426 exploreP:0.0573
# Episode:493 meanR:157.1300 R:291.0 loss:39.5493 exploreP:0.0560
# Episode:494 meanR:161.6200 R:500.0 loss:36.4222 exploreP:0.0537
# Episode:495 meanR:164.6200 R:391.0 loss:35.5958 exploreP:0.0521
# Episode:496 meanR:168.8600 R:500.0 loss:40.3065 exploreP:0.0500
# Episode:497 meanR:172.9400 R:500.0 loss:39.5438 exploreP:0.0481
# Episode:498 meanR:177.1500 R:470.0 loss:41.1639 exploreP:0.0463
# Episode:499 meanR:180.5500 R:426.0 loss:33.3969 exploreP:0.0448
# Episode:500 meanR:184.1900 R:409.0 loss:33.4850 exploreP:0.0434
# Episode:501 meanR:188.1200 R:489.0 loss:47.9868 exploreP:0.0418
# Episode:502 meanR:191.0300 R:367.0 loss:46.1056 exploreP:0.0407
# Episode:503 meanR:194.3000 R:422.0 loss:44.4439 exploreP:0.0394
# Episode:504 meanR:197.4000 R:346.0 loss:44.4053 exploreP:0.0384
# Episode:505 meanR:201.6700 R:500.0 loss:39.2496 exploreP:0.0370
# Episode:506 meanR:205.0400 R:500.0 loss:40.4135 exploreP:0.0357
# Episode:507 meanR:207.7400 R:326.0 loss:60.8086 exploreP:0.0349
# Episode:508 meanR:209.3900 R:288.0 loss:43.0640 exploreP:0.0342
# Episode:509 meanR:213.2500 R:500.0 loss:49.5795 exploreP:0.0330
# Episode:510 meanR:216.1200 R:448.0 loss:56.8800 exploreP:0.0320
# Episode:511 meanR:220.4500 R:500.0 loss:61.1771 exploreP:0.0309
# Episode:512 meanR:222.7200 R:286.0 loss:62.6686 exploreP:0.0303
# Episode:513 meanR:226.4400 R:500.0 loss:63.4022 exploreP:0.0293
# Episode:514 meanR:229.6600 R:373.0 loss:63.8027 exploreP:0.0286
# Episode:515 meanR:231.6800 R:283.0 loss:70.8726 exploreP:0.0281
# Episode:516 meanR:235.3600 R:436.0 loss:63.4256 exploreP:0.0273
# Episode:517 meanR:239.4900 R:486.0 loss:50.2538 exploreP:0.0265
# Episode:518 meanR:241.4600 R:306.0 loss:84.1880 exploreP:0.0260
# Episode:519 meanR:244.8300 R:500.0 loss:76.3585 exploreP:0.0252
# Episode:520 meanR:247.9500 R:420.0 loss:81.4024 exploreP:0.0246
# Episode:521 meanR:251.5800 R:500.0 loss:67.1089 exploreP:0.0239
# Episode:522 meanR:253.3800 R:327.0 loss:81.1536 exploreP:0.0234
# Episode:523 meanR:255.0000 R:303.0 loss:90.9206 exploreP:0.0230
# Episode:524 meanR:254.5800 R:408.0 loss:104.3104 exploreP:0.0225
# Episode:525 meanR:258.0400 R:431.0 loss:97.4306 exploreP:0.0220
# Episode:526 meanR:262.0700 R:500.0 loss:108.4782 exploreP:0.0214
# Episode:527 meanR:266.4300 R:500.0 loss:117.4972 exploreP:0.0209
# Episode:528 meanR:269.6900 R:500.0 loss:142.9022 exploreP:0.0203
# Episode:529 meanR:273.3600 R:500.0 loss:155.0179 exploreP:0.0198
# Episode:530 meanR:275.4900 R:295.0 loss:137.2716 exploreP:0.0195
# Episode:531 meanR:279.4300 R:491.0 loss:141.9604 exploreP:0.0191
# Episode:532 meanR:281.3600 R:349.0 loss:157.9757 exploreP:0.0188
# Episode:533 meanR:283.0400 R:237.0 loss:157.3834 exploreP:0.0186
# Episode:534 meanR:287.3200 R:500.0 loss:175.5712 exploreP:0.0181
# Episode:535 meanR:291.5300 R:500.0 loss:160.6230 exploreP:0.0177
# Episode:536 meanR:295.4600 R:500.0 loss:165.9473 exploreP:0.0174
# Episode:537 meanR:298.3900 R:422.0 loss:169.1685 exploreP:0.0171
# Episode:538 meanR:300.7700 R:314.0 loss:211.7427 exploreP:0.0168
# Episode:539 meanR:304.9600 R:497.0 loss:202.4441 exploreP:0.0165
# Episode:540 meanR:308.5500 R:500.0 loss:234.8540 exploreP:0.0162
# Episode:541 meanR:313.0500 R:500.0 loss:233.8524 exploreP:0.0159
# Episode:542 meanR:316.7800 R:500.0 loss:205.8622 exploreP:0.0156
# Episode:543 meanR:320.8900 R:500.0 loss:220.4528 exploreP:0.0153
# Episode:544 meanR:325.0900 R:500.0 loss:235.2460 exploreP:0.0151
# Episode:545 meanR:329.1300 R:500.0 loss:257.7004 exploreP:0.0148
# Episode:546 meanR:332.0500 R:500.0 loss:267.9042 exploreP:0.0146
# Episode:547 meanR:336.0100 R:500.0 loss:297.1401 exploreP:0.0144
# Episode:548 meanR:339.4700 R:500.0 loss:280.3188 exploreP:0.0142
# Episode:549 meanR:342.1200 R:416.0 loss:294.0178 exploreP:0.0140
# Episode:550 meanR:345.4800 R:500.0 loss:349.5510 exploreP:0.0138
# Episode:551 meanR:347.1800 R:292.0 loss:412.0685 exploreP:0.0137
# Episode:552 meanR:349.3900 R:450.0 loss:371.5839 exploreP:0.0135
# Episode:553 meanR:352.2400 R:500.0 loss:385.9872 exploreP:0.0133
# Episode:554 meanR:352.1600 R:316.0 loss:450.3973 exploreP:0.0132
# Episode:555 meanR:353.6500 R:288.0 loss:479.1890 exploreP:0.0132
# Episode:556 meanR:357.0000 R:500.0 loss:456.8098 exploreP:0.0130
# Episode:557 meanR:360.6700 R:500.0 loss:492.2635 exploreP:0.0129
# Episode:558 meanR:363.7200 R:500.0 loss:489.7647 exploreP:0.0127
# Episode:559 meanR:365.8000 R:321.0 loss:509.2037 exploreP:0.0126
# Episode:560 meanR:367.6200 R:313.0 loss:465.9731 exploreP:0.0125
# Episode:561 meanR:369.0000 R:459.0 loss:510.5005 exploreP:0.0124
# Episode:562 meanR:372.5800 R:500.0 loss:484.3844 exploreP:0.0123
# Episode:563 meanR:374.7100 R:424.0 loss:399.9212 exploreP:0.0122
# Episode:564 meanR:376.3800 R:388.0 loss:444.1876 exploreP:0.0121
# Episode:565 meanR:377.9400 R:287.0 loss:523.0463 exploreP:0.0121
# Episode:566 meanR:381.1700 R:500.0 loss:507.1215 exploreP:0.0120
# Episode:567 meanR:382.2900 R:268.0 loss:503.8214 exploreP:0.0119
# Episode:568 meanR:384.0900 R:471.0 loss:501.2523 exploreP:0.0118
# Episode:569 meanR:386.2700 R:500.0 loss:471.9972 exploreP:0.0117
# Episode:570 meanR:387.6900 R:304.0 loss:494.9559 exploreP:0.0117
# Episode:571 meanR:390.1700 R:491.0 loss:519.5608 exploreP:0.0116
# Episode:572 meanR:392.3000 R:500.0 loss:556.0133 exploreP:0.0115
# Episode:573 meanR:395.7700 R:500.0 loss:600.5044 exploreP:0.0115
# Episode:574 meanR:396.9900 R:304.0 loss:514.6345 exploreP:0.0114
# Episode:575 meanR:400.4600 R:500.0 loss:617.2479 exploreP:0.0113
# Episode:576 meanR:403.1300 R:500.0 loss:586.0613 exploreP:0.0113
# Episode:577 meanR:405.5600 R:500.0 loss:587.6874 exploreP:0.0112
# Episode:578 meanR:406.9600 R:427.0 loss:728.6545 exploreP:0.0112
# Episode:579 meanR:409.9300 R:500.0 loss:572.4160 exploreP:0.0111
# Episode:580 meanR:410.4800 R:303.0 loss:648.1646 exploreP:0.0111
# Episode:581 meanR:411.9500 R:500.0 loss:641.0650 exploreP:0.0110
# Episode:582 meanR:412.6100 R:326.0 loss:681.2885 exploreP:0.0110
# Episode:583 meanR:415.0000 R:446.0 loss:662.2758 exploreP:0.0109
# Episode:584 meanR:417.6000 R:436.0 loss:719.0564 exploreP:0.0109
# Episode:585 meanR:416.4000 R:272.0 loss:683.4468 exploreP:0.0109
# Episode:586 meanR:415.9100 R:261.0 loss:713.5406 exploreP:0.0109
# Episode:587 meanR:418.8500 R:500.0 loss:646.5366 exploreP:0.0108
# Episode:588 meanR:419.1800 R:248.0 loss:597.2228 exploreP:0.0108
# Episode:589 meanR:420.7500 R:417.0 loss:522.4205 exploreP:0.0108
# Episode:590 meanR:422.4100 R:396.0 loss:655.3933 exploreP:0.0107
# Episode:591 meanR:424.5400 R:500.0 loss:595.7920 exploreP:0.0107
# Episode:592 meanR:426.6100 R:500.0 loss:595.8965 exploreP:0.0107
# Episode:593 meanR:426.3200 R:262.0 loss:534.7855 exploreP:0.0106
# Episode:594 meanR:425.2500 R:393.0 loss:510.2586 exploreP:0.0106
# Episode:595 meanR:424.0400 R:270.0 loss:587.5519 exploreP:0.0106
# Episode:596 meanR:424.0200 R:498.0 loss:504.3172 exploreP:0.0106
# Episode:597 meanR:422.3200 R:330.0 loss:428.7975 exploreP:0.0106
# Episode:598 meanR:420.9600 R:334.0 loss:431.5304 exploreP:0.0105
# Episode:599 meanR:419.0600 R:236.0 loss:389.5587 exploreP:0.0105
# Episode:600 meanR:418.1900 R:322.0 loss:415.5890 exploreP:0.0105
# Episode:601 meanR:417.5200 R:422.0 loss:491.5194 exploreP:0.0105
# Episode:602 meanR:416.7600 R:291.0 loss:450.9783 exploreP:0.0105
# Episode:603 meanR:415.9500 R:341.0 loss:510.2523 exploreP:0.0105
# Episode:604 meanR:417.4900 R:500.0 loss:456.5258 exploreP:0.0104
# Episode:605 meanR:414.9000 R:241.0 loss:449.2464 exploreP:0.0104
# Episode:606 meanR:413.4100 R:351.0 loss:474.1369 exploreP:0.0104
# Episode:607 meanR:412.6000 R:245.0 loss:475.1448 exploreP:0.0104
# Episode:608 meanR:414.7200 R:500.0 loss:471.9408 exploreP:0.0104
# Episode:609 meanR:413.7400 R:402.0 loss:471.1068 exploreP:0.0104
# Episode:610 meanR:414.1300 R:487.0 loss:508.1372 exploreP:0.0103
# Episode:611 meanR:413.3800 R:425.0 loss:420.9237 exploreP:0.0103
# Episode:612 meanR:413.3300 R:281.0 loss:642.7637 exploreP:0.0103
# Episode:613 meanR:410.6300 R:230.0 loss:617.6128 exploreP:0.0103
# Episode:614 meanR:409.4600 R:256.0 loss:634.0854 exploreP:0.0103
# Episode:615 meanR:409.9300 R:330.0 loss:693.4515 exploreP:0.0103
# Episode:616 meanR:410.5700 R:500.0 loss:630.8499 exploreP:0.0103
# Episode:617 meanR:409.6800 R:397.0 loss:687.4579 exploreP:0.0103
# Episode:618 meanR:410.2700 R:365.0 loss:733.6844 exploreP:0.0103
# Episode:619 meanR:409.2700 R:400.0 loss:715.6553 exploreP:0.0103
# Episode:620 meanR:408.2000 R:313.0 loss:772.7457 exploreP:0.0102
# Episode:621 meanR:406.3800 R:318.0 loss:895.7612 exploreP:0.0102
# Episode:622 meanR:406.8700 R:376.0 loss:809.0963 exploreP:0.0102
# Episode:623 meanR:406.2000 R:236.0 loss:721.7877 exploreP:0.0102
# Episode:624 meanR:404.9100 R:279.0 loss:863.9906 exploreP:0.0102
# Episode:625 meanR:403.0100 R:241.0 loss:1032.5404 exploreP:0.0102
# Episode:626 meanR:401.1700 R:316.0 loss:1029.1903 exploreP:0.0102
# Episode:627 meanR:401.1700 R:500.0 loss:1070.6558 exploreP:0.0102
# Episode:628 meanR:401.1700 R:500.0 loss:1029.1954 exploreP:0.0102
# Episode:629 meanR:399.4500 R:328.0 loss:1234.7499 exploreP:0.0102
# Episode:630 meanR:398.8400 R:234.0 loss:1197.2598 exploreP:0.0102
# Episode:631 meanR:397.2500 R:332.0 loss:1145.5978 exploreP:0.0102
# Episode:632 meanR:396.1100 R:235.0 loss:1259.2437 exploreP:0.0102
# Episode:633 meanR:398.7400 R:500.0 loss:1191.6611 exploreP:0.0102
# Episode:634 meanR:396.1100 R:237.0 loss:1088.2101 exploreP:0.0102
# Episode:635 meanR:394.5500 R:344.0 loss:1120.9067 exploreP:0.0101
# Episode:636 meanR:391.9100 R:236.0 loss:1254.3669 exploreP:0.0101
# Episode:637 meanR:391.5400 R:385.0 loss:1359.0085 exploreP:0.0101
# Episode:638 meanR:393.2100 R:481.0 loss:1418.7062 exploreP:0.0101
# Episode:639 meanR:391.1400 R:290.0 loss:1519.3101 exploreP:0.0101
# Episode:640 meanR:390.3900 R:425.0 loss:1532.3118 exploreP:0.0101
# Episode:641 meanR:388.4300 R:304.0 loss:1553.9633 exploreP:0.0101
# Episode:642 meanR:385.5500 R:212.0 loss:1522.2577 exploreP:0.0101
# Episode:643 meanR:383.5300 R:298.0 loss:1674.5343 exploreP:0.0101
# Episode:644 meanR:380.5400 R:201.0 loss:1476.6710 exploreP:0.0101
# Episode:645 meanR:378.1300 R:259.0 loss:1652.7609 exploreP:0.0101
# Episode:646 meanR:377.0900 R:396.0 loss:1705.2164 exploreP:0.0101
# Episode:647 meanR:375.1300 R:304.0 loss:1861.5201 exploreP:0.0101
# Episode:648 meanR:373.1800 R:305.0 loss:1729.0664 exploreP:0.0101
# Episode:649 meanR:374.0200 R:500.0 loss:1872.0715 exploreP:0.0101
# Episode:650 meanR:371.6700 R:265.0 loss:1819.9114 exploreP:0.0101
# Episode:651 meanR:371.3900 R:264.0 loss:1811.6544 exploreP:0.0101
# Episode:652 meanR:371.3000 R:441.0 loss:2092.1753 exploreP:0.0101
# Episode:653 meanR:369.9900 R:369.0 loss:2160.7388 exploreP:0.0101
# Episode:654 meanR:371.5100 R:468.0 loss:2077.8523 exploreP:0.0101
# Episode:655 meanR:370.9500 R:232.0 loss:1919.9849 exploreP:0.0101
# Episode:656 meanR:370.5000 R:455.0 loss:2076.0332 exploreP:0.0101
# Episode:657 meanR:367.7400 R:224.0 loss:2081.8479 exploreP:0.0101
# Episode:658 meanR:365.6100 R:287.0 loss:2243.0303 exploreP:0.0101
# Episode:659 meanR:365.1600 R:276.0 loss:2172.4624 exploreP:0.0101
# Episode:660 meanR:367.0300 R:500.0 loss:2394.0190 exploreP:0.0101
# Episode:661 meanR:364.4300 R:199.0 loss:2416.1472 exploreP:0.0101
# Episode:662 meanR:362.4800 R:305.0 loss:2397.2964 exploreP:0.0101
# Episode:663 meanR:363.2400 R:500.0 loss:2354.7649 exploreP:0.0101
# Episode:664 meanR:362.2400 R:288.0 loss:2316.2563 exploreP:0.0101
# Episode:665 meanR:361.4300 R:206.0 loss:2636.9866 exploreP:0.0101
# Episode:666 meanR:359.0900 R:266.0 loss:2591.7334 exploreP:0.0101
# Episode:667 meanR:358.8300 R:242.0 loss:2688.4971 exploreP:0.0101
# Episode:668 meanR:358.7200 R:460.0 loss:2763.6472 exploreP:0.0101
# Episode:669 meanR:358.7200 R:500.0 loss:2830.6274 exploreP:0.0100
# Episode:670 meanR:358.7000 R:302.0 loss:2901.8318 exploreP:0.0100
# Episode:671 meanR:358.5000 R:471.0 loss:2746.3323 exploreP:0.0100
# Episode:672 meanR:358.5000 R:500.0 loss:2879.7268 exploreP:0.0100
# Episode:673 meanR:358.5000 R:500.0 loss:2875.9470 exploreP:0.0100
# Episode:674 meanR:360.4600 R:500.0 loss:2617.8960 exploreP:0.0100
# Episode:675 meanR:357.9400 R:248.0 loss:2703.3271 exploreP:0.0100
# Episode:676 meanR:357.0200 R:408.0 loss:3022.4878 exploreP:0.0100
# Episode:677 meanR:355.4000 R:338.0 loss:2907.2046 exploreP:0.0100
# Episode:678 meanR:354.7700 R:364.0 loss:3133.8784 exploreP:0.0100
# Episode:679 meanR:351.9100 R:214.0 loss:2763.5264 exploreP:0.0100
# Episode:680 meanR:351.0000 R:212.0 loss:3028.0625 exploreP:0.0100
# Episode:681 meanR:351.0000 R:500.0 loss:2920.1565 exploreP:0.0100
# Episode:682 meanR:352.1000 R:436.0 loss:2907.2283 exploreP:0.0100
# Episode:683 meanR:349.7200 R:208.0 loss:3032.2842 exploreP:0.0100
# Episode:684 meanR:347.5000 R:214.0 loss:3427.4092 exploreP:0.0100
# Episode:685 meanR:349.4700 R:469.0 loss:3056.3027 exploreP:0.0100
# Episode:686 meanR:350.1300 R:327.0 loss:3280.2744 exploreP:0.0100
# Episode:687 meanR:349.5700 R:444.0 loss:3317.4905 exploreP:0.0100
# Episode:688 meanR:349.4000 R:231.0 loss:3383.3723 exploreP:0.0100
# Episode:689 meanR:347.0700 R:184.0 loss:3508.0896 exploreP:0.0100
# Episode:690 meanR:348.1100 R:500.0 loss:3695.1846 exploreP:0.0100
# Episode:691 meanR:346.7500 R:364.0 loss:4006.6758 exploreP:0.0100
# Episode:692 meanR:346.7500 R:500.0 loss:3902.8726 exploreP:0.0100
# Episode:693 meanR:346.1700 R:204.0 loss:3904.5950 exploreP:0.0100
# Episode:694 meanR:344.9300 R:269.0 loss:3665.8062 exploreP:0.0100
# Episode:695 meanR:347.2300 R:500.0 loss:3539.7429 exploreP:0.0100
# Episode:696 meanR:344.2300 R:198.0 loss:4152.5547 exploreP:0.0100
# Episode:697 meanR:343.0500 R:212.0 loss:3804.3625 exploreP:0.0100
# Episode:698 meanR:342.2100 R:250.0 loss:4087.9556 exploreP:0.0100
# Episode:699 meanR:342.2900 R:244.0 loss:3889.5051 exploreP:0.0100
# Episode:700 meanR:342.5100 R:344.0 loss:3971.4717 exploreP:0.0100
# Episode:701 meanR:343.2900 R:500.0 loss:4141.8057 exploreP:0.0100
# Episode:702 meanR:344.4300 R:405.0 loss:3726.7703 exploreP:0.0100
# Episode:703 meanR:343.5200 R:250.0 loss:4177.4531 exploreP:0.0100
# Episode:704 meanR:342.8400 R:432.0 loss:4095.2644 exploreP:0.0100
# Episode:705 meanR:343.2700 R:284.0 loss:4328.5146 exploreP:0.0100
# Episode:706 meanR:342.2500 R:249.0 loss:4311.3975 exploreP:0.0100
# Episode:707 meanR:342.6900 R:289.0 loss:4547.6094 exploreP:0.0100
# Episode:708 meanR:340.8000 R:311.0 loss:4794.1782 exploreP:0.0100
# Episode:709 meanR:339.1500 R:237.0 loss:4409.1050 exploreP:0.0100
# Episode:710 meanR:336.1100 R:183.0 loss:4356.0459 exploreP:0.0100
# Episode:711 meanR:334.9300 R:307.0 loss:4652.2612 exploreP:0.0100
# Episode:712 meanR:334.4100 R:229.0 loss:4901.8936 exploreP:0.0100
# Episode:713 meanR:335.0000 R:289.0 loss:4990.5200 exploreP:0.0100
# Episode:714 meanR:337.1400 R:470.0 loss:4960.5967 exploreP:0.0100
# Episode:715 meanR:337.5300 R:369.0 loss:5023.0508 exploreP:0.0100
# Episode:716 meanR:335.4200 R:289.0 loss:5378.4033 exploreP:0.0100
# Episode:717 meanR:334.3300 R:288.0 loss:5264.1748 exploreP:0.0100
# Episode:718 meanR:332.3000 R:162.0 loss:4864.2729 exploreP:0.0100
# Episode:719 meanR:331.4700 R:317.0 loss:5351.3555 exploreP:0.0100
# Episode:720 meanR:329.9800 R:164.0 loss:5402.6069 exploreP:0.0100
# Episode:721 meanR:331.8000 R:500.0 loss:5333.8105 exploreP:0.0100
# Episode:722 meanR:330.4400 R:240.0 loss:5365.5918 exploreP:0.0100
# Episode:723 meanR:332.9300 R:485.0 loss:5916.0444 exploreP:0.0100
# Episode:724 meanR:331.7400 R:160.0 loss:5522.9189 exploreP:0.0100
# Episode:725 meanR:331.9200 R:259.0 loss:5530.9248 exploreP:0.0100
# Episode:726 meanR:330.6300 R:187.0 loss:6210.2139 exploreP:0.0100
# Episode:727 meanR:327.7900 R:216.0 loss:5940.5229 exploreP:0.0100
# Episode:728 meanR:326.7000 R:391.0 loss:5209.4727 exploreP:0.0100
# Episode:729 meanR:325.6500 R:223.0 loss:5934.4502 exploreP:0.0100
# Episode:730 meanR:325.4500 R:214.0 loss:5211.7891 exploreP:0.0100
# Episode:731 meanR:323.8600 R:173.0 loss:5623.1606 exploreP:0.0100
# Episode:732 meanR:324.3300 R:282.0 loss:5386.5986 exploreP:0.0100
# Episode:733 meanR:321.4100 R:208.0 loss:5814.6348 exploreP:0.0100
# Episode:734 meanR:320.8800 R:184.0 loss:5547.7705 exploreP:0.0100
# Episode:735 meanR:319.0900 R:165.0 loss:5174.2896 exploreP:0.0100
# Episode:736 meanR:320.0900 R:336.0 loss:5922.8540 exploreP:0.0100
# Episode:737 meanR:319.6100 R:337.0 loss:5925.8130 exploreP:0.0100
# Episode:738 meanR:318.0900 R:329.0 loss:5917.6548 exploreP:0.0100
# Episode:739 meanR:318.7000 R:351.0 loss:6457.2144 exploreP:0.0100
# Episode:740 meanR:317.0900 R:264.0 loss:6763.9736 exploreP:0.0100
# Episode:741 meanR:316.5200 R:247.0 loss:7151.5317 exploreP:0.0100
# Episode:742 meanR:319.4000 R:500.0 loss:7560.5913 exploreP:0.0100
# Episode:743 meanR:320.0200 R:360.0 loss:7783.1196 exploreP:0.0100
# Episode:744 meanR:323.0100 R:500.0 loss:8604.5596 exploreP:0.0100
# Episode:745 meanR:324.4300 R:401.0 loss:9498.1797 exploreP:0.0100
# Episode:746 meanR:323.3400 R:287.0 loss:9063.6436 exploreP:0.0100
# Episode:747 meanR:323.1700 R:287.0 loss:9829.5439 exploreP:0.0100
# Episode:748 meanR:324.2200 R:410.0 loss:10511.2412 exploreP:0.0100
# Episode:749 meanR:321.8600 R:264.0 loss:10125.8311 exploreP:0.0100
# Episode:750 meanR:323.2200 R:401.0 loss:10656.1367 exploreP:0.0100
# Episode:751 meanR:323.1800 R:260.0 loss:11312.0000 exploreP:0.0100
# Episode:752 meanR:321.8600 R:309.0 loss:11349.4883 exploreP:0.0100
# Episode:753 meanR:323.1700 R:500.0 loss:11565.1758 exploreP:0.0100
# Episode:754 meanR:321.1600 R:267.0 loss:11976.1914 exploreP:0.0100
# Episode:755 meanR:322.6400 R:380.0 loss:12812.9707 exploreP:0.0100
# Episode:756 meanR:320.5800 R:249.0 loss:11671.8711 exploreP:0.0100
# Episode:757 meanR:320.4600 R:212.0 loss:12072.3701 exploreP:0.0100
# Episode:758 meanR:322.5600 R:497.0 loss:12660.4707 exploreP:0.0100
# Episode:759 meanR:323.5300 R:373.0 loss:12383.1875 exploreP:0.0100
# ...
# Episode:1963 meanR:118.5700 R:11.0 loss:6446.0552 exploreP:0.0100
# Episode:1964 meanR:118.5900 R:12.0 loss:9795.7109 exploreP:0.0100
# Episode:1965 meanR:118.6300 R:13.0 loss:9704.1377 exploreP:0.0100
# Episode:1966 meanR:118.6800 R:14.0 loss:8652.2959 exploreP:0.0100
# Episode:1967 meanR:118.6900 R:11.0 loss:5723.3091 exploreP:0.0100
# Episode:1968 meanR:118.7200 R:11.0 loss:19254.5488 exploreP:0.0100
# Episode:1969 meanR:118.7500 R:13.0 loss:4494.7295 exploreP:0.0100
# Episode:1970 meanR:118.7800 R:11.0 loss:10106.9248 exploreP:0.0100
# Episode:1971 meanR:118.8000 R:13.0 loss:12123.4385 exploreP:0.0100
# Episode:1972 meanR:118.8200 R:12.0 loss:13636.8115 exploreP:0.0100
# Episode:1973 meanR:118.8400 R:11.0 loss:19521.7793 exploreP:0.0100
# Episode:1974 meanR:118.8600 R:12.0 loss:33485.5352 exploreP:0.0100
# Episode:1975 meanR:118.8700 R:11.0 loss:11036.2539 exploreP:0.0100
# Episode:1976 meanR:118.9000 R:12.0 loss:22059.3184 exploreP:0.0100
# Episode:1977 meanR:118.9500 R:13.0 loss:4878.0498 exploreP:0.0100
# Episode:1978 meanR:118.9900 R:14.0 loss:3836.1792 exploreP:0.0100
# Episode:1979 meanR:119.0300 R:13.0 loss:21428.8262 exploreP:0.0100
# Episode:1980 meanR:119.0900 R:14.0 loss:10014.4297 exploreP:0.0100
# Episode:1981 meanR:119.1400 R:15.0 loss:17139.7207 exploreP:0.0100
# Episode:1982 meanR:119.1800 R:14.0 loss:16429.2695 exploreP:0.0100
# Episode:1983 meanR:119.2300 R:14.0 loss:4746.4297 exploreP:0.0100
# Episode:1984 meanR:119.2600 R:14.0 loss:21811.8535 exploreP:0.0100
# Episode:1985 meanR:119.3000 R:13.0 loss:10664.7207 exploreP:0.0100
# Episode:1986 meanR:119.3400 R:13.0 loss:9472.2773 exploreP:0.0100
# Episode:1987 meanR:119.3500 R:13.0 loss:5607.8809 exploreP:0.0100
# Episode:1988 meanR:119.3900 R:14.0 loss:20695.5410 exploreP:0.0100
# Episode:1989 meanR:119.4100 R:13.0 loss:28143.1348 exploreP:0.0100
# Episode:1990 meanR:119.4200 R:12.0 loss:18712.8281 exploreP:0.0100
# Episode:1991 meanR:119.4100 R:12.0 loss:6945.2017 exploreP:0.0100
# Episode:1992 meanR:119.4100 R:12.0 loss:4360.1646 exploreP:0.0100
# Episode:1993 meanR:119.1500 R:13.0 loss:16634.2012 exploreP:0.0100
# Episode:1994 meanR:118.4200 R:11.0 loss:8660.8291 exploreP:0.0100
# Episode:1995 meanR:117.4600 R:12.0 loss:9179.0059 exploreP:0.0100
# Episode:1996 meanR:115.5800 R:11.0 loss:5265.7324 exploreP:0.0100
# Episode:1997 meanR:113.4100 R:10.0 loss:6462.6475 exploreP:0.0100
# Episode:1998 meanR:111.5200 R:12.0 loss:8197.7881 exploreP:0.0100
# Episode:1999 meanR:106.6400 R:12.0 loss:16327.9736 exploreP:0.0100
# Episode:2000 meanR:101.7600 R:12.0 loss:19360.6621 exploreP:0.0100
# Episode:2001 meanR:96.8700 R:11.0 loss:30087.7051 exploreP:0.0100
# Episode:2002 meanR:91.9700 R:10.0 loss:7298.9507 exploreP:0.0100
# Episode:2003 meanR:87.0800 R:11.0 loss:41804.2148 exploreP:0.0100
# Episode:2004 meanR:82.1800 R:10.0 loss:14344.2246 exploreP:0.0100
# Episode:2005 meanR:77.2900 R:11.0 loss:6694.0239 exploreP:0.0100
# Episode:2006 meanR:72.4100 R:12.0 loss:4361.8071 exploreP:0.0100
# Episode:2007 meanR:67.5400 R:13.0 loss:22272.7520 exploreP:0.0100
# Episode:2008 meanR:62.6600 R:12.0 loss:1801.0533 exploreP:0.0100
# Episode:2009 meanR:57.7800 R:12.0 loss:26620.4160 exploreP:0.0100
# Episode:2010 meanR:52.8800 R:10.0 loss:5658.3301 exploreP:0.0100
# Episode:2011 meanR:47.9900 R:11.0 loss:6798.0620 exploreP:0.0100
# Episode:2012 meanR:43.0900 R:10.0 loss:6984.5576 exploreP:0.0100
# Episode:2013 meanR:38.2000 R:11.0 loss:24928.8809 exploreP:0.0100
# Episode:2014 meanR:33.3200 R:12.0 loss:5723.3066 exploreP:0.0100
# Episode:2015 meanR:28.4400 R:12.0 loss:1471.2440 exploreP:0.0100
# Episode:2016 meanR:23.5600 R:12.0 loss:3578.9353 exploreP:0.0100
# Episode:2017 meanR:18.6800 R:12.0 loss:22325.9219 exploreP:0.0100
# Episode:2018 meanR:13.7900 R:11.0 loss:7558.1753 exploreP:0.0100
# Episode:2019 meanR:13.7600 R:12.0 loss:3469.8728 exploreP:0.0100
# Episode:2020 meanR:13.7200 R:12.0 loss:19511.6328 exploreP:0.0100
# Episode:2021 meanR:13.6800 R:11.0 loss:5064.5693 exploreP:0.0100
# Episode:2022 meanR:13.6400 R:11.0 loss:29844.2949 exploreP:0.0100
# Episode:2023 meanR:13.6100 R:12.0 loss:6470.2500 exploreP:0.0100
# Episode:2024 meanR:13.5700 R:11.0 loss:2531.9255 exploreP:0.0100
# Episode:2025 meanR:13.5500 R:13.0 loss:4636.0239 exploreP:0.0100
# Episode:2026 meanR:13.5100 R:10.0 loss:11553.4014 exploreP:0.0100
# Episode:2027 meanR:13.5100 R:13.0 loss:9414.7910 exploreP:0.0100
# Episode:2028 meanR:13.4800 R:10.0 loss:631.4697 exploreP:0.0100
# Episode:2029 meanR:13.4700 R:11.0 loss:5941.5718 exploreP:0.0100
# Episode:2030 meanR:13.4700 R:10.0 loss:11216.0801 exploreP:0.0100
# Episode:2031 meanR:13.4700 R:11.0 loss:20563.8711 exploreP:0.0100
# Episode:2032 meanR:13.4500 R:11.0 loss:4306.0264 exploreP:0.0100
# Episode:2033 meanR:13.4200 R:11.0 loss:28467.5918 exploreP:0.0100
# Episode:2034 meanR:13.3800 R:10.0 loss:11193.0645 exploreP:0.0100
# Episode:2035 meanR:13.3800 R:11.0 loss:401.4907 exploreP:0.0100
# Episode:2036 meanR:13.3400 R:10.0 loss:4484.9404 exploreP:0.0100
# Episode:2037 meanR:13.3000 R:10.0 loss:14606.4766 exploreP:0.0100
# Episode:2038 meanR:13.2800 R:12.0 loss:776.7693 exploreP:0.0100
# Episode:2039 meanR:13.2200 R:10.0 loss:12283.0137 exploreP:0.0100
# Episode:2040 meanR:13.1300 R:11.0 loss:23821.1152 exploreP:0.0100
# Episode:2041 meanR:13.0300 R:10.0 loss:3635.5386 exploreP:0.0100
# Episode:2042 meanR:12.9900 R:10.0 loss:2782.0356 exploreP:0.0100
# Episode:2043 meanR:12.9400 R:10.0 loss:8006.1421 exploreP:0.0100
# Episode:2044 meanR:12.8600 R:11.0 loss:12978.4062 exploreP:0.0100
# Episode:2045 meanR:12.7700 R:9.0 loss:18084.0859 exploreP:0.0100
# Episode:2046 meanR:12.7200 R:11.0 loss:9187.0273 exploreP:0.0100
# Episode:2047 meanR:12.6400 R:11.0 loss:19791.0918 exploreP:0.0100
# Episode:2048 meanR:11.7600 R:10.0 loss:797.4706 exploreP:0.0100
# Episode:2049 meanR:11.7200 R:10.0 loss:5927.6045 exploreP:0.0100
# Episode:2050 meanR:11.6700 R:10.0 loss:6235.1748 exploreP:0.0100
# Episode:2051 meanR:11.6600 R:12.0 loss:9815.3701 exploreP:0.0100
# Episode:2052 meanR:11.6500 R:11.0 loss:41979.7734 exploreP:0.0100
# Episode:2053 meanR:11.6300 R:11.0 loss:1423.9354 exploreP:0.0100
# Episode:2054 meanR:11.6300 R:12.0 loss:35425.6250 exploreP:0.0100
# Episode:2055 meanR:11.6200 R:11.0 loss:2160.2834 exploreP:0.0100
# Episode:2056 meanR:11.6100 R:11.0 loss:6370.3472 exploreP:0.0100
# Episode:2057 meanR:11.6200 R:13.0 loss:24448.4473 exploreP:0.0100
# Episode:2058 meanR:11.6200 R:12.0 loss:23810.5566 exploreP:0.0100
# Episode:2059 meanR:11.6300 R:13.0 loss:24740.2598 exploreP:0.0100
# Episode:2060 meanR:11.6200 R:11.0 loss:7395.9839 exploreP:0.0100
# Episode:2061 meanR:11.6100 R:11.0 loss:9419.8584 exploreP:0.0100
# Episode:2062 meanR:11.6200 R:13.0 loss:2446.2747 exploreP:0.0100
# Episode:2063 meanR:11.6500 R:14.0 loss:49238.4648 exploreP:0.0100
# Episode:2064 meanR:11.6900 R:16.0 loss:8825.5947 exploreP:0.0100
# Episode:2065 meanR:11.7200 R:16.0 loss:9449.2090 exploreP:0.0100
# Episode:2066 meanR:11.7600 R:18.0 loss:11820.6016 exploreP:0.0100
# Episode:2067 meanR:11.8700 R:22.0 loss:15067.8594 exploreP:0.0100
# Episode:2068 meanR:11.9900 R:23.0 loss:16811.7793 exploreP:0.0100
# Episode:2069 meanR:12.0500 R:19.0 loss:23725.7754 exploreP:0.0100
# Episode:2070 meanR:12.1400 R:20.0 loss:10920.8066 exploreP:0.0100
# Episode:2071 meanR:12.1300 R:12.0 loss:6089.0024 exploreP:0.0100
# Episode:2072 meanR:12.1800 R:17.0 loss:15970.0205 exploreP:0.0100
# Episode:2073 meanR:12.2200 R:15.0 loss:16431.6191 exploreP:0.0100
# Episode:2074 meanR:12.3300 R:23.0 loss:10623.0518 exploreP:0.0100
# Episode:2075 meanR:12.5300 R:31.0 loss:21125.5098 exploreP:0.0100
# Episode:2076 meanR:13.5100 R:110.0 loss:10119.2520 exploreP:0.0100
# Episode:2077 meanR:14.5800 R:120.0 loss:14205.2832 exploreP:0.0100
# Episode:2078 meanR:15.8500 R:141.0 loss:18250.6348 exploreP:0.0100
# Episode:2079 meanR:17.2000 R:148.0 loss:13014.1738 exploreP:0.0100
# Episode:2080 meanR:22.0600 R:500.0 loss:19613.5488 exploreP:0.0100
# Episode:2081 meanR:26.9100 R:500.0 loss:29376.2793 exploreP:0.0100
# Episode:2082 meanR:31.7700 R:500.0 loss:37033.5234 exploreP:0.0100
# Episode:2083 meanR:36.6300 R:500.0 loss:45074.9141 exploreP:0.0100
# Episode:2084 meanR:41.4900 R:500.0 loss:45783.3359 exploreP:0.0100
# Episode:2085 meanR:46.3600 R:500.0 loss:48921.8945 exploreP:0.0100
# Episode:2086 meanR:51.2300 R:500.0 loss:47792.6641 exploreP:0.0100
# Episode:2087 meanR:56.1000 R:500.0 loss:42821.3984 exploreP:0.0100
# Episode:2088 meanR:58.3700 R:241.0 loss:41235.9922 exploreP:0.0100
# Episode:2089 meanR:63.2400 R:500.0 loss:38517.1445 exploreP:0.0100
# Episode:2090 meanR:68.1200 R:500.0 loss:32270.5371 exploreP:0.0100
# Episode:2091 meanR:73.0000 R:500.0 loss:31909.0176 exploreP:0.0100
# Episode:2092 meanR:77.8800 R:500.0 loss:28623.1992 exploreP:0.0100
# Episode:2093 meanR:82.7500 R:500.0 loss:21549.1797 exploreP:0.0100
# Episode:2094 meanR:87.2600 R:462.0 loss:16204.5107 exploreP:0.0100
# Episode:2095 meanR:92.1400 R:500.0 loss:12884.9336 exploreP:0.0100
# Episode:2096 meanR:96.2400 R:421.0 loss:10247.5283 exploreP:0.0100
# Episode:2097 meanR:101.1400 R:500.0 loss:10156.0078 exploreP:0.0100
# Episode:2098 meanR:106.0200 R:500.0 loss:9720.7275 exploreP:0.0100
# Episode:2099 meanR:110.9000 R:500.0 loss:8078.1045 exploreP:0.0100
# Episode:2100 meanR:115.7800 R:500.0 loss:7563.0029 exploreP:0.0100
# Episode:2101 meanR:120.6700 R:500.0 loss:8113.3159 exploreP:0.0100
# Episode:2102 meanR:125.3700 R:480.0 loss:8468.7021 exploreP:0.0100
# Episode:2103 meanR:130.2600 R:500.0 loss:10571.5859 exploreP:0.0100
# Episode:2104 meanR:135.1600 R:500.0 loss:9790.4277 exploreP:0.0100
# Episode:2105 meanR:140.0500 R:500.0 loss:12257.5225 exploreP:0.0100
# Episode:2106 meanR:144.9300 R:500.0 loss:11858.0566 exploreP:0.0100
# Episode:2107 meanR:149.8000 R:500.0 loss:11246.8770 exploreP:0.0100
# Episode:2108 meanR:154.6800 R:500.0 loss:11751.6660 exploreP:0.0100
# Episode:2109 meanR:159.5600 R:500.0 loss:12636.8438 exploreP:0.0100
# Episode:2110 meanR:164.4600 R:500.0 loss:13791.8623 exploreP:0.0100
# Episode:2111 meanR:169.3500 R:500.0 loss:11792.9199 exploreP:0.0100
# Episode:2112 meanR:174.2500 R:500.0 loss:13326.9033 exploreP:0.0100
# Episode:2113 meanR:179.1400 R:500.0 loss:12051.0352 exploreP:0.0100
# Episode:2114 meanR:184.0200 R:500.0 loss:12887.9336 exploreP:0.0100
# Episode:2115 meanR:188.9000 R:500.0 loss:12901.2822 exploreP:0.0100
# Episode:2116 meanR:193.7800 R:500.0 loss:11615.8896 exploreP:0.0100
# Episode:2117 meanR:198.6600 R:500.0 loss:11669.6855 exploreP:0.0100
# Episode:2118 meanR:203.5500 R:500.0 loss:13211.6182 exploreP:0.0100
# Episode:2119 meanR:208.4300 R:500.0 loss:11883.7588 exploreP:0.0100
# Episode:2120 meanR:213.3100 R:500.0 loss:14823.2236 exploreP:0.0100
# Episode:2121 meanR:218.2000 R:500.0 loss:13620.5742 exploreP:0.0100
# Episode:2122 meanR:223.0900 R:500.0 loss:13661.2480 exploreP:0.0100
# Episode:2123 meanR:226.5700 R:360.0 loss:13769.6250 exploreP:0.0100
# Episode:2124 meanR:231.4600 R:500.0 loss:15074.7402 exploreP:0.0100
# Episode:2125 meanR:235.0900 R:376.0 loss:13179.7285 exploreP:0.0100
# Episode:2126 meanR:239.4600 R:447.0 loss:14332.0918 exploreP:0.0100
# Episode:2127 meanR:244.3300 R:500.0 loss:14393.5742 exploreP:0.0100
# Episode:2128 meanR:248.7800 R:455.0 loss:13576.6465 exploreP:0.0100
# Episode:2129 meanR:253.6700 R:500.0 loss:13700.1514 exploreP:0.0100
# Episode:2130 meanR:258.5700 R:500.0 loss:14438.4004 exploreP:0.0100
# Episode:2131 meanR:261.9500 R:349.0 loss:17199.3691 exploreP:0.0100
# Episode:2132 meanR:266.8400 R:500.0 loss:16536.8926 exploreP:0.0100
# Episode:2133 meanR:271.7300 R:500.0 loss:18461.3203 exploreP:0.0100
# Episode:2134 meanR:276.1200 R:449.0 loss:17417.5820 exploreP:0.0100
# Episode:2135 meanR:281.0100 R:500.0 loss:18644.1074 exploreP:0.0100
# Episode:2136 meanR:285.9100 R:500.0 loss:18466.2129 exploreP:0.0100
# Episode:2137 meanR:290.8100 R:500.0 loss:18214.2402 exploreP:0.0100
# Episode:2138 meanR:295.6900 R:500.0 loss:17868.8770 exploreP:0.0100
# Episode:2139 meanR:300.5900 R:500.0 loss:16436.2402 exploreP:0.0100
# Episode:2140 meanR:305.4800 R:500.0 loss:16020.6123 exploreP:0.0100
# Episode:2141 meanR:310.3800 R:500.0 loss:16638.2773 exploreP:0.0100
# Episode:2142 meanR:315.2800 R:500.0 loss:17883.8164 exploreP:0.0100
# Episode:2143 meanR:320.1800 R:500.0 loss:16777.6758 exploreP:0.0100
# Episode:2144 meanR:325.0700 R:500.0 loss:16272.7471 exploreP:0.0100
# Episode:2145 meanR:329.9800 R:500.0 loss:15382.3418 exploreP:0.0100
# Episode:2146 meanR:334.8700 R:500.0 loss:16875.3496 exploreP:0.0100
# Episode:2147 meanR:339.7600 R:500.0 loss:16692.8691 exploreP:0.0100
# Episode:2148 meanR:344.6600 R:500.0 loss:15601.7080 exploreP:0.0100
# Episode:2149 meanR:349.5600 R:500.0 loss:15293.2900 exploreP:0.0100
# Episode:2150 meanR:354.4600 R:500.0 loss:15681.3203 exploreP:0.0100
# Episode:2151 meanR:359.3400 R:500.0 loss:16080.7842 exploreP:0.0100
# Episode:2152 meanR:364.2300 R:500.0 loss:16922.5918 exploreP:0.0100
# Episode:2153 meanR:369.1200 R:500.0 loss:18349.9453 exploreP:0.0100
# Episode:2154 meanR:374.0000 R:500.0 loss:18484.6934 exploreP:0.0100
# Episode:2155 meanR:378.8900 R:500.0 loss:18429.6387 exploreP:0.0100
# Episode:2156 meanR:383.7800 R:500.0 loss:17320.5586 exploreP:0.0100
# Episode:2157 meanR:388.6500 R:500.0 loss:18559.9805 exploreP:0.0100
# Episode:2158 meanR:393.5300 R:500.0 loss:17144.4238 exploreP:0.0100
# Episode:2159 meanR:398.4000 R:500.0 loss:16874.9570 exploreP:0.0100
# Episode:2160 meanR:403.2900 R:500.0 loss:16478.4316 exploreP:0.0100
# Episode:2161 meanR:408.1800 R:500.0 loss:17907.2129 exploreP:0.0100
# Episode:2162 meanR:413.0500 R:500.0 loss:20059.0234 exploreP:0.0100
# Episode:2163 meanR:417.9100 R:500.0 loss:18709.0879 exploreP:0.0100
# Episode:2164 meanR:422.7500 R:500.0 loss:17824.2363 exploreP:0.0100
# Episode:2165 meanR:427.5900 R:500.0 loss:16958.0801 exploreP:0.0100
# Episode:2166 meanR:432.4100 R:500.0 loss:16081.2559 exploreP:0.0100
# Episode:2167 meanR:437.1900 R:500.0 loss:16006.8037 exploreP:0.0100
# Episode:2168 meanR:441.9600 R:500.0 loss:15900.7500 exploreP:0.0100
# Episode:2169 meanR:446.7700 R:500.0 loss:17256.7246 exploreP:0.0100
# Episode:2170 meanR:451.5700 R:500.0 loss:16908.8691 exploreP:0.0100
# Episode:2171 meanR:456.4500 R:500.0 loss:15882.9844 exploreP:0.0100
# Episode:2172 meanR:461.2800 R:500.0 loss:16995.8125 exploreP:0.0100
# Episode:2173 meanR:466.1300 R:500.0 loss:16323.7656 exploreP:0.0100
# Episode:2174 meanR:470.9000 R:500.0 loss:16092.0039 exploreP:0.0100
# Episode:2175 meanR:475.5900 R:500.0 loss:16756.2363 exploreP:0.0100
# Episode:2176 meanR:479.4900 R:500.0 loss:17178.5762 exploreP:0.0100
# Episode:2177 meanR:483.2900 R:500.0 loss:17294.6758 exploreP:0.0100
# Episode:2178 meanR:486.8800 R:500.0 loss:16086.4307 exploreP:0.0100
# Episode:2179 meanR:490.4000 R:500.0 loss:15359.4600 exploreP:0.0100
# Episode:2180 meanR:490.4000 R:500.0 loss:16578.0938 exploreP:0.0100
# Episode:2181 meanR:490.4000 R:500.0 loss:15654.0713 exploreP:0.0100
# Episode:2182 meanR:490.4000 R:500.0 loss:15455.1064 exploreP:0.0100
# Episode:2183 meanR:490.4000 R:500.0 loss:16473.8848 exploreP:0.0100
# Episode:2184 meanR:490.4000 R:500.0 loss:16462.1934 exploreP:0.0100
# Episode:2185 meanR:490.4000 R:500.0 loss:17462.0684 exploreP:0.0100
# Episode:2186 meanR:490.4000 R:500.0 loss:16508.6797 exploreP:0.0100
# Episode:2187 meanR:490.4000 R:500.0 loss:14350.3027 exploreP:0.0100
# Episode:2188 meanR:492.9900 R:500.0 loss:14686.0039 exploreP:0.0100
# Episode:2189 meanR:492.9900 R:500.0 loss:14784.7822 exploreP:0.0100
# Episode:2190 meanR:492.9900 R:500.0 loss:13230.7070 exploreP:0.0100
# Episode:2191 meanR:492.9900 R:500.0 loss:12300.3203 exploreP:0.0100
# Episode:2192 meanR:492.9900 R:500.0 loss:14886.5645 exploreP:0.0100
# Episode:2193 meanR:492.9900 R:500.0 loss:16231.0518 exploreP:0.0100
# Episode:2194 meanR:493.3700 R:500.0 loss:13797.5811 exploreP:0.0100
# Episode:2195 meanR:493.3700 R:500.0 loss:13173.4805 exploreP:0.0100
# Episode:2196 meanR:494.1600 R:500.0 loss:13841.8213 exploreP:0.0100
# Episode:2197 meanR:494.1600 R:500.0 loss:14170.3672 exploreP:0.0100
# Episode:2198 meanR:494.1600 R:500.0 loss:12784.8838 exploreP:0.0100
# Episode:2199 meanR:494.1600 R:500.0 loss:12303.1377 exploreP:0.0100
# Episode:2200 meanR:494.1600 R:500.0 loss:12211.1182 exploreP:0.0100
# Episode:2201 meanR:494.1600 R:500.0 loss:12595.8516 exploreP:0.0100

# %% [markdown]
# # Visualizing training
#
# Below I'll plot the total rewards for each episode. I'm plotting the rolling average too, in blue.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

def running_mean(x, N):
    cumsum = np.cumsum(np.insert(x, 0, 0)) 
    return (cumsum[N:] - cumsum[:-N]) / N

# %%
eps, arr = np.array(episode_rewards_list).T
smoothed_arr = running_mean(arr, 10)
plt.plot(eps[-len(smoothed_arr):], smoothed_arr)
plt.plot(eps, arr, color='grey', alpha=0.3)
plt.xlabel('Episode')
plt.ylabel('Total rewards')
# Out:
# Text(0, 0.5, 'Total rewards')

# %%
eps, arr = np.array(episode_rewards_list).T
smoothed_arr = running_mean(arr, 10)
plt.plot(eps[-len(smoothed_arr):], smoothed_arr)
plt.plot(eps, arr, color='grey', alpha=0.3)
plt.xlabel('Episode')
plt.ylabel('Total rewards')
# Out:
# Text(0, 0.5, 'Total rewards')

# %%
eps, arr = np.array(rewards_list).T
smoothed_arr = running_mean(arr, 10)
plt.plot(eps[-len(smoothed_arr):], smoothed_arr)
plt.plot(eps, arr, color='grey', alpha=0.3)
plt.xlabel('Episode')
plt.ylabel('Total rewards')
# Out:
# Text(0, 0.5, 'Total rewards')

# %%
eps, arr = np.array(rewards_list).T
smoothed_arr = running_mean(arr, 10)
plt.plot(eps[-len(smoothed_arr):], smoothed_arr)
plt.plot(eps, arr, color='grey', alpha=0.3)
plt.xlabel('Episode')
plt.ylabel('Total rewards')
# Out:
# Text(0, 0.5, 'Total rewards')

# %%
eps, arr = np.array(episode_rewards_list).T
smoothed_arr = running_mean(arr, 10)
plt.plot(eps[-len(smoothed_arr):], smoothed_arr)
plt.plot(eps, arr, color='grey', alpha=0.3)
plt.xlabel('Episode')
plt.ylabel('Total rewards')
# Out:
# Text(0, 0.5, 'Total rewards')

# %%
eps, arr = np.array(rewards_list).T
smoothed_arr = running_mean(arr, 10)
plt.plot(eps[-len(smoothed_arr):], smoothed_arr)
plt.plot(eps, arr, color='grey', alpha=0.3)
plt.xlabel('Episode')
plt.ylabel('Total rewards')
# Out:
# Text(0, 0.5, 'Total rewards')

# %% [markdown]
# ## Testing
#
# Let's checkout how our trained agent plays the game.

# %%
# Creating a gym env
import gym
env = gym.make('CartPole-v0')
env = gym.make('CartPole-v1')

# A training graph session
with tf.Session(graph=graph) as sess:
    #sess.run(tf.global_variables_initializer())
    saver.restore(sess, 'checkpoints/model-qn.ckpt')    
    #saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    
    # Episodes/epochs
    for _ in range(10):
        state = env.reset()
        total_reward = 0

        # Steps/batches
        while True:
            env.render()
            
            action = act(sess, state)
            
            state, reward, done, _ = env.step(action)
            
            total_reward += reward
            
            if done:
                break
                
        # Closing the env
        print('total_reward: {}'.format(total_reward))

# Close the env at the end
env.close()
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/model-qn.ckpt
# total_reward: 10.0
# total_reward: 10.0
# total_reward: 9.0
# total_reward: 9.0
# total_reward: 9.0
# total_reward: 9.0
# total_reward: 9.0
# total_reward: 10.0
# total_reward: 9.0
# total_reward: 10.0

# %% [markdown]
# ## Extending this
#
# So, Cart-Pole is a pretty simple game. However, the same model can be used to train an agent to play something much more complicated like Pong or Space Invaders. Instead of a state like we're using here though, you'd want to use convolutional layers to get the state from the screen images.
#
# ![Deep Q-Learning Atari](assets/atari-network.png)
#
# I'll leave it as a challenge for you to use deep Q-learning to train an agent to play Atari games. Here's the original paper which will get you started: http://www.davidqiu.com:8888/research/nature14236.pdf.
