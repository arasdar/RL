# %% [markdown]
# # Deep Deterministic Policy Gradients (DDPG)
# ---
# In this notebook, we train DDPG with OpenAI Gym's Cart-pole environment.
#
# ### 1. Import the Necessary Packages

# %%
import gym
import random
import torch
import numpy as np
from collections import deque
import matplotlib.pyplot as plt
# %matplotlib inline

from ddpg_agent import Agent

# %% [markdown]
# ### 2. Instantiate the Environment and Agent

# %%
#env = gym.make('CartPole-v0')
env = gym.make('CartPole-v1')
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# /home/arasdar/anaconda3/envs/env/lib/python3.6/site-packages/gym/__init__.py:22: UserWarning: DEPRECATION WARNING: to improve load times, gym no longer automatically loads gym.spaces. Please run "import gym.spaces" to load gym.spaces on your own. This warning will turn into an error in a future version of gym.
#   warnings.warn('DEPRECATION WARNING: to improve load times, gym no longer automatically loads gym.spaces. Please run "import gym.spaces" to load gym.spaces on your own. This warning will turn into an error in a future version of gym.')

# %%
env.action_space, env.observation_space, env.reward_range
# Out:
# (Discrete(2), Box(4,), (-inf, inf))

# %%
print(env.action_space.n, env.reward_range, env.observation_space.shape[0])
# Out:
# 2 (-inf, inf) 4

# %%
env.seed(2)
agent = Agent(state_size=4, action_size=2, random_seed=2)

# %% [markdown]
# ### 3. Train the Agent with DDPG

# %%
# agent.actor_local.load_state_dict(torch.load('cartpole-checkpoint_actor.pth'))
# agent.critic_local.load_state_dict(torch.load('cartpole-checkpoint_critic.pth'))
total_reward_deque = deque(maxlen=100)
for ep in range(111111):
    state = env.reset()
    agent.reset()
    total_reward = 0
    while True:
        action = agent.act(state)
        #print(action)
        action_class = np.argmax(action)
        #print(action_class)
        next_state, reward, done, _ = env.step(action_class)
        agent.step(state, action, reward, next_state, done)
        state = next_state
        total_reward += reward
        if done:
            break 
    total_reward_deque.append(total_reward)
    print('\rEpisode {}\tAverage Score: {:.2f}'.format(ep, np.mean(total_reward_deque)))   
    if np.mean(total_reward_deque) >= 500:
        torch.save(agent.actor_local.state_dict(), 'cartpole-checkpoint_actor.pth')
        torch.save(agent.critic_local.state_dict(), 'cartpole-checkpoint_critic.pth')
        break
# Out:
# /home/arasdar/anaconda3/envs/env/lib/python3.6/site-packages/torch/nn/functional.py:995: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# Episode 0	Average Score: 26.00
# Episode 1	Average Score: 20.50
# Episode 2	Average Score: 26.00
# Episode 3	Average Score: 23.50
# Episode 4	Average Score: 21.80
# Episode 5	Average Score: 20.83
# Episode 6	Average Score: 20.00
# Episode 7	Average Score: 20.38
# Episode 8	Average Score: 20.67
# Episode 9	Average Score: 20.90
# Episode 10	Average Score: 20.64
# Episode 11	Average Score: 21.17
# Episode 12	Average Score: 21.00
# Episode 13	Average Score: 21.07
# Episode 14	Average Score: 21.00
# Episode 15	Average Score: 20.75
# Episode 16	Average Score: 20.82
# Episode 17	Average Score: 20.67
# Episode 18	Average Score: 20.84
# Episode 19	Average Score: 20.80
# Episode 20	Average Score: 20.48
# Episode 21	Average Score: 20.23
# ...

# %% [markdown]
# ### 4. Watch a Smart Agent!

# %%
agent.actor_local.load_state_dict(torch.load('pendulum-checkpoint_actor.pth'))
agent.critic_local.load_state_dict(torch.load('pendulum-checkpoint_critic.pth'))

state = env.reset()
while True:
    env.render()
    action = agent.act(state, add_noise=False)
    state, reward, done, _ = env.step(action)
    if done:
        break 

env.close()
# Out:
# /home/arasdar/anaconda3/envs/env/lib/python3.6/site-packages/torch/nn/functional.py:995: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")

# %% [markdown]
# ### 6. Explore
#
# In this exercise, we have provided a sample DDPG agent and demonstrated how to use it to solve an OpenAI Gym environment.  To continue your learning, you are encouraged to complete any (or all!) of the following tasks:
# - Amend the various hyperparameters and network architecture to see if you can get your agent to solve the environment faster than this benchmark implementation.  Once you build intuition for the hyperparameters that work well with this environment, try solving a different OpenAI Gym task!
# - Write your own DDPG implementation.  Use this code as reference only when needed -- try as much as you can to write your own algorithm from scratch.
# - You may also like to implement prioritized experience replay, to see if it speeds learning.
# - The current implementation adds Ornsetein-Uhlenbeck noise to the action space.  However, it has [been shown](https://blog.openai.com/better-exploration-with-parameter-noise/) that adding noise to the parameters of the neural network policy can improve performance.  Make this change to the code, to verify it for yourself!
# - Write a blog post explaining the intuition behind the DDPG algorithm and demonstrating how to use it to solve an RL environment of your choosing.
