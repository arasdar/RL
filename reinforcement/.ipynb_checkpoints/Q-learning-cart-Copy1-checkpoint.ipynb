# %% [markdown]
# # Deep Q-learning
#
# In this notebook, we'll build a neural network that can learn to play games through reinforcement learning. More specifically, we'll use Q-learning to train an agent to play a game called [Cart-Pole](https://gym.openai.com/envs/CartPole-v0). In this game, a freely swinging pole is attached to a cart. The cart can move to the left and right, and the goal is to keep the pole upright as long as possible.
#
# ![Cart-Pole](assets/cart-pole.jpg)
#
# We can simulate this game using [OpenAI Gym](https://gym.openai.com/). First, let's check out how OpenAI Gym works. Then, we'll get into training an agent to play the Cart-Pole game.

# %%
import gym
import tensorflow as tf
import numpy as np

# %% [markdown]
# >**Note:** Make sure you have OpenAI Gym cloned into the same directory with this notebook. I've included `gym` as a submodule, so you can run `git submodule --init --recursive` to pull the contents into the `gym` repo.

# %%
# Create the Cart-Pole game environment
env = gym.make('CartPole-v0')
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# /home/arasdar/anaconda3/envs/env/lib/python3.6/site-packages/gym/__init__.py:22: UserWarning: DEPRECATION WARNING: to improve load times, gym no longer automatically loads gym.spaces. Please run "import gym.spaces" to load gym.spaces on your own. This warning will turn into an error in a future version of gym.
#   warnings.warn('DEPRECATION WARNING: to improve load times, gym no longer automatically loads gym.spaces. Please run "import gym.spaces" to load gym.spaces on your own. This warning will turn into an error in a future version of gym.')

# %% [markdown]
# We interact with the simulation through `env`. To show the simulation running, you can use `env.render()` to render one frame. Passing in an action as an integer to `env.step` will generate the next step in the simulation.  You can see how many actions are possible from `env.action_space` and to get a random action you can use `env.action_space.sample()`. This is general to all Gym games. In the Cart-Pole game, there are two possible actions, moving the cart left or right. So there are two actions we can take, encoded as 0 and 1.
#
# Run the code below to watch the simulation run.

# %%
env.reset()
rewards = []
for _ in range(100):
#     env.render()
    action = env.action_space.sample()
    state, reward, done, info = env.step(action) # take a random action
    rewards.append(reward)
    if done:
        print('state, action, reward, done, info')
        print(state, action, reward, done, info)
        rewards = []
        env.reset()
# Out:
# state, action, reward, done, info
# [ 0.24013295  0.82259953 -0.23784838 -1.29949612] 0 1.0 True {}
# state, action, reward, done, info
# [-0.00581849  0.14986304  0.21255629  0.7173987 ] 0 1.0 True {}
# state, action, reward, done, info
# [ 0.16452457  1.37484547 -0.22523271 -2.24495792] 1 1.0 True {}
# state, action, reward, done, info
# [-0.09106584 -0.59241023  0.21737483  1.14515868] 1 1.0 True {}
# state, action, reward, done, info
# [ 0.10922156  0.60124384 -0.22686971 -1.24536983] 0 1.0 True {}

# %% [markdown]
# To shut the window showing the simulation, use `env.close()`.

# %% [markdown]
# If you ran the simulation above, we can look at the rewards:

# %%
print(rewards[-20:])
# Out:
# [1.0, 1.0, 1.0, 1.0]

# %% [markdown]
# The game resets after the pole has fallen past a certain angle. For each frame while the simulation is running, it returns a reward of 1.0. The longer the game runs, the more reward we get. Then, our network's goal is to maximize the reward by keeping the pole vertical. It will do this by moving the cart to the left and the right.

# %% [markdown]
# ## Q-Network
#
# We train our Q-learning agent using the Bellman Equation:
#
# $$
# Q(s, a) = r + \gamma \max{Q(s', a')}
# $$
#
# where $s$ is a state, $a$ is an action, and $s'$ is the next state from state $s$ and action $a$.
#
# Before we used this equation to learn values for a Q-_table_. However, for this game there are a huge number of states available. The state has four values: the position and velocity of the cart, and the position and velocity of the pole. These are all real-valued numbers, so ignoring floating point precisions, you practically have infinite states. Instead of using a table then, we'll replace it with a neural network that will approximate the Q-table lookup function.
#
# <img src="assets/deep-q-learning.png" width=450px>
#
# Now, our Q value, $Q(s, a)$ is calculated by passing in a state to the network. The output will be Q-values for each available action, with fully connected hidden layers.
#
# <img src="assets/q-network.png" width=550px>
#
#
# As I showed before, we can define our targets for training as $\hat{Q}(s,a) = r + \gamma \max{Q(s', a')}$. Then we update the weights by minimizing $(\hat{Q}(s,a) - Q(s,a))^2$.
#
# For this Cart-Pole game, we have four inputs, one for each value in the state, and two outputs, one for each action. To get $\hat{Q}$, we'll first choose an action, then simulate the game using that action. This will get us the next state, $s'$, and the reward. With that, we can calculate $\hat{Q}$ then pass it back into the $Q$ network to run the optimizer and update the weights.
#
# Below is my implementation of the Q-network. I used two fully connected layers with ReLU activations. Two seems to be good enough, three might be better. Feel free to try it out.

# %%
# class QNetwork:
#     def __init__(self, learning_rate=0.01, state_size=4, action_size=2, hidden_size=10, name='QNetwork'):
#         # state inputs to the Q-network
#         with tf.variable_scope(name):
#             # Given data
#             self.inputs_ = tf.placeholder(tf.float32, [None, state_size], name='inputs')
#             self.actions_ = tf.placeholder(tf.int32, [None], name='actions')

#             # One hot encode the actions to later choose the Q-value for the action
#             one_hot_actions = tf.one_hot(self.actions_, action_size)

#             # ReLU hidden layers
#             fc1 = tf.contrib.layers.fully_connected(self.inputs_, hidden_size)
#             fc2 = tf.contrib.layers.fully_connected(fc1, hidden_size)

#             # Linear output layer
#             self.output = tf.contrib.layers.fully_connected(fc2, action_size, activation_fn=None)
                    
#             ### Train with loss (targetQ - Q)^2
#             # output has length 2, for two actions. This next line chooses
#             # one value from output (per row) according to the one-hot encoded actions.
#             self.Q = tf.reduce_sum(tf.multiply(self.output, one_hot_actions), axis=1)

#             # Target Q values for training
#             self.targetQs_ = tf.placeholder(tf.float32, [None], name='target')

#             # error backpropagation: loss and opt
#             self.loss = tf.reduce_mean(tf.square(self.targetQs_ - self.Q))
#             self.opt = tf.train.AdamOptimizer(learning_rate).minimize(self.loss)

# %%
# tf.layers.dense(
#     inputs, ---
#     units, -----
#     activation=None,
#     use_bias=True,  -----------
#     kernel_initializer=None,
#     bias_initializer=tf.zeros_initializer(), ----------
#     kernel_regularizer=None,
#     bias_regularizer=None,
#     activity_regularizer=None,
#     kernel_constraint=None,
#     bias_constraint=None,
#     trainable=True, -----------------
#     name=None,
#     reuse=None
# )

# %%
def generator(in_state, state_size=4, action_size=2, hidden_size=10, alpha=0.1, reuse=False, training=True):
    with tf.variable_scope('generator', reuse=reuse):
        # First fully connected layer
        h1 = tf.layers.dense(in_state, hidden_size)
        bn1 = tf.layers.batch_normalization(h1, training=training)
        nl1 = tf.maximum(alpha * bn1, bn1)
        
        # Second fully connected layer
        h2 = tf.layers.dense(nl1, hidden_size)
        bn2 = tf.layers.batch_normalization(h2, training=training)
        nl2 = tf.maximum(alpha * bn2, bn2)
        
        # Output layer
        logits_state_next = tf.layers.dense(nl2, state_size, trainable=False)        
        logits_action = tf.layers.dense(nl2, action_size, trainable=False)        
        # out = tf.tanh(logits)

        return logits_state_next, logits_action

# %%
def discriminator(in_state_next, out_action, action_size=2, hidden_size=10, reuse=False, alpha=0.1):
    with tf.variable_scope('discriminator', reuse=reuse):
        # First fully connected layer
        fused = tf.concat(values=[in_state_next, out_action], axis=1)
        h1 = tf.layers.dense(fused, hidden_size)
        bn1 = tf.layers.batch_normalization(h1, training=True)
        nl1 = tf.maximum(alpha * bn1, bn1)
        
        # Second fully connected layer
        h2 = tf.layers.dense(nl1, hidden_size)
        bn2 = tf.layers.batch_normalization(h2, training=True)
        nl2 = tf.maximum(alpha * bn2, bn2)
        
        # Output layer
        logits = tf.layers.dense(nl2, 1, trainable=False)   
        out = tf.sigmoid(logits)

        # logits for loss and reward/prob/out
        return out, logits

# %%
def model_inputs(state_size=4, action_size=2):
    # Current input states
    inputs_ = tf.placeholder(tf.float32, [None, state_size], name='inputs') # NxCin
    # print(self.inputs_)

    # Current output action: for generation/prediction
    actions_ = tf.placeholder(tf.int32, [None], name='actions')
    actions_onehot = tf.one_hot(actions_, action_size)
    # print(actions_onehot)

    # Next input real and generated/fake/predicted
    inputs_next = tf.placeholder(tf.float32, [None, state_size], name='inputs_next') # NxCin
    # print(self.inputs_next)
    
    return inputs_, actions_onehot, inputs_next

# %%
def model_loss(inputs_, actions_onehot, inputs_next, alpha=0.1, hidden_size=10):
    """
    Get the loss for the discriminator and generator
    :param inputs_: real input states
    :param actions_onehot: onehot encoded/vec action
    :param inputs_next: real next input states
    :return: A tuple of (discriminator loss, generator loss)
    """
    input_state_gen, out_action_gen = generator(in_state=inputs_)
    d_out_fake, d_logits_fake = discriminator(in_state_next=input_state_gen, out_action=out_action_gen)
    d_out_real, d_logits_real = discriminator(in_state_next=inputs_next, out_action=actions_onehot, reuse=True)

    d_loss_real = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_real, labels=tf.ones_like(d_logits_real)))
    d_loss_fake = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, labels=tf.zeros_like(d_logits_fake)))
    d_loss = d_loss_real + d_loss_fake
    
    g_loss = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, labels=tf.ones_like(d_logits_fake)))
    
    return d_loss, g_loss

# %%
def model_opt(d_loss, g_loss, learning_rate):
    """
    Get optimization operations
    :param d_loss: Discriminator loss Tensor for reward function
    :param g_loss: Generator loss Tensor for action & next state predicton
    :param learning_rate: Learning Rate Placeholder
    :return: A tuple of (discriminator training operation, generator training operation)
    """
    # Get weights and bias to update
    t_vars = tf.trainable_variables()
    d_vars = [var for var in t_vars if var.name.startswith('discriminator')]
    g_vars = [var for var in t_vars if var.name.startswith('generator')]

    # Optimize
    with tf.control_dependencies(tf.get_collection(tf.GraphKeys.UPDATE_OPS)):
        d_train_opt = tf.train.AdamOptimizer(learning_rate).minimize(d_loss, var_list=d_vars)
        g_train_opt = tf.train.AdamOptimizer(learning_rate).minimize(g_loss, var_list=g_vars)

    return d_train_opt, g_train_opt

# %%
class Net:
    def __init__(self, action_size=2, state_size=4, hidden_size=10, learning_rate=0.01, alpha=0.1):
        tf.reset_default_graph()
        
        self.inputs_, self.actions_onehot, self.inputs_next = model_inputs(action_size, state_size)
        
        self.d_loss, self.g_loss = model_loss(self.inputs_, self.actions_onehot, self.inputs_next, hidden_size)
        
        self.d_opt, self.g_opt = model_opt(d_loss=self.d_loss, g_loss=self.g_loss, learning_rate=learning_rate)

# %%
# # def generator(in_state, state_size=4, action_size=2, hidden_size=10, name='generator', reuse=False, ):
# #     # state inputs to the Q-network2
# #     with tf.variable_scope(name, reuse=reuse): # for saving the generator weights and biases (model parameters)

# #         # ReLU hidden layers: generators
# #         fc1 = tf.contrib.layers.fully_connected(in_state, hidden_size)
# #         fc2 = tf.contrib.layers.fully_connected(fc1, hidden_size)

# #         # Linear output layer
# #         logits_state_next = tf.contrib.layers.fully_connected(fc2, state_size, activation_fn=None, trainable=False)
# #         logits_action = tf.contrib.layers.fully_connected(fc2, action_size, activation_fn=None, trainable=False)

# #         # # Split it into in and out
# #         # logits_state_next, logits_action = tf.split(value=logits, num_or_size_splits=[state_size, action_size], axis=1)

# #         # logits_action is for applying to the env or env.step and the predicted next state is for D
# #         return logits_state_next, logits_action

# # def discriminator(in_state_next, out_action, action_size=2, hidden_size=10, name='discriminator', reuse=False):
# #     # state inputs to the Q-network2
# #     with tf.variable_scope(name, reuse=reuse):
        
# #         # ReLU hidden layers: discriminator
# #         fused = tf.concat(values=[in_state_next, out_action], axis=1)
# #         # print(in_state_next.shape, out_action.shape, fused.shape)
# #         fc1 = tf.contrib.layers.fully_connected(fused, hidden_size)
# #         fc2 = tf.contrib.layers.fully_connected(fc1, hidden_size)

# #         # Linear output layer: logits and prob/logistics
# #         logits = tf.contrib.layers.fully_connected(fc2, 1, activation_fn=None)
# #         # reward = tf.sigmoid(x=logits) # for reward accumulation -  reward: 0-1

# #         # outputing the logits and prob reward: logits for loss and prob for accumulaion
# #         return logits

# # # This GAN for iDRL
# class Net:
#     def __init__(self, state_size=4, action_size=2, hidden_size=10, learning_rate=0.01):            
#         # Current input states
#         self.inputs_ = tf.placeholder(tf.float32, [None, state_size], name='inputs') # NxCin
#         # print(self.inputs_)

#         # Current output action: for generation/prediction
#         self.actions_ = tf.placeholder(tf.int32, [None], name='actions')
#         actions_onehot = tf.one_hot(self.actions_, action_size)
#         # print(actions_onehot)

#         # Next input real and generated/fake/predicted
#         self.inputs_next = tf.placeholder(tf.float32, [None, state_size], name='inputs_next') # NxCin
#         # print(self.inputs_next)

#         # Linear output layer
#         inputs_next_gen, self.output_gen = generator(self.inputs_)

#         # Linear output layer
#         d_logits_fake = discriminator(inputs_next_gen, self.output_gen) # , self.d_reward_fake
#         d_logits_real = discriminator(self.inputs_next, actions_onehot, reuse=True) #, self.d_reward_real

#         d_loss_fake = tf.nn.sigmoid_cross_entropy_with_logits(labels=d_logits_fake, 
#                                                       logits=tf.zeros_like(d_logits_fake))
#         d_loss_real = tf.nn.sigmoid_cross_entropy_with_logits(labels=d_logits_real, 
#                                                       logits=tf.ones_like(d_logits_real))

#         self.d_loss = d_loss_fake + d_loss_real
#         self.g_loss = tf.nn.sigmoid_cross_entropy_with_logits(labels=d_logits_fake, 
#                                                       logits=tf.ones_like(d_logits_fake))

#         self.d_opt = tf.train.AdamOptimizer(learning_rate).minimize(self.d_loss)
#         self.g_opt = tf.train.AdamOptimizer(learning_rate).minimize(self.g_loss)

# %% [markdown]
# ## Experience replay
#
# Reinforcement learning algorithms can have stability issues due to correlations between states. To reduce correlations when training, we can store the agent's experiences and later draw a random mini-batch of those experiences to train on.
#
# Here, we'll create a `Memory` object that will store our experiences, our transitions $<s, a, r, s'>$. This memory will have a maxmium capacity, so we can keep newer experiences in memory while getting rid of older experiences. Then, we'll sample a random mini-batch of transitions $<s, a, r, s'>$ and train on those.
#
# Below, I've implemented a `Memory` object. If you're unfamiliar with `deque`, this is a double-ended queue. You can think of it like a tube open on both sides. You can put objects in either side of the tube. But if it's full, adding anything more will push an object out the other side. This is a great data structure to use for the memory buffer.

# %%
from collections import deque
class Memory():
    def __init__(self, max_size = 1000):
        self.buffer = deque(maxlen=max_size)
    
    def add(self, experience):
        self.buffer.append(experience)
            
    def sample(self, batch_size):
        idx = np.random.choice(np.arange(len(self.buffer)), 
                               size=batch_size, 
                               replace=False)
        return [self.buffer[ii] for ii in idx]

# %% [markdown]
# ## Exploration - Exploitation
#
# To learn about the environment and rules of the game, the agent needs to explore by taking random actions. We'll do this by choosing a random action with some probability $\epsilon$ (epsilon).  That is, with some probability $\epsilon$ the agent will make a random action and with probability $1 - \epsilon$, the agent will choose an action from $Q(s,a)$. This is called an **$\epsilon$-greedy policy**.
#
#
# At first, the agent needs to do a lot of exploring. Later when it has learned more, the agent can favor choosing actions based on what it has learned. This is called _exploitation_. We'll set it up so the agent is more likely to explore early in training, then more likely to exploit later in training.

# %% [markdown]
# ## Q-Learning training algorithm
#
# Putting all this together, we can list out the algorithm we'll use to train the network. We'll train the network in _episodes_. One *episode* is one simulation of the game. For this game, the goal is to keep the pole upright for 195 frames. So we can start a new episode once meeting that goal. The game ends if the pole tilts over too far, or if the cart moves too far the left or right. When a game ends, we'll start a new episode. Now, to train the agent:
#
# * Initialize the memory $D$
# * Initialize the action-value network $Q$ with random weights
# * **For** episode = 1, $M$ **do**
#   * **For** $t$, $T$ **do**
#      * With probability $\epsilon$ select a random action $a_t$, otherwise select $a_t = \mathrm{argmax}_a Q(s,a)$
#      * Execute action $a_t$ in simulator and observe reward $r_{t+1}$ and new state $s_{t+1}$
#      * Store transition $<s_t, a_t, r_{t+1}, s_{t+1}>$ in memory $D$
#      * Sample random mini-batch from $D$: $<s_j, a_j, r_j, s'_j>$
#      * Set $\hat{Q}_j = r_j$ if the episode ends at $j+1$, otherwise set $\hat{Q}_j = r_j + \gamma \max_{a'}{Q(s'_j, a')}$
#      * Make a gradient descent step with loss $(\hat{Q}_j - Q(s_j, a_j))^2$
#   * **endfor**
# * **endfor**

# %% [markdown]
# ## Hyperparameters
#
# One of the more difficult aspects of reinforcememt learning are the large number of hyperparameters. Not only are we tuning the network, but we're tuning the simulation.

# %%
train_episodes = 3000          # max number of episodes to learn from
max_steps = 200                # max steps in an episode
gamma = 0.99                   # future reward discount

# Exploration parameters
explore_start = 1.0            # exploration probability at start
explore_stop = 0.01            # minimum exploration probability 
decay_rate = 0.0001            # exponential decay rate for exploration prob

# Network parameters
hidden_size = 64               # number of units in each Q-network hidden layer
learning_rate = 0.0001         # Q-network learning rate

# Memory parameters
memory_size = 10000            # memory capacity
batch_size = 20                # experience mini-batch size
pretrain_length = batch_size   # number experiences to pretrain the memory

# %%
tf.reset_default_graph()
# mainQN = QNetwork(name='main', hidden_size=hidden_size, learning_rate=learning_rate)
mainNet = Net(hidden_size=hidden_size, learning_rate=learning_rate)

# %% [markdown]
# ## Populate the experience memory
#
# Here I'm re-initializing the simulation and pre-populating the memory. The agent is taking random actions and storing the transitions in memory. This will help the agent with exploring the game.

# %%
# Initialize the simulation
env.reset()

# Take one random step to get the pole and cart moving
state, reward, done, _ = env.step(env.action_space.sample())

# init memory
memory = Memory(max_size=memory_size)

# Make a bunch of random actions and store the experiences
for _ in range(pretrain_length):
    # Uncomment the line below to watch the simulation
    # env.render()

    # Make a random action
    action = env.action_space.sample()
    next_state, reward, done, _ = env.step(action)

    if done:
        # The simulation fails so no next state
        next_state = np.zeros(state.shape)
        
        # Add experience to memory
        memory.add((state, action, reward, next_state))
        
        # Start new episode
        env.reset()
        
        # Take one random step to get the pole and cart moving
        state, reward, done, _ = env.step(env.action_space.sample())
    else:
        # Add experience to memory
        memory.add((state, action, reward, next_state))
        state = next_state

# %% [markdown]
# ## Training
#
# Below we'll train our agent. If you want to watch it train, uncomment the `env.render()` line. This is slow because it's rendering the frames slower than the network can train. But, it's cool to watch the agent get better at the game.

# %%
# Now train with experiences
saver = tf.train.Saver()

# Total rewards list for plotting
rewards_list = []

# TF session for training
with tf.Session() as sess:
    
    # Initialize variables
    sess.run(tf.global_variables_initializer())
    
    step = 0
    for ep in range(train_episodes):
        total_reward = 0
        
        t = 0
        while t < max_steps:
            step += 1
            
            # Uncomment this next line to watch the training
            # env.render() 
            
            # Explore or Exploit
            explore_p = explore_stop + (explore_start - explore_stop)*np.exp(-decay_rate*step) 
            if explore_p > np.random.rand():
                # Make a random action
                action = env.action_space.sample()
            else:
                # # Get action from Q-network
                # feed = {mainQN.inputs_: state.reshape((1, *state.shape))}
                # Qs = sess.run(mainQN.output, feed_dict=feed)
                # action = np.argmax(Qs)
                # Get action from GD-network
                feed = {mainNet.inputs_: state.reshape((1, *state.shape))}
                # state_next, action 
                gen = generator(in_state=mainNet.inputs_, reuse=True, training=False)
                _, Qs = sess.run(gen, feed_dict=feed)
                action = np.argmax(Qs)
            
            # Take action, get new state and reward
            next_state, reward, done, _ = env.step(action)
    
            # Cumulative reward
            total_reward += reward
            
            if done:
                # the episode ends so no next state
                next_state = np.zeros(state.shape)
                t = max_steps
                
                print('Episode: {}'.format(ep),
                      'Total reward: {}'.format(total_reward),
#                       'Training loss: {:.4f}'.format(loss),
                      'Explore P: {:.4f}'.format(explore_p))
                
                # total rewards for plotting
                rewards_list.append((ep, total_reward))
                
                # Add experience to memory
                memory.add((state, action, reward, next_state))
                
                # Start new episode
                env.reset()
                
                # Take one random step to get the pole and cart moving
                state, reward, done, _ = env.step(env.action_space.sample())

            else:
                # Add experience to memory
                memory.add((state, action, reward, next_state))
                state = next_state
                t += 1
            
            # Sample mini-batch from memory
            batch = memory.sample(batch_size)
            states = np.array([each[0] for each in batch])
            actions = np.array([each[1] for each in batch])
            # rewards = np.array([each[2] for each in batch])
            next_states = np.array([each[3] for each in batch])
            
            # # Train network
            # target_Qs = sess.run(mainQN.output, feed_dict={mainQN.inputs_: next_states})

            # # Set target_Qs to 0 for states where episode ends
            # episode_ends = (next_states == np.zeros(states[0].shape)).all(axis=1)
            # target_Qs[episode_ends] = (0, 0)

            # targets = rewards + gamma * np.max(target_Qs, axis=1)

            # loss, _ = sess.run([mainQN.loss, mainQN.opt],
            #                     feed_dict={mainQN.inputs_: states,
            #                                mainQN.targetQs_: targets,
            #                                mainQN.actions_: actions})
            feed_dict={mainNet.inputs_: states,
                       mainNet.inputs_next: next_states,
                       mainNet.actions_: actions}
            d_loss, _ = sess.run([mainNet.d_loss, mainNet.d_opt], feed_dict)
            g_loss, _ = sess.run([mainNet.g_loss, mainNet.g_opt], feed_dict)
            
    saver.save(sess, "checkpoints/cartpole__.ckpt")
# Out:
# Episode: 0 Total reward: 9.0 Explore P: 0.9991
# Episode: 1 Total reward: 83.0 Explore P: 0.9909
# Episode: 2 Total reward: 19.0 Explore P: 0.9891
# Episode: 3 Total reward: 14.0 Explore P: 0.9877
# Episode: 4 Total reward: 13.0 Explore P: 0.9864
# Episode: 5 Total reward: 24.0 Explore P: 0.9841
# Episode: 6 Total reward: 19.0 Explore P: 0.9822
# Episode: 7 Total reward: 30.0 Explore P: 0.9793
# Episode: 8 Total reward: 42.0 Explore P: 0.9753
# Episode: 9 Total reward: 18.0 Explore P: 0.9735
# Episode: 10 Total reward: 64.0 Explore P: 0.9674
# Episode: 11 Total reward: 8.0 Explore P: 0.9666
# Episode: 12 Total reward: 17.0 Explore P: 0.9650
# Episode: 13 Total reward: 12.0 Explore P: 0.9638
# Episode: 14 Total reward: 19.0 Explore P: 0.9620
# Episode: 15 Total reward: 15.0 Explore P: 0.9606
# Episode: 16 Total reward: 10.0 Explore P: 0.9597
# Episode: 17 Total reward: 30.0 Explore P: 0.9568
# Episode: 18 Total reward: 23.0 Explore P: 0.9546
# Episode: 19 Total reward: 32.0 Explore P: 0.9516
# Episode: 20 Total reward: 15.0 Explore P: 0.9502
# Episode: 21 Total reward: 84.0 Explore P: 0.9423
# Episode: 22 Total reward: 32.0 Explore P: 0.9394
# Episode: 23 Total reward: 55.0 Explore P: 0.9343
# Episode: 24 Total reward: 12.0 Explore P: 0.9332
# Episode: 25 Total reward: 22.0 Explore P: 0.9311
# Episode: 26 Total reward: 16.0 Explore P: 0.9297
# Episode: 27 Total reward: 19.0 Explore P: 0.9279
# Episode: 28 Total reward: 18.0 Explore P: 0.9263
# Episode: 29 Total reward: 12.0 Explore P: 0.9252
# Episode: 30 Total reward: 36.0 Explore P: 0.9219
# Episode: 31 Total reward: 15.0 Explore P: 0.9205
# Episode: 32 Total reward: 26.0 Explore P: 0.9181
# Episode: 33 Total reward: 31.0 Explore P: 0.9153
# Episode: 34 Total reward: 9.0 Explore P: 0.9145
# Episode: 35 Total reward: 20.0 Explore P: 0.9127
# Episode: 36 Total reward: 13.0 Explore P: 0.9115
# Episode: 37 Total reward: 24.0 Explore P: 0.9094
# Episode: 38 Total reward: 48.0 Explore P: 0.9051
# Episode: 39 Total reward: 47.0 Explore P: 0.9009
# Episode: 40 Total reward: 26.0 Explore P: 0.8986
# Episode: 41 Total reward: 31.0 Explore P: 0.8958
# Episode: 42 Total reward: 22.0 Explore P: 0.8939
# Episode: 43 Total reward: 49.0 Explore P: 0.8895
# Episode: 44 Total reward: 16.0 Explore P: 0.8881
# Episode: 45 Total reward: 53.0 Explore P: 0.8835
# Episode: 46 Total reward: 35.0 Explore P: 0.8804
# Episode: 47 Total reward: 16.0 Explore P: 0.8791
# Episode: 48 Total reward: 16.0 Explore P: 0.8777
# Episode: 49 Total reward: 10.0 Explore P: 0.8768
# Episode: 50 Total reward: 11.0 Explore P: 0.8758
# Episode: 51 Total reward: 13.0 Explore P: 0.8747
# Episode: 52 Total reward: 15.0 Explore P: 0.8734
# Episode: 53 Total reward: 17.0 Explore P: 0.8720
# Episode: 54 Total reward: 14.0 Explore P: 0.8708
# Episode: 55 Total reward: 35.0 Explore P: 0.8677
# Episode: 56 Total reward: 14.0 Explore P: 0.8665
# Episode: 57 Total reward: 17.0 Explore P: 0.8651
# Episode: 58 Total reward: 13.0 Explore P: 0.8640
# Episode: 59 Total reward: 14.0 Explore P: 0.8628
# Episode: 60 Total reward: 12.0 Explore P: 0.8618
# Episode: 61 Total reward: 23.0 Explore P: 0.8598
# Episode: 62 Total reward: 17.0 Explore P: 0.8584
# Episode: 63 Total reward: 13.0 Explore P: 0.8573
# Episode: 64 Total reward: 11.0 Explore P: 0.8563
# Episode: 65 Total reward: 15.0 Explore P: 0.8551
# Episode: 66 Total reward: 13.0 Explore P: 0.8540
# Episode: 67 Total reward: 14.0 Explore P: 0.8528
# Episode: 68 Total reward: 11.0 Explore P: 0.8519
# Episode: 69 Total reward: 20.0 Explore P: 0.8502
# Episode: 70 Total reward: 20.0 Explore P: 0.8485
# Episode: 71 Total reward: 51.0 Explore P: 0.8442
# Episode: 72 Total reward: 25.0 Explore P: 0.8421
# Episode: 73 Total reward: 21.0 Explore P: 0.8404
# Episode: 74 Total reward: 17.0 Explore P: 0.8390
# Episode: 75 Total reward: 9.0 Explore P: 0.8382
# Episode: 76 Total reward: 20.0 Explore P: 0.8366
# Episode: 77 Total reward: 30.0 Explore P: 0.8341
# Episode: 78 Total reward: 14.0 Explore P: 0.8330
# Episode: 79 Total reward: 23.0 Explore P: 0.8311
# Episode: 80 Total reward: 22.0 Explore P: 0.8293
# Episode: 81 Total reward: 28.0 Explore P: 0.8270
# Episode: 82 Total reward: 12.0 Explore P: 0.8260
# Episode: 83 Total reward: 24.0 Explore P: 0.8240
# Episode: 84 Total reward: 16.0 Explore P: 0.8227
# Episode: 85 Total reward: 24.0 Explore P: 0.8208
# Episode: 86 Total reward: 34.0 Explore P: 0.8180
# Episode: 87 Total reward: 11.0 Explore P: 0.8171
# Episode: 88 Total reward: 27.0 Explore P: 0.8150
# Episode: 89 Total reward: 20.0 Explore P: 0.8134
# Episode: 90 Total reward: 34.0 Explore P: 0.8106
# Episode: 91 Total reward: 26.0 Explore P: 0.8086
# Episode: 92 Total reward: 38.0 Explore P: 0.8055
# Episode: 93 Total reward: 38.0 Explore P: 0.8025
# Episode: 94 Total reward: 11.0 Explore P: 0.8016
# Episode: 95 Total reward: 43.0 Explore P: 0.7982
# Episode: 96 Total reward: 17.0 Explore P: 0.7969
# Episode: 97 Total reward: 9.0 Explore P: 0.7962
# Episode: 98 Total reward: 13.0 Explore P: 0.7952
# Episode: 99 Total reward: 7.0 Explore P: 0.7946
# Episode: 100 Total reward: 12.0 Explore P: 0.7937
# Episode: 101 Total reward: 11.0 Explore P: 0.7928
# Episode: 102 Total reward: 15.0 Explore P: 0.7916
# Episode: 103 Total reward: 18.0 Explore P: 0.7902
# Episode: 104 Total reward: 28.0 Explore P: 0.7881
# Episode: 105 Total reward: 8.0 Explore P: 0.7874
# Episode: 106 Total reward: 34.0 Explore P: 0.7848
# Episode: 107 Total reward: 13.0 Explore P: 0.7838
# Episode: 108 Total reward: 17.0 Explore P: 0.7825
# Episode: 109 Total reward: 8.0 Explore P: 0.7819
# Episode: 110 Total reward: 11.0 Explore P: 0.7810
# Episode: 111 Total reward: 12.0 Explore P: 0.7801
# Episode: 112 Total reward: 21.0 Explore P: 0.7785
# Episode: 113 Total reward: 10.0 Explore P: 0.7777
# Episode: 114 Total reward: 14.0 Explore P: 0.7766
# Episode: 115 Total reward: 11.0 Explore P: 0.7758
# Episode: 116 Total reward: 22.0 Explore P: 0.7741
# Episode: 117 Total reward: 7.0 Explore P: 0.7736
# Episode: 118 Total reward: 11.0 Explore P: 0.7727
# Episode: 119 Total reward: 12.0 Explore P: 0.7718
# Episode: 120 Total reward: 11.0 Explore P: 0.7710
# Episode: 121 Total reward: 11.0 Explore P: 0.7701
# Episode: 122 Total reward: 10.0 Explore P: 0.7694
# Episode: 123 Total reward: 17.0 Explore P: 0.7681
# Episode: 124 Total reward: 8.0 Explore P: 0.7675
# Episode: 125 Total reward: 10.0 Explore P: 0.7667
# Episode: 126 Total reward: 7.0 Explore P: 0.7662
# Episode: 127 Total reward: 20.0 Explore P: 0.7647
# Episode: 128 Total reward: 15.0 Explore P: 0.7636
# Episode: 129 Total reward: 9.0 Explore P: 0.7629
# Episode: 130 Total reward: 10.0 Explore P: 0.7621
# Episode: 131 Total reward: 31.0 Explore P: 0.7598
# Episode: 132 Total reward: 9.0 Explore P: 0.7591
# Episode: 133 Total reward: 21.0 Explore P: 0.7576
# Episode: 134 Total reward: 11.0 Explore P: 0.7567
# Episode: 135 Total reward: 18.0 Explore P: 0.7554
# Episode: 136 Total reward: 15.0 Explore P: 0.7543
# Episode: 137 Total reward: 21.0 Explore P: 0.7527
# Episode: 138 Total reward: 46.0 Explore P: 0.7493
# Episode: 139 Total reward: 11.0 Explore P: 0.7485
# Episode: 140 Total reward: 33.0 Explore P: 0.7461
# Episode: 141 Total reward: 20.0 Explore P: 0.7446
# Episode: 142 Total reward: 11.0 Explore P: 0.7438
# Episode: 143 Total reward: 16.0 Explore P: 0.7426
# Episode: 144 Total reward: 16.0 Explore P: 0.7414
# Episode: 145 Total reward: 11.0 Explore P: 0.7406
# Episode: 146 Total reward: 8.0 Explore P: 0.7400
# Episode: 147 Total reward: 13.0 Explore P: 0.7391
# Episode: 148 Total reward: 10.0 Explore P: 0.7384
# Episode: 149 Total reward: 48.0 Explore P: 0.7349
# Episode: 150 Total reward: 8.0 Explore P: 0.7343
# Episode: 151 Total reward: 16.0 Explore P: 0.7331
# Episode: 152 Total reward: 10.0 Explore P: 0.7324
# Episode: 153 Total reward: 16.0 Explore P: 0.7313
# Episode: 154 Total reward: 10.0 Explore P: 0.7305
# Episode: 155 Total reward: 22.0 Explore P: 0.7290
# Episode: 156 Total reward: 9.0 Explore P: 0.7283
# Episode: 157 Total reward: 24.0 Explore P: 0.7266
# Episode: 158 Total reward: 25.0 Explore P: 0.7248
# Episode: 159 Total reward: 17.0 Explore P: 0.7236
# Episode: 160 Total reward: 19.0 Explore P: 0.7222
# Episode: 161 Total reward: 33.0 Explore P: 0.7199
# Episode: 162 Total reward: 17.0 Explore P: 0.7187
# Episode: 163 Total reward: 69.0 Explore P: 0.7138
# Episode: 164 Total reward: 17.0 Explore P: 0.7126
# Episode: 165 Total reward: 14.0 Explore P: 0.7116
# Episode: 166 Total reward: 37.0 Explore P: 0.7090
# Episode: 167 Total reward: 15.0 Explore P: 0.7080
# Episode: 168 Total reward: 31.0 Explore P: 0.7058
# Episode: 169 Total reward: 11.0 Explore P: 0.7051
# Episode: 170 Total reward: 8.0 Explore P: 0.7045
# Episode: 171 Total reward: 14.0 Explore P: 0.7035
# Episode: 172 Total reward: 8.0 Explore P: 0.7030
# Episode: 173 Total reward: 13.0 Explore P: 0.7021
# Episode: 174 Total reward: 23.0 Explore P: 0.7005
# Episode: 175 Total reward: 12.0 Explore P: 0.6997
# Episode: 176 Total reward: 15.0 Explore P: 0.6986
# Episode: 177 Total reward: 17.0 Explore P: 0.6975
# Episode: 178 Total reward: 8.0 Explore P: 0.6969
# Episode: 179 Total reward: 17.0 Explore P: 0.6957
# Episode: 180 Total reward: 10.0 Explore P: 0.6951
# Episode: 181 Total reward: 38.0 Explore P: 0.6925
# Episode: 182 Total reward: 14.0 Explore P: 0.6915
# Episode: 183 Total reward: 12.0 Explore P: 0.6907
# Episode: 184 Total reward: 45.0 Explore P: 0.6876
# Episode: 185 Total reward: 10.0 Explore P: 0.6870
# Episode: 186 Total reward: 15.0 Explore P: 0.6859
# Episode: 187 Total reward: 32.0 Explore P: 0.6838
# Episode: 188 Total reward: 8.0 Explore P: 0.6832
# Episode: 189 Total reward: 13.0 Explore P: 0.6824
# Episode: 190 Total reward: 13.0 Explore P: 0.6815
# Episode: 191 Total reward: 15.0 Explore P: 0.6805
# Episode: 192 Total reward: 21.0 Explore P: 0.6791
# Episode: 193 Total reward: 31.0 Explore P: 0.6770
# Episode: 194 Total reward: 20.0 Explore P: 0.6757
# Episode: 195 Total reward: 17.0 Explore P: 0.6745
# Episode: 196 Total reward: 8.0 Explore P: 0.6740
# Episode: 197 Total reward: 16.0 Explore P: 0.6730
# Episode: 198 Total reward: 11.0 Explore P: 0.6722
# Episode: 199 Total reward: 12.0 Explore P: 0.6714
# Episode: 200 Total reward: 14.0 Explore P: 0.6705
# Episode: 201 Total reward: 19.0 Explore P: 0.6693
# Episode: 202 Total reward: 18.0 Explore P: 0.6681
# Episode: 203 Total reward: 38.0 Explore P: 0.6656
# Episode: 204 Total reward: 9.0 Explore P: 0.6650
# Episode: 205 Total reward: 15.0 Explore P: 0.6640
# Episode: 206 Total reward: 18.0 Explore P: 0.6628
# Episode: 207 Total reward: 43.0 Explore P: 0.6600
# Episode: 208 Total reward: 10.0 Explore P: 0.6594
# Episode: 209 Total reward: 30.0 Explore P: 0.6574
# Episode: 210 Total reward: 11.0 Explore P: 0.6567
# Episode: 211 Total reward: 10.0 Explore P: 0.6561
# Episode: 212 Total reward: 38.0 Explore P: 0.6536
# Episode: 213 Total reward: 12.0 Explore P: 0.6528
# Episode: 214 Total reward: 35.0 Explore P: 0.6506
# Episode: 215 Total reward: 13.0 Explore P: 0.6498
# Episode: 216 Total reward: 8.0 Explore P: 0.6493
# Episode: 217 Total reward: 11.0 Explore P: 0.6486
# Episode: 218 Total reward: 9.0 Explore P: 0.6480
# Episode: 219 Total reward: 13.0 Explore P: 0.6471
# Episode: 220 Total reward: 32.0 Explore P: 0.6451
# Episode: 221 Total reward: 12.0 Explore P: 0.6444
# Episode: 222 Total reward: 13.0 Explore P: 0.6435
# Episode: 223 Total reward: 26.0 Explore P: 0.6419
# Episode: 224 Total reward: 12.0 Explore P: 0.6411
# Episode: 225 Total reward: 10.0 Explore P: 0.6405
# Episode: 226 Total reward: 20.0 Explore P: 0.6392
# Episode: 227 Total reward: 14.0 Explore P: 0.6384
# Episode: 228 Total reward: 11.0 Explore P: 0.6377
# Episode: 229 Total reward: 18.0 Explore P: 0.6365
# Episode: 230 Total reward: 13.0 Explore P: 0.6357
# Episode: 231 Total reward: 13.0 Explore P: 0.6349
# Episode: 232 Total reward: 8.0 Explore P: 0.6344
# Episode: 233 Total reward: 43.0 Explore P: 0.6317
# Episode: 234 Total reward: 11.0 Explore P: 0.6310
# Episode: 235 Total reward: 11.0 Explore P: 0.6304
# Episode: 236 Total reward: 19.0 Explore P: 0.6292
# Episode: 237 Total reward: 10.0 Explore P: 0.6286
# Episode: 238 Total reward: 9.0 Explore P: 0.6280
# Episode: 239 Total reward: 12.0 Explore P: 0.6273
# Episode: 240 Total reward: 19.0 Explore P: 0.6261
# Episode: 241 Total reward: 15.0 Explore P: 0.6252
# Episode: 242 Total reward: 10.0 Explore P: 0.6246
# Episode: 243 Total reward: 10.0 Explore P: 0.6239
# Episode: 244 Total reward: 14.0 Explore P: 0.6231
# Episode: 245 Total reward: 15.0 Explore P: 0.6222
# Episode: 246 Total reward: 8.0 Explore P: 0.6217
# Episode: 247 Total reward: 17.0 Explore P: 0.6206
# Episode: 248 Total reward: 15.0 Explore P: 0.6197
# Episode: 249 Total reward: 13.0 Explore P: 0.6189
# Episode: 250 Total reward: 9.0 Explore P: 0.6184
# Episode: 251 Total reward: 11.0 Explore P: 0.6177
# Episode: 252 Total reward: 12.0 Explore P: 0.6170
# Episode: 253 Total reward: 21.0 Explore P: 0.6157
# Episode: 254 Total reward: 7.0 Explore P: 0.6153
# Episode: 255 Total reward: 14.0 Explore P: 0.6144
# Episode: 256 Total reward: 10.0 Explore P: 0.6138
# Episode: 257 Total reward: 14.0 Explore P: 0.6130
# Episode: 258 Total reward: 13.0 Explore P: 0.6122
# Episode: 259 Total reward: 11.0 Explore P: 0.6115
# Episode: 260 Total reward: 9.0 Explore P: 0.6110
# Episode: 261 Total reward: 8.0 Explore P: 0.6105
# Episode: 262 Total reward: 12.0 Explore P: 0.6098
# Episode: 263 Total reward: 23.0 Explore P: 0.6084
# Episode: 264 Total reward: 9.0 Explore P: 0.6079
# Episode: 265 Total reward: 36.0 Explore P: 0.6057
# Episode: 266 Total reward: 26.0 Explore P: 0.6042
# Episode: 267 Total reward: 25.0 Explore P: 0.6027
# Episode: 268 Total reward: 17.0 Explore P: 0.6017
# Episode: 269 Total reward: 10.0 Explore P: 0.6011
# Episode: 270 Total reward: 7.0 Explore P: 0.6007
# Episode: 271 Total reward: 11.0 Explore P: 0.6000
# Episode: 272 Total reward: 13.0 Explore P: 0.5993
# Episode: 273 Total reward: 17.0 Explore P: 0.5983
# Episode: 274 Total reward: 25.0 Explore P: 0.5968
# Episode: 275 Total reward: 13.0 Explore P: 0.5960
# Episode: 276 Total reward: 12.0 Explore P: 0.5953
# Episode: 277 Total reward: 18.0 Explore P: 0.5943
# Episode: 278 Total reward: 18.0 Explore P: 0.5932
# Episode: 279 Total reward: 9.0 Explore P: 0.5927
# Episode: 280 Total reward: 11.0 Explore P: 0.5921
# Episode: 281 Total reward: 10.0 Explore P: 0.5915
# Episode: 282 Total reward: 13.0 Explore P: 0.5907
# Episode: 283 Total reward: 13.0 Explore P: 0.5900
# Episode: 284 Total reward: 21.0 Explore P: 0.5888
# Episode: 285 Total reward: 14.0 Explore P: 0.5880
# Episode: 286 Total reward: 13.0 Explore P: 0.5872
# Episode: 287 Total reward: 10.0 Explore P: 0.5866
# Episode: 288 Total reward: 32.0 Explore P: 0.5848
# Episode: 289 Total reward: 33.0 Explore P: 0.5829
# Episode: 290 Total reward: 15.0 Explore P: 0.5820
# Episode: 291 Total reward: 12.0 Explore P: 0.5814
# Episode: 292 Total reward: 8.0 Explore P: 0.5809
# Episode: 293 Total reward: 17.0 Explore P: 0.5799
# Episode: 294 Total reward: 16.0 Explore P: 0.5790
# Episode: 295 Total reward: 17.0 Explore P: 0.5780
# Episode: 296 Total reward: 7.0 Explore P: 0.5776
# Episode: 297 Total reward: 12.0 Explore P: 0.5770
# Episode: 298 Total reward: 25.0 Explore P: 0.5756
# Episode: 299 Total reward: 11.0 Explore P: 0.5749
# Episode: 300 Total reward: 13.0 Explore P: 0.5742
# Episode: 301 Total reward: 29.0 Explore P: 0.5726
# Episode: 302 Total reward: 15.0 Explore P: 0.5717
# Episode: 303 Total reward: 11.0 Explore P: 0.5711
# Episode: 304 Total reward: 15.0 Explore P: 0.5703
# Episode: 305 Total reward: 13.0 Explore P: 0.5695
# Episode: 306 Total reward: 11.0 Explore P: 0.5689
# Episode: 307 Total reward: 23.0 Explore P: 0.5676
# Episode: 308 Total reward: 13.0 Explore P: 0.5669
# Episode: 309 Total reward: 13.0 Explore P: 0.5662
# Episode: 310 Total reward: 14.0 Explore P: 0.5654
# Episode: 311 Total reward: 25.0 Explore P: 0.5640
# Episode: 312 Total reward: 12.0 Explore P: 0.5634
# Episode: 313 Total reward: 9.0 Explore P: 0.5629
# Episode: 314 Total reward: 17.0 Explore P: 0.5619
# Episode: 315 Total reward: 19.0 Explore P: 0.5609
# Episode: 316 Total reward: 12.0 Explore P: 0.5602
# Episode: 317 Total reward: 10.0 Explore P: 0.5597
# Episode: 318 Total reward: 16.0 Explore P: 0.5588
# Episode: 319 Total reward: 22.0 Explore P: 0.5576
# Episode: 320 Total reward: 12.0 Explore P: 0.5569
# Episode: 321 Total reward: 12.0 Explore P: 0.5563
# Episode: 322 Total reward: 9.0 Explore P: 0.5558
# Episode: 323 Total reward: 11.0 Explore P: 0.5552
# Episode: 324 Total reward: 15.0 Explore P: 0.5544
# Episode: 325 Total reward: 11.0 Explore P: 0.5538
# Episode: 326 Total reward: 9.0 Explore P: 0.5533
# Episode: 327 Total reward: 11.0 Explore P: 0.5527
# Episode: 328 Total reward: 11.0 Explore P: 0.5521
# Episode: 329 Total reward: 12.0 Explore P: 0.5514
# Episode: 330 Total reward: 21.0 Explore P: 0.5503
# Episode: 331 Total reward: 11.0 Explore P: 0.5497
# Episode: 332 Total reward: 14.0 Explore P: 0.5489
# Episode: 333 Total reward: 8.0 Explore P: 0.5485
# Episode: 334 Total reward: 8.0 Explore P: 0.5481
# Episode: 335 Total reward: 9.0 Explore P: 0.5476
# Episode: 336 Total reward: 10.0 Explore P: 0.5471
# Episode: 337 Total reward: 11.0 Explore P: 0.5465
# Episode: 338 Total reward: 16.0 Explore P: 0.5456
# Episode: 339 Total reward: 22.0 Explore P: 0.5444
# Episode: 340 Total reward: 10.0 Explore P: 0.5439
# Episode: 341 Total reward: 10.0 Explore P: 0.5434
# Episode: 342 Total reward: 12.0 Explore P: 0.5427
# Episode: 343 Total reward: 13.0 Explore P: 0.5420
# Episode: 344 Total reward: 11.0 Explore P: 0.5414
# Episode: 345 Total reward: 13.0 Explore P: 0.5408
# Episode: 346 Total reward: 12.0 Explore P: 0.5401
# Episode: 347 Total reward: 16.0 Explore P: 0.5393
# Episode: 348 Total reward: 11.0 Explore P: 0.5387
# Episode: 349 Total reward: 8.0 Explore P: 0.5383
# Episode: 350 Total reward: 22.0 Explore P: 0.5371
# Episode: 351 Total reward: 28.0 Explore P: 0.5356
# Episode: 352 Total reward: 11.0 Explore P: 0.5351
# Episode: 353 Total reward: 11.0 Explore P: 0.5345
# Episode: 354 Total reward: 7.0 Explore P: 0.5341
# Episode: 355 Total reward: 14.0 Explore P: 0.5334
# Episode: 356 Total reward: 11.0 Explore P: 0.5328
# Episode: 357 Total reward: 7.0 Explore P: 0.5324
# Episode: 358 Total reward: 19.0 Explore P: 0.5314
# Episode: 359 Total reward: 42.0 Explore P: 0.5293
# Episode: 360 Total reward: 11.0 Explore P: 0.5287
# Episode: 361 Total reward: 9.0 Explore P: 0.5282
# Episode: 362 Total reward: 16.0 Explore P: 0.5274
# Episode: 363 Total reward: 7.0 Explore P: 0.5270
# Episode: 364 Total reward: 13.0 Explore P: 0.5264
# Episode: 365 Total reward: 26.0 Explore P: 0.5250
# Episode: 366 Total reward: 11.0 Explore P: 0.5245
# Episode: 367 Total reward: 10.0 Explore P: 0.5239
# Episode: 368 Total reward: 12.0 Explore P: 0.5233
# Episode: 369 Total reward: 10.0 Explore P: 0.5228
# Episode: 370 Total reward: 24.0 Explore P: 0.5216
# Episode: 371 Total reward: 11.0 Explore P: 0.5210
# Episode: 372 Total reward: 9.0 Explore P: 0.5206
# Episode: 373 Total reward: 11.0 Explore P: 0.5200
# Episode: 374 Total reward: 11.0 Explore P: 0.5194
# Episode: 375 Total reward: 15.0 Explore P: 0.5187
# Episode: 376 Total reward: 16.0 Explore P: 0.5179
# Episode: 377 Total reward: 21.0 Explore P: 0.5168
# Episode: 378 Total reward: 34.0 Explore P: 0.5151
# Episode: 379 Total reward: 12.0 Explore P: 0.5145
# Episode: 380 Total reward: 12.0 Explore P: 0.5139
# Episode: 381 Total reward: 9.0 Explore P: 0.5134
# Episode: 382 Total reward: 10.0 Explore P: 0.5129
# Episode: 383 Total reward: 13.0 Explore P: 0.5123
# Episode: 384 Total reward: 13.0 Explore P: 0.5116
# Episode: 385 Total reward: 12.0 Explore P: 0.5110
# Episode: 386 Total reward: 12.0 Explore P: 0.5104
# Episode: 387 Total reward: 12.0 Explore P: 0.5098
# Episode: 388 Total reward: 14.0 Explore P: 0.5091
# Episode: 389 Total reward: 16.0 Explore P: 0.5083
# Episode: 390 Total reward: 18.0 Explore P: 0.5074
# Episode: 391 Total reward: 17.0 Explore P: 0.5066
# Episode: 392 Total reward: 13.0 Explore P: 0.5059
# Episode: 393 Total reward: 12.0 Explore P: 0.5053
# Episode: 394 Total reward: 28.0 Explore P: 0.5039
# Episode: 395 Total reward: 9.0 Explore P: 0.5035
# Episode: 396 Total reward: 19.0 Explore P: 0.5026
# Episode: 397 Total reward: 10.0 Explore P: 0.5021
# Episode: 398 Total reward: 10.0 Explore P: 0.5016
# Episode: 399 Total reward: 8.0 Explore P: 0.5012
# Episode: 400 Total reward: 15.0 Explore P: 0.5004
# Episode: 401 Total reward: 19.0 Explore P: 0.4995
# Episode: 402 Total reward: 11.0 Explore P: 0.4990
# Episode: 403 Total reward: 14.0 Explore P: 0.4983
# Episode: 404 Total reward: 10.0 Explore P: 0.4978
# Episode: 405 Total reward: 14.0 Explore P: 0.4971
# Episode: 406 Total reward: 9.0 Explore P: 0.4967
# Episode: 407 Total reward: 10.0 Explore P: 0.4962
# Episode: 408 Total reward: 11.0 Explore P: 0.4957
# Episode: 409 Total reward: 13.0 Explore P: 0.4950
# Episode: 410 Total reward: 12.0 Explore P: 0.4944
# Episode: 411 Total reward: 14.0 Explore P: 0.4938
# Episode: 412 Total reward: 18.0 Explore P: 0.4929
# Episode: 413 Total reward: 13.0 Explore P: 0.4923
# Episode: 414 Total reward: 21.0 Explore P: 0.4913
# Episode: 415 Total reward: 12.0 Explore P: 0.4907
# Episode: 416 Total reward: 10.0 Explore P: 0.4902
# Episode: 417 Total reward: 19.0 Explore P: 0.4893
# Episode: 418 Total reward: 10.0 Explore P: 0.4888
# Episode: 419 Total reward: 9.0 Explore P: 0.4884
# Episode: 420 Total reward: 8.0 Explore P: 0.4880
# Episode: 421 Total reward: 16.0 Explore P: 0.4872
# Episode: 422 Total reward: 18.0 Explore P: 0.4864
# Episode: 423 Total reward: 14.0 Explore P: 0.4857
# Episode: 424 Total reward: 16.0 Explore P: 0.4849
# Episode: 425 Total reward: 8.0 Explore P: 0.4846
# Episode: 426 Total reward: 13.0 Explore P: 0.4840
# Episode: 427 Total reward: 16.0 Explore P: 0.4832
# Episode: 428 Total reward: 11.0 Explore P: 0.4827
# Episode: 429 Total reward: 18.0 Explore P: 0.4818
# Episode: 430 Total reward: 14.0 Explore P: 0.4812
# Episode: 431 Total reward: 11.0 Explore P: 0.4806
# Episode: 432 Total reward: 18.0 Explore P: 0.4798
# Episode: 433 Total reward: 9.0 Explore P: 0.4794
# Episode: 434 Total reward: 21.0 Explore P: 0.4784
# Episode: 435 Total reward: 16.0 Explore P: 0.4776
# Episode: 436 Total reward: 8.0 Explore P: 0.4773
# Episode: 437 Total reward: 17.0 Explore P: 0.4765
# Episode: 438 Total reward: 15.0 Explore P: 0.4758
# Episode: 439 Total reward: 14.0 Explore P: 0.4751
# Episode: 440 Total reward: 13.0 Explore P: 0.4745
# Episode: 441 Total reward: 9.0 Explore P: 0.4741
# Episode: 442 Total reward: 10.0 Explore P: 0.4736
# Episode: 443 Total reward: 8.0 Explore P: 0.4733
# Episode: 444 Total reward: 11.0 Explore P: 0.4728
# Episode: 445 Total reward: 16.0 Explore P: 0.4720
# Episode: 446 Total reward: 14.0 Explore P: 0.4714
# Episode: 447 Total reward: 12.0 Explore P: 0.4708
# Episode: 448 Total reward: 10.0 Explore P: 0.4704
# Episode: 449 Total reward: 15.0 Explore P: 0.4697
# Episode: 450 Total reward: 14.0 Explore P: 0.4690
# Episode: 451 Total reward: 9.0 Explore P: 0.4686
# Episode: 452 Total reward: 8.0 Explore P: 0.4682
# Episode: 453 Total reward: 10.0 Explore P: 0.4678
# Episode: 454 Total reward: 11.0 Explore P: 0.4673
# Episode: 455 Total reward: 14.0 Explore P: 0.4666
# Episode: 456 Total reward: 10.0 Explore P: 0.4662
# Episode: 457 Total reward: 11.0 Explore P: 0.4657
# Episode: 458 Total reward: 40.0 Explore P: 0.4639
# Episode: 459 Total reward: 7.0 Explore P: 0.4635
# Episode: 460 Total reward: 9.0 Explore P: 0.4631
# Episode: 461 Total reward: 12.0 Explore P: 0.4626
# Episode: 462 Total reward: 21.0 Explore P: 0.4616
# Episode: 463 Total reward: 12.0 Explore P: 0.4611
# Episode: 464 Total reward: 14.0 Explore P: 0.4605
# Episode: 465 Total reward: 9.0 Explore P: 0.4601
# Episode: 466 Total reward: 18.0 Explore P: 0.4593
# Episode: 467 Total reward: 19.0 Explore P: 0.4584
# Episode: 468 Total reward: 12.0 Explore P: 0.4579
# Episode: 469 Total reward: 15.0 Explore P: 0.4572
# Episode: 470 Total reward: 17.0 Explore P: 0.4564
# Episode: 471 Total reward: 9.0 Explore P: 0.4560
# Episode: 472 Total reward: 10.0 Explore P: 0.4556
# Episode: 473 Total reward: 14.0 Explore P: 0.4550
# Episode: 474 Total reward: 12.0 Explore P: 0.4544
# Episode: 475 Total reward: 26.0 Explore P: 0.4533
# Episode: 476 Total reward: 9.0 Explore P: 0.4529
# Episode: 477 Total reward: 11.0 Explore P: 0.4524
# Episode: 478 Total reward: 13.0 Explore P: 0.4518
# Episode: 479 Total reward: 17.0 Explore P: 0.4511
# Episode: 480 Total reward: 12.0 Explore P: 0.4505
# Episode: 481 Total reward: 12.0 Explore P: 0.4500
# Episode: 482 Total reward: 18.0 Explore P: 0.4492
# Episode: 483 Total reward: 14.0 Explore P: 0.4486
# Episode: 484 Total reward: 12.0 Explore P: 0.4481
# Episode: 485 Total reward: 14.0 Explore P: 0.4475
# Episode: 486 Total reward: 28.0 Explore P: 0.4462
# Episode: 487 Total reward: 10.0 Explore P: 0.4458
# Episode: 488 Total reward: 14.0 Explore P: 0.4452
# Episode: 489 Total reward: 25.0 Explore P: 0.4441
# Episode: 490 Total reward: 9.0 Explore P: 0.4437
# Episode: 491 Total reward: 13.0 Explore P: 0.4432
# Episode: 492 Total reward: 10.0 Explore P: 0.4427
# Episode: 493 Total reward: 11.0 Explore P: 0.4423
# Episode: 494 Total reward: 10.0 Explore P: 0.4418
# Episode: 495 Total reward: 12.0 Explore P: 0.4413
# Episode: 496 Total reward: 15.0 Explore P: 0.4407
# Episode: 497 Total reward: 13.0 Explore P: 0.4401
# Episode: 498 Total reward: 13.0 Explore P: 0.4395
# Episode: 499 Total reward: 13.0 Explore P: 0.4390
# Episode: 500 Total reward: 11.0 Explore P: 0.4385
# Episode: 501 Total reward: 12.0 Explore P: 0.4380
# Episode: 502 Total reward: 10.0 Explore P: 0.4376
# Episode: 503 Total reward: 9.0 Explore P: 0.4372
# Episode: 504 Total reward: 14.0 Explore P: 0.4366
# Episode: 505 Total reward: 11.0 Explore P: 0.4361
# Episode: 506 Total reward: 8.0 Explore P: 0.4358
# Episode: 507 Total reward: 19.0 Explore P: 0.4350
# Episode: 508 Total reward: 14.0 Explore P: 0.4344
# Episode: 509 Total reward: 11.0 Explore P: 0.4339
# Episode: 510 Total reward: 10.0 Explore P: 0.4335
# Episode: 511 Total reward: 10.0 Explore P: 0.4331
# Episode: 512 Total reward: 28.0 Explore P: 0.4319
# Episode: 513 Total reward: 9.0 Explore P: 0.4315
# Episode: 514 Total reward: 11.0 Explore P: 0.4310
# Episode: 515 Total reward: 15.0 Explore P: 0.4304
# Episode: 516 Total reward: 16.0 Explore P: 0.4297
# Episode: 517 Total reward: 10.0 Explore P: 0.4293
# Episode: 518 Total reward: 9.0 Explore P: 0.4289
# Episode: 519 Total reward: 8.0 Explore P: 0.4286
# Episode: 520 Total reward: 21.0 Explore P: 0.4277
# Episode: 521 Total reward: 10.0 Explore P: 0.4273
# Episode: 522 Total reward: 13.0 Explore P: 0.4268
# Episode: 523 Total reward: 13.0 Explore P: 0.4262
# Episode: 524 Total reward: 17.0 Explore P: 0.4255
# Episode: 525 Total reward: 10.0 Explore P: 0.4251
# Episode: 526 Total reward: 20.0 Explore P: 0.4243
# Episode: 527 Total reward: 14.0 Explore P: 0.4237
# Episode: 528 Total reward: 10.0 Explore P: 0.4233
# Episode: 529 Total reward: 11.0 Explore P: 0.4228
# Episode: 530 Total reward: 8.0 Explore P: 0.4225
# Episode: 531 Total reward: 12.0 Explore P: 0.4220
# Episode: 532 Total reward: 12.0 Explore P: 0.4215
# Episode: 533 Total reward: 18.0 Explore P: 0.4208
# Episode: 534 Total reward: 9.0 Explore P: 0.4204
# Episode: 535 Total reward: 15.0 Explore P: 0.4198
# Episode: 536 Total reward: 13.0 Explore P: 0.4192
# Episode: 537 Total reward: 8.0 Explore P: 0.4189
# Episode: 538 Total reward: 11.0 Explore P: 0.4185
# Episode: 539 Total reward: 11.0 Explore P: 0.4180
# Episode: 540 Total reward: 18.0 Explore P: 0.4173
# Episode: 541 Total reward: 11.0 Explore P: 0.4168
# Episode: 542 Total reward: 15.0 Explore P: 0.4162
# Episode: 543 Total reward: 15.0 Explore P: 0.4156
# Episode: 544 Total reward: 10.0 Explore P: 0.4152
# Episode: 545 Total reward: 11.0 Explore P: 0.4148
# Episode: 546 Total reward: 32.0 Explore P: 0.4135
# Episode: 547 Total reward: 17.0 Explore P: 0.4128
# Episode: 548 Total reward: 14.0 Explore P: 0.4122
# Episode: 549 Total reward: 8.0 Explore P: 0.4119
# Episode: 550 Total reward: 14.0 Explore P: 0.4113
# Episode: 551 Total reward: 11.0 Explore P: 0.4109
# Episode: 552 Total reward: 11.0 Explore P: 0.4105
# Episode: 553 Total reward: 12.0 Explore P: 0.4100
# Episode: 554 Total reward: 16.0 Explore P: 0.4093
# Episode: 555 Total reward: 14.0 Explore P: 0.4088
# Episode: 556 Total reward: 7.0 Explore P: 0.4085
# Episode: 557 Total reward: 15.0 Explore P: 0.4079
# Episode: 558 Total reward: 10.0 Explore P: 0.4075
# Episode: 559 Total reward: 12.0 Explore P: 0.4070
# Episode: 560 Total reward: 12.0 Explore P: 0.4066
# Episode: 561 Total reward: 10.0 Explore P: 0.4062
# Episode: 562 Total reward: 13.0 Explore P: 0.4056
# Episode: 563 Total reward: 11.0 Explore P: 0.4052
# Episode: 564 Total reward: 8.0 Explore P: 0.4049
# Episode: 565 Total reward: 12.0 Explore P: 0.4044
# Episode: 566 Total reward: 13.0 Explore P: 0.4039
# Episode: 567 Total reward: 9.0 Explore P: 0.4035
# Episode: 568 Total reward: 11.0 Explore P: 0.4031
# Episode: 569 Total reward: 19.0 Explore P: 0.4024
# Episode: 570 Total reward: 14.0 Explore P: 0.4018
# Episode: 571 Total reward: 11.0 Explore P: 0.4014
# Episode: 572 Total reward: 8.0 Explore P: 0.4011
# Episode: 573 Total reward: 9.0 Explore P: 0.4007
# Episode: 574 Total reward: 8.0 Explore P: 0.4004
# Episode: 575 Total reward: 14.0 Explore P: 0.3999
# Episode: 576 Total reward: 13.0 Explore P: 0.3994
# Episode: 577 Total reward: 15.0 Explore P: 0.3988
# Episode: 578 Total reward: 10.0 Explore P: 0.3984
# Episode: 579 Total reward: 9.0 Explore P: 0.3980
# Episode: 580 Total reward: 8.0 Explore P: 0.3977
# Episode: 581 Total reward: 8.0 Explore P: 0.3974
# Episode: 582 Total reward: 11.0 Explore P: 0.3970
# Episode: 583 Total reward: 14.0 Explore P: 0.3965
# Episode: 584 Total reward: 13.0 Explore P: 0.3959
# Episode: 585 Total reward: 19.0 Explore P: 0.3952
# Episode: 586 Total reward: 9.0 Explore P: 0.3949
# Episode: 587 Total reward: 9.0 Explore P: 0.3945
# Episode: 588 Total reward: 8.0 Explore P: 0.3942
# Episode: 589 Total reward: 9.0 Explore P: 0.3939
# Episode: 590 Total reward: 13.0 Explore P: 0.3934
# Episode: 591 Total reward: 25.0 Explore P: 0.3924
# Episode: 592 Total reward: 9.0 Explore P: 0.3921
# Episode: 593 Total reward: 12.0 Explore P: 0.3916
# Episode: 594 Total reward: 12.0 Explore P: 0.3912
# Episode: 595 Total reward: 13.0 Explore P: 0.3907
# Episode: 596 Total reward: 15.0 Explore P: 0.3901
# Episode: 597 Total reward: 11.0 Explore P: 0.3897
# Episode: 598 Total reward: 16.0 Explore P: 0.3891
# Episode: 599 Total reward: 11.0 Explore P: 0.3886
# Episode: 600 Total reward: 12.0 Explore P: 0.3882
# Episode: 601 Total reward: 13.0 Explore P: 0.3877
# Episode: 602 Total reward: 12.0 Explore P: 0.3872
# Episode: 603 Total reward: 9.0 Explore P: 0.3869
# Episode: 604 Total reward: 8.0 Explore P: 0.3866
# Episode: 605 Total reward: 11.0 Explore P: 0.3862
# Episode: 606 Total reward: 9.0 Explore P: 0.3859
# Episode: 607 Total reward: 11.0 Explore P: 0.3854
# Episode: 608 Total reward: 10.0 Explore P: 0.3851
# Episode: 609 Total reward: 10.0 Explore P: 0.3847
# Episode: 610 Total reward: 11.0 Explore P: 0.3843
# Episode: 611 Total reward: 9.0 Explore P: 0.3839
# Episode: 612 Total reward: 8.0 Explore P: 0.3836
# Episode: 613 Total reward: 11.0 Explore P: 0.3832
# Episode: 614 Total reward: 13.0 Explore P: 0.3827
# Episode: 615 Total reward: 12.0 Explore P: 0.3823
# Episode: 616 Total reward: 14.0 Explore P: 0.3818
# Episode: 617 Total reward: 13.0 Explore P: 0.3813
# Episode: 618 Total reward: 12.0 Explore P: 0.3809
# Episode: 619 Total reward: 10.0 Explore P: 0.3805
# Episode: 620 Total reward: 12.0 Explore P: 0.3800
# Episode: 621 Total reward: 10.0 Explore P: 0.3797
# Episode: 622 Total reward: 8.0 Explore P: 0.3794
# Episode: 623 Total reward: 12.0 Explore P: 0.3789
# Episode: 624 Total reward: 10.0 Explore P: 0.3786
# Episode: 625 Total reward: 7.0 Explore P: 0.3783
# Episode: 626 Total reward: 8.0 Explore P: 0.3780
# Episode: 627 Total reward: 9.0 Explore P: 0.3777
# Episode: 628 Total reward: 17.0 Explore P: 0.3771
# Episode: 629 Total reward: 12.0 Explore P: 0.3766
# Episode: 630 Total reward: 9.0 Explore P: 0.3763
# Episode: 631 Total reward: 9.0 Explore P: 0.3760
# Episode: 632 Total reward: 21.0 Explore P: 0.3752
# Episode: 633 Total reward: 9.0 Explore P: 0.3749
# Episode: 634 Total reward: 10.0 Explore P: 0.3745
# Episode: 635 Total reward: 12.0 Explore P: 0.3741
# Episode: 636 Total reward: 17.0 Explore P: 0.3734
# Episode: 637 Total reward: 11.0 Explore P: 0.3730
# Episode: 638 Total reward: 12.0 Explore P: 0.3726
# Episode: 639 Total reward: 15.0 Explore P: 0.3721
# Episode: 640 Total reward: 12.0 Explore P: 0.3716
# Episode: 641 Total reward: 13.0 Explore P: 0.3712
# Episode: 642 Total reward: 11.0 Explore P: 0.3708
# Episode: 643 Total reward: 28.0 Explore P: 0.3697
# Episode: 644 Total reward: 9.0 Explore P: 0.3694
# Episode: 645 Total reward: 10.0 Explore P: 0.3691
# Episode: 646 Total reward: 12.0 Explore P: 0.3686
# Episode: 647 Total reward: 10.0 Explore P: 0.3683
# Episode: 648 Total reward: 7.0 Explore P: 0.3680
# Episode: 649 Total reward: 17.0 Explore P: 0.3674
# Episode: 650 Total reward: 19.0 Explore P: 0.3667
# Episode: 651 Total reward: 15.0 Explore P: 0.3662
# Episode: 652 Total reward: 16.0 Explore P: 0.3656
# Episode: 653 Total reward: 14.0 Explore P: 0.3651
# Episode: 654 Total reward: 12.0 Explore P: 0.3647
# Episode: 655 Total reward: 9.0 Explore P: 0.3644
# Episode: 656 Total reward: 13.0 Explore P: 0.3639
# Episode: 657 Total reward: 12.0 Explore P: 0.3635
# Episode: 658 Total reward: 14.0 Explore P: 0.3630
# Episode: 659 Total reward: 9.0 Explore P: 0.3627
# Episode: 660 Total reward: 7.0 Explore P: 0.3624
# Episode: 661 Total reward: 9.0 Explore P: 0.3621
# Episode: 662 Total reward: 14.0 Explore P: 0.3616
# Episode: 663 Total reward: 11.0 Explore P: 0.3613
# Episode: 664 Total reward: 14.0 Explore P: 0.3608
# Episode: 665 Total reward: 11.0 Explore P: 0.3604
# Episode: 666 Total reward: 11.0 Explore P: 0.3600
# Episode: 667 Total reward: 13.0 Explore P: 0.3595
# Episode: 668 Total reward: 11.0 Explore P: 0.3592
# Episode: 669 Total reward: 14.0 Explore P: 0.3587
# Episode: 670 Total reward: 12.0 Explore P: 0.3582
# Episode: 671 Total reward: 18.0 Explore P: 0.3576
# Episode: 672 Total reward: 12.0 Explore P: 0.3572
# Episode: 673 Total reward: 9.0 Explore P: 0.3569
# Episode: 674 Total reward: 17.0 Explore P: 0.3563
# Episode: 675 Total reward: 16.0 Explore P: 0.3557
# Episode: 676 Total reward: 17.0 Explore P: 0.3552
# Episode: 677 Total reward: 15.0 Explore P: 0.3546
# Episode: 678 Total reward: 16.0 Explore P: 0.3541
# Episode: 679 Total reward: 10.0 Explore P: 0.3537
# Episode: 680 Total reward: 10.0 Explore P: 0.3534
# Episode: 681 Total reward: 11.0 Explore P: 0.3530
# Episode: 682 Total reward: 10.0 Explore P: 0.3527
# Episode: 683 Total reward: 12.0 Explore P: 0.3523
# Episode: 684 Total reward: 10.0 Explore P: 0.3519
# Episode: 685 Total reward: 12.0 Explore P: 0.3515
# Episode: 686 Total reward: 9.0 Explore P: 0.3512
# Episode: 687 Total reward: 12.0 Explore P: 0.3508
# Episode: 688 Total reward: 11.0 Explore P: 0.3504
# Episode: 689 Total reward: 12.0 Explore P: 0.3500
# Episode: 690 Total reward: 12.0 Explore P: 0.3496
# Episode: 691 Total reward: 8.0 Explore P: 0.3493
# Episode: 692 Total reward: 9.0 Explore P: 0.3490
# Episode: 693 Total reward: 9.0 Explore P: 0.3487
# Episode: 694 Total reward: 11.0 Explore P: 0.3484
# Episode: 695 Total reward: 9.0 Explore P: 0.3481
# Episode: 696 Total reward: 18.0 Explore P: 0.3474
# Episode: 697 Total reward: 10.0 Explore P: 0.3471
# Episode: 698 Total reward: 14.0 Explore P: 0.3466
# Episode: 699 Total reward: 13.0 Explore P: 0.3462
# Episode: 700 Total reward: 12.0 Explore P: 0.3458
# Episode: 701 Total reward: 11.0 Explore P: 0.3454
# Episode: 702 Total reward: 14.0 Explore P: 0.3450
# Episode: 703 Total reward: 13.0 Explore P: 0.3445
# Episode: 704 Total reward: 12.0 Explore P: 0.3441
# Episode: 705 Total reward: 9.0 Explore P: 0.3438
# Episode: 706 Total reward: 9.0 Explore P: 0.3435
# Episode: 707 Total reward: 14.0 Explore P: 0.3431
# Episode: 708 Total reward: 10.0 Explore P: 0.3427
# Episode: 709 Total reward: 11.0 Explore P: 0.3424
# Episode: 710 Total reward: 10.0 Explore P: 0.3420
# Episode: 711 Total reward: 12.0 Explore P: 0.3416
# Episode: 712 Total reward: 8.0 Explore P: 0.3414
# Episode: 713 Total reward: 12.0 Explore P: 0.3410
# Episode: 714 Total reward: 8.0 Explore P: 0.3407
# Episode: 715 Total reward: 8.0 Explore P: 0.3404
# Episode: 716 Total reward: 8.0 Explore P: 0.3402
# Episode: 717 Total reward: 18.0 Explore P: 0.3396
# Episode: 718 Total reward: 8.0 Explore P: 0.3393
# Episode: 719 Total reward: 17.0 Explore P: 0.3388
# Episode: 720 Total reward: 14.0 Explore P: 0.3383
# Episode: 721 Total reward: 13.0 Explore P: 0.3379
# Episode: 722 Total reward: 9.0 Explore P: 0.3376
# Episode: 723 Total reward: 12.0 Explore P: 0.3372
# Episode: 724 Total reward: 10.0 Explore P: 0.3369
# Episode: 725 Total reward: 10.0 Explore P: 0.3365
# Episode: 726 Total reward: 13.0 Explore P: 0.3361
# Episode: 727 Total reward: 24.0 Explore P: 0.3353
# Episode: 728 Total reward: 8.0 Explore P: 0.3351
# Episode: 729 Total reward: 11.0 Explore P: 0.3347
# Episode: 730 Total reward: 9.0 Explore P: 0.3344
# Episode: 731 Total reward: 12.0 Explore P: 0.3340
# Episode: 732 Total reward: 12.0 Explore P: 0.3336
# Episode: 733 Total reward: 11.0 Explore P: 0.3333
# Episode: 734 Total reward: 16.0 Explore P: 0.3328
# Episode: 735 Total reward: 9.0 Explore P: 0.3325
# Episode: 736 Total reward: 13.0 Explore P: 0.3320
# Episode: 737 Total reward: 7.0 Explore P: 0.3318
# Episode: 738 Total reward: 7.0 Explore P: 0.3316
# Episode: 739 Total reward: 14.0 Explore P: 0.3311
# Episode: 740 Total reward: 10.0 Explore P: 0.3308
# Episode: 741 Total reward: 10.0 Explore P: 0.3305
# Episode: 742 Total reward: 14.0 Explore P: 0.3301
# Episode: 743 Total reward: 14.0 Explore P: 0.3296
# Episode: 744 Total reward: 10.0 Explore P: 0.3293
# Episode: 745 Total reward: 18.0 Explore P: 0.3287
# Episode: 746 Total reward: 14.0 Explore P: 0.3283
# Episode: 747 Total reward: 10.0 Explore P: 0.3280
# Episode: 748 Total reward: 16.0 Explore P: 0.3274
# Episode: 749 Total reward: 8.0 Explore P: 0.3272
# Episode: 750 Total reward: 9.0 Explore P: 0.3269
# Episode: 751 Total reward: 12.0 Explore P: 0.3265
# Episode: 752 Total reward: 17.0 Explore P: 0.3260
# Episode: 753 Total reward: 12.0 Explore P: 0.3256
# Episode: 754 Total reward: 9.0 Explore P: 0.3253
# Episode: 755 Total reward: 12.0 Explore P: 0.3249
# Episode: 756 Total reward: 10.0 Explore P: 0.3246
# Episode: 757 Total reward: 16.0 Explore P: 0.3241
# Episode: 758 Total reward: 17.0 Explore P: 0.3236
# Episode: 759 Total reward: 9.0 Explore P: 0.3233
# Episode: 760 Total reward: 7.0 Explore P: 0.3231
# Episode: 761 Total reward: 13.0 Explore P: 0.3227
# Episode: 762 Total reward: 12.0 Explore P: 0.3223
# Episode: 763 Total reward: 9.0 Explore P: 0.3220
# Episode: 764 Total reward: 10.0 Explore P: 0.3217
# Episode: 765 Total reward: 10.0 Explore P: 0.3214
# Episode: 766 Total reward: 9.0 Explore P: 0.3211
# Episode: 767 Total reward: 11.0 Explore P: 0.3208
# Episode: 768 Total reward: 15.0 Explore P: 0.3203
# Episode: 769 Total reward: 9.0 Explore P: 0.3200
# Episode: 770 Total reward: 12.0 Explore P: 0.3197
# Episode: 771 Total reward: 9.0 Explore P: 0.3194
# Episode: 772 Total reward: 11.0 Explore P: 0.3191
# Episode: 773 Total reward: 15.0 Explore P: 0.3186
# Episode: 774 Total reward: 9.0 Explore P: 0.3183
# Episode: 775 Total reward: 9.0 Explore P: 0.3180
# Episode: 776 Total reward: 10.0 Explore P: 0.3177
# Episode: 777 Total reward: 12.0 Explore P: 0.3174
# Episode: 778 Total reward: 12.0 Explore P: 0.3170
# Episode: 779 Total reward: 9.0 Explore P: 0.3167
# Episode: 780 Total reward: 8.0 Explore P: 0.3165
# Episode: 781 Total reward: 9.0 Explore P: 0.3162
# Episode: 782 Total reward: 9.0 Explore P: 0.3159
# Episode: 783 Total reward: 8.0 Explore P: 0.3157
# Episode: 784 Total reward: 11.0 Explore P: 0.3153
# Episode: 785 Total reward: 13.0 Explore P: 0.3149
# Episode: 786 Total reward: 15.0 Explore P: 0.3145
# Episode: 787 Total reward: 10.0 Explore P: 0.3142
# Episode: 788 Total reward: 12.0 Explore P: 0.3138
# Episode: 789 Total reward: 9.0 Explore P: 0.3135
# Episode: 790 Total reward: 16.0 Explore P: 0.3131
# Episode: 791 Total reward: 10.0 Explore P: 0.3127
# Episode: 792 Total reward: 10.0 Explore P: 0.3124
# Episode: 793 Total reward: 14.0 Explore P: 0.3120
# Episode: 794 Total reward: 7.0 Explore P: 0.3118
# Episode: 795 Total reward: 13.0 Explore P: 0.3114
# Episode: 796 Total reward: 8.0 Explore P: 0.3112
# Episode: 797 Total reward: 10.0 Explore P: 0.3109
# Episode: 798 Total reward: 10.0 Explore P: 0.3106
# Episode: 799 Total reward: 8.0 Explore P: 0.3103
# Episode: 800 Total reward: 13.0 Explore P: 0.3099
# Episode: 801 Total reward: 15.0 Explore P: 0.3095
# Episode: 802 Total reward: 16.0 Explore P: 0.3090
# Episode: 803 Total reward: 8.0 Explore P: 0.3088
# Episode: 804 Total reward: 12.0 Explore P: 0.3084
# Episode: 805 Total reward: 9.0 Explore P: 0.3082
# Episode: 806 Total reward: 12.0 Explore P: 0.3078
# Episode: 807 Total reward: 9.0 Explore P: 0.3075
# Episode: 808 Total reward: 8.0 Explore P: 0.3073
# Episode: 809 Total reward: 10.0 Explore P: 0.3070
# Episode: 810 Total reward: 11.0 Explore P: 0.3067
# Episode: 811 Total reward: 18.0 Explore P: 0.3061
# Episode: 812 Total reward: 11.0 Explore P: 0.3058
# Episode: 813 Total reward: 9.0 Explore P: 0.3055
# Episode: 814 Total reward: 14.0 Explore P: 0.3051
# Episode: 815 Total reward: 8.0 Explore P: 0.3049
# Episode: 816 Total reward: 9.0 Explore P: 0.3046
# Episode: 817 Total reward: 13.0 Explore P: 0.3042
# Episode: 818 Total reward: 9.0 Explore P: 0.3040
# Episode: 819 Total reward: 14.0 Explore P: 0.3036
# Episode: 820 Total reward: 11.0 Explore P: 0.3032
# Episode: 821 Total reward: 14.0 Explore P: 0.3028
# Episode: 822 Total reward: 10.0 Explore P: 0.3025
# Episode: 823 Total reward: 12.0 Explore P: 0.3022
# Episode: 824 Total reward: 10.0 Explore P: 0.3019
# Episode: 825 Total reward: 24.0 Explore P: 0.3012
# Episode: 826 Total reward: 7.0 Explore P: 0.3010
# Episode: 827 Total reward: 15.0 Explore P: 0.3006
# Episode: 828 Total reward: 9.0 Explore P: 0.3003
# Episode: 829 Total reward: 11.0 Explore P: 0.3000
# Episode: 830 Total reward: 10.0 Explore P: 0.2997
# Episode: 831 Total reward: 12.0 Explore P: 0.2993
# Episode: 832 Total reward: 8.0 Explore P: 0.2991
# Episode: 833 Total reward: 13.0 Explore P: 0.2987
# Episode: 834 Total reward: 8.0 Explore P: 0.2985
# Episode: 835 Total reward: 9.0 Explore P: 0.2982
# Episode: 836 Total reward: 10.0 Explore P: 0.2980
# Episode: 837 Total reward: 9.0 Explore P: 0.2977
# Episode: 838 Total reward: 12.0 Explore P: 0.2974
# Episode: 839 Total reward: 12.0 Explore P: 0.2970
# Episode: 840 Total reward: 11.0 Explore P: 0.2967
# Episode: 841 Total reward: 9.0 Explore P: 0.2964
# Episode: 842 Total reward: 12.0 Explore P: 0.2961
# Episode: 843 Total reward: 16.0 Explore P: 0.2956
# Episode: 844 Total reward: 17.0 Explore P: 0.2951
# Episode: 845 Total reward: 12.0 Explore P: 0.2948
# Episode: 846 Total reward: 13.0 Explore P: 0.2944
# Episode: 847 Total reward: 7.0 Explore P: 0.2942
# Episode: 848 Total reward: 14.0 Explore P: 0.2938
# Episode: 849 Total reward: 11.0 Explore P: 0.2935
# Episode: 850 Total reward: 8.0 Explore P: 0.2933
# Episode: 851 Total reward: 14.0 Explore P: 0.2929
# Episode: 852 Total reward: 8.0 Explore P: 0.2927
# Episode: 853 Total reward: 8.0 Explore P: 0.2925
# Episode: 854 Total reward: 8.0 Explore P: 0.2922
# Episode: 855 Total reward: 8.0 Explore P: 0.2920
# Episode: 856 Total reward: 8.0 Explore P: 0.2918
# Episode: 857 Total reward: 9.0 Explore P: 0.2915
# Episode: 858 Total reward: 13.0 Explore P: 0.2912
# Episode: 859 Total reward: 12.0 Explore P: 0.2908
# Episode: 860 Total reward: 13.0 Explore P: 0.2905
# Episode: 861 Total reward: 15.0 Explore P: 0.2900
# Episode: 862 Total reward: 13.0 Explore P: 0.2897
# Episode: 863 Total reward: 11.0 Explore P: 0.2894
# Episode: 864 Total reward: 11.0 Explore P: 0.2891
# Episode: 865 Total reward: 8.0 Explore P: 0.2888
# Episode: 866 Total reward: 13.0 Explore P: 0.2885
# Episode: 867 Total reward: 14.0 Explore P: 0.2881
# Episode: 868 Total reward: 7.0 Explore P: 0.2879
# Episode: 869 Total reward: 9.0 Explore P: 0.2876
# Episode: 870 Total reward: 11.0 Explore P: 0.2873
# Episode: 871 Total reward: 14.0 Explore P: 0.2869
# Episode: 872 Total reward: 9.0 Explore P: 0.2867
# Episode: 873 Total reward: 11.0 Explore P: 0.2864
# Episode: 874 Total reward: 11.0 Explore P: 0.2861
# Episode: 875 Total reward: 20.0 Explore P: 0.2855
# Episode: 876 Total reward: 11.0 Explore P: 0.2852
# Episode: 877 Total reward: 11.0 Explore P: 0.2849
# Episode: 878 Total reward: 16.0 Explore P: 0.2845
# Episode: 879 Total reward: 9.0 Explore P: 0.2842
# Episode: 880 Total reward: 17.0 Explore P: 0.2838
# Episode: 881 Total reward: 8.0 Explore P: 0.2836
# Episode: 882 Total reward: 8.0 Explore P: 0.2833
# Episode: 883 Total reward: 16.0 Explore P: 0.2829
# Episode: 884 Total reward: 12.0 Explore P: 0.2826
# Episode: 885 Total reward: 10.0 Explore P: 0.2823
# Episode: 886 Total reward: 10.0 Explore P: 0.2820
# Episode: 887 Total reward: 13.0 Explore P: 0.2817
# Episode: 888 Total reward: 8.0 Explore P: 0.2815
# Episode: 889 Total reward: 10.0 Explore P: 0.2812
# Episode: 890 Total reward: 10.0 Explore P: 0.2809
# Episode: 891 Total reward: 11.0 Explore P: 0.2806
# Episode: 892 Total reward: 13.0 Explore P: 0.2803
# Episode: 893 Total reward: 9.0 Explore P: 0.2800
# Episode: 894 Total reward: 10.0 Explore P: 0.2798
# Episode: 895 Total reward: 12.0 Explore P: 0.2794
# Episode: 896 Total reward: 11.0 Explore P: 0.2791
# Episode: 897 Total reward: 11.0 Explore P: 0.2788
# Episode: 898 Total reward: 10.0 Explore P: 0.2786
# Episode: 899 Total reward: 11.0 Explore P: 0.2783
# Episode: 900 Total reward: 7.0 Explore P: 0.2781
# Episode: 901 Total reward: 15.0 Explore P: 0.2777
# Episode: 902 Total reward: 12.0 Explore P: 0.2774
# Episode: 903 Total reward: 11.0 Explore P: 0.2771
# Episode: 904 Total reward: 10.0 Explore P: 0.2768
# Episode: 905 Total reward: 9.0 Explore P: 0.2766
# Episode: 906 Total reward: 10.0 Explore P: 0.2763
# Episode: 907 Total reward: 10.0 Explore P: 0.2760
# Episode: 908 Total reward: 11.0 Explore P: 0.2757
# Episode: 909 Total reward: 9.0 Explore P: 0.2755
# Episode: 910 Total reward: 7.0 Explore P: 0.2753
# Episode: 911 Total reward: 10.0 Explore P: 0.2750
# Episode: 912 Total reward: 11.0 Explore P: 0.2748
# Episode: 913 Total reward: 11.0 Explore P: 0.2745
# Episode: 914 Total reward: 19.0 Explore P: 0.2740
# Episode: 915 Total reward: 10.0 Explore P: 0.2737
# Episode: 916 Total reward: 11.0 Explore P: 0.2734
# Episode: 917 Total reward: 9.0 Explore P: 0.2732
# Episode: 918 Total reward: 12.0 Explore P: 0.2729
# Episode: 919 Total reward: 10.0 Explore P: 0.2726
# Episode: 920 Total reward: 9.0 Explore P: 0.2724
# Episode: 921 Total reward: 13.0 Explore P: 0.2720
# Episode: 922 Total reward: 8.0 Explore P: 0.2718
# Episode: 923 Total reward: 13.0 Explore P: 0.2715
# Episode: 924 Total reward: 9.0 Explore P: 0.2712
# Episode: 925 Total reward: 8.0 Explore P: 0.2710
# Episode: 926 Total reward: 11.0 Explore P: 0.2707
# Episode: 927 Total reward: 15.0 Explore P: 0.2703
# Episode: 928 Total reward: 11.0 Explore P: 0.2701
# Episode: 929 Total reward: 13.0 Explore P: 0.2697
# Episode: 930 Total reward: 11.0 Explore P: 0.2694
# Episode: 931 Total reward: 14.0 Explore P: 0.2691
# Episode: 932 Total reward: 11.0 Explore P: 0.2688
# Episode: 933 Total reward: 10.0 Explore P: 0.2685
# Episode: 934 Total reward: 12.0 Explore P: 0.2682
# Episode: 935 Total reward: 17.0 Explore P: 0.2678
# Episode: 936 Total reward: 11.0 Explore P: 0.2675
# Episode: 937 Total reward: 13.0 Explore P: 0.2672
# Episode: 938 Total reward: 9.0 Explore P: 0.2669
# Episode: 939 Total reward: 11.0 Explore P: 0.2666
# Episode: 940 Total reward: 9.0 Explore P: 0.2664
# Episode: 941 Total reward: 9.0 Explore P: 0.2662
# Episode: 942 Total reward: 10.0 Explore P: 0.2659
# Episode: 943 Total reward: 10.0 Explore P: 0.2657
# Episode: 944 Total reward: 14.0 Explore P: 0.2653
# Episode: 945 Total reward: 12.0 Explore P: 0.2650
# Episode: 946 Total reward: 12.0 Explore P: 0.2647
# Episode: 947 Total reward: 9.0 Explore P: 0.2645
# Episode: 948 Total reward: 8.0 Explore P: 0.2643
# Episode: 949 Total reward: 9.0 Explore P: 0.2640
# Episode: 950 Total reward: 16.0 Explore P: 0.2636
# Episode: 951 Total reward: 13.0 Explore P: 0.2633
# Episode: 952 Total reward: 13.0 Explore P: 0.2630
# Episode: 953 Total reward: 12.0 Explore P: 0.2627
# Episode: 954 Total reward: 7.0 Explore P: 0.2625
# Episode: 955 Total reward: 9.0 Explore P: 0.2623
# Episode: 956 Total reward: 14.0 Explore P: 0.2619
# Episode: 957 Total reward: 11.0 Explore P: 0.2616
# Episode: 958 Total reward: 9.0 Explore P: 0.2614
# Episode: 959 Total reward: 12.0 Explore P: 0.2611
# Episode: 960 Total reward: 8.0 Explore P: 0.2609
# Episode: 961 Total reward: 13.0 Explore P: 0.2606
# Episode: 962 Total reward: 11.0 Explore P: 0.2603
# Episode: 963 Total reward: 11.0 Explore P: 0.2600
# Episode: 964 Total reward: 11.0 Explore P: 0.2598
# Episode: 965 Total reward: 14.0 Explore P: 0.2594
# ...
# Episode: 2684 Total reward: 11.0 Explore P: 0.0529
# Episode: 2685 Total reward: 8.0 Explore P: 0.0529
# Episode: 2686 Total reward: 10.0 Explore P: 0.0529
# Episode: 2687 Total reward: 11.0 Explore P: 0.0528
# Episode: 2688 Total reward: 9.0 Explore P: 0.0528
# Episode: 2689 Total reward: 7.0 Explore P: 0.0528
# Episode: 2690 Total reward: 9.0 Explore P: 0.0527
# Episode: 2691 Total reward: 9.0 Explore P: 0.0527
# Episode: 2692 Total reward: 8.0 Explore P: 0.0526
# Episode: 2693 Total reward: 12.0 Explore P: 0.0526
# Episode: 2694 Total reward: 7.0 Explore P: 0.0526
# Episode: 2695 Total reward: 9.0 Explore P: 0.0525
# Episode: 2696 Total reward: 7.0 Explore P: 0.0525
# Episode: 2697 Total reward: 12.0 Explore P: 0.0524
# Episode: 2698 Total reward: 10.0 Explore P: 0.0524
# Episode: 2699 Total reward: 11.0 Explore P: 0.0524
# Episode: 2700 Total reward: 10.0 Explore P: 0.0523
# Episode: 2701 Total reward: 10.0 Explore P: 0.0523
# Episode: 2702 Total reward: 9.0 Explore P: 0.0522
# Episode: 2703 Total reward: 9.0 Explore P: 0.0522
# Episode: 2704 Total reward: 9.0 Explore P: 0.0522
# Episode: 2705 Total reward: 8.0 Explore P: 0.0521
# Episode: 2706 Total reward: 12.0 Explore P: 0.0521
# Episode: 2707 Total reward: 10.0 Explore P: 0.0520
# Episode: 2708 Total reward: 10.0 Explore P: 0.0520
# Episode: 2709 Total reward: 8.0 Explore P: 0.0520
# Episode: 2710 Total reward: 8.0 Explore P: 0.0519
# Episode: 2711 Total reward: 8.0 Explore P: 0.0519
# Episode: 2712 Total reward: 9.0 Explore P: 0.0519
# Episode: 2713 Total reward: 10.0 Explore P: 0.0518
# Episode: 2714 Total reward: 10.0 Explore P: 0.0518
# Episode: 2715 Total reward: 12.0 Explore P: 0.0517
# Episode: 2716 Total reward: 7.0 Explore P: 0.0517
# Episode: 2717 Total reward: 11.0 Explore P: 0.0516
# Episode: 2718 Total reward: 11.0 Explore P: 0.0516
# Episode: 2719 Total reward: 10.0 Explore P: 0.0516
# Episode: 2720 Total reward: 11.0 Explore P: 0.0515
# Episode: 2721 Total reward: 8.0 Explore P: 0.0515
# Episode: 2722 Total reward: 10.0 Explore P: 0.0514
# Episode: 2723 Total reward: 8.0 Explore P: 0.0514
# Episode: 2724 Total reward: 10.0 Explore P: 0.0514
# Episode: 2725 Total reward: 9.0 Explore P: 0.0513
# Episode: 2726 Total reward: 11.0 Explore P: 0.0513
# Episode: 2727 Total reward: 8.0 Explore P: 0.0512
# Episode: 2728 Total reward: 7.0 Explore P: 0.0512
# Episode: 2729 Total reward: 9.0 Explore P: 0.0512
# Episode: 2730 Total reward: 9.0 Explore P: 0.0511
# Episode: 2731 Total reward: 12.0 Explore P: 0.0511
# Episode: 2732 Total reward: 8.0 Explore P: 0.0511
# Episode: 2733 Total reward: 11.0 Explore P: 0.0510
# Episode: 2734 Total reward: 9.0 Explore P: 0.0510
# Episode: 2735 Total reward: 10.0 Explore P: 0.0509
# Episode: 2736 Total reward: 7.0 Explore P: 0.0509
# Episode: 2737 Total reward: 11.0 Explore P: 0.0509
# Episode: 2738 Total reward: 11.0 Explore P: 0.0508
# Episode: 2739 Total reward: 11.0 Explore P: 0.0508
# Episode: 2740 Total reward: 8.0 Explore P: 0.0507
# Episode: 2741 Total reward: 11.0 Explore P: 0.0507
# Episode: 2742 Total reward: 9.0 Explore P: 0.0507
# Episode: 2743 Total reward: 9.0 Explore P: 0.0506
# Episode: 2744 Total reward: 12.0 Explore P: 0.0506
# Episode: 2745 Total reward: 9.0 Explore P: 0.0505
# Episode: 2746 Total reward: 8.0 Explore P: 0.0505
# Episode: 2747 Total reward: 9.0 Explore P: 0.0505
# Episode: 2748 Total reward: 10.0 Explore P: 0.0504
# Episode: 2749 Total reward: 9.0 Explore P: 0.0504
# Episode: 2750 Total reward: 16.0 Explore P: 0.0503
# Episode: 2751 Total reward: 9.0 Explore P: 0.0503
# Episode: 2752 Total reward: 11.0 Explore P: 0.0502
# Episode: 2753 Total reward: 12.0 Explore P: 0.0502
# Episode: 2754 Total reward: 13.0 Explore P: 0.0501
# Episode: 2755 Total reward: 8.0 Explore P: 0.0501
# Episode: 2756 Total reward: 9.0 Explore P: 0.0501
# Episode: 2757 Total reward: 11.0 Explore P: 0.0500
# Episode: 2758 Total reward: 8.0 Explore P: 0.0500
# Episode: 2759 Total reward: 11.0 Explore P: 0.0500
# Episode: 2760 Total reward: 12.0 Explore P: 0.0499
# Episode: 2761 Total reward: 10.0 Explore P: 0.0499
# Episode: 2762 Total reward: 13.0 Explore P: 0.0498
# Episode: 2763 Total reward: 8.0 Explore P: 0.0498
# Episode: 2764 Total reward: 10.0 Explore P: 0.0497
# Episode: 2765 Total reward: 12.0 Explore P: 0.0497
# Episode: 2766 Total reward: 9.0 Explore P: 0.0497
# Episode: 2767 Total reward: 9.0 Explore P: 0.0496
# Episode: 2768 Total reward: 9.0 Explore P: 0.0496
# Episode: 2769 Total reward: 8.0 Explore P: 0.0496
# Episode: 2770 Total reward: 8.0 Explore P: 0.0495
# Episode: 2771 Total reward: 13.0 Explore P: 0.0495
# Episode: 2772 Total reward: 11.0 Explore P: 0.0494
# Episode: 2773 Total reward: 11.0 Explore P: 0.0494
# Episode: 2774 Total reward: 9.0 Explore P: 0.0494
# Episode: 2775 Total reward: 7.0 Explore P: 0.0493
# Episode: 2776 Total reward: 10.0 Explore P: 0.0493
# Episode: 2777 Total reward: 10.0 Explore P: 0.0492
# Episode: 2778 Total reward: 8.0 Explore P: 0.0492
# Episode: 2779 Total reward: 10.0 Explore P: 0.0492
# Episode: 2780 Total reward: 8.0 Explore P: 0.0491
# Episode: 2781 Total reward: 11.0 Explore P: 0.0491
# Episode: 2782 Total reward: 9.0 Explore P: 0.0491
# Episode: 2783 Total reward: 10.0 Explore P: 0.0490
# Episode: 2784 Total reward: 12.0 Explore P: 0.0490
# Episode: 2785 Total reward: 10.0 Explore P: 0.0489
# Episode: 2786 Total reward: 8.0 Explore P: 0.0489
# Episode: 2787 Total reward: 11.0 Explore P: 0.0489
# Episode: 2788 Total reward: 11.0 Explore P: 0.0488
# Episode: 2789 Total reward: 11.0 Explore P: 0.0488
# Episode: 2790 Total reward: 11.0 Explore P: 0.0487
# Episode: 2791 Total reward: 11.0 Explore P: 0.0487
# Episode: 2792 Total reward: 11.0 Explore P: 0.0487
# Episode: 2793 Total reward: 11.0 Explore P: 0.0486
# Episode: 2794 Total reward: 8.0 Explore P: 0.0486
# Episode: 2795 Total reward: 11.0 Explore P: 0.0485
# Episode: 2796 Total reward: 7.0 Explore P: 0.0485
# Episode: 2797 Total reward: 9.0 Explore P: 0.0485
# Episode: 2798 Total reward: 8.0 Explore P: 0.0484
# Episode: 2799 Total reward: 9.0 Explore P: 0.0484
# Episode: 2800 Total reward: 10.0 Explore P: 0.0484
# Episode: 2801 Total reward: 11.0 Explore P: 0.0483
# Episode: 2802 Total reward: 11.0 Explore P: 0.0483
# Episode: 2803 Total reward: 11.0 Explore P: 0.0482
# Episode: 2804 Total reward: 11.0 Explore P: 0.0482
# Episode: 2805 Total reward: 12.0 Explore P: 0.0482
# Episode: 2806 Total reward: 12.0 Explore P: 0.0481
# Episode: 2807 Total reward: 8.0 Explore P: 0.0481
# Episode: 2808 Total reward: 9.0 Explore P: 0.0481
# Episode: 2809 Total reward: 12.0 Explore P: 0.0480
# Episode: 2810 Total reward: 8.0 Explore P: 0.0480
# Episode: 2811 Total reward: 10.0 Explore P: 0.0479
# Episode: 2812 Total reward: 9.0 Explore P: 0.0479
# Episode: 2813 Total reward: 8.0 Explore P: 0.0479
# Episode: 2814 Total reward: 10.0 Explore P: 0.0478
# Episode: 2815 Total reward: 10.0 Explore P: 0.0478
# Episode: 2816 Total reward: 10.0 Explore P: 0.0478
# Episode: 2817 Total reward: 8.0 Explore P: 0.0477
# Episode: 2818 Total reward: 8.0 Explore P: 0.0477
# Episode: 2819 Total reward: 12.0 Explore P: 0.0477
# Episode: 2820 Total reward: 8.0 Explore P: 0.0476
# Episode: 2821 Total reward: 10.0 Explore P: 0.0476
# Episode: 2822 Total reward: 8.0 Explore P: 0.0476
# Episode: 2823 Total reward: 7.0 Explore P: 0.0475
# Episode: 2824 Total reward: 9.0 Explore P: 0.0475
# Episode: 2825 Total reward: 11.0 Explore P: 0.0475
# Episode: 2826 Total reward: 8.0 Explore P: 0.0474
# Episode: 2827 Total reward: 9.0 Explore P: 0.0474
# Episode: 2828 Total reward: 11.0 Explore P: 0.0473
# Episode: 2829 Total reward: 12.0 Explore P: 0.0473
# Episode: 2830 Total reward: 7.0 Explore P: 0.0473
# Episode: 2831 Total reward: 9.0 Explore P: 0.0472
# Episode: 2832 Total reward: 8.0 Explore P: 0.0472
# Episode: 2833 Total reward: 8.0 Explore P: 0.0472
# Episode: 2834 Total reward: 7.0 Explore P: 0.0472
# Episode: 2835 Total reward: 12.0 Explore P: 0.0471
# Episode: 2836 Total reward: 13.0 Explore P: 0.0471
# Episode: 2837 Total reward: 10.0 Explore P: 0.0470
# Episode: 2838 Total reward: 9.0 Explore P: 0.0470
# Episode: 2839 Total reward: 10.0 Explore P: 0.0470
# Episode: 2840 Total reward: 11.0 Explore P: 0.0469
# Episode: 2841 Total reward: 12.0 Explore P: 0.0469
# Episode: 2842 Total reward: 9.0 Explore P: 0.0468
# Episode: 2843 Total reward: 9.0 Explore P: 0.0468
# Episode: 2844 Total reward: 10.0 Explore P: 0.0468
# Episode: 2845 Total reward: 11.0 Explore P: 0.0467
# Episode: 2846 Total reward: 10.0 Explore P: 0.0467
# Episode: 2847 Total reward: 11.0 Explore P: 0.0467
# Episode: 2848 Total reward: 7.0 Explore P: 0.0466
# Episode: 2849 Total reward: 9.0 Explore P: 0.0466
# Episode: 2850 Total reward: 9.0 Explore P: 0.0466
# Episode: 2851 Total reward: 9.0 Explore P: 0.0465
# Episode: 2852 Total reward: 9.0 Explore P: 0.0465
# Episode: 2853 Total reward: 10.0 Explore P: 0.0465
# Episode: 2854 Total reward: 9.0 Explore P: 0.0464
# Episode: 2855 Total reward: 10.0 Explore P: 0.0464
# Episode: 2856 Total reward: 9.0 Explore P: 0.0464
# Episode: 2857 Total reward: 12.0 Explore P: 0.0463
# Episode: 2858 Total reward: 10.0 Explore P: 0.0463
# Episode: 2859 Total reward: 9.0 Explore P: 0.0462
# Episode: 2860 Total reward: 12.0 Explore P: 0.0462
# Episode: 2861 Total reward: 8.0 Explore P: 0.0462
# Episode: 2862 Total reward: 8.0 Explore P: 0.0461
# Episode: 2863 Total reward: 8.0 Explore P: 0.0461
# Episode: 2864 Total reward: 12.0 Explore P: 0.0461
# Episode: 2865 Total reward: 7.0 Explore P: 0.0460
# Episode: 2866 Total reward: 10.0 Explore P: 0.0460
# Episode: 2867 Total reward: 8.0 Explore P: 0.0460
# Episode: 2868 Total reward: 12.0 Explore P: 0.0459
# Episode: 2869 Total reward: 9.0 Explore P: 0.0459
# Episode: 2870 Total reward: 8.0 Explore P: 0.0459
# Episode: 2871 Total reward: 12.0 Explore P: 0.0458
# Episode: 2872 Total reward: 8.0 Explore P: 0.0458
# Episode: 2873 Total reward: 9.0 Explore P: 0.0458
# Episode: 2874 Total reward: 8.0 Explore P: 0.0457
# Episode: 2875 Total reward: 9.0 Explore P: 0.0457
# Episode: 2876 Total reward: 9.0 Explore P: 0.0457
# Episode: 2877 Total reward: 7.0 Explore P: 0.0457
# Episode: 2878 Total reward: 9.0 Explore P: 0.0456
# Episode: 2879 Total reward: 10.0 Explore P: 0.0456
# Episode: 2880 Total reward: 11.0 Explore P: 0.0455
# Episode: 2881 Total reward: 10.0 Explore P: 0.0455
# Episode: 2882 Total reward: 12.0 Explore P: 0.0455
# Episode: 2883 Total reward: 10.0 Explore P: 0.0454
# Episode: 2884 Total reward: 9.0 Explore P: 0.0454
# Episode: 2885 Total reward: 9.0 Explore P: 0.0454
# Episode: 2886 Total reward: 10.0 Explore P: 0.0453
# Episode: 2887 Total reward: 10.0 Explore P: 0.0453
# Episode: 2888 Total reward: 9.0 Explore P: 0.0453
# Episode: 2889 Total reward: 10.0 Explore P: 0.0452
# Episode: 2890 Total reward: 12.0 Explore P: 0.0452
# Episode: 2891 Total reward: 12.0 Explore P: 0.0451
# Episode: 2892 Total reward: 8.0 Explore P: 0.0451
# Episode: 2893 Total reward: 8.0 Explore P: 0.0451
# Episode: 2894 Total reward: 14.0 Explore P: 0.0450
# Episode: 2895 Total reward: 12.0 Explore P: 0.0450
# Episode: 2896 Total reward: 9.0 Explore P: 0.0450
# Episode: 2897 Total reward: 10.0 Explore P: 0.0449
# Episode: 2898 Total reward: 9.0 Explore P: 0.0449
# Episode: 2899 Total reward: 10.0 Explore P: 0.0449
# Episode: 2900 Total reward: 8.0 Explore P: 0.0448
# Episode: 2901 Total reward: 10.0 Explore P: 0.0448
# Episode: 2902 Total reward: 10.0 Explore P: 0.0448
# Episode: 2903 Total reward: 11.0 Explore P: 0.0447
# Episode: 2904 Total reward: 11.0 Explore P: 0.0447
# Episode: 2905 Total reward: 10.0 Explore P: 0.0447
# Episode: 2906 Total reward: 9.0 Explore P: 0.0446
# Episode: 2907 Total reward: 8.0 Explore P: 0.0446
# Episode: 2908 Total reward: 10.0 Explore P: 0.0446
# Episode: 2909 Total reward: 10.0 Explore P: 0.0445
# Episode: 2910 Total reward: 9.0 Explore P: 0.0445
# Episode: 2911 Total reward: 13.0 Explore P: 0.0445
# Episode: 2912 Total reward: 10.0 Explore P: 0.0444
# Episode: 2913 Total reward: 8.0 Explore P: 0.0444
# Episode: 2914 Total reward: 9.0 Explore P: 0.0444
# Episode: 2915 Total reward: 10.0 Explore P: 0.0443
# Episode: 2916 Total reward: 10.0 Explore P: 0.0443
# Episode: 2917 Total reward: 10.0 Explore P: 0.0443
# Episode: 2918 Total reward: 10.0 Explore P: 0.0442
# Episode: 2919 Total reward: 10.0 Explore P: 0.0442
# Episode: 2920 Total reward: 8.0 Explore P: 0.0442
# Episode: 2921 Total reward: 10.0 Explore P: 0.0441
# Episode: 2922 Total reward: 10.0 Explore P: 0.0441
# Episode: 2923 Total reward: 10.0 Explore P: 0.0441
# Episode: 2924 Total reward: 9.0 Explore P: 0.0440
# Episode: 2925 Total reward: 11.0 Explore P: 0.0440
# Episode: 2926 Total reward: 10.0 Explore P: 0.0440
# Episode: 2927 Total reward: 8.0 Explore P: 0.0439
# Episode: 2928 Total reward: 10.0 Explore P: 0.0439
# Episode: 2929 Total reward: 9.0 Explore P: 0.0439
# Episode: 2930 Total reward: 11.0 Explore P: 0.0438
# Episode: 2931 Total reward: 10.0 Explore P: 0.0438
# Episode: 2932 Total reward: 9.0 Explore P: 0.0438
# Episode: 2933 Total reward: 8.0 Explore P: 0.0437
# Episode: 2934 Total reward: 12.0 Explore P: 0.0437
# Episode: 2935 Total reward: 11.0 Explore P: 0.0437
# Episode: 2936 Total reward: 10.0 Explore P: 0.0436
# Episode: 2937 Total reward: 11.0 Explore P: 0.0436
# Episode: 2938 Total reward: 9.0 Explore P: 0.0436
# Episode: 2939 Total reward: 12.0 Explore P: 0.0435
# Episode: 2940 Total reward: 11.0 Explore P: 0.0435
# Episode: 2941 Total reward: 9.0 Explore P: 0.0435
# Episode: 2942 Total reward: 10.0 Explore P: 0.0434
# Episode: 2943 Total reward: 9.0 Explore P: 0.0434
# Episode: 2944 Total reward: 15.0 Explore P: 0.0433
# Episode: 2945 Total reward: 11.0 Explore P: 0.0433
# Episode: 2946 Total reward: 9.0 Explore P: 0.0433
# Episode: 2947 Total reward: 10.0 Explore P: 0.0432
# Episode: 2948 Total reward: 10.0 Explore P: 0.0432
# Episode: 2949 Total reward: 9.0 Explore P: 0.0432
# Episode: 2950 Total reward: 8.0 Explore P: 0.0432
# Episode: 2951 Total reward: 10.0 Explore P: 0.0431
# Episode: 2952 Total reward: 8.0 Explore P: 0.0431
# Episode: 2953 Total reward: 8.0 Explore P: 0.0431
# Episode: 2954 Total reward: 9.0 Explore P: 0.0430
# Episode: 2955 Total reward: 8.0 Explore P: 0.0430
# Episode: 2956 Total reward: 8.0 Explore P: 0.0430
# Episode: 2957 Total reward: 9.0 Explore P: 0.0430
# Episode: 2958 Total reward: 10.0 Explore P: 0.0429
# Episode: 2959 Total reward: 9.0 Explore P: 0.0429
# Episode: 2960 Total reward: 12.0 Explore P: 0.0429
# Episode: 2961 Total reward: 12.0 Explore P: 0.0428
# Episode: 2962 Total reward: 10.0 Explore P: 0.0428
# Episode: 2963 Total reward: 11.0 Explore P: 0.0427
# Episode: 2964 Total reward: 12.0 Explore P: 0.0427
# Episode: 2965 Total reward: 9.0 Explore P: 0.0427
# Episode: 2966 Total reward: 9.0 Explore P: 0.0426
# Episode: 2967 Total reward: 7.0 Explore P: 0.0426
# Episode: 2968 Total reward: 8.0 Explore P: 0.0426
# Episode: 2969 Total reward: 8.0 Explore P: 0.0426
# Episode: 2970 Total reward: 9.0 Explore P: 0.0425
# Episode: 2971 Total reward: 9.0 Explore P: 0.0425
# Episode: 2972 Total reward: 7.0 Explore P: 0.0425
# Episode: 2973 Total reward: 8.0 Explore P: 0.0425
# Episode: 2974 Total reward: 9.0 Explore P: 0.0424
# Episode: 2975 Total reward: 11.0 Explore P: 0.0424
# Episode: 2976 Total reward: 10.0 Explore P: 0.0424
# Episode: 2977 Total reward: 11.0 Explore P: 0.0423
# Episode: 2978 Total reward: 12.0 Explore P: 0.0423
# Episode: 2979 Total reward: 11.0 Explore P: 0.0423
# Episode: 2980 Total reward: 11.0 Explore P: 0.0422
# Episode: 2981 Total reward: 9.0 Explore P: 0.0422
# Episode: 2982 Total reward: 9.0 Explore P: 0.0422
# Episode: 2983 Total reward: 10.0 Explore P: 0.0421
# Episode: 2984 Total reward: 10.0 Explore P: 0.0421
# Episode: 2985 Total reward: 10.0 Explore P: 0.0421
# Episode: 2986 Total reward: 11.0 Explore P: 0.0420
# Episode: 2987 Total reward: 10.0 Explore P: 0.0420
# Episode: 2988 Total reward: 10.0 Explore P: 0.0420
# Episode: 2989 Total reward: 9.0 Explore P: 0.0419
# Episode: 2990 Total reward: 8.0 Explore P: 0.0419
# Episode: 2991 Total reward: 8.0 Explore P: 0.0419
# Episode: 2992 Total reward: 8.0 Explore P: 0.0419
# Episode: 2993 Total reward: 9.0 Explore P: 0.0418
# Episode: 2994 Total reward: 9.0 Explore P: 0.0418
# Episode: 2995 Total reward: 10.0 Explore P: 0.0418
# Episode: 2996 Total reward: 8.0 Explore P: 0.0417
# Episode: 2997 Total reward: 8.0 Explore P: 0.0417
# Episode: 2998 Total reward: 10.0 Explore P: 0.0417
# Episode: 2999 Total reward: 8.0 Explore P: 0.0417

# %% [markdown]
# ## Visualizing training
#
# Below I'll plot the total rewards for each episode. I'm plotting the rolling average too, in blue.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

def running_mean(x, N):
    cumsum = np.cumsum(np.insert(x, 0, 0)) 
    return (cumsum[N:] - cumsum[:-N]) / N

# %%
eps, rews = np.array(rewards_list).T
smoothed_rews = running_mean(rews, 10)
plt.plot(eps[-len(smoothed_rews):], smoothed_rews)
plt.plot(eps, rews, color='grey', alpha=0.3)
plt.xlabel('Episode')
plt.ylabel('Total Reward')
# Out:
# Text(0,0.5,'Total Reward')

# %% [markdown]
# ## Testing
#
# Let's checkout how our trained agent plays the game.

# %%
test_episodes = 10
test_max_steps = 400
env.reset()
with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    
    for ep in range(1, test_episodes):
        t = 0
        while t < test_max_steps:
            env.render() 
            
            # Get action from Q-network
            feed = {mainQN.inputs_: state.reshape((1, *state.shape))}
            Qs = sess.run(mainQN.output, feed_dict=feed)
            action = np.argmax(Qs)
            
            # Take action, get new state and reward
            next_state, reward, done, _ = env.step(action)
            
            if done:
                t = test_max_steps
                env.reset()
                # Take one random step to get the pole and cart moving
                state, reward, done, _ = env.step(env.action_space.sample())

            else:
                state = next_state
                t += 1
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/cartpole.ckpt

# %%
env.close()

# %% [markdown]
# ## Extending this
#
# So, Cart-Pole is a pretty simple game. However, the same model can be used to train an agent to play something much more complicated like Pong or Space Invaders. Instead of a state like we're using here though, you'd want to use convolutional layers to get the state from the screen images.
#
# ![Deep Q-Learning Atari](assets/atari-network.png)
#
# I'll leave it as a challenge for you to use deep Q-learning to train an agent to play Atari games. Here's the original paper which will get you started: http://www.davidqiu.com:8888/research/nature14236.pdf.
