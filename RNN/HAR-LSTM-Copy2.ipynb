# %% [markdown]
# # HAR LSTM training

# %%
# Imports
import numpy as np
import os
from utils.utilities import *
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Prepare data

# %%
Xtrain, Ytrain, list_ch_train = read_data(data_path="/home/arasdar/datasets/har-data/", split="train") # train
Xtest, Ytest, list_ch_test = read_data(data_path="/home/arasdar/datasets/har-data/", split="test") # test

assert list_ch_train == list_ch_test, "Mistmatch in channels!"
# Out:
# /home/arasdar/github/deep-learning-HAR/utils/utilities.py:37: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   X[:,:,i_ch] = dat_.as_matrix()

# %%
# # Standardize
# X_train, X_test = standardize(X_train, X_test)

# %% [markdown]
# Train/Validation Split

# %%
Xtrain, Xvalid, Ytrain, Yvalid = train_test_split(Xtrain, Ytrain,
                                                  stratify=Ytrain, random_state=123)

# %% [markdown]
# One-hot encoding:

# %%
# y_tr = one_hot(lab_tr)
# y_vld = one_hot(lab_vld)
# y_test = one_hot(labels_test)

# %% [markdown]
# ### Hyperparameters

# %%
# Imports
import tensorflow as tf

lstm_size = 27         # 3 times the amount of channels
lstm_layers = 2        # Number of layers
batch_size = 600       # Batch size
seq_len = 128          # Number of steps
learning_rate = 0.0001 # Learning rate (default is 0.001)
epochs = 1000

# Fixed
n_classes = 6
n_channels = 9

# %% [markdown]
# ### Construct the graph
# Placeholders

# %%
graph = tf.Graph()

# Construct placeholders
with graph.as_default():
    inputs_ = tf.placeholder(tf.float32, [None, seq_len, n_channels], name = 'inputs')
    print(inputs_.shape, inputs_.dtype)
    indices_ = tf.placeholder(tf.int32, [None], name = 'indices')
    print(indices_.shape, indices_.dtype)
    #     keep_prob_ = tf.placeholder(tf.float32, name = 'keep')
    #     learning_rate_ = tf.placeholder(tf.float32, name = 'learning_rate')
# Out:
# (?, 128, 9) <dtype: 'float32'>
# (?,) <dtype: 'int32'>

# %% [markdown]
# Construct inputs to LSTM

# %%
with graph.as_default():
    # Construct the LSTM inputs and LSTM cells
    lstm_in = tf.transpose(inputs_, [1,0,2]) # reshape into (seq_len, N, channels)
    print(lstm_in.shape, lstm_in.dtype)
    lstm_in = tf.reshape(lstm_in, [-1, n_channels]) # Now (seq_len*N, n_channels)
    print(lstm_in.shape, lstm_in.dtype)
    
    # To cells: Resize input data to the RNN input
    lstm_in = tf.layers.dense(lstm_in, lstm_size, activation=None) # or tf.nn.relu, tf.nn.sigmoid, tf.nn.tanh?
    print(lstm_in.shape, lstm_in.dtype)
    
    # Open up the tensor into a list of seq_len pieces
    lstm_in = tf.split(lstm_in, seq_len, 0)
    print(len(lstm_in), lstm_in[0].shape, lstm_in[0].dtype)
    
    # Add LSTM layers
    lstm = tf.contrib.rnn.BasicLSTMCell(lstm_size)
    #drop = tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob_)
    cell = tf.contrib.rnn.MultiRNNCell([lstm] * lstm_layers)
    initial_state = cell.zero_state(batch_size, tf.float32)
    outputs, final_state = tf.contrib.rnn.static_rnn(cell, lstm_in, dtype=tf.float32, initial_state = initial_state)
    print(len(outputs), outputs[-1])
    
    # To cells: Resize the RNN output to output classes
    # We only need the last output tensor to pass into a classifier: Resize to the output classes/labels
    logits = tf.layers.dense(inputs=outputs[-1], units=n_classes, name='logits')
    labels = tf.one_hot(indices=indices_, depth=n_classes, dtype=logits.dtype)
    print(logits.shape, logits.dtype)
    print(labels.shape, labels.dtype)
# Out:
# (128, ?, 9) <dtype: 'float32'>
# (?, 9) <dtype: 'float32'>
# (?, 27) <dtype: 'float32'>
# 128 (?, 27) <dtype: 'float32'>
# 128 Tensor("rnn/rnn/multi_rnn_cell/cell_0/basic_lstm_cell/Mul_767:0", shape=(600, 27), dtype=float32)
# (600, 6) <dtype: 'float32'>
# (?, 6) <dtype: 'float32'>

# %%
initial_state[0][0].shape
# Out:
# TensorShape([Dimension(600), Dimension(27)])

# %% [markdown]
# Define forward pass, cost function and optimizer:

# %%
with graph.as_default():
    
    # Model loss using logits and labels
    cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=logits, labels=labels))
    
    # Model opimizier/update
    optimizer = tf.train.AdamOptimizer(learning_rate=0.0001).minimize(cost) # No grad clipping
    
    #     # Grad clipping
    #     train_op = tf.train.AdamOptimizer(learning_rate_)

    #     gradients = train_op.compute_gradients(cost)
    #     capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients]
    #     optimizer = train_op.apply_gradients(capped_gradients)

    # Accuracy
    correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(labels, 1))
    accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

# %% [markdown]
# ### Train the network

# %%
if (os.path.exists('checkpoints') == False):
    # !mkdir checkpoints

# %%
validation_acc = []
validation_loss = []

train_acc = []
train_loss = []

with graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=graph) as sess:
    sess.run(tf.global_variables_initializer())
    iteration = 1
    
    for e in range(epochs):
        
        # Training: Loop over batches
        state = sess.run(initial_state)
        for Xbatch, Ybatch in get_batches(Xtrain, Ytrain, batch_size):
            
            # Feed dictionary
            feed_dict = {inputs_: Xbatch, indices_: Ybatch, initial_state: state}
            loss, _ , state, acc = sess.run([cost, optimizer, final_state, accuracy], feed_dict)
            train_acc.append(acc)
            train_loss.append(loss)
            
            # Print at each 5 iters
            if (iteration % 5 == 0):
                print("Epoch: {}/{}".format(e, epochs),
                      "Iteration: {:d}".format(iteration),
                      "Train loss: {:6f}".format(loss),
                      "Train acc: {:.6f}".format(acc))
            
            # Compute validation loss at every 25 iterations
            if (iteration%25 == 0):
                
                # Initiate for validation set
                val_state = sess.run(cell.zero_state(batch_size, tf.float32))
                
                val_acc_ = []
                val_loss_ = []
                for Xbatch, Ybatch in get_batches(Xvalid, Yvalid, batch_size):
                    
                    # Feed dictionary
                    feed_dict = {inputs_: Xbatch, indices_: Ybatch, initial_state: val_state}
                    loss_v, state_v, acc_v = sess.run([cost, final_state, accuracy], feed_dict)
                    val_acc_.append(acc_v)
                    val_loss_.append(loss_v)
                
                # Print info
                print("Epoch: {}/{}".format(e, epochs),
                      "Iteration: {:d}".format(iteration),
                      "Validation loss: {:6f}".format(np.mean(val_loss_)),
                      "Validation acc: {:.6f}".format(np.mean(val_acc_)))
                
                # Store
                validation_acc.append(np.mean(val_acc_))
                validation_loss.append(np.mean(val_loss_))
            
            # Iterate 
            iteration += 1
    
    saver.save(sess,"checkpoints/har-lstm.ckpt")
# Out:
# Epoch: 0/1000 Iteration: 5 Train loss: 1.412533 Train acc: 0.173333
# Epoch: 1/1000 Iteration: 10 Train loss: 1.439450 Train acc: 0.168333
# Epoch: 1/1000 Iteration: 15 Train loss: 1.411583 Train acc: 0.198333
# Epoch: 272/1000 Iteration: 2455 Train loss: 0.262438 Train acc: 0.741667
# Epoch: 273/1000 Iteration: 2460 Train loss: 0.280756 Train acc: 0.750000
# Epoch: 273/1000 Iteration: 2465 Train loss: 0.286892 Train acc: 0.755000
# Epoch: 274/1000 Iteration: 2470 Train loss: 0.295429 Train acc: 0.758333
# Epoch: 274/1000 Iteration: 2475 Train loss: 0.304958 Train acc: 0.768333
# Epoch: 274/1000 Iteration: 2475 Validation loss: 0.302979 Validation acc: 0.737778
# Epoch: 275/1000 Iteration: 2480 Train loss: 0.283561 Train acc: 0.711667
# Epoch: 276/1000 Iteration: 2485 Train loss: 0.249513 Train acc: 0.748333
# Epoch: 276/1000 Iteration: 2490 Train loss: 0.260733 Train acc: 0.723333
# Epoch: 277/1000 Iteration: 2495 Train loss: 0.271776 Train acc: 0.735000
# Epoch: 277/1000 Iteration: 2500 Train loss: 0.257103 Train acc: 0.750000
# Epoch: 277/1000 Iteration: 2500 Validation loss: 0.300913 Validation acc: 0.742778
# Epoch: 278/1000 Iteration: 2505 Train loss: 0.277233 Train acc: 0.748333
# Epoch: 278/1000 Iteration: 2510 Train loss: 0.273976 Train acc: 0.766667
# Epoch: 279/1000 Iteration: 2515 Train loss: 0.292106 Train acc: 0.758333
# Epoch: 279/1000 Iteration: 2520 Train loss: 0.299373 Train acc: 0.770000
# Epoch: 280/1000 Iteration: 2525 Train loss: 0.284077 Train acc: 0.708333
# Epoch: 280/1000 Iteration: 2525 Validation loss: 0.297741 Validation acc: 0.740556
# Epoch: 281/1000 Iteration: 2530 Train loss: 0.242005 Train acc: 0.751667
# Epoch: 281/1000 Iteration: 2535 Train loss: 0.258481 Train acc: 0.721667
# Epoch: 282/1000 Iteration: 2540 Train loss: 0.264455 Train acc: 0.735000
# Epoch: 282/1000 Iteration: 2545 Train loss: 0.252052 Train acc: 0.748333
# Epoch: 283/1000 Iteration: 2550 Train loss: 0.274411 Train acc: 0.748333
# Epoch: 283/1000 Iteration: 2550 Validation loss: 0.297646 Validation acc: 0.739444
# Epoch: 283/1000 Iteration: 2555 Train loss: 0.266067 Train acc: 0.771667

# %%
# Plot training and test loss
t = np.arange(iteration-1)

plt.figure(figsize = (6,6))
plt.plot(t, np.array(train_loss), 'r-', t[t % 25 == 0], np.array(validation_loss), 'b*')
plt.xlabel("iteration")
plt.ylabel("Loss")
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %%
# Plot Accuracies
plt.figure(figsize = (6,6))

plt.plot(t, np.array(train_acc), 'r-', t[t % 25 == 0], validation_acc, 'b*')
plt.xlabel("iteration")
plt.ylabel("Accuray")
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %% [markdown]
# ## Evaluate on test set

# %%
test_acc = []

with tf.Session(graph=graph) as sess:
    # Restore
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    
    # Testing: Loop over bacthes
    test_state = sess.run(cell.zero_state(batch_size, tf.float32))
    for Xbatch, Ybatch in get_batches(Xtest, Ytest, batch_size):
        feed = {inputs_: Xbatch, indices_: Ybatch, initial_state: test_state}
        batch_acc, test_state = sess.run([accuracy, final_state], feed_dict=feed)
        test_acc.append(batch_acc)
    print("Test accuracy: {:.6f}".format(np.mean(test_acc)))
